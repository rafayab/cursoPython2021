# %%
import pandas as pd

# %%
pwd
# Out:
# 'D:\\Curso_Python\\Codigo\\cursoPython2021'

# %%
# Se crea el dataframe
# Los datos han sido descargados de https://insights.stackoverflow.com/survey
# Pertenecen a la encuesta anual de desarrolladores año 2021
datos = pd.read_csv('survey_results_public.csv')

# %%
datos
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country    US_State  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UK_Country                                            EdLevel  \
# 0            NaN  Secondary school (e.g. American high school, G...
# 1            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3            NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438        NaN                 Professional degree (JD, MD, etc.)
#
#           Age1stCode                                          LearnCode  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YearsCode  ...              Age Gender Trans                Sexuality  \
# 0           NaN  ...  25-34 years old    Man    No  Straight / Heterosexual
# 1             7  ...  18-24 years old    Man    No  Straight / Heterosexual
# 2           NaN  ...  18-24 years old    Man    No        Prefer not to say
# 3           NaN  ...  35-44 years old    Man    No  Straight / Heterosexual
# 4            17  ...  25-34 years old    Man    No                      NaN
# ...         ...  ...              ...    ...   ...                      ...
# 83434         6  ...  25-34 years old    Man    No  Straight / Heterosexual
# 83435         4  ...  18-24 years old    Man    No  Straight / Heterosexual
# 83436        10  ...  25-34 years old    Man    No                      NaN
# 83437         5  ...  25-34 years old    Man    No  Straight / Heterosexual
# 83438        14  ...  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity                Accessibility  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MentalHealth  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase ConvertedCompYearly
# 0      Appropriate in length                        Easy             62268.0
# 1      Appropriate in length                        Easy                 NaN
# 2      Appropriate in length                        Easy                 NaN
# 3      Appropriate in length  Neither easy nor difficult                 NaN
# 4      Appropriate in length                        Easy                 NaN
# ...                      ...                         ...                 ...
# 83434  Appropriate in length                        Easy            160500.0
# 83435  Appropriate in length                        Easy              3960.0
# 83436  Appropriate in length  Neither easy nor difficult             90000.0
# 83437  Appropriate in length  Neither easy nor difficult            816816.0
# 83438  Appropriate in length                        Easy             21168.0
#
# [83439 rows x 48 columns]

# %%
datos.shape
# Out:
# (83439, 48)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
#  12  OrgSize                       60726 non-null  object
#  13  Currency                      61080 non-null  object
#  14  CompTotal                     47183 non-null  float64
#  15  CompFreq                      52150 non-null  object
#  16  LanguageHaveWorkedWith        82357 non-null  object
#  17  LanguageWantToWorkWith        76821 non-null  object
#  18  DatabaseHaveWorkedWith        69546 non-null  object
#  19  DatabaseWantToWorkWith        58299 non-null  object
#  20  PlatformHaveWorkedWith        52135 non-null  object
#  21  PlatformWantToWorkWith        41619 non-null  object
#  22  WebframeHaveWorkedWith        61707 non-null  object
#  23  WebframeWantToWorkWith        52095 non-null  object
#  24  MiscTechHaveWorkedWith        47055 non-null  object
#  25  MiscTechWantToWorkWith        38021 non-null  object
#  26  ToolsTechHaveWorkedWith       72537 non-null  object
#  27  ToolsTechWantToWorkWith       65480 non-null  object
#  28  NEWCollabToolsHaveWorkedWith  81234 non-null  object
#  29  NEWCollabToolsWantToWorkWith  73022 non-null  object
#  30  OpSys                         83294 non-null  object
#  31  NEWStuck                      83052 non-null  object
#  32  NEWSOSites                    83171 non-null  object
#  33  SOVisitFreq                   82413 non-null  object
#  34  SOAccount                     82525 non-null  object
#  35  SOPartFreq                    67553 non-null  object
#  36  SOComm                        82319 non-null  object
#  37  NEWOtherComms                 82828 non-null  object
#  38  Age                           82407 non-null  object
#  39  Gender                        82286 non-null  object
#  40  Trans                         80678 non-null  object
#  41  Sexuality                     73366 non-null  object
#  42  Ethnicity                     79464 non-null  object
#  43  Accessibility                 77603 non-null  object
#  44  MentalHealth                  76920 non-null  object
#  45  SurveyLength                  81711 non-null  object
#  46  SurveyEase                    81948 non-null  object
#  47  ConvertedCompYearly           46844 non-null  float64
# dtypes: float64(2), int64(1), object(45)
# memory usage: 30.6+ MB

# %%
# Muestra todas las columnas del fichero
pd.set_option('display.max_columns', 48)
pd.set_option('display.max_rows', 50)

# %%
# Se crea el schema del dataframe
schema_datos = pd.read_csv('survey_results_schema.csv')

# %%
datos
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country    US_State  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UK_Country                                            EdLevel  \
# 0            NaN  Secondary school (e.g. American high school, G...
# 1            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3            NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438        NaN                 Professional degree (JD, MD, etc.)
#
#           Age1stCode                                          LearnCode  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YearsCode YearsCodePro  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DevType  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LanguageHaveWorkedWith  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 0                                                  Swift
# 1                                                    NaN
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DatabaseHaveWorkedWith  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WebframeHaveWorkedWith  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MiscTechHaveWorkedWith  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWStuck  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq SOAccount  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPartFreq           SOComm  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOtherComms              Age Gender Trans                Sexuality  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity                Accessibility  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MentalHealth  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]

# %%
schema_datos
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# 29   QID91                  S4
# 30  QID266          NEWSOSites
# 31  QID100         SOVisitFreq
# 32  QID101           SOAccount
# 33  QID102          SOPartFreq
# 34  QID106              SOComm
# 35  QID267       NEWOtherComms
# 36  QID268  NEWOtherCommsNames
# 37  QID121                  S5
# 38  QID127                 Age
# 39  QID122              Gender
# 40  QID153               Trans
# 41  QID136           Sexuality
# 42  QID126           Ethnicity
# 43  QID124       Accessibility
# 44  QID125        MentalHealth
# 45  QID131                  S6
# 46  QID132        SurveyLength
# 47  QID133          SurveyEase
#
#                                              question  force_resp    type  \
# 0   <div><span style="font-size:19px;"><strong>Hel...       False      DB
# 1                                   Browser Meta Info       False    Meta
# 2   <span style="font-size:22px; font-family: aria...       False      DB
# 3   Which of the following options best describes ...        True      MC
# 4   Which of the following best describes your cur...       False      MC
# 5   Where do you live? <span style="font-weight: b...        True      MC
# 6   <p>In which state or territory of the USA do y...       False      MC
# 7   In which part of the United Kingdom do you liv...       False      MC
# 8   <span style="font-size:22px; font-family: aria...       False      DB
# 9   Which of the following best describes the high...       False      MC
# 10  At what age did you write your first line of c...       False      MC
# 11  How did you learn to code? Select all that apply.       False      MC
# 12  Including any education, how many years have y...       False      MC
# 13  NOT including education, how many years have y...       False      MC
# 14  Which of the following describes your current ...       False      MC
# 15  Approximately how many people are employed by ...       False      MC
# 16  Which currency do you use day-to-day? If your ...        True      MC
# 17  What is your current total compensation (salar...       False      TE
# 18   Is that compensation weekly, monthly, or yearly?       False      MC
# 19  <span style="font-size:22px; font-family: aria...       False      DB
# 20  Which <b>programming, scripting, and markup la...       False  Matrix
# 21  Which <b>database environments </b>have you do...       False  Matrix
# 22  Which <b>cloud platforms</b> have you done ext...       False  Matrix
# 23  Which <strong>web frameworks </strong><span st...       False  Matrix
# 24  Which <b>other frameworks and libraries</b> ha...       False  Matrix
# 25  Which <strong>tools</strong> have you done ext...       False  Matrix
# 26  Which <strong>development environments</strong...       False  Matrix
# 27  What is the primary operating system in which ...       False      MC
# 28  What do you do when you get stuck on a problem...       False      MC
# 29  <span style="font-size:22px; font-family: aria...       False      DB
# 30  Which of the following Stack Overflow sites ha...       False      MC
# 31  How frequently would you say you visit Stack O...       False      MC
# 32              Do you have a Stack Overflow account?       False      MC
# 33  How frequently would you say you participate i...       False      MC
# 34  Do you consider yourself a member of the Stack...       False      MC
# 35  Are you a member of any other online developer...       False      MC
# 36  Please name up to 5 other online developer com...       False  Matrix
# 37  <span style="font-size:22px; font-family: aria...       False      DB
# 38                                  What is your age?       False      MC
# 39  Which of the following describe you, if any? P...       False      MC
# 40                    Do you identify as transgender?       False      MC
# 41  Which of the following describe you, if any? P...       False      MC
# 42  Which of the following describe you, if any? P...       False      MC
# 43  Which of the following describe you, if any? P...       False      MC
# 44  Which of the following describe you, if any? P...       False      MC
# 45  <span style="font-size:22px;"><strong>Final Qu...       False      DB
# 46  How do you feel about the length of the survey...       False      MC
# 47  How easy or difficult was this survey to compl...       False      MC
#
#    selector
# 0        TB
# 1   Browser
# 2        TB
# 3      SAVR
# 4      MAVR
# 5        DL
# 6        DL
# 7        DL
# 8        TB
# 9      SAVR
# 10     MAVR
# 11     MAVR
# 12       DL
# 13       DL
# 14     MAVR
# 15     MAVR
# 16       SB
# 17       SL
# 18     MAVR
# 19       TB
# 20   Likert
# 21   Likert
# 22   Likert
# 23   Likert
# 24   Likert
# 25   Likert
# 26   Likert
# 27     SAVR
# 28     MAVR
# 29       TB
# 30     MAVR
# 31     MAVR
# 32     MAVR
# 33     MAVR
# 34     MAVR
# 35     MAVR
# 36   Likert
# 37       TB
# 38     MAVR
# 39     MAVR
# 40     MAVR
# 41     MAVR
# 42     MAVR
# 43     MAVR
# 44     MAVR
# 45       TB
# 46     MAVR
# 47     MAVR

# %%
# Muestra los 5 primeros registros del dataframe
datos.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# 2                                 Russian Federation      NaN        NaN
# 3                                            Austria      NaN        NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN    England
#
#                                              EdLevel     Age1stCode  \
# 0  Secondary school (e.g. American high school, G...  18 - 24 years
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
#
#                                            LearnCode YearsCode YearsCodePro  \
# 0  Coding Bootcamp;Other online resources (ex: vi...       NaN          NaN
# 1  Other online resources (ex: videos, blogs, etc...         7          NaN
# 2  Other online resources (ex: videos, blogs, etc...       NaN          NaN
# 3                                                NaN       NaN          NaN
# 4                            Friend or family member        17           10
#
#                                              DevType  \
# 0                                  Developer, mobile
# 1                                                NaN
# 2                                                NaN
# 3                               Developer, front-end
# 4  Developer, desktop or enterprise applications;...
#
#                                              OrgSize             Currency  \
# 0                                 20 to 99 employees    EUR European Euro
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                               100 to 499 employees    EUR European Euro
# 4  Just me - I am a freelancer, sole proprietor, ...  GBP\tPound sterling
#
#    CompTotal CompFreq                         LanguageHaveWorkedWith  \
# 0     4800.0  Monthly  C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1        NaN      NaN                              JavaScript;Python
# 2        NaN      NaN                       Assembly;C;Python;R;Rust
# 3        NaN  Monthly                          JavaScript;TypeScript
# 4        NaN      NaN                 Bash/Shell;HTML/CSS;Python;SQL
#
#            LanguageWantToWorkWith          DatabaseHaveWorkedWith  \
# 0                           Swift               PostgreSQL;SQLite
# 1                             NaN                      PostgreSQL
# 2               Julia;Python;Rust                          SQLite
# 3           JavaScript;TypeScript                             NaN
# 4  Bash/Shell;HTML/CSS;Python;SQL  Elasticsearch;PostgreSQL;Redis
#
#                      DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# 0                                    SQLite                    NaN
# 1                                       NaN                    NaN
# 2                                    SQLite                 Heroku
# 3                                       NaN                    NaN
# 4  Cassandra;Elasticsearch;PostgreSQL;Redis                    NaN
#
#   PlatformWantToWorkWith WebframeHaveWorkedWith WebframeWantToWorkWith  \
# 0                    NaN        Laravel;Symfony                    NaN
# 1                    NaN   Angular;Flask;Vue.js                    NaN
# 2                    NaN                  Flask                  Flask
# 3                    NaN         Angular;jQuery         Angular;jQuery
# 4                    NaN                  Flask                  Flask
#
#                   MiscTechHaveWorkedWith  \
# 0                                    NaN
# 1                                Cordova
# 2  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                    NaN
# 4       Apache Spark;Hadoop;NumPy;Pandas
#
#                         MiscTechWantToWorkWith     ToolsTechHaveWorkedWith  \
# 0                                          NaN                         NaN
# 1                                          NaN             Docker;Git;Yarn
# 2  Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch                         NaN
# 3                                          NaN                         NaN
# 4                          Hadoop;NumPy;Pandas  Docker;Git;Kubernetes;Yarn
#
#       ToolsTechWantToWorkWith  \
# 0                         NaN
# 1                         Git
# 2                         NaN
# 3                         NaN
# 4  Docker;Git;Kubernetes;Yarn
#
#                         NEWCollabToolsHaveWorkedWith  \
# 0                                     PHPStorm;Xcode
# 1          Android Studio;IntelliJ;Notepad++;PyCharm
# 2  IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                NaN
# 4         Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
#
#                         NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                         Atom;Xcode        MacOS
# 1                                                NaN      Windows
# 2  IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                NaN      Windows
# 4  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
#
#                                             NEWStuck  \
# 0  Call a coworker or friend;Visit Stack Overflow...
# 1                     Visit Stack Overflow;Google it
# 2  Visit Stack Overflow;Google it;Watch help / tu...
# 3  Call a coworker or friend;Visit Stack Overflow...
# 4  Visit Stack Overflow;Go for a walk or other ph...
#
#                       NEWSOSites             SOVisitFreq SOAccount  \
# 0                 Stack Overflow  Multiple times per day       Yes
# 1                 Stack Overflow   Daily or almost daily       Yes
# 2  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 3                 Stack Overflow   Daily or almost daily       Yes
# 4  Stack Overflow;Stack Exchange   Daily or almost daily       Yes
#
#                         SOPartFreq           SOComm NEWOtherComms  \
# 0  A few times per month or weekly  Yes, definitely            No
# 1            Daily or almost daily  Yes, definitely            No
# 2           Multiple times per day  Yes, definitely           Yes
# 3            Daily or almost daily          Neutral            No
# 4             A few times per week    Yes, somewhat            No
#
#                Age Gender Trans                Sexuality  \
# 0  25-34 years old    Man    No  Straight / Heterosexual
# 1  18-24 years old    Man    No  Straight / Heterosexual
# 2  18-24 years old    Man    No        Prefer not to say
# 3  35-44 years old    Man    No  Straight / Heterosexual
# 4  25-34 years old    Man    No                      NaN
#
#                       Ethnicity                Accessibility  \
# 0  White or of European descent            None of the above
# 1  White or of European descent            None of the above
# 2             Prefer not to say            None of the above
# 3  White or of European descent  I am deaf / hard of hearing
# 4  White or of European descent            None of the above
#
#         MentalHealth           SurveyLength                  SurveyEase  \
# 0  None of the above  Appropriate in length                        Easy
# 1  None of the above  Appropriate in length                        Easy
# 2  None of the above  Appropriate in length                        Easy
# 3                NaN  Appropriate in length  Neither easy nor difficult
# 4                NaN  Appropriate in length                        Easy
#
#    ConvertedCompYearly
# 0              62268.0
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
# Muestra los últimos 10 registros
datos.tail(10)
# Out:
#        ResponseId                      MainBranch  \
# 83429       83430     I code primarily as a hobby
# 83430       83431  I am a developer by profession
# 83431       83432  I am a developer by profession
# 83432       83433  I am a developer by profession
# 83433       83434  I am a developer by profession
# 83434       83435  I am a developer by profession
# 83435       83436  I am a developer by profession
# 83436       83437  I am a developer by profession
# 83437       83438  I am a developer by profession
# 83438       83439  I am a developer by profession
#
#                                               Employment  \
# 83429                 Not employed, but looking for work
# 83430                                 Employed full-time
# 83431  Independent contractor, freelancer, or self-em...
# 83432                                 Employed full-time
# 83433  Independent contractor, freelancer, or self-em...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                         Country    US_State UK_Country  \
# 83429  United States of America  Washington        NaN
# 83430  United States of America    Illinois        NaN
# 83431                  Pakistan         NaN        NaN
# 83432                    Canada         NaN        NaN
# 83433                    Brazil         NaN        NaN
# 83434  United States of America       Texas        NaN
# 83435                     Benin         NaN        NaN
# 83436  United States of America  New Jersey        NaN
# 83437                    Canada         NaN        NaN
# 83438                    Brazil         NaN        NaN
#
#                                                  EdLevel     Age1stCode  \
# 83429       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83430    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 83431       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83433       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83435       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83436  Secondary school (e.g. American high school, G...  11 - 17 years
# 83437       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83438                 Professional degree (JD, MD, etc.)  11 - 17 years
#
#                                                LearnCode YearsCode  \
# 83429    Other online resources (ex: videos, blogs, etc)         6
# 83430  Other online resources (ex: videos, blogs, etc...        23
# 83431  Other online resources (ex: videos, blogs, etc...         9
# 83432                                             School         5
# 83433  Online Forum;Online Courses or Certification;O...        15
# 83434  Other online resources (ex: videos, blogs, etc...         6
# 83435  Other online resources (ex: videos, blogs, etc...         4
# 83436                                             School        10
# 83437  Online Courses or Certification;Books / Physic...         5
# 83438                                             School        14
#
#            YearsCodePro                                            DevType  \
# 83429               NaN                    Other (please specify):;Student
# 83430                21  Developer, front-end;Developer, full-stack;Dev...
# 83431                 4  Developer, mobile;Developer, desktop or enterp...
# 83432  Less than 1 year                                Developer, back-end
# 83433                11  Developer, mobile;Developer, front-end;Develop...
# 83434                 5                                Developer, back-end
# 83435                 2                              Developer, full-stack
# 83436                 4  Data scientist or machine learning specialist;...
# 83437                 3                                Developer, back-end
# 83438                 4  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 83429                                                NaN
# 83430                                 10 to 19 employees
# 83431                                   2 to 9 employees
# 83432                           10,000 or more employees
# 83433                           1,000 to 4,999 employees
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 83429                          NaN        NaN      NaN
# 83430    USD\tUnited States dollar   125000.0   Yearly
# 83431         PKR\tPakistani rupee   150000.0  Monthly
# 83432         CAD\tCanadian dollar   106000.0   Yearly
# 83433          BRL\tBrazilian real    80000.0   Yearly
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                                   LanguageHaveWorkedWith  \
# 83429             HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83430        APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83431  C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83432                                               Ruby
# 83433      Java;JavaScript;Kotlin;Objective-C;TypeScript
# 83434                                 Clojure;Kotlin;SQL
# 83435                                                NaN
# 83436                                 Groovy;Java;Python
# 83437               Bash/Shell;JavaScript;Node.js;Python
# 83438             Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 83429  C#;Go;HTML/CSS;Java;JavaScript;PHP;Python;SQL;VBA
# 83430                         APL;Clojure;Haskell;LISP;R
# 83431  C#;Dart;HTML/CSS;JavaScript;Kotlin;Node.js;Pyt...
# 83432                               Java;Ruby;TypeScript
# 83433                                             Kotlin
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DatabaseHaveWorkedWith  \
# 83429                          MongoDB;MySQL;PostgreSQL
# 83430                    MongoDB;MySQL;PostgreSQL;Redis
# 83431                             Firebase;MySQL;SQLite
# 83432                                  MySQL;PostgreSQL
# 83433                     Firebase;MongoDB;MySQL;SQLite
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 83429  MariaDB;Microsoft SQL Server;MongoDB;MySQL;Pos...
# 83430                                         PostgreSQL
# 83431             DynamoDB;Firebase;MongoDB;MySQL;SQLite
# 83432                                                NaN
# 83433                                                NaN
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#                               PlatformHaveWorkedWith  \
# 83429                                         Heroku
# 83430  AWS;DigitalOcean;Google Cloud Platform;Heroku
# 83431                          Google Cloud Platform
# 83432                   Google Cloud Platform;Heroku
# 83433                                            NaN
# 83434                                            AWS
# 83435                                            NaN
# 83436                      AWS;Google Cloud Platform
# 83437                                         Heroku
# 83438                                Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 83429  AWS;Heroku;IBM Cloud or Watson;Microsoft Azure...
# 83430             AWS;DigitalOcean;Google Cloud Platform
# 83431                          AWS;Google Cloud Platform
# 83432                                                NaN
# 83433                                                NaN
# 83434                                                AWS
# 83435                                                NaN
# 83436                                                AWS
# 83437                                   AWS;DigitalOcean
# 83438                                                AWS
#
#                              WebframeHaveWorkedWith  \
# 83429                           Django;Flask;jQuery
# 83430                 Django;React.js;Ruby on Rails
# 83431                                  Flask;jQuery
# 83432           Flask;React.js;Ruby on Rails;Vue.js
# 83433                                      React.js
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 83429  Angular.js;ASP.NET;ASP.NET Core ;Django;FastAP...
# 83430                                                NaN
# 83431                Angular;Django;Flask;jQuery;Laravel
# 83432                                                NaN
# 83433                                                NaN
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MiscTechHaveWorkedWith  \
# 83429                           NumPy;Pandas
# 83430                                    NaN
# 83431                                Flutter
# 83432  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83433                           React Native
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MiscTechWantToWorkWith  \
# 83429     .NET Framework;.NET Core / .NET 5;NumPy;Pandas
# 83430                                                NaN
# 83431      Flutter;Hadoop;NumPy;TensorFlow;Torch/PyTorch
# 83432                                                NaN
# 83433                                            Flutter
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 83429                           Git               Docker;Git;Xamarin
# 83430                    Docker;Git   Docker;Git;Kubernetes;Unity 3D
# 83431                           Git                       Docker;Git
# 83432    Docker;Git;Kubernetes;Yarn                              NaN
# 83433               Docker;Git;Yarn                       Docker;Git
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 83429     Atom;Notepad++;Sublime Text;Visual Studio Code
# 83430                                          Emacs;Vim
# 83431  Android Studio;IntelliJ;IPython/Jupyter;Notepa...
# 83432        Atom;IPython/Jupyter;Vim;Visual Studio Code
# 83433            Android Studio;Visual Studio Code;Xcode
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 83429     Atom;Notepad++;Sublime Text;Visual Studio Code      Windows
# 83430                                              Emacs  Linux-based
# 83431  Android Studio;IntelliJ;IPython/Jupyter;PyChar...      Windows
# 83432                                                NaN        MacOS
# 83433                               Android Studio;Xcode        MacOS
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWStuck  \
# 83429  Visit Stack Overflow;Google it;Watch help / tu...
# 83430  Call a coworker or friend;Visit Stack Overflow...
# 83431  Visit Stack Overflow;Go for a walk or other ph...
# 83432  Visit Stack Overflow;Go for a walk or other ph...
# 83433  Call a coworker or friend;Visit Stack Overflow...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 83429                      Stack Overflow;Stack Exchange
# 83430                      Stack Overflow;Stack Exchange
# 83431                      Stack Overflow;Stack Exchange
# 83432                      Stack Overflow;Stack Exchange
# 83433                                     Stack Overflow
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq                SOAccount  \
# 83429  A few times per month or weekly  Not sure/can't remember
# 83430             A few times per week                       No
# 83431           Multiple times per day                      Yes
# 83432            Daily or almost daily                       No
# 83433            Daily or almost daily                      Yes
# 83434             A few times per week                       No
# 83435           Multiple times per day                      Yes
# 83436             A few times per week                      Yes
# 83437  A few times per month or weekly                      Yes
# 83438             A few times per week                      Yes
#
#                                               SOPartFreq           SOComm  \
# 83429                                                NaN    Yes, somewhat
# 83430                                                NaN   No, not really
# 83431                    A few times per month or weekly  Yes, definitely
# 83432                                                NaN   No, not really
# 83433                    A few times per month or weekly    Yes, somewhat
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOtherComms              Age                      Gender Trans  \
# 83429            No  25-34 years old  Man;Or, in your own words:   Yes
# 83430            No  45-54 years old                         Man    No
# 83431            No  18-24 years old                         Man    No
# 83432            No  18-24 years old                       Woman    No
# 83433            No  25-34 years old                         Man    No
# 83434            No  25-34 years old                         Man    No
# 83435            No  18-24 years old                         Man    No
# 83436            No  25-34 years old                         Man    No
# 83437            No  25-34 years old                         Man    No
# 83438            No  18-24 years old                         Man    No
#
#                      Sexuality                     Ethnicity  \
# 83429                    Queer  White or of European descent
# 83430  Straight / Heterosexual  White or of European descent
# 83431  Straight / Heterosexual               Southeast Asian
# 83432  Straight / Heterosexual                    East Asian
# 83433  Straight / Heterosexual        Hispanic or Latino/a/x
# 83434  Straight / Heterosexual  White or of European descent
# 83435  Straight / Heterosexual   Black or of African descent
# 83436                      NaN  White or of European descent
# 83437  Straight / Heterosexual  White or of European descent
# 83438  Straight / Heterosexual        Hispanic or Latino/a/x
#
#                                            Accessibility  \
# 83429  I am unable to / find it difficult to walk or ...
# 83430                                  None of the above
# 83431                                  None of the above
# 83432                                  None of the above
# 83433                                  None of the above
# 83434                                  None of the above
# 83435                                  None of the above
# 83436                                  None of the above
# 83437                                  None of the above
# 83438                                  None of the above
#
#                                             MentalHealth  \
# 83429                         I have an anxiety disorder
# 83430                                  None of the above
# 83431                                  None of the above
# 83432                                  None of the above
# 83433                         I have an anxiety disorder
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 83429  Appropriate in length  Neither easy nor difficult                  NaN
# 83430  Appropriate in length                        Easy             125000.0
# 83431  Appropriate in length                        Easy              11676.0
# 83432  Appropriate in length                        Easy              80169.0
# 83433  Appropriate in length                        Easy              18326.0
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0

# %%
# Accede a los datos de la columna 'Employment'
datos.Employment
# Out:
# 0        Independent contractor, freelancer, or self-em...
# 1                                       Student, full-time
# 2                                       Student, full-time
# 3                                       Employed full-time
# 4        Independent contractor, freelancer, or self-em...
#                                ...
# 83434                                   Employed full-time
# 83435    Independent contractor, freelancer, or self-em...
# 83436                                   Employed full-time
# 83437                                   Employed full-time
# 83438                                   Employed full-time
# Name: Employment, Length: 83439, dtype: object

# %%
# Accede a los datos de las columnas 'Employment', 'Country', 'YearsCode'
datos[['Employment', 'Country', 'YearsCode']]
# Out:
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country YearsCode
# 0                                               Slovakia       NaN
# 1                                            Netherlands         7
# 2                                     Russian Federation       NaN
# 3                                                Austria       NaN
# 4      United Kingdom of Great Britain and Northern I...        17
# ...                                                  ...       ...
# 83434                           United States of America         6
# 83435                                              Benin         4
# 83436                           United States of America        10
# 83437                                             Canada         5
# 83438                                             Brazil        14
#
# [83439 rows x 3 columns]

# %%
# Muestra las columnas del dataframe
datos.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
# Accede a filas con iloc (integer location)
datos.iloc[0]
# Out:
# ResponseId                                                                      1
# MainBranch                                         I am a developer by profession
# Employment                      Independent contractor, freelancer, or self-em...
# Country                                                                  Slovakia
# US_State                                                                      NaN
# UK_Country                                                                    NaN
# EdLevel                         Secondary school (e.g. American high school, G...
# Age1stCode                                                          18 - 24 years
# LearnCode                       Coding Bootcamp;Other online resources (ex: vi...
# YearsCode                                                                     NaN
# YearsCodePro                                                                  NaN
# DevType                                                         Developer, mobile
# OrgSize                                                        20 to 99 employees
# Currency                                                        EUR European Euro
# CompTotal                                                                  4800.0
# CompFreq                                                                  Monthly
# LanguageHaveWorkedWith              C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# LanguageWantToWorkWith                                                      Swift
# DatabaseHaveWorkedWith                                          PostgreSQL;SQLite
# DatabaseWantToWorkWith                                                     SQLite
# PlatformHaveWorkedWith                                                        NaN
# PlatformWantToWorkWith                                                        NaN
# WebframeHaveWorkedWith                                            Laravel;Symfony
# WebframeWantToWorkWith                                                        NaN
# MiscTechHaveWorkedWith                                                        NaN
# MiscTechWantToWorkWith                                                        NaN
# ToolsTechHaveWorkedWith                                                       NaN
# ToolsTechWantToWorkWith                                                       NaN
# NEWCollabToolsHaveWorkedWith                                       PHPStorm;Xcode
# NEWCollabToolsWantToWorkWith                                           Atom;Xcode
# OpSys                                                                       MacOS
# NEWStuck                        Call a coworker or friend;Visit Stack Overflow...
# NEWSOSites                                                         Stack Overflow
# SOVisitFreq                                                Multiple times per day
# SOAccount                                                                     Yes
# SOPartFreq                                        A few times per month or weekly
# SOComm                                                            Yes, definitely
# NEWOtherComms                                                                  No
# Age                                                               25-34 years old
# Gender                                                                        Man
# Trans                                                                          No
# Sexuality                                                 Straight / Heterosexual
# Ethnicity                                            White or of European descent
# Accessibility                                                   None of the above
# MentalHealth                                                    None of the above
# SurveyLength                                                Appropriate in length
# SurveyEase                                                                   Easy
# ConvertedCompYearly                                                       62268.0
# Name: 0, dtype: object

# %%
datos.iloc[[0, 3, 5]]
# Out:
#    ResponseId                              MainBranch  \
# 0           1          I am a developer by profession
# 3           4          I am a developer by profession
# 5           6  I am a student who is learning to code
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 3                                 Employed full-time
# 5                                 Student, part-time
#
#                     Country US_State UK_Country  \
# 0                  Slovakia      NaN        NaN
# 3                   Austria      NaN        NaN
# 5  United States of America  Georgia        NaN
#
#                                              EdLevel     Age1stCode  \
# 0  Secondary school (e.g. American high school, G...  18 - 24 years
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 5       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
#
#                                            LearnCode YearsCode YearsCodePro  \
# 0  Coding Bootcamp;Other online resources (ex: vi...       NaN          NaN
# 3                                                NaN       NaN          NaN
# 5  Other online resources (ex: videos, blogs, etc...       NaN          NaN
#
#                 DevType               OrgSize           Currency  CompTotal  \
# 0     Developer, mobile    20 to 99 employees  EUR European Euro     4800.0
# 3  Developer, front-end  100 to 499 employees  EUR European Euro        NaN
# 5                   NaN                   NaN                NaN        NaN
#
#   CompFreq                             LanguageHaveWorkedWith  \
# 0  Monthly      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 3  Monthly                              JavaScript;TypeScript
# 5      NaN  C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
#
#                               LanguageWantToWorkWith   DatabaseHaveWorkedWith  \
# 0                                              Swift        PostgreSQL;SQLite
# 3                              JavaScript;TypeScript                      NaN
# 5  C#;C++;Go;HTML/CSS;Java;JavaScript;Node.js;Obj...  MySQL;PostgreSQL;SQLite
#
#                               DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# 0                                             SQLite                    NaN
# 3                                                NaN                    NaN
# 5  Elasticsearch;Firebase;IBM DB2;MariaDB;Microso...                    NaN
#
#   PlatformWantToWorkWith         WebframeHaveWorkedWith  \
# 0                    NaN                Laravel;Symfony
# 3                    NaN                 Angular;jQuery
# 5                    NaN  Express;Flask;jQuery;React.js
#
#           WebframeWantToWorkWith                       MiscTechHaveWorkedWith  \
# 0                            NaN                                          NaN
# 3                 Angular;jQuery                                          NaN
# 5  Express;Flask;jQuery;React.js  Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
#
#                               MiscTechWantToWorkWith ToolsTechHaveWorkedWith  \
# 0                                                NaN                     NaN
# 3                                                NaN                     NaN
# 5  Keras;NumPy;Pandas;Qt;React Native;TensorFlow;...                     Git
#
#              ToolsTechWantToWorkWith  \
# 0                                NaN
# 3                                NaN
# 5  Docker;Git;Unity 3D;Unreal Engine
#
#                         NEWCollabToolsHaveWorkedWith  \
# 0                                     PHPStorm;Xcode
# 3                                                NaN
# 5  IPython/Jupyter;Notepad++;PyCharm;Sublime Text...
#
#                         NEWCollabToolsWantToWorkWith    OpSys  \
# 0                                         Atom;Xcode    MacOS
# 3                                                NaN  Windows
# 5  Android Studio;IPython/Jupyter;Vim;Visual Stud...  Windows
#
#                                             NEWStuck  \
# 0  Call a coworker or friend;Visit Stack Overflow...
# 3  Call a coworker or friend;Visit Stack Overflow...
# 5  Visit Stack Overflow;Go for a walk or other ph...
#
#                       NEWSOSites             SOVisitFreq SOAccount  \
# 0                 Stack Overflow  Multiple times per day       Yes
# 3                 Stack Overflow   Daily or almost daily       Yes
# 5  Stack Overflow;Stack Exchange  Multiple times per day       Yes
#
#                                           SOPartFreq           SOComm  \
# 0                    A few times per month or weekly  Yes, definitely
# 3                              Daily or almost daily          Neutral
# 5  I have never participated in Q&A on Stack Over...    Yes, somewhat
#
#   NEWOtherComms              Age             Gender Trans  \
# 0            No  25-34 years old                Man    No
# 3            No  35-44 years old                Man    No
# 5            No  18-24 years old  Prefer not to say    No
#
#                  Sexuality                     Ethnicity  \
# 0  Straight / Heterosexual  White or of European descent
# 3  Straight / Heterosexual  White or of European descent
# 5  Straight / Heterosexual             Prefer not to say
#
#                  Accessibility  \
# 0            None of the above
# 3  I am deaf / hard of hearing
# 5            None of the above
#
#                                         MentalHealth           SurveyLength  \
# 0                                  None of the above  Appropriate in length
# 3                                                NaN  Appropriate in length
# 5  I have a concentration and/or memory disorder ...               Too long
#
#                    SurveyEase  ConvertedCompYearly
# 0                        Easy              62268.0
# 3  Neither easy nor difficult                  NaN
# 5  Neither easy nor difficult                  NaN

# %%
# Muestra la columna 3 de las filas 0, 3, y 5
datos.iloc[[0, 3, 5], 3]
# Out:
# 0                    Slovakia
# 3                     Austria
# 5    United States of America
# Name: Country, dtype: object

# %%
# loc muestra resultados buscando por etiquetas (labels)
datos.loc[[0, 3, 5], 'Country']
# Out:
# 0                    Slovakia
# 3                     Austria
# 5    United States of America
# Name: Country, dtype: object

# %%
# Cuenta los países de donde provienen los programadores
datos.Country.value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
# Determinar una columna como identificador primario
datos.set_index('ResponseId')
# Para establecerla
# datos.set_index('ResponseId', inplace=True)
# Para volver al ID original
# datos.reset_index(inplace=True)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 83435                                      Employed full-time
# 83436       Independent contractor, freelancer, or self-em...
# 83437                                      Employed full-time
# 83438                                      Employed full-time
# 83439                                      Employed full-time
#
#                                                       Country    US_State  \
# ResponseId
# 1                                                    Slovakia         NaN
# 2                                                 Netherlands         NaN
# 3                                          Russian Federation         NaN
# 4                                                     Austria         NaN
# 5           United Kingdom of Great Britain and Northern I...         NaN
# ...                                                       ...         ...
# 83435                                United States of America       Texas
# 83436                                                   Benin         NaN
# 83437                                United States of America  New Jersey
# 83438                                                  Canada         NaN
# 83439                                                  Brazil         NaN
#
#            UK_Country                                            EdLevel  \
# ResponseId
# 1                 NaN  Secondary school (e.g. American high school, G...
# 2                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                 NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5             England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...               ...                                                ...
# 83435             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83437             NaN  Secondary school (e.g. American high school, G...
# 83438             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83439             NaN                 Professional degree (JD, MD, etc.)
#
#                Age1stCode                                          LearnCode  \
# ResponseId
# 1           18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 2           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 4           11 - 17 years                                                NaN
# 5            5 - 10 years                            Friend or family member
# ...                   ...                                                ...
# 83435       11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436       11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83437       11 - 17 years                                             School
# 83438       11 - 17 years  Online Courses or Certification;Books / Physic...
# 83439       11 - 17 years                                             School
#
#            YearsCode YearsCodePro  \
# ResponseId
# 1                NaN          NaN
# 2                  7          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# 5                 17           10
# ...              ...          ...
# 83435              6            5
# 83436              4            2
# 83437             10            4
# 83438              5            3
# 83439             14            4
#
#                                                       DevType  \
# ResponseId
# 1                                           Developer, mobile
# 2                                                         NaN
# 3                                                         NaN
# 4                                        Developer, front-end
# 5           Developer, desktop or enterprise applications;...
# ...                                                       ...
# 83435                                     Developer, back-end
# 83436                                   Developer, full-stack
# 83437       Data scientist or machine learning specialist;...
# 83438                                     Developer, back-end
# 83439       Developer, front-end;Developer, full-stack;Dev...
#
#                                                       OrgSize  \
# ResponseId
# 1                                          20 to 99 employees
# 2                                                         NaN
# 3                                                         NaN
# 4                                        100 to 499 employees
# 5           Just me - I am a freelancer, sole proprietor, ...
# ...                                                       ...
# 83435                                      20 to 99 employees
# 83436       Just me - I am a freelancer, sole proprietor, ...
# 83437                                10,000 or more employees
# 83438                                      20 to 99 employees
# 83439                                            I don’t know
#
#                                Currency  CompTotal CompFreq  \
# ResponseId
# 1                     EUR European Euro     4800.0  Monthly
# 2                                   NaN        NaN      NaN
# 3                                   NaN        NaN      NaN
# 4                     EUR European Euro        NaN  Monthly
# 5                   GBP\tPound sterling        NaN      NaN
# ...                                 ...        ...      ...
# 83435         USD\tUnited States dollar   160500.0   Yearly
# 83436       XOF\tWest African CFA franc   200000.0  Monthly
# 83437         USD\tUnited States dollar     1800.0   Weekly
# 83438              CAD\tCanadian dollar    90000.0  Monthly
# 83439               BRL\tBrazilian real     7700.0  Monthly
#
#                                    LanguageHaveWorkedWith  \
# ResponseId
# 1           C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                       JavaScript;Python
# 3                                Assembly;C;Python;R;Rust
# 4                                   JavaScript;TypeScript
# 5                          Bash/Shell;HTML/CSS;Python;SQL
# ...                                                   ...
# 83435                                  Clojure;Kotlin;SQL
# 83436                                                 NaN
# 83437                                  Groovy;Java;Python
# 83438                Bash/Shell;JavaScript;Node.js;Python
# 83439              Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1                                                       Swift
# 2                                                         NaN
# 3                                           Julia;Python;Rust
# 4                                       JavaScript;TypeScript
# 5                              Bash/Shell;HTML/CSS;Python;SQL
# ...                                                       ...
# 83435                                                 Clojure
# 83436                                                     NaN
# 83437                                             Java;Python
# 83438                                                 Go;Rust
# 83439       Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                       DatabaseHaveWorkedWith  \
# ResponseId
# 1                                          PostgreSQL;SQLite
# 2                                                 PostgreSQL
# 3                                                     SQLite
# 4                                                        NaN
# 5                             Elasticsearch;PostgreSQL;Redis
# ...                                                      ...
# 83435                                          Oracle;SQLite
# 83436         Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83437        DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438       Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83439                                      Oracle;PostgreSQL
#
#                                        DatabaseWantToWorkWith  \
# ResponseId
# 1                                                      SQLite
# 2                                                         NaN
# 3                                                      SQLite
# 4                                                         NaN
# 5                    Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                       ...
# 83435                                                  SQLite
# 83436       Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83437                                          DynamoDB;Redis
# 83438                                                     NaN
# 83439       Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#                PlatformHaveWorkedWith PlatformWantToWorkWith  \
# ResponseId
# 1                                 NaN                    NaN
# 2                                 NaN                    NaN
# 3                              Heroku                    NaN
# 4                                 NaN                    NaN
# 5                                 NaN                    NaN
# ...                               ...                    ...
# 83435                             AWS                    AWS
# 83436                             NaN                    NaN
# 83437       AWS;Google Cloud Platform                    AWS
# 83438                          Heroku       AWS;DigitalOcean
# 83439                 Microsoft Azure                    AWS
#
#                                   WebframeHaveWorkedWith  \
# ResponseId
# 1                                        Laravel;Symfony
# 2                                   Angular;Flask;Vue.js
# 3                                                  Flask
# 4                                         Angular;jQuery
# 5                                                  Flask
# ...                                                  ...
# 83435                                                NaN
# 83436       Django;jQuery;Laravel;React.js;Ruby on Rails
# 83437                                      FastAPI;Flask
# 83438                      Django;Express;Flask;React.js
# 83439                                     Angular;Spring
#
#                                        WebframeWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                       Flask
# 4                                              Angular;jQuery
# 5                                                       Flask
# ...                                                       ...
# 83435                                                     NaN
# 83436       Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83437                                           FastAPI;Flask
# 83438                                                     NaN
# 83439                          Express;Laravel;Spring;Symfony
#
#                            MiscTechHaveWorkedWith  \
# ResponseId
# 1                                             NaN
# 2                                         Cordova
# 3           NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                             NaN
# 5                Apache Spark;Hadoop;NumPy;Pandas
# ...                                           ...
# 83435                                         NaN
# 83436                                  Flutter;Qt
# 83437                   Hadoop;Keras;NumPy;Pandas
# 83438       NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83439                                         NaN
#
#                                        MiscTechWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                 Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                                         NaN
# 5                                         Hadoop;NumPy;Pandas
# ...                                                       ...
# 83435                                                     NaN
# 83436                                                     NaN
# 83437       Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83438                   NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83439                                                     NaN
#
#                  ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# ResponseId
# 1                                    NaN                              NaN
# 2                        Docker;Git;Yarn                              Git
# 3                                    NaN                              NaN
# 4                                    NaN                              NaN
# 5             Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                                  ...                              ...
# 83435                         Docker;Git                   Git;Kubernetes
# 83436         Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83437       Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83438       Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83439                         Docker;Git            Docker;Git;Kubernetes
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                              PHPStorm;Xcode
# 2                   Android Studio;IntelliJ;Notepad++;PyCharm
# 3           IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 4                                                         NaN
# 5                  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                       ...
# 83435            IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83436       Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83437       Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83438                                    PyCharm;Sublime Text
# 83439                             IntelliJ;Visual Studio Code
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 1                                                  Atom;Xcode        MacOS
# 2                                                         NaN      Windows
# 3           IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 4                                                         NaN      Windows
# 5           Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                       ...          ...
# 83435                                        Sublime Text;Vim        MacOS
# 83436       Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83437                  IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83438                                                     NaN        MacOS
# 83439                    IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                      NEWStuck  \
# ResponseId
# 1           Call a coworker or friend;Visit Stack Overflow...
# 2                              Visit Stack Overflow;Google it
# 3           Visit Stack Overflow;Google it;Watch help / tu...
# 4           Call a coworker or friend;Visit Stack Overflow...
# 5           Visit Stack Overflow;Go for a walk or other ph...
# ...                                                       ...
# 83435                     Call a coworker or friend;Google it
# 83436       Call a coworker or friend;Visit Stack Overflow...
# 83437       Call a coworker or friend;Visit Stack Overflow...
# 83438       Call a coworker or friend;Visit Stack Overflow...
# 83439       Call a coworker or friend;Visit Stack Overflow...
#
#                                                    NEWSOSites  \
# ResponseId
# 1                                              Stack Overflow
# 2                                              Stack Overflow
# 3                               Stack Overflow;Stack Exchange
# 4                                              Stack Overflow
# 5                               Stack Overflow;Stack Exchange
# ...                                                       ...
# 83435                           Stack Overflow;Stack Exchange
# 83436                           Stack Overflow;Stack Exchange
# 83437                           Stack Overflow;Stack Exchange
# 83438                                          Stack Overflow
# 83439       Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                                 SOVisitFreq SOAccount  \
# ResponseId
# 1                    Multiple times per day       Yes
# 2                     Daily or almost daily       Yes
# 3                    Multiple times per day       Yes
# 4                     Daily or almost daily       Yes
# 5                     Daily or almost daily       Yes
# ...                                     ...       ...
# 83435                  A few times per week        No
# 83436                Multiple times per day       Yes
# 83437                  A few times per week       Yes
# 83438       A few times per month or weekly       Yes
# 83439                  A few times per week       Yes
#
#                                                    SOPartFreq  \
# ResponseId
# 1                             A few times per month or weekly
# 2                                       Daily or almost daily
# 3                                      Multiple times per day
# 4                                       Daily or almost daily
# 5                                        A few times per week
# ...                                                       ...
# 83435                                                     NaN
# 83436       I have never participated in Q&A on Stack Over...
# 83437       I have never participated in Q&A on Stack Over...
# 83438                     Less than once per month or monthly
# 83439                                    A few times per week
#
#                      SOComm NEWOtherComms              Age Gender Trans  \
# ResponseId
# 1           Yes, definitely            No  25-34 years old    Man    No
# 2           Yes, definitely            No  18-24 years old    Man    No
# 3           Yes, definitely           Yes  18-24 years old    Man    No
# 4                   Neutral            No  35-44 years old    Man    No
# 5             Yes, somewhat            No  25-34 years old    Man    No
# ...                     ...           ...              ...    ...   ...
# 83435        No, not at all            No  25-34 years old    Man    No
# 83436         Yes, somewhat            No  18-24 years old    Man    No
# 83437        No, not really            No  25-34 years old    Man    No
# 83438        No, not really            No  25-34 years old    Man    No
# 83439         Yes, somewhat            No  18-24 years old    Man    No
#
#                           Sexuality                     Ethnicity  \
# ResponseId
# 1           Straight / Heterosexual  White or of European descent
# 2           Straight / Heterosexual  White or of European descent
# 3                 Prefer not to say             Prefer not to say
# 4           Straight / Heterosexual  White or of European descent
# 5                               NaN  White or of European descent
# ...                             ...                           ...
# 83435       Straight / Heterosexual  White or of European descent
# 83436       Straight / Heterosexual   Black or of African descent
# 83437                           NaN  White or of European descent
# 83438       Straight / Heterosexual  White or of European descent
# 83439       Straight / Heterosexual        Hispanic or Latino/a/x
#
#                           Accessibility  \
# ResponseId
# 1                     None of the above
# 2                     None of the above
# 3                     None of the above
# 4           I am deaf / hard of hearing
# 5                     None of the above
# ...                                 ...
# 83435                 None of the above
# 83436                 None of the above
# 83437                 None of the above
# 83438                 None of the above
# 83439                 None of the above
#
#                                                  MentalHealth  \
# ResponseId
# 1                                           None of the above
# 2                                           None of the above
# 3                                           None of the above
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 83435       I have a concentration and/or memory disorder ...
# 83436                                       None of the above
# 83437                                       None of the above
# 83438       I have a mood or emotional disorder (e.g. depr...
# 83439                                       None of the above
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 1           Appropriate in length                        Easy
# 2           Appropriate in length                        Easy
# 3           Appropriate in length                        Easy
# 4           Appropriate in length  Neither easy nor difficult
# 5           Appropriate in length                        Easy
# ...                           ...                         ...
# 83435       Appropriate in length                        Easy
# 83436       Appropriate in length                        Easy
# 83437       Appropriate in length  Neither easy nor difficult
# 83438       Appropriate in length  Neither easy nor difficult
# 83439       Appropriate in length                        Easy
#
#             ConvertedCompYearly
# ResponseId
# 1                       62268.0
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# ...                         ...
# 83435                  160500.0
# 83436                    3960.0
# 83437                   90000.0
# 83438                  816816.0
# 83439                   21168.0
#
# [83439 rows x 47 columns]

# %%
datos
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country    US_State  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UK_Country                                            EdLevel  \
# 0            NaN  Secondary school (e.g. American high school, G...
# 1            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3            NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438        NaN                 Professional degree (JD, MD, etc.)
#
#           Age1stCode                                          LearnCode  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YearsCode YearsCodePro  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DevType  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LanguageHaveWorkedWith  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 0                                                  Swift
# 1                                                    NaN
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DatabaseHaveWorkedWith  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WebframeHaveWorkedWith  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MiscTechHaveWorkedWith  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWStuck  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq SOAccount  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPartFreq           SOComm  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOtherComms              Age Gender Trans                Sexuality  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity                Accessibility  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MentalHealth  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]

# %%
# Determinar una columna como identificador primario al crear el dataframe
schema_datos = pd.read_csv('survey_results_schema.csv', index_col='qname')

# %%
schema_datos
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# LearnCode           QID276  How did you learn to code? Select all that apply.
# YearsCode            QID32  Including any education, how many years have y...
# YearsCodePro         QID34  NOT including education, how many years have y...
# DevType              QID31  Which of the following describes your current ...
# OrgSize              QID29  Approximately how many people are employed by ...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# CompTotal            QID51  What is your current total compensation (salar...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# S3                   QID61  <span style="font-size:22px; font-family: aria...
# Language            QID233  Which <b>programming, scripting, and markup la...
# Database            QID262  Which <b>database environments </b>have you do...
# Platform            QID263  Which <b>cloud platforms</b> have you done ext...
# Webframe            QID264  Which <strong>web frameworks </strong><span st...
# MiscTech            QID265  Which <b>other frameworks and libraries</b> ha...
# ToolsTech           QID275  Which <strong>tools</strong> have you done ext...
# NEWCollabTools      QID274  Which <strong>development environments</strong...
# OpSys                QID71  What is the primary operating system in which ...
# NEWStuck            QID243  What do you do when you get stuck on a problem...
# S4                   QID91  <span style="font-size:22px; font-family: aria...
# NEWSOSites          QID266  Which of the following Stack Overflow sites ha...
# SOVisitFreq         QID100  How frequently would you say you visit Stack O...
# SOAccount           QID101              Do you have a Stack Overflow account?
# SOPartFreq          QID102  How frequently would you say you participate i...
# SOComm              QID106  Do you consider yourself a member of the Stack...
# NEWOtherComms       QID267  Are you a member of any other online developer...
# NEWOtherCommsNames  QID268  Please name up to 5 other online developer com...
# S5                  QID121  <span style="font-size:22px; font-family: aria...
# Age                 QID127                                  What is your age?
# Gender              QID122  Which of the following describe you, if any? P...
# Trans               QID153                    Do you identify as transgender?
# Sexuality           QID136  Which of the following describe you, if any? P...
# Ethnicity           QID126  Which of the following describe you, if any? P...
# Accessibility       QID124  Which of the following describe you, if any? P...
# MentalHealth        QID125  Which of the following describe you, if any? P...
# S6                  QID131  <span style="font-size:22px;"><strong>Final Qu...
# SurveyLength        QID132  How do you feel about the length of the survey...
# SurveyEase          QID133  How easy or difficult was this survey to compl...
#
#                     force_resp    type selector
# qname
# S0                       False      DB       TB
# MetaInfo                 False    Meta  Browser
# S1                       False      DB       TB
# MainBranch                True      MC     SAVR
# Employment               False      MC     MAVR
# Country                   True      MC       DL
# US_State                 False      MC       DL
# UK_Country               False      MC       DL
# S2                       False      DB       TB
# EdLevel                  False      MC     SAVR
# Age1stCode               False      MC     MAVR
# LearnCode                False      MC     MAVR
# YearsCode                False      MC       DL
# YearsCodePro             False      MC       DL
# DevType                  False      MC     MAVR
# OrgSize                  False      MC     MAVR
# Currency                  True      MC       SB
# CompTotal                False      TE       SL
# CompFreq                 False      MC     MAVR
# S3                       False      DB       TB
# Language                 False  Matrix   Likert
# Database                 False  Matrix   Likert
# Platform                 False  Matrix   Likert
# Webframe                 False  Matrix   Likert
# MiscTech                 False  Matrix   Likert
# ToolsTech                False  Matrix   Likert
# NEWCollabTools           False  Matrix   Likert
# OpSys                    False      MC     SAVR
# NEWStuck                 False      MC     MAVR
# S4                       False      DB       TB
# NEWSOSites               False      MC     MAVR
# SOVisitFreq              False      MC     MAVR
# SOAccount                False      MC     MAVR
# SOPartFreq               False      MC     MAVR
# SOComm                   False      MC     MAVR
# NEWOtherComms            False      MC     MAVR
# NEWOtherCommsNames       False  Matrix   Likert
# S5                       False      DB       TB
# Age                      False      MC     MAVR
# Gender                   False      MC     MAVR
# Trans                    False      MC     MAVR
# Sexuality                False      MC     MAVR
# Ethnicity                False      MC     MAVR
# Accessibility            False      MC     MAVR
# MentalHealth             False      MC     MAVR
# S6                       False      DB       TB
# SurveyLength             False      MC     MAVR
# SurveyEase               False      MC     MAVR

# %%
# Se accede al dato a través del campo 'Country'
schema_datos.loc['Country', 'question']
# Out:
# 'Where do you live? <span style="font-weight: bolder;">*</span>'

# %%
# Ordenar los datos: ascendente
schema_datos.sort_index()
# Ordenar los datos: descendente
# schema_datos.sort_index(ascending=False)
# Out:
#                        qid                                           question  \
# qname
# Accessibility       QID124  Which of the following describe you, if any? P...
# Age                 QID127                                  What is your age?
# Age1stCode          QID149  At what age did you write your first line of c...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal            QID51  What is your current total compensation (salar...
# Country               QID6  Where do you live? <span style="font-weight: b...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Database            QID262  Which <b>database environments </b>have you do...
# DevType              QID31  Which of the following describes your current ...
# EdLevel              QID25  Which of the following best describes the high...
# Employment           QID24  Which of the following best describes your cur...
# Ethnicity           QID126  Which of the following describe you, if any? P...
# Gender              QID122  Which of the following describe you, if any? P...
# Language            QID233  Which <b>programming, scripting, and markup la...
# LearnCode           QID276  How did you learn to code? Select all that apply.
# MainBranch            QID2  Which of the following options best describes ...
# MentalHealth        QID125  Which of the following describe you, if any? P...
# MetaInfo             QID12                                  Browser Meta Info
# MiscTech            QID265  Which <b>other frameworks and libraries</b> ha...
# NEWCollabTools      QID274  Which <strong>development environments</strong...
# NEWOtherComms       QID267  Are you a member of any other online developer...
# NEWOtherCommsNames  QID268  Please name up to 5 other online developer com...
# NEWSOSites          QID266  Which of the following Stack Overflow sites ha...
# NEWStuck            QID243  What do you do when you get stuck on a problem...
# OpSys                QID71  What is the primary operating system in which ...
# OrgSize              QID29  Approximately how many people are employed by ...
# Platform            QID263  Which <b>cloud platforms</b> have you done ext...
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# S3                   QID61  <span style="font-size:22px; font-family: aria...
# S4                   QID91  <span style="font-size:22px; font-family: aria...
# S5                  QID121  <span style="font-size:22px; font-family: aria...
# S6                  QID131  <span style="font-size:22px;"><strong>Final Qu...
# SOAccount           QID101              Do you have a Stack Overflow account?
# SOComm              QID106  Do you consider yourself a member of the Stack...
# SOPartFreq          QID102  How frequently would you say you participate i...
# SOVisitFreq         QID100  How frequently would you say you visit Stack O...
# Sexuality           QID136  Which of the following describe you, if any? P...
# SurveyEase          QID133  How easy or difficult was this survey to compl...
# SurveyLength        QID132  How do you feel about the length of the survey...
# ToolsTech           QID275  Which <strong>tools</strong> have you done ext...
# Trans               QID153                    Do you identify as transgender?
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# US_State              QID7  <p>In which state or territory of the USA do y...
# Webframe            QID264  Which <strong>web frameworks </strong><span st...
# YearsCode            QID32  Including any education, how many years have y...
# YearsCodePro         QID34  NOT including education, how many years have y...
#
#                     force_resp    type selector
# qname
# Accessibility            False      MC     MAVR
# Age                      False      MC     MAVR
# Age1stCode               False      MC     MAVR
# CompFreq                 False      MC     MAVR
# CompTotal                False      TE       SL
# Country                   True      MC       DL
# Currency                  True      MC       SB
# Database                 False  Matrix   Likert
# DevType                  False      MC     MAVR
# EdLevel                  False      MC     SAVR
# Employment               False      MC     MAVR
# Ethnicity                False      MC     MAVR
# Gender                   False      MC     MAVR
# Language                 False  Matrix   Likert
# LearnCode                False      MC     MAVR
# MainBranch                True      MC     SAVR
# MentalHealth             False      MC     MAVR
# MetaInfo                 False    Meta  Browser
# MiscTech                 False  Matrix   Likert
# NEWCollabTools           False  Matrix   Likert
# NEWOtherComms            False      MC     MAVR
# NEWOtherCommsNames       False  Matrix   Likert
# NEWSOSites               False      MC     MAVR
# NEWStuck                 False      MC     MAVR
# OpSys                    False      MC     SAVR
# OrgSize                  False      MC     MAVR
# Platform                 False  Matrix   Likert
# S0                       False      DB       TB
# S1                       False      DB       TB
# S2                       False      DB       TB
# S3                       False      DB       TB
# S4                       False      DB       TB
# S5                       False      DB       TB
# S6                       False      DB       TB
# SOAccount                False      MC     MAVR
# SOComm                   False      MC     MAVR
# SOPartFreq               False      MC     MAVR
# SOVisitFreq              False      MC     MAVR
# Sexuality                False      MC     MAVR
# SurveyEase               False      MC     MAVR
# SurveyLength             False      MC     MAVR
# ToolsTech                False  Matrix   Likert
# Trans                    False      MC     MAVR
# UK_Country               False      MC       DL
# US_State                 False      MC       DL
# Webframe                 False  Matrix   Likert
# YearsCode                False      MC       DL
# YearsCodePro             False      MC       DL

# %%
# Muestra todos los registros que cumplen con el criterio
filtro = datos['Country'] == 'Spain'

# %%
schema_datos
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# LearnCode           QID276  How did you learn to code? Select all that apply.
# YearsCode            QID32  Including any education, how many years have y...
# YearsCodePro         QID34  NOT including education, how many years have y...
# DevType              QID31  Which of the following describes your current ...
# OrgSize              QID29  Approximately how many people are employed by ...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# CompTotal            QID51  What is your current total compensation (salar...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# S3                   QID61  <span style="font-size:22px; font-family: aria...
# Language            QID233  Which <b>programming, scripting, and markup la...
# Database            QID262  Which <b>database environments </b>have you do...
# Platform            QID263  Which <b>cloud platforms</b> have you done ext...
# Webframe            QID264  Which <strong>web frameworks </strong><span st...
# MiscTech            QID265  Which <b>other frameworks and libraries</b> ha...
# ToolsTech           QID275  Which <strong>tools</strong> have you done ext...
# NEWCollabTools      QID274  Which <strong>development environments</strong...
# OpSys                QID71  What is the primary operating system in which ...
# NEWStuck            QID243  What do you do when you get stuck on a problem...
# S4                   QID91  <span style="font-size:22px; font-family: aria...
# NEWSOSites          QID266  Which of the following Stack Overflow sites ha...
# SOVisitFreq         QID100  How frequently would you say you visit Stack O...
# SOAccount           QID101              Do you have a Stack Overflow account?
# SOPartFreq          QID102  How frequently would you say you participate i...
# SOComm              QID106  Do you consider yourself a member of the Stack...
# NEWOtherComms       QID267  Are you a member of any other online developer...
# NEWOtherCommsNames  QID268  Please name up to 5 other online developer com...
# S5                  QID121  <span style="font-size:22px; font-family: aria...
# Age                 QID127                                  What is your age?
# Gender              QID122  Which of the following describe you, if any? P...
# Trans               QID153                    Do you identify as transgender?
# Sexuality           QID136  Which of the following describe you, if any? P...
# Ethnicity           QID126  Which of the following describe you, if any? P...
# Accessibility       QID124  Which of the following describe you, if any? P...
# MentalHealth        QID125  Which of the following describe you, if any? P...
# S6                  QID131  <span style="font-size:22px;"><strong>Final Qu...
# SurveyLength        QID132  How do you feel about the length of the survey...
# SurveyEase          QID133  How easy or difficult was this survey to compl...
#
#                     force_resp    type selector
# qname
# S0                       False      DB       TB
# MetaInfo                 False    Meta  Browser
# S1                       False      DB       TB
# MainBranch                True      MC     SAVR
# Employment               False      MC     MAVR
# Country                   True      MC       DL
# US_State                 False      MC       DL
# UK_Country               False      MC       DL
# S2                       False      DB       TB
# EdLevel                  False      MC     SAVR
# Age1stCode               False      MC     MAVR
# LearnCode                False      MC     MAVR
# YearsCode                False      MC       DL
# YearsCodePro             False      MC       DL
# DevType                  False      MC     MAVR
# OrgSize                  False      MC     MAVR
# Currency                  True      MC       SB
# CompTotal                False      TE       SL
# CompFreq                 False      MC     MAVR
# S3                       False      DB       TB
# Language                 False  Matrix   Likert
# Database                 False  Matrix   Likert
# Platform                 False  Matrix   Likert
# Webframe                 False  Matrix   Likert
# MiscTech                 False  Matrix   Likert
# ToolsTech                False  Matrix   Likert
# NEWCollabTools           False  Matrix   Likert
# OpSys                    False      MC     SAVR
# NEWStuck                 False      MC     MAVR
# S4                       False      DB       TB
# NEWSOSites               False      MC     MAVR
# SOVisitFreq              False      MC     MAVR
# SOAccount                False      MC     MAVR
# SOPartFreq               False      MC     MAVR
# SOComm                   False      MC     MAVR
# NEWOtherComms            False      MC     MAVR
# NEWOtherCommsNames       False  Matrix   Likert
# S5                       False      DB       TB
# Age                      False      MC     MAVR
# Gender                   False      MC     MAVR
# Trans                    False      MC     MAVR
# Sexuality                False      MC     MAVR
# Ethnicity                False      MC     MAVR
# Accessibility            False      MC     MAVR
# MentalHealth             False      MC     MAVR
# S6                       False      DB       TB
# SurveyLength             False      MC     MAVR
# SurveyEase               False      MC     MAVR

# %%
datos[filtro]
# Out:
#        ResponseId                              MainBranch  \
# 11             12          I am a developer by profession
# 68             69          I am a developer by profession
# 79             80          I am a developer by profession
# 108           109          I am a developer by profession
# 267           268          I am a developer by profession
# ...           ...                                     ...
# 83097       83098  I am a student who is learning to code
# 83133       83134          I am a developer by profession
# 83137       83138          I am a developer by profession
# 83159       83160          I am a developer by profession
# 83313       83314          I am a developer by profession
#
#                                               Employment Country US_State  \
# 11                                    Employed full-time   Spain      NaN
# 68                                    Employed full-time   Spain      NaN
# 79                                    Employed full-time   Spain      NaN
# 108                                   Employed full-time   Spain      NaN
# 267                                   Employed full-time   Spain      NaN
# ...                                                  ...     ...      ...
# 83097                                 Student, part-time   Spain      NaN
# 83133                                 Employed full-time   Spain      NaN
# 83137                 Not employed, but looking for work   Spain      NaN
# 83159                                 Student, full-time   Spain      NaN
# 83313  Independent contractor, freelancer, or self-em...   Spain      NaN
#
#       UK_Country                                            EdLevel  \
# 11           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 68           NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 79           NaN                Associate degree (A.A., A.S., etc.)
# 108          NaN                Associate degree (A.A., A.S., etc.)
# 267          NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...          ...                                                ...
# 83097        NaN  Secondary school (e.g. American high school, G...
# 83133        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 83137        NaN  Some college/university study without earning ...
# 83159        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 83313        NaN                 Professional degree (JD, MD, etc.)
#
#           Age1stCode                                          LearnCode  \
# 11     11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 68     11 - 17 years                                             School
# 79     11 - 17 years                    Online Courses or Certification
# 108    25 - 34 years                             Coding Bootcamp;School
# 267    11 - 17 years                            Other (please specify):
# ...              ...                                                ...
# 83097  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83133  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83137   5 - 10 years  Other online resources (ex: videos, blogs, etc...
# 83159  11 - 17 years    Other online resources (ex: videos, blogs, etc)
# 83313  11 - 17 years  Coding Bootcamp;Other online resources (ex: vi...
#
#       YearsCode YearsCodePro  \
# 11           12            5
# 68           20           10
# 79          NaN          NaN
# 108          10            8
# 267          27           13
# ...         ...          ...
# 83097         3          NaN
# 83133         8            3
# 83137        30          NaN
# 83159        10          NaN
# 83313        10            5
#
#                                                  DevType  \
# 11                                   Developer, back-end
# 68                                   Developer, back-end
# 79                                   Developer, back-end
# 108    Developer, full-stack;Developer, back-end;Prod...
# 267                                Developer, full-stack
# ...                                                  ...
# 83097                                                NaN
# 83133  Engineer, data;Data scientist or machine learn...
# 83137  Developer, mobile;Developer, front-end;Develop...
# 83159                                                NaN
# 83313  Developer, front-end;Developer, full-stack;Dev...
#
#                         OrgSize           Currency  CompTotal CompFreq  \
# 11           10 to 19 employees  EUR European Euro    43000.0   Yearly
# 68     10,000 or more employees  EUR European Euro    54000.0   Yearly
# 79         100 to 499 employees  EUR European Euro    20000.0   Yearly
# 108        100 to 499 employees  EUR European Euro    36000.0   Yearly
# 267    1,000 to 4,999 employees  EUR European Euro        NaN  Monthly
# ...                         ...                ...        ...      ...
# 83097                       NaN                NaN        NaN      NaN
# 83133        20 to 99 employees  EUR European Euro    50000.0   Yearly
# 83137                       NaN                NaN        NaN      NaN
# 83159                       NaN                NaN        NaN      NaN
# 83313          2 to 9 employees  EUR European Euro     2300.0  Monthly
#
#                                   LanguageHaveWorkedWith  \
# 11     Bash/Shell;HTML/CSS;JavaScript;Node.js;SQL;Typ...
# 68              Bash/Shell;JavaScript;Node.js;TypeScript
# 79                                     C#;Go;Java;Python
# 108          HTML/CSS;Java;JavaScript;Node.js;Python;SQL
# 267                 HTML/CSS;Java;JavaScript;Node.js;SQL
# ...                                                  ...
# 83097                                  HTML/CSS;Java;SQL
# 83133        C;C++;Go;HTML/CSS;JavaScript;Node.js;Python
# 83137  Bash/Shell;F#;HTML/CSS;Java;JavaScript;Kotlin;...
# 83159  Assembly;Bash/Shell;C;C#;C++;HTML/CSS;Java;Jav...
# 83313                             Elixir;JavaScript;Ruby
#
#                                   LanguageWantToWorkWith  \
# 11     C++;Clojure;JavaScript;Node.js;Rust;SQL;TypeSc...
# 68                  JavaScript;Node.js;Python;TypeScript
# 79                                   C++;Clojure;Go;Rust
# 108    HTML/CSS;Java;JavaScript;Node.js;Python;SQL;Ty...
# 267          HTML/CSS;Java;JavaScript;Node.js;Python;SQL
# ...                                                  ...
# 83097  C#;HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;SQL
# 83133        C;C++;Go;Haskell;HTML/CSS;Python;Rust;Scala
# 83137                      F#;HTML/CSS;Kotlin;TypeScript
# 83159  Assembly;Bash/Shell;C;C#;C++;Clojure;Crystal;E...
# 83313                                        Elixir;Ruby
#
#                                   DatabaseHaveWorkedWith  \
# 11                                            PostgreSQL
# 68                                              DynamoDB
# 79     Elasticsearch;Firebase;MariaDB;MySQL;PostgreSQ...
# 108              Microsoft SQL Server;MongoDB;PostgreSQL
# 267                                       MongoDB;Oracle
# ...                                                  ...
# 83097                                      MariaDB;MySQL
# 83133                  Cassandra;PostgreSQL;Redis;SQLite
# 83137                        Firebase;MySQL;Redis;SQLite
# 83159             Cassandra;MariaDB;MongoDB;MySQL;SQLite
# 83313                          Firebase;PostgreSQL;Redis
#
#                                   DatabaseWantToWorkWith  \
# 11                              MongoDB;PostgreSQL;Redis
# 68                                     DynamoDB;Firebase
# 79                                            PostgreSQL
# 108                                   MongoDB;PostgreSQL
# 267                                       MongoDB;Oracle
# ...                                                  ...
# 83097                                       MySQL;SQLite
# 83133                  Cassandra;PostgreSQL;Redis;SQLite
# 83137                        Firebase;MySQL;Redis;SQLite
# 83159  Couchbase;Elasticsearch;MongoDB;MySQL;PostgreS...
# 83313                          Firebase;PostgreSQL;Redis
#
#                        PlatformHaveWorkedWith  \
# 11                                        AWS
# 68                                        AWS
# 79           AWS;Google Cloud Platform;Heroku
# 108                                       NaN
# 267                                       NaN
# ...                                       ...
# 83097                                     NaN
# 83133               AWS;Google Cloud Platform
# 83137                                     AWS
# 83159                                     AWS
# 83313  AWS;DigitalOcean;Google Cloud Platform
#
#                        PlatformWantToWorkWith        WebframeHaveWorkedWith  \
# 11                                        NaN       Express;React.js;Vue.js
# 68                        AWS;Microsoft Azure                           NaN
# 79                                 AWS;Heroku  Angular;Django;FastAPI;Flask
# 108                                       NaN                 jQuery;Spring
# 267                                       NaN         Express;jQuery;Spring
# ...                                       ...                           ...
# 83097                                     NaN                           NaN
# 83133               AWS;Google Cloud Platform                Flask;React.js
# 83137                                     NaN  jQuery;Svelte;Symfony;Vue.js
# 83159                                     AWS        Express;Flask;React.js
# 83313  AWS;DigitalOcean;Google Cloud Platform          jQuery;Ruby on Rails
#
#                                   WebframeWantToWorkWith  \
# 11                                        Express;Vue.js
# 68                                                   NaN
# 79                                              React.js
# 108                    Angular;Angular.js;Express;Spring
# 267                                Express;jQuery;Spring
# ...                                                  ...
# 83097                                                NaN
# 83133                             FastAPI;Flask;React.js
# 83137                                      Svelte;Vue.js
# 83159  Angular;Express;Flask;Gatsby;jQuery;Laravel;Re...
# 83313                        Django;Ruby on Rails;Vue.js
#
#                                   MiscTechHaveWorkedWith  \
# 11                                                   NaN
# 68                                                   NaN
# 79                                               Flutter
# 108                                                  NaN
# 267                                                  NaN
# ...                                                  ...
# 83097                                                NaN
# 83133                                NumPy;Torch/PyTorch
# 83137                                                NaN
# 83159  .NET Framework;Apache Spark;Keras;NumPy;Pandas...
# 83313                                                NaN
#
#                                   MiscTechWantToWorkWith  \
# 11                                                   NaN
# 68                                                   NaN
# 79                                          NumPy;Pandas
# 108                                                  NaN
# 267                                                  NaN
# ...                                                  ...
# 83097                                                NaN
# 83133                   Apache Spark;NumPy;Torch/PyTorch
# 83137                                                NaN
# 83159  .NET Framework;Apache Spark;Cordova;Flutter;Ke...
# 83313                                                NaN
#
#                             ToolsTechHaveWorkedWith  \
# 11                                              Git
# 68                                        Terraform
# 79                    Docker;Git;Terraform;Unity 3D
# 108                                      Docker;Git
# 267                                             NaN
# ...                                             ...
# 83097                                           Git
# 83133               Docker;Git;Kubernetes;Terraform
# 83137                                    Docker;Git
# 83159  Docker;Git;Kubernetes;Unity 3D;Unreal Engine
# 83313                       Ansible;Docker;Git;Yarn
#
#                       ToolsTechWantToWorkWith  \
# 11                                        Git
# 68                                  Terraform
# 79                       Deno;Kubernetes;Yarn
# 108                        Ansible;Docker;Git
# 267                                       NaN
# ...                                       ...
# 83097                            Git;Unity 3D
# 83133  Docker;Git;Kubernetes;Puppet;Terraform
# 83137                         Deno;Docker;Git
# 83159     Ansible;Docker;Git;Unity 3D;Xamarin
# 83313      Ansible;Docker;Git;Kubernetes;Yarn
#
#                             NEWCollabToolsHaveWorkedWith  \
# 11                                                  Atom
# 68                      Notepad++;Vim;Visual Studio Code
# 79     Android Studio;IntelliJ;NetBeans;Visual Studio...
# 108                                    Eclipse;Notepad++
# 267                                    Eclipse;Notepad++
# ...                                                  ...
# 83097                                  Eclipse;Notepad++
# 83133                       Emacs;Vim;Visual Studio Code
# 83137  Android Studio;Atom;NetBeans;Notepad++;Sublime...
# 83159  Android Studio;Atom;Eclipse;IPython/Jupyter;Ne...
# 83313                        RubyMine;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 11                                                  Atom  Linux-based
# 68                                Vim;Visual Studio Code      Windows
# 79                                          Emacs;Neovim        MacOS
# 108                                    Eclipse;Notepad++      Windows
# 267                                    Eclipse;Notepad++      Windows
# ...                                                  ...          ...
# 83097  Android Studio;Eclipse;Notepad++;Visual Studio...      Windows
# 83133                       Emacs;Vim;Visual Studio Code  Linux-based
# 83137                  Android Studio;Visual Studio Code  Linux-based
# 83159  Atom;IPython/Jupyter;Notepad++;Visual Studio Code  Linux-based
# 83313                                 Visual Studio Code        MacOS
#
#                                                 NEWStuck  \
# 11     Call a coworker or friend;Visit Stack Overflow...
# 68     Call a coworker or friend;Visit Stack Overflow...
# 79     Call a coworker or friend;Visit Stack Overflow...
# 108    Visit Stack Overflow;Go for a walk or other ph...
# 267    Visit Stack Overflow;Google it;Do other work a...
# ...                                                  ...
# 83097  Call a coworker or friend;Visit Stack Overflow...
# 83133  Call a coworker or friend;Visit Stack Overflow...
# 83137  Visit Stack Overflow;Google it;Do other work a...
# 83159  Go for a walk or other physical activity;Play ...
# 83313                     Visit Stack Overflow;Google it
#
#                           NEWSOSites             SOVisitFreq SOAccount  \
# 11     Stack Overflow;Stack Exchange   Daily or almost daily       Yes
# 68     Stack Overflow;Stack Exchange   Daily or almost daily       Yes
# 79     Stack Overflow;Stack Exchange   Daily or almost daily       Yes
# 108                   Stack Overflow  Multiple times per day       Yes
# 267    Stack Overflow;Stack Exchange   Daily or almost daily       Yes
# ...                              ...                     ...       ...
# 83097                 Stack Overflow   Daily or almost daily       Yes
# 83133  Stack Overflow;Stack Exchange    A few times per week       Yes
# 83137  Stack Overflow;Stack Exchange    A few times per week       Yes
# 83159  Stack Overflow;Stack Exchange   Daily or almost daily       Yes
# 83313  Stack Overflow;Stack Exchange  Multiple times per day       Yes
#
#                                               SOPartFreq           SOComm  \
# 11                   Less than once per month or monthly    Yes, somewhat
# 68                                  A few times per week    Yes, somewhat
# 79     I have never participated in Q&A on Stack Over...   No, not at all
# 108                                 A few times per week  Yes, definitely
# 267                      A few times per month or weekly    Yes, somewhat
# ...                                                  ...              ...
# 83097  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83133                Less than once per month or monthly    Yes, somewhat
# 83137  I have never participated in Q&A on Stack Over...   No, not really
# 83159                    A few times per month or weekly  Yes, definitely
# 83313                Less than once per month or monthly    Yes, somewhat
#
#       NEWOtherComms              Age             Gender              Trans  \
# 11              Yes  25-34 years old                Man                 No
# 68               No  35-44 years old                Man                 No
# 79               No  18-24 years old                Man                 No
# 108              No  25-34 years old                Man                 No
# 267              No  35-44 years old                Man                 No
# ...             ...              ...                ...                ...
# 83097           Yes  18-24 years old                Man                 No
# 83133            No  25-34 years old                Man                 No
# 83137            No  35-44 years old  Prefer not to say  Prefer not to say
# 83159           Yes  18-24 years old                Man                 No
# 83313            No  25-34 years old                Man                 No
#
#                      Sexuality  \
# 11     Straight / Heterosexual
# 68     Straight / Heterosexual
# 79     Straight / Heterosexual
# 108    Straight / Heterosexual
# 267    Straight / Heterosexual
# ...                        ...
# 83097  Straight / Heterosexual
# 83133  Straight / Heterosexual
# 83137        Prefer not to say
# 83159  Straight / Heterosexual
# 83313  Straight / Heterosexual
#
#                                                Ethnicity      Accessibility  \
# 11     White or of European descent;Hispanic or Latin...  None of the above
# 68                                                   NaN  None of the above
# 79                                Hispanic or Latino/a/x                NaN
# 108                         White or of European descent  None of the above
# 267                         White or of European descent  None of the above
# ...                                                  ...                ...
# 83097                       White or of European descent  None of the above
# 83133                       White or of European descent  None of the above
# 83137                                  Prefer not to say  Prefer not to say
# 83159                       White or of European descent  None of the above
# 83313                             Hispanic or Latino/a/x  None of the above
#
#                                             MentalHealth  \
# 11                                     None of the above
# 68                                     None of the above
# 79                                                   NaN
# 108                                    None of the above
# 267                                    None of the above
# ...                                                  ...
# 83097                                  None of the above
# 83133  I have a concentration and/or memory disorder ...
# 83137                                  Prefer not to say
# 83159                                  None of the above
# 83313                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 11                  Too long                        Easy              46482.0
# 68     Appropriate in length                        Easy              58373.0
# 79     Appropriate in length                        Easy              21620.0
# 108    Appropriate in length  Neither easy nor difficult              38915.0
# 267    Appropriate in length  Neither easy nor difficult                  NaN
# ...                      ...                         ...                  ...
# 83097  Appropriate in length                        Easy                  NaN
# 83133  Appropriate in length                        Easy              54049.0
# 83137  Appropriate in length  Neither easy nor difficult                  NaN
# 83159  Appropriate in length                        Easy                  NaN
# 83313  Appropriate in length                        Easy              29832.0
#
# [1485 rows x 48 columns]

# %%
# Datos filtrados usando loc
datos.loc[filtro, 'Employment']
# Out:
# 11                                      Employed full-time
# 68                                      Employed full-time
# 79                                      Employed full-time
# 108                                     Employed full-time
# 267                                     Employed full-time
#                                ...
# 83097                                   Student, part-time
# 83133                                   Employed full-time
# 83137                   Not employed, but looking for work
# 83159                                   Student, full-time
# 83313    Independent contractor, freelancer, or self-em...
# Name: Employment, Length: 1485, dtype: object

# %%
prog_python = (datos['Country'] == 'Spain') & (datos['LanguageHaveWorkedWith'] == 'Python')

# %%
datos.loc[prog_python]
# Out:
#        ResponseId                                         MainBranch  \
# 503           504  I am not primarily a developer, but I write co...
# 2746         2747  I am not primarily a developer, but I write co...
# 4033         4034             I am a student who is learning to code
# 8433         8434             I am a student who is learning to code
# 18022       18023  I am not primarily a developer, but I write co...
# 19666       19667                     I am a developer by profession
# 23070       23071                     I am a developer by profession
# 24391       24392                     I am a developer by profession
# 41991       41992  I am not primarily a developer, but I write co...
# 51907       51908                     I am a developer by profession
# 54100       54101  I am not primarily a developer, but I write co...
# 54537       54538                     I am a developer by profession
# 55187       55188             I am a student who is learning to code
# 56851       56852  I am not primarily a developer, but I write co...
# 58643       58644  I am not primarily a developer, but I write co...
# 63396       63397                     I am a developer by profession
# 63685       63686                     I am a developer by profession
# 66698       66699                        I code primarily as a hobby
# 66947       66948                     I am a developer by profession
# 69700       69701             I am a student who is learning to code
# 73557       73558  I am not primarily a developer, but I write co...
# 76104       76105                     I am a developer by profession
# 79253       79254                        I code primarily as a hobby
# 82733       82734             I am a student who is learning to code
#
#                                               Employment Country US_State  \
# 503                                   Employed full-time   Spain      NaN
# 2746                                  Employed full-time   Spain      NaN
# 4033                                  Student, full-time   Spain      NaN
# 8433                                  Student, part-time   Spain      NaN
# 18022                                 Employed full-time   Spain      NaN
# 19666                                 Employed full-time   Spain      NaN
# 23070                                 Employed full-time   Spain      NaN
# 24391                                 Employed full-time   Spain      NaN
# 41991                                 Employed full-time   Spain      NaN
# 51907                                 Employed full-time   Spain      NaN
# 54100                                 Employed full-time   Spain      NaN
# 54537                                 Employed full-time   Spain      NaN
# 55187                                 Student, full-time   Spain      NaN
# 56851  Independent contractor, freelancer, or self-em...   Spain      NaN
# 58643                                 Employed full-time   Spain      NaN
# 63396                                 Employed full-time   Spain      NaN
# 63685                                 Employed full-time   Spain      NaN
# 66698                                 Student, full-time   Spain      NaN
# 66947                                 Employed full-time   Spain      NaN
# 69700                                 Student, full-time   Spain      NaN
# 73557                                 Employed full-time   Spain      NaN
# 76104                                 Employed full-time   Spain      NaN
# 79253                                 Student, full-time   Spain      NaN
# 82733                                 Student, part-time   Spain      NaN
#
#       UK_Country                                            EdLevel  \
# 503          NaN         Other doctoral degree (Ph.D., Ed.D., etc.)
# 2746         NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4033         NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8433         NaN  Secondary school (e.g. American high school, G...
# 18022        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 19666        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 23070        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 24391        NaN         Other doctoral degree (Ph.D., Ed.D., etc.)
# 41991        NaN         Other doctoral degree (Ph.D., Ed.D., etc.)
# 51907        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 54100        NaN         Other doctoral degree (Ph.D., Ed.D., etc.)
# 54537        NaN  Some college/university study without earning ...
# 55187        NaN                          Primary/elementary school
# 56851        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 58643        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 63396        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 63685        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 66698        NaN  Secondary school (e.g. American high school, G...
# 66947        NaN  Some college/university study without earning ...
# 69700        NaN  Secondary school (e.g. American high school, G...
# 73557        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 76104        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 79253        NaN                                     Something else
# 82733        NaN  Secondary school (e.g. American high school, G...
#
#           Age1stCode                                          LearnCode  \
# 503    11 - 17 years    Friend or family member;Other (please specify):
# 2746   11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 4033   11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 8433   11 - 17 years  Coding Bootcamp;Other online resources (ex: vi...
# 18022  18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 19666  11 - 17 years    Other online resources (ex: videos, blogs, etc)
# 23070  11 - 17 years                                             School
# 24391  11 - 17 years                             Books / Physical media
# 41991  18 - 24 years                            Other (please specify):
# 51907   5 - 10 years  Other online resources (ex: videos, blogs, etc...
# 54100  11 - 17 years                             Books / Physical media
# 54537  11 - 17 years  School;Online Courses or Certification;Books /...
# 55187   5 - 10 years  Other online resources (ex: videos, blogs, etc...
# 56851  18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 58643  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 63396  11 - 17 years    Other online resources (ex: videos, blogs, etc)
# 63685  18 - 24 years                                          Colleague
# 66698  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 66947  11 - 17 years  Online Forum;Online Courses or Certification;B...
# 69700   5 - 10 years  Other online resources (ex: videos, blogs, etc...
# 73557  18 - 24 years                                       Online Forum
# 76104  18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 79253   5 - 10 years  Coding Bootcamp;Other online resources (ex: vi...
# 82733   5 - 10 years                             Books / Physical media
#
#               YearsCode      YearsCodePro  \
# 503                  25                20
# 2746                 13                 5
# 4033                NaN               NaN
# 8433                NaN               NaN
# 18022                 7  Less than 1 year
# 19666                 7                 3
# 23070                 9                 2
# 24391                20                 5
# 41991                14                11
# 51907                20                11
# 54100                35                15
# 54537                17                14
# 55187                 2               NaN
# 56851                11                 6
# 58643                17                 9
# 63396                10                 3
# 63685                 8                 3
# 66698                 2               NaN
# 66947                20                20
# 69700  Less than 1 year               NaN
# 73557                 4                 4
# 76104                 6                 4
# 79253                 4               NaN
# 82733                 1               NaN
#
#                                                  DevType  \
# 503        Data scientist or machine learning specialist
# 2746                         Academic researcher;Student
# 4033                                                 NaN
# 8433                                                 NaN
# 18022                      Academic researcher;Scientist
# 19666                                Developer, back-end
# 23070                                     Engineer, data
# 24391                                Developer, back-end
# 41991      Data scientist or machine learning specialist
# 51907                                Developer, back-end
# 54100  Data scientist or machine learning specialist;...
# 54537  Data scientist or machine learning specialist;...
# 55187                                                NaN
# 56851  Other (please specify):;Data scientist or mach...
# 58643                        Academic researcher;Student
# 63396  Engineer, data;Data scientist or machine learn...
# 63685            Developer, back-end;Academic researcher
# 66698                                                NaN
# 66947  Developer, desktop or enterprise applications;...
# 69700                                                NaN
# 73557                 Engineer, data;Engineering manager
# 76104      Data scientist or machine learning specialist
# 79253                                                NaN
# 82733                                                NaN
#
#                         OrgSize           Currency  CompTotal CompFreq  \
# 503    1,000 to 4,999 employees  EUR European Euro    60000.0   Yearly
# 2746         10 to 19 employees  EUR European Euro     1200.0  Monthly
# 4033                        NaN                NaN        NaN      NaN
# 8433                        NaN                NaN        NaN      NaN
# 18022        20 to 99 employees  EUR European Euro    35000.0   Yearly
# 19666      100 to 499 employees  EUR European Euro    31000.0   Yearly
# 23070      100 to 499 employees  EUR European Euro     1700.0  Monthly
# 24391      500 to 999 employees  EUR European Euro    86000.0   Yearly
# 41991        10 to 19 employees  EUR European Euro    35000.0   Yearly
# 51907        20 to 99 employees  EUR European Euro    45000.0   Yearly
# 54100          2 to 9 employees  EUR European Euro     3000.0  Monthly
# 54537        10 to 19 employees  EUR European Euro     3250.0  Monthly
# 55187                       NaN                NaN        NaN      NaN
# 56851          2 to 9 employees  EUR European Euro      900.0  Monthly
# 58643  1,000 to 4,999 employees  EUR European Euro        NaN      NaN
# 63396              I don’t know  EUR European Euro    25000.0   Yearly
# 63685          2 to 9 employees  EUR European Euro        NaN  Monthly
# 66698                       NaN                NaN        NaN      NaN
# 66947      100 to 499 employees  EUR European Euro    35000.0   Yearly
# 69700                       NaN                NaN        NaN      NaN
# 73557      100 to 499 employees  EUR European Euro    34500.0   Yearly
# 76104      100 to 499 employees  EUR European Euro    24080.0   Yearly
# 79253                       NaN                NaN        NaN      NaN
# 82733                       NaN                NaN        NaN      NaN
#
#       LanguageHaveWorkedWith                  LanguageWantToWorkWith  \
# 503                   Python                   Julia;Kotlin;Python;R
# 2746                  Python                             Python;Rust
# 4033                  Python                       Bash/Shell;Python
# 8433                  Python                             C;Go;Python
# 18022                 Python                                  Python
# 19666                 Python                                  Python
# 23070                 Python                            C++;Python;R
# 24391                 Python                                  Python
# 41991                 Python                                  Python
# 51907                 Python                               C;Go;Rust
# 54100                 Python                                  Python
# 54537                 Python                                  Python
# 55187                 Python                                  Python
# 56851                 Python          Dart;JavaScript;Node.js;Python
# 58643                 Python                               Go;Python
# 63396                 Python                                     NaN
# 63685                 Python                                  Python
# 66698                 Python                       JavaScript;Python
# 66947                 Python                          Go;Python;Rust
# 69700                 Python              C++;Java;JavaScript;Python
# 73557                 Python                                  Python
# 76104                 Python  C++;Haskell;Java;Kotlin;Python;R;Scala
# 79253                 Python                                      C#
# 82733                 Python                              JavaScript
#
#       DatabaseHaveWorkedWith          DatabaseWantToWorkWith  \
# 503       MariaDB;PostgreSQL        MariaDB;PostgreSQL;Redis
# 2746                     NaN                             NaN
# 4033                     NaN                             NaN
# 8433                     NaN                             NaN
# 18022                    NaN                             NaN
# 19666                  MySQL                           MySQL
# 23070                MongoDB                             NaN
# 24391                MariaDB              MariaDB;PostgreSQL
# 41991                    NaN                             NaN
# 51907  MariaDB;MongoDB;Redis  Elasticsearch;PostgreSQL;Redis
# 54100                    NaN                             NaN
# 54537      PostgreSQL;SQLite                      PostgreSQL
# 55187                    NaN                             NaN
# 56851                    NaN                             NaN
# 58643                    NaN                             NaN
# 63396                  MySQL                             NaN
# 63685                    NaN                             NaN
# 66698                    NaN                             NaN
# 66947      PostgreSQL;SQLite               PostgreSQL;SQLite
# 69700                    NaN                             NaN
# 73557                    NaN                             NaN
# 76104          MariaDB;MySQL                             NaN
# 79253                    NaN                             NaN
# 82733                    NaN                             NaN
#
#       PlatformHaveWorkedWith     PlatformWantToWorkWith  \
# 503                      AWS                        AWS
# 2746                     NaN                        NaN
# 4033   Google Cloud Platform      Google Cloud Platform
# 8433                     NaN                        NaN
# 18022  Google Cloud Platform                        NaN
# 19666                    AWS      Google Cloud Platform
# 23070  Google Cloud Platform    AWS;IBM Cloud or Watson
# 24391                    AWS                        AWS
# 41991                    AWS                        AWS
# 51907  Google Cloud Platform  AWS;Google Cloud Platform
# 54100                    NaN                        NaN
# 54537                    AWS                        AWS
# 55187                    NaN                        NaN
# 56851                    NaN                        NaN
# 58643                    NaN                        NaN
# 63396  Google Cloud Platform                        NaN
# 63685                    NaN                        NaN
# 66698                    NaN                        NaN
# 66947                    NaN                        NaN
# 69700                    NaN                        NaN
# 73557                    NaN                        NaN
# 76104                    NaN                        NaN
# 79253                    AWS                        NaN
# 82733                    NaN                        NaN
#
#        WebframeHaveWorkedWith WebframeWantToWorkWith  \
# 503                       NaN                    NaN
# 2746                      NaN                    NaN
# 4033                      NaN                    NaN
# 8433                      NaN                    NaN
# 18022                     NaN                    NaN
# 19666                   Flask  Django;Flask;React.js
# 23070                   Flask                    NaN
# 24391  Django;React.js;Svelte        Django;React.js
# 41991                     NaN                    NaN
# 51907                  Django                  Flask
# 54100                     NaN                    NaN
# 54537         Django;React.js        Django;React.js
# 55187                     NaN                    NaN
# 56851                  Django                 Django
# 58643                     NaN                    NaN
# 63396                   Flask                    NaN
# 63685                     NaN                    NaN
# 66698                     NaN                    NaN
# 66947           FastAPI;Flask                FastAPI
# 69700                     NaN                    NaN
# 73557                     NaN                    NaN
# 76104                     NaN                    NaN
# 79253                     NaN                    NaN
# 82733                     NaN                    NaN
#
#                      MiscTechHaveWorkedWith  \
# 503                            NumPy;Pandas
# 2746                                    NaN
# 4033                                    NaN
# 8433                                    NaN
# 18022                                 NumPy
# 19666                                   NaN
# 23070  Keras;NumPy;TensorFlow;Torch/PyTorch
# 24391                                 NumPy
# 41991            NumPy;Pandas;Torch/PyTorch
# 51907                          NumPy;Pandas
# 54100                          NumPy;Pandas
# 54537                          NumPy;Pandas
# 55187                                 NumPy
# 56851                                 NumPy
# 58643                                   NaN
# 63396                          NumPy;Pandas
# 63685         Keras;NumPy;Pandas;TensorFlow
# 66698                                   NaN
# 66947                                    Qt
# 69700                                 NumPy
# 73557                                Pandas
# 76104         Keras;NumPy;Pandas;TensorFlow
# 79253                                   NaN
# 82733                                   NaN
#
#                                   MiscTechWantToWorkWith  \
# 503          Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 2746                                                 NaN
# 4033                                                 NaN
# 8433                                                 NaN
# 18022                                       NumPy;Pandas
# 19666                                                NaN
# 23070                                      Torch/PyTorch
# 24391                                NumPy;Torch/PyTorch
# 41991                         NumPy;Pandas;Torch/PyTorch
# 51907                                NumPy;Torch/PyTorch
# 54100                                       NumPy;Pandas
# 54537                                       NumPy;Pandas
# 55187                                                NaN
# 56851                        Flutter;NumPy;Torch/PyTorch
# 58643                                                NaN
# 63396                                                NaN
# 63685                      Keras;NumPy;Pandas;TensorFlow
# 66698                                                NaN
# 66947                                                 Qt
# 69700                  .NET Framework;.NET Core / .NET 5
# 73557                                             Pandas
# 76104  Apache Spark;Keras;NumPy;Pandas;TensorFlow;Tor...
# 79253                                                NaN
# 82733                                                NaN
#
#       ToolsTechHaveWorkedWith       ToolsTechWantToWorkWith  \
# 503                Docker;Git                    Docker;Git
# 2746                      Git                    Docker;Git
# 4033                      Git                  Git;Unity 3D
# 8433                      NaN                           NaN
# 18022                     NaN                           NaN
# 19666              Docker;Git         Docker;Git;Kubernetes
# 23070              Docker;Git                        Docker
# 24391                     Git                           Git
# 41991              Docker;Git          Docker;Git;Terraform
# 51907              Docker;Git  Ansible;Docker;Git;Terraform
# 54100                     Git                    Docker;Git
# 54537              Docker;Git                    Docker;Git
# 55187                     NaN                           NaN
# 56851                     Git                           Git
# 58643                     Git         Docker;Git;Kubernetes
# 63396                     Git                           NaN
# 63685                     Git                           Git
# 66698                     NaN                           NaN
# 66947                     Git                           Git
# 69700                Unity 3D                      Unity 3D
# 73557                     NaN                           NaN
# 76104                     Git                           Git
# 79253                     NaN                           NaN
# 82733                     NaN                           NaN
#
#                     NEWCollabToolsHaveWorkedWith  \
# 503                                  PyCharm;Vim
# 2746                     IPython/Jupyter;PyCharm
# 4033            Visual Studio;Visual Studio Code
# 8433                     Atom;Visual Studio Code
# 18022                         Atom;Notepad++;Vim
# 19666                    IPython/Jupyter;PyCharm
# 23070                    IPython/Jupyter;PyCharm
# 24391                                        Vim
# 41991                                    PyCharm
# 51907                                 Neovim;Vim
# 54100                         Visual Studio Code
# 54537                                PyCharm;Vim
# 55187                         Visual Studio Code
# 56851                         Visual Studio Code
# 58643  Atom;IntelliJ;IPython/Jupyter;PyCharm;Vim
# 63396     IPython/Jupyter;Vim;Visual Studio Code
# 63685                                      Emacs
# 66698                         Visual Studio Code
# 66947                 PyCharm;Visual Studio Code
# 69700  Android Studio;PyCharm;Visual Studio Code
# 73557                                    PyCharm
# 76104                         Visual Studio Code
# 79253                              Visual Studio
# 82733                    Notepad++;Visual Studio
#
#            NEWCollabToolsWantToWorkWith        OpSys  \
# 503                         PyCharm;Vim  Linux-based
# 2746            IPython/Jupyter;PyCharm  Linux-based
# 4033   Visual Studio;Visual Studio Code      Windows
# 8433                                NaN      Windows
# 18022                          Atom;Vim  Linux-based
# 19666           IPython/Jupyter;PyCharm  Linux-based
# 23070                   IPython/Jupyter        MacOS
# 24391                               Vim  Linux-based
# 41991                           PyCharm  Linux-based
# 51907                            Neovim  Linux-based
# 54100                Visual Studio Code  Linux-based
# 54537                       PyCharm;Vim  Linux-based
# 55187                Visual Studio Code  Linux-based
# 56851                Visual Studio Code      Windows
# 58643                          Atom;Vim  Linux-based
# 63396                               NaN        MacOS
# 63685                             Emacs  Linux-based
# 66698                Visual Studio Code        MacOS
# 66947        PyCharm;Visual Studio Code      Windows
# 69700                Visual Studio Code      Windows
# 73557                           PyCharm      Windows
# 76104            Vim;Visual Studio Code      Windows
# 79253     Android Studio;Atom;Notepad++      Windows
# 82733                               NaN      Windows
#
#                                                 NEWStuck  \
# 503                       Visit Stack Overflow;Google it
# 2746   Call a coworker or friend;Visit Stack Overflow...
# 4033   Visit Stack Overflow;Go for a walk or other ph...
# 8433   Visit Stack Overflow;Google it;Watch help / tu...
# 18022  Call a coworker or friend;Visit Stack Overflow...
# 19666  Call a coworker or friend;Visit Stack Overflow...
# 23070  Go for a walk or other physical activity;Googl...
# 24391  Call a coworker or friend;Visit Stack Overflow...
# 41991  Call a coworker or friend;Visit Stack Overflow...
# 51907  Call a coworker or friend;Visit Stack Overflow...
# 54100       Call a coworker or friend;Google it;Meditate
# 54537                     Visit Stack Overflow;Google it
# 55187  Visit Stack Overflow;Go for a walk or other ph...
# 56851  Visit Stack Overflow;Go for a walk or other ph...
# 58643  Call a coworker or friend;Visit Stack Overflow...
# 63396  Visit Stack Overflow;Go for a walk or other ph...
# 63685  Call a coworker or friend;Visit Stack Overflow...
# 66698  Visit Stack Overflow;Google it;Watch help / tu...
# 66947  Visit Stack Overflow;Google it;Watch help / tu...
# 69700  Visit Stack Overflow;Google it;Watch help / tu...
# 73557  Call a coworker or friend;Visit Stack Overflow...
# 76104  Call a coworker or friend;Visit Stack Overflow...
# 79253  Call a coworker or friend;Visit Stack Overflow...
# 82733  Visit Stack Overflow;Google it;Watch help / tu...
#
#                           NEWSOSites                      SOVisitFreq  \
# 503    Stack Overflow;Stack Exchange             A few times per week
# 2746   Stack Overflow;Stack Exchange           Multiple times per day
# 4033                  Stack Overflow  A few times per month or weekly
# 8433   Stack Overflow;Stack Exchange  A few times per month or weekly
# 18022  Stack Overflow;Stack Exchange            Daily or almost daily
# 19666                 Stack Overflow             A few times per week
# 23070  Stack Overflow;Stack Exchange            Daily or almost daily
# 24391  Stack Overflow;Stack Exchange             A few times per week
# 41991  Stack Overflow;Stack Exchange             A few times per week
# 51907  Stack Overflow;Stack Exchange            Daily or almost daily
# 54100                 Stack Overflow  A few times per month or weekly
# 54537  Stack Overflow;Stack Exchange            Daily or almost daily
# 55187                 Stack Overflow             A few times per week
# 56851                 Stack Overflow             A few times per week
# 58643  Stack Overflow;Stack Exchange           Multiple times per day
# 63396  Stack Overflow;Stack Exchange            Daily or almost daily
# 63685  Stack Overflow;Stack Exchange  A few times per month or weekly
# 66698                 Stack Overflow  A few times per month or weekly
# 66947  Stack Overflow;Stack Exchange            Daily or almost daily
# 69700                 Stack Overflow  A few times per month or weekly
# 73557                 Stack Overflow             A few times per week
# 76104  Stack Overflow;Stack Exchange             A few times per week
# 79253                 Stack Overflow            Daily or almost daily
# 82733                 Stack Overflow             A few times per week
#
#                      SOAccount  \
# 503                        Yes
# 2746                       Yes
# 4033                       Yes
# 8433                       Yes
# 18022                      Yes
# 19666                      Yes
# 23070                       No
# 24391                      Yes
# 41991                      Yes
# 51907                      Yes
# 54100                      Yes
# 54537                      Yes
# 55187                      Yes
# 56851                      Yes
# 58643                      Yes
# 63396  Not sure/can't remember
# 63685  Not sure/can't remember
# 66698                       No
# 66947                      Yes
# 69700                      Yes
# 73557                      Yes
# 76104  Not sure/can't remember
# 79253                       No
# 82733                      Yes
#
#                                               SOPartFreq           SOComm  \
# 503                  Less than once per month or monthly          Neutral
# 2746                              Multiple times per day  Yes, definitely
# 4033                 Less than once per month or monthly          Neutral
# 8433                     A few times per month or weekly    Yes, somewhat
# 18022                Less than once per month or monthly   No, not really
# 19666  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 23070                                                NaN   No, not at all
# 24391                    A few times per month or weekly   No, not really
# 41991                    A few times per month or weekly    Yes, somewhat
# 51907                    A few times per month or weekly    Yes, somewhat
# 54100                Less than once per month or monthly   No, not really
# 54537                               A few times per week    Yes, somewhat
# 55187  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 56851                Less than once per month or monthly  Yes, definitely
# 58643                Less than once per month or monthly   No, not really
# 63396                                                NaN          Neutral
# 63685                                                NaN   No, not at all
# 66698                                                NaN         Not sure
# 66947                Less than once per month or monthly   No, not really
# 69700  I have never participated in Q&A on Stack Over...   No, not really
# 73557                    A few times per month or weekly    Yes, somewhat
# 76104                                                NaN   No, not really
# 79253                                                NaN   No, not really
# 82733  I have never participated in Q&A on Stack Over...         Not sure
#
#       NEWOtherComms                 Age                      Gender Trans  \
# 503              No     35-44 years old                         Man    No
# 2746             No     25-34 years old                         Man    No
# 4033             No  Under 18 years old                         Man    No
# 8433            Yes  Under 18 years old                         Man    No
# 18022            No     25-34 years old                         Man    No
# 19666            No     25-34 years old                         Man    No
# 23070            No     25-34 years old                       Woman    No
# 24391            No     35-44 years old                         Man    No
# 41991           Yes     25-34 years old                         Man    No
# 51907            No     35-44 years old                         Man    No
# 54100            No     45-54 years old                         Man    No
# 54537            No     35-44 years old                         Man    No
# 55187            No  Under 18 years old                         Man    No
# 56851            No     25-34 years old                         Man    No
# 58643           Yes     35-44 years old                       Woman    No
# 63396           Yes     25-34 years old                       Woman    No
# 63685           Yes     25-34 years old                         Man    No
# 66698            No  Under 18 years old                         Man    No
# 66947            No     35-44 years old                         Man    No
# 69700           Yes  Under 18 years old                         Man    No
# 73557            No     25-34 years old                         Man    No
# 76104            No     18-24 years old                       Woman    No
# 79253            No  Under 18 years old                         Man    No
# 82733           Yes                 NaN  Man;Or, in your own words:    No
#
#                      Sexuality  \
# 503                        NaN
# 2746   Straight / Heterosexual
# 4033   Straight / Heterosexual
# 8433   Straight / Heterosexual
# 18022  Straight / Heterosexual
# 19666  Straight / Heterosexual
# 23070  Straight / Heterosexual
# 24391  Straight / Heterosexual
# 41991  Straight / Heterosexual
# 51907        Prefer not to say
# 54100  Straight / Heterosexual
# 54537  Straight / Heterosexual
# 55187  Straight / Heterosexual
# 56851  Straight / Heterosexual
# 58643  Straight / Heterosexual
# 63396  Straight / Heterosexual
# 63685  Straight / Heterosexual
# 66698           Gay or Lesbian
# 66947  Straight / Heterosexual
# 69700  Straight / Heterosexual
# 73557  Straight / Heterosexual
# 76104  Straight / Heterosexual
# 79253  Straight / Heterosexual
# 82733                 Bisexual
#
#                                                Ethnicity  \
# 503                         White or of European descent
# 2746                        White or of European descent
# 4033   White or of European descent;Hispanic or Latin...
# 8433                        White or of European descent
# 18022                             Hispanic or Latino/a/x
# 19666                       White or of European descent
# 23070                       White or of European descent
# 24391                             Hispanic or Latino/a/x
# 41991                       White or of European descent
# 51907                       White or of European descent
# 54100                       White or of European descent
# 54537                             Hispanic or Latino/a/x
# 55187  White or of European descent;I don't know;Hisp...
# 56851  White or of European descent;Hispanic or Latin...
# 58643                       White or of European descent
# 63396  White or of European descent;Hispanic or Latin...
# 63685                       White or of European descent
# 66698  White or of European descent;Hispanic or Latin...
# 66947                       White or of European descent
# 69700                             Hispanic or Latino/a/x
# 73557                       White or of European descent
# 76104  White or of European descent;I don't know;Hisp...
# 79253                       White or of European descent
# 82733                       White or of European descent
#
#                      Accessibility                MentalHealth  \
# 503              None of the above           None of the above
# 2746             None of the above           None of the above
# 4033             None of the above           None of the above
# 8433             None of the above           None of the above
# 18022            None of the above           None of the above
# 19666            None of the above           None of the above
# 23070            None of the above           None of the above
# 24391            None of the above           None of the above
# 41991            None of the above           None of the above
# 51907            None of the above           Prefer not to say
# 54100            None of the above           None of the above
# 54537            None of the above           None of the above
# 55187            None of the above           None of the above
# 56851            None of the above           None of the above
# 58643            None of the above           None of the above
# 63396            None of the above           None of the above
# 63685            None of the above           None of the above
# 66698            None of the above           None of the above
# 66947            None of the above           None of the above
# 69700  I am deaf / hard of hearing  I have an anxiety disorder
# 73557            None of the above           None of the above
# 76104            None of the above           None of the above
# 79253            None of the above           None of the above
# 82733            None of the above           Prefer not to say
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 503    Appropriate in length                        Easy              64859.0
# 2746   Appropriate in length                        Easy              15564.0
# 4033   Appropriate in length                        Easy                  NaN
# 8433   Appropriate in length                        Easy                  NaN
# 18022  Appropriate in length                        Easy              37834.0
# 19666  Appropriate in length                        Easy              33510.0
# 23070  Appropriate in length                        Easy              22056.0
# 24391  Appropriate in length                        Easy              92964.0
# 41991  Appropriate in length                        Easy              37834.0
# 51907  Appropriate in length                        Easy              48644.0
# 54100  Appropriate in length                        Easy              38916.0
# 54537  Appropriate in length                        Easy              42156.0
# 55187  Appropriate in length  Neither easy nor difficult                  NaN
# 56851  Appropriate in length                        Easy              11676.0
# 58643               Too long                        Easy                  NaN
# 63396  Appropriate in length                        Easy              27025.0
# 63685  Appropriate in length                        Easy                  NaN
# 66698  Appropriate in length                        Easy                  NaN
# 66947  Appropriate in length                        Easy              37834.0
# 69700  Appropriate in length  Neither easy nor difficult                  NaN
# 73557  Appropriate in length                        Easy              37294.0
# 76104  Appropriate in length  Neither easy nor difficult              26030.0
# 79253  Appropriate in length  Neither easy nor difficult                  NaN
# 82733               Too long                        Easy                  NaN

# %%
filtrar_paises = (datos['Country'] == 'Spain') | (datos['Country'] == 'France')

# %%
datos.loc[filtrar_paises]
# Negación
# datos.loc[~filtrar_paises]
# Out:
#        ResponseId                                         MainBranch  \
# 11             12                     I am a developer by profession
# 23             24                     I am a developer by profession
# 41             42  I am not primarily a developer, but I write co...
# 44             45                     I am a developer by profession
# 68             69                     I am a developer by profession
# ...           ...                                                ...
# 83313       83314                     I am a developer by profession
# 83326       83327             I am a student who is learning to code
# 83333       83334                     I am a developer by profession
# 83344       83345                     I am a developer by profession
# 83420       83421                     I am a developer by profession
#
#                                               Employment Country US_State  \
# 11                                    Employed full-time   Spain      NaN
# 23                                    Employed full-time  France      NaN
# 41                                    Employed full-time  France      NaN
# 44                                    Employed full-time  France      NaN
# 68                                    Employed full-time   Spain      NaN
# ...                                                  ...     ...      ...
# 83313  Independent contractor, freelancer, or self-em...   Spain      NaN
# 83326                                 Student, full-time  France      NaN
# 83333                                 Employed full-time  France      NaN
# 83344                                 Employed full-time  France      NaN
# 83420                                 Employed full-time  France      NaN
#
#       UK_Country                                          EdLevel  \
# 11           NaN     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 23           NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 41           NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 44           NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 68           NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                              ...
# 83313        NaN               Professional degree (JD, MD, etc.)
# 83326        NaN                                   Something else
# 83333        NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 83344        NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 83420        NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#           Age1stCode                                          LearnCode  \
# 11     11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 23     11 - 17 years             School;Online Courses or Certification
# 41     11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 44     18 - 24 years                                             School
# 68     11 - 17 years                                             School
# ...              ...                                                ...
# 83313  11 - 17 years  Coding Bootcamp;Other online resources (ex: vi...
# 83326  11 - 17 years                    Online Courses or Certification
# 83333  18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 83344  18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 83420   5 - 10 years  Other online resources (ex: videos, blogs, etc...
#
#       YearsCode      YearsCodePro  \
# 11           12                 5
# 23            9                 2
# 41            6                 3
# 44            6  Less than 1 year
# 68           20                10
# ...         ...               ...
# 83313        10                 5
# 83326         5               NaN
# 83333         4                 3
# 83344        10                 5
# 83420        16                 4
#
#                                                  DevType  \
# 11                                   Developer, back-end
# 23     Engineer, data;Data scientist or machine learn...
# 41                 Academic researcher;Scientist;Student
# 44                                 Developer, full-stack
# 68                                   Developer, back-end
# ...                                                  ...
# 83313  Developer, front-end;Developer, full-stack;Dev...
# 83326                                                NaN
# 83333                              Developer, full-stack
# 83344                                Developer, back-end
# 83420  Developer, front-end;Developer, desktop or ent...
#
#                         OrgSize           Currency  CompTotal CompFreq  \
# 11           10 to 19 employees  EUR European Euro    43000.0   Yearly
# 23           10 to 19 employees  EUR European Euro    36000.0   Yearly
# 41           20 to 99 employees  EUR European Euro    24000.0   Yearly
# 44           10 to 19 employees  EUR European Euro        NaN      NaN
# 68     10,000 or more employees  EUR European Euro    54000.0   Yearly
# ...                         ...                ...        ...      ...
# 83313          2 to 9 employees  EUR European Euro     2300.0  Monthly
# 83326                       NaN                NaN        NaN      NaN
# 83333      100 to 499 employees  EUR European Euro    50000.0   Yearly
# 83344        20 to 99 employees  EUR European Euro    50000.0   Yearly
# 83420          2 to 9 employees  EUR European Euro    33000.0   Yearly
#
#                                   LanguageHaveWorkedWith  \
# 11     Bash/Shell;HTML/CSS;JavaScript;Node.js;SQL;Typ...
# 23                                     JavaScript;Python
# 41                              Bash/Shell;C#;C++;Python
# 44     HTML/CSS;JavaScript;Node.js;Python;R;SQL;TypeS...
# 68              Bash/Shell;JavaScript;Node.js;TypeScript
# ...                                                  ...
# 83313                             Elixir;JavaScript;Ruby
# 83326                                             Python
# 83333             JavaScript;Node.js;Ruby;SQL;TypeScript
# 83344                                HTML/CSS;Python;SQL
# 83420  Bash/Shell;C#;C++;Go;Groovy;HTML/CSS;Java;Java...
#
#                                   LanguageWantToWorkWith  \
# 11     C++;Clojure;JavaScript;Node.js;Rust;SQL;TypeSc...
# 23                                            Python;SQL
# 41                                            C++;Python
# 44                                                   NaN
# 68                  JavaScript;Node.js;Python;TypeScript
# ...                                                  ...
# 83313                                        Elixir;Ruby
# 83326                         HTML/CSS;JavaScript;Python
# 83333  C#;C++;Crystal;Go;JavaScript;Node.js;Python;Ru...
# 83344                HTML/CSS;Python;Rust;SQL;TypeScript
# 83420  HTML/CSS;Java;JavaScript;Node.js;Python;TypeSc...
#
#                                   DatabaseHaveWorkedWith  \
# 11                                            PostgreSQL
# 23                                                 MySQL
# 41                                                   NaN
# 44                                            PostgreSQL
# 68                                              DynamoDB
# ...                                                  ...
# 83313                          Firebase;PostgreSQL;Redis
# 83326                                 MongoDB;PostgreSQL
# 83333                                        MySQL;Redis
# 83344                                            MariaDB
# 83420  Elasticsearch;Firebase;IBM DB2;MariaDB;Microso...
#
#                               DatabaseWantToWorkWith  \
# 11                          MongoDB;PostgreSQL;Redis
# 23            Elasticsearch;MongoDB;MySQL;PostgreSQL
# 41                                               NaN
# 44                                               NaN
# 68                                 DynamoDB;Firebase
# ...                                              ...
# 83313                      Firebase;PostgreSQL;Redis
# 83326                                        MongoDB
# 83333  Elasticsearch;Firebase;MySQL;PostgreSQL;Redis
# 83344                                        MariaDB
# 83420                    Elasticsearch;MongoDB;Redis
#
#                        PlatformHaveWorkedWith  \
# 11                                        AWS
# 23                                        NaN
# 41                                        NaN
# 44                      Google Cloud Platform
# 68                                        AWS
# ...                                       ...
# 83313  AWS;DigitalOcean;Google Cloud Platform
# 83326                  Heroku;Microsoft Azure
# 83333                                  Heroku
# 83344                                     NaN
# 83420                                     NaN
#
#                               PlatformWantToWorkWith  \
# 11                                               NaN
# 23                                               NaN
# 41                                               NaN
# 44                                               NaN
# 68                               AWS;Microsoft Azure
# ...                                              ...
# 83313         AWS;DigitalOcean;Google Cloud Platform
# 83326                                            NaN
# 83333  AWS;DigitalOcean;Google Cloud Platform;Heroku
# 83344                                            NaN
# 83420                                            NaN
#
#                                   WebframeHaveWorkedWith  \
# 11                               Express;React.js;Vue.js
# 23                                                   NaN
# 41                                                   NaN
# 44                                   Django;Flask;Vue.js
# 68                                                   NaN
# ...                                                  ...
# 83313                               jQuery;Ruby on Rails
# 83326                              Django;Flask;React.js
# 83333                             React.js;Ruby on Rails
# 83344                                 Angular.js;FastAPI
# 83420  Angular;ASP.NET;ASP.NET Core ;Express;React.js...
#
#                                   WebframeWantToWorkWith  \
# 11                                        Express;Vue.js
# 23                                                   NaN
# 41                                                   NaN
# 44                                                   NaN
# 68                                                   NaN
# ...                                                  ...
# 83313                        Django;Ruby on Rails;Vue.js
# 83326                                     Flask;React.js
# 83333  ASP.NET;ASP.NET Core ;Django;Express;FastAPI;F...
# 83344                    Angular;FastAPI;React.js;Vue.js
# 83420                     Express;React.js;Spring;Vue.js
#
#                                   MiscTechHaveWorkedWith  \
# 11                                                   NaN
# 23     Apache Spark;Keras;NumPy;Pandas;TensorFlow;Tor...
# 41     .NET Framework;.NET Core / .NET 5;NumPy;Pandas;Qt
# 44                                      NumPy;TensorFlow
# 68                                                   NaN
# ...                                                  ...
# 83313                                                NaN
# 83326        Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83333                                                NaN
# 83344                                                NaN
# 83420     .NET Framework;.NET Core / .NET 5;Apache Spark
#
#                                   MiscTechWantToWorkWith  \
# 11                                                   NaN
# 23     Apache Spark;Keras;NumPy;Pandas;TensorFlow;Tor...
# 41     .NET Framework;.NET Core / .NET 5;NumPy;Pandas;Qt
# 44                                                   NaN
# 68                                                   NaN
# ...                                                  ...
# 83313                                                NaN
# 83326        Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83333                                                NaN
# 83344                                                NaN
# 83420              Apache Spark;TensorFlow;Torch/PyTorch
#
#                                  ToolsTechHaveWorkedWith  \
# 11                                                   Git
# 23                                            Docker;Git
# 41                                                   Git
# 44                                 Docker;Git;Kubernetes
# 68                                             Terraform
# ...                                                  ...
# 83313                            Ansible;Docker;Git;Yarn
# 83326                                                Git
# 83333                                                Git
# 83344                                         Docker;Git
# 83420  Ansible;Deno;Docker;Git;Kubernetes;Puppet;Terr...
#
#                                  ToolsTechWantToWorkWith  \
# 11                                                   Git
# 23                                 Docker;Git;Kubernetes
# 41                                                   Git
# 44                                                   NaN
# 68                                             Terraform
# ...                                                  ...
# 83313                 Ansible;Docker;Git;Kubernetes;Yarn
# 83326                                                Git
# 83333                                      Chef;Deno;Git
# 83344                                         Docker;Git
# 83420  Deno;Docker;Git;Kubernetes;Unity 3D;Unreal Eng...
#
#                             NEWCollabToolsHaveWorkedWith  \
# 11                                                  Atom
# 23                                    Visual Studio Code
# 41     IPython/Jupyter;Notepad++;Visual Studio;Visual...
# 44                                         Visual Studio
# 68                      Notepad++;Vim;Visual Studio Code
# ...                                                  ...
# 83313                        RubyMine;Visual Studio Code
# 83326                 IPython/Jupyter;Visual Studio Code
# 83333                                 Visual Studio Code
# 83344                                            PyCharm
# 83420  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
#
#                             NEWCollabToolsWantToWorkWith  \
# 11                                                  Atom
# 23                                    Visual Studio Code
# 41                    IPython/Jupyter;Visual Studio Code
# 44                                                   NaN
# 68                                Vim;Visual Studio Code
# ...                                                  ...
# 83313                                 Visual Studio Code
# 83326                 IPython/Jupyter;Visual Studio Code
# 83333     PyCharm;Visual Studio;Visual Studio Code;Xcode
# 83344                         PyCharm;Visual Studio Code
# 83420  IntelliJ;IPython/Jupyter;Visual Studio Code;We...
#
#                                    OpSys  \
# 11                           Linux-based
# 23                           Linux-based
# 41                               Windows
# 44                           Linux-based
# 68                               Windows
# ...                                  ...
# 83313                              MacOS
# 83326  Windows Subsystem for Linux (WSL)
# 83333                              MacOS
# 83344                        Linux-based
# 83420                            Windows
#
#                                                 NEWStuck  \
# 11     Call a coworker or friend;Visit Stack Overflow...
# 23                        Visit Stack Overflow;Google it
# 41     Visit Stack Overflow;Google it;Watch help / tu...
# 44                   Call a coworker or friend;Google it
# 68     Call a coworker or friend;Visit Stack Overflow...
# ...                                                  ...
# 83313                     Visit Stack Overflow;Google it
# 83326  Visit Stack Overflow;Google it;Do other work a...
# 83333                                          Google it
# 83344  Visit Stack Overflow;Google it;Do other work a...
# 83420                     Visit Stack Overflow;Google it
#
#                           NEWSOSites             SOVisitFreq  \
# 11     Stack Overflow;Stack Exchange   Daily or almost daily
# 23     Stack Overflow;Stack Exchange    A few times per week
# 41     Stack Overflow;Stack Exchange   Daily or almost daily
# 44                    Stack Overflow    A few times per week
# 68     Stack Overflow;Stack Exchange   Daily or almost daily
# ...                              ...                     ...
# 83313  Stack Overflow;Stack Exchange  Multiple times per day
# 83326  Stack Overflow;Stack Exchange   Daily or almost daily
# 83333  Stack Overflow;Stack Exchange   Daily or almost daily
# 83344  Stack Overflow;Stack Exchange   Daily or almost daily
# 83420                 Stack Overflow   Daily or almost daily
#
#                      SOAccount  \
# 11                         Yes
# 23                         Yes
# 41                         Yes
# 44                          No
# 68                         Yes
# ...                        ...
# 83313                      Yes
# 83326                      Yes
# 83333  Not sure/can't remember
# 83344                      Yes
# 83420                      Yes
#
#                                               SOPartFreq          SOComm  \
# 11                   Less than once per month or monthly   Yes, somewhat
# 23                   Less than once per month or monthly   Yes, somewhat
# 41                                  A few times per week   Yes, somewhat
# 44                                                   NaN         Neutral
# 68                                  A few times per week   Yes, somewhat
# ...                                                  ...             ...
# 83313                Less than once per month or monthly   Yes, somewhat
# 83326                               A few times per week   Yes, somewhat
# 83333                                                NaN   Yes, somewhat
# 83344                Less than once per month or monthly  No, not at all
# 83420  I have never participated in Q&A on Stack Over...         Neutral
#
#       NEWOtherComms              Age Gender Trans                Sexuality  \
# 11              Yes  25-34 years old    Man    No  Straight / Heterosexual
# 23               No  25-34 years old    Man    No                      NaN
# 41               No  25-34 years old    Man    No  Straight / Heterosexual
# 44               No  18-24 years old  Woman    No  Straight / Heterosexual
# 68               No  35-44 years old    Man    No  Straight / Heterosexual
# ...             ...              ...    ...   ...                      ...
# 83313            No  25-34 years old    Man    No  Straight / Heterosexual
# 83326            No  18-24 years old    Man    No        Prefer not to say
# 83333           Yes  25-34 years old    Man    No  Straight / Heterosexual
# 83344            No  25-34 years old    Man    No  Straight / Heterosexual
# 83420           Yes  25-34 years old    Man    No  Straight / Heterosexual
#
#                                                Ethnicity      Accessibility  \
# 11     White or of European descent;Hispanic or Latin...  None of the above
# 23                          White or of European descent  None of the above
# 41                                Hispanic or Latino/a/x  None of the above
# 44                          White or of European descent  None of the above
# 68                                                   NaN  None of the above
# ...                                                  ...                ...
# 83313                             Hispanic or Latino/a/x  None of the above
# 83326                                  Prefer not to say  Prefer not to say
# 83333                       White or of European descent  None of the above
# 83344              White or of European descent;Biracial  None of the above
# 83420                       White or of European descent  None of the above
#
#                                             MentalHealth  \
# 11                                     None of the above
# 23                                     None of the above
# 41                                     None of the above
# 44                                     None of the above
# 68                                     None of the above
# ...                                                  ...
# 83313                                  None of the above
# 83326                                  Prefer not to say
# 83333                                  None of the above
# 83344                                  None of the above
# 83420  I have a mood or emotional disorder (e.g. depr...
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 11                  Too long                        Easy              46482.0
# 23     Appropriate in length  Neither easy nor difficult              38915.0
# 41                  Too long                        Easy              25944.0
# 44     Appropriate in length  Neither easy nor difficult                  NaN
# 68     Appropriate in length                        Easy              58373.0
# ...                      ...                         ...                  ...
# 83313  Appropriate in length                        Easy              29832.0
# 83326  Appropriate in length                         NaN                  NaN
# 83333  Appropriate in length  Neither easy nor difficult              54049.0
# 83344  Appropriate in length                        Easy              54049.0
# 83420  Appropriate in length                        Easy              35672.0
#
# [4193 rows x 48 columns]

# %%
salario_alto = datos['ConvertedCompYearly'] > 80000

# %%
datos.loc[salario_alto]
# Out:
#        ResponseId                                         MainBranch  \
# 18             19  I am not primarily a developer, but I write co...
# 26             27  I am not primarily a developer, but I write co...
# 31             32                     I am a developer by profession
# 36             37                     I am a developer by profession
# 37             38                     I am a developer by profession
# ...           ...                                                ...
# 83430       83431                     I am a developer by profession
# 83432       83433                     I am a developer by profession
# 83434       83435                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
#
#                 Employment                   Country              US_State  \
# 18     I prefer not to say                 Singapore                   NaN
# 26      Employed full-time               Switzerland                   NaN
# 31      Employed full-time                    Israel                   NaN
# 36      Employed full-time  United States of America  District of Columbia
# 37      Employed full-time  United States of America         Massachusetts
# ...                    ...                       ...                   ...
# 83430   Employed full-time  United States of America              Illinois
# 83432   Employed full-time                    Canada                   NaN
# 83434   Employed full-time  United States of America                 Texas
# 83436   Employed full-time  United States of America            New Jersey
# 83437   Employed full-time                    Canada                   NaN
#
#       UK_Country                                            EdLevel  \
# 18           NaN         Other doctoral degree (Ph.D., Ed.D., etc.)
# 26           NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 31           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 36           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 37           NaN  Some college/university study without earning ...
# ...          ...                                                ...
# 83430        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 83432        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#           Age1stCode                                          LearnCode  \
# 18     11 - 17 years                            Other (please specify):
# 26     11 - 17 years                            Other (please specify):
# 31     25 - 34 years             School;Online Courses or Certification
# 36     11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 37     18 - 24 years    Other online resources (ex: videos, blogs, etc)
# ...              ...                                                ...
# 83430  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83432  18 - 24 years                                             School
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
#
#       YearsCode      YearsCodePro  \
# 18           40                30
# 26           14                 5
# 31            4                 2
# 36            8  Less than 1 year
# 37           20                15
# ...         ...               ...
# 83430        23                21
# 83432         5  Less than 1 year
# 83434         6                 5
# 83436        10                 4
# 83437         5                 3
#
#                                                  DevType  \
# 18                                                   NaN
# 26                 Academic researcher;Scientist;Student
# 31                    Engineer, data;Developer, back-end
# 36           Developer, embedded applications or devices
# 37                                   Developer, back-end
# ...                                                  ...
# 83430  Developer, front-end;Developer, full-stack;Dev...
# 83432                                Developer, back-end
# 83434                                Developer, back-end
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
#
#                         OrgSize                   Currency  CompTotal  \
# 18     5,000 to 9,999 employees      SGD\tSingapore dollar    18700.0
# 26     5,000 to 9,999 employees           CHF\tSwiss franc    80000.0
# 31     5,000 to 9,999 employees    ILS\tIsraeli new shekel    35000.0
# 36           20 to 99 employees  USD\tUnited States dollar   103000.0
# 37     1,000 to 4,999 employees  USD\tUnited States dollar   300000.0
# ...                         ...                        ...        ...
# 83430        10 to 19 employees  USD\tUnited States dollar   125000.0
# 83432  10,000 or more employees       CAD\tCanadian dollar   106000.0
# 83434        20 to 99 employees  USD\tUnited States dollar   160500.0
# 83436  10,000 or more employees  USD\tUnited States dollar     1800.0
# 83437        20 to 99 employees       CAD\tCanadian dollar    90000.0
#
#       CompFreq                       LanguageHaveWorkedWith  \
# 18     Monthly                                   C++;Python
# 26      Yearly                                   C++;Python
# 31     Monthly  Bash/Shell;Go;Java;Node.js;Python;Scala;SQL
# 36      Yearly                  Assembly;C;Java;Kotlin;Rust
# 37      Yearly                                           Go
# ...        ...                                          ...
# 83430   Yearly  APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83432   Yearly                                         Ruby
# 83434   Yearly                           Clojure;Kotlin;SQL
# 83436   Weekly                           Groovy;Java;Python
# 83437  Monthly         Bash/Shell;JavaScript;Node.js;Python
#
#                  LanguageWantToWorkWith  \
# 18                           C++;Python
# 26                   C++;Go;Java;Python
# 31     Bash/Shell;Java;Python;Scala;SQL
# 36             Assembly;Kotlin;Rust;SQL
# 37                              Go;Rust
# ...                                 ...
# 83430        APL;Clojure;Haskell;LISP;R
# 83432              Java;Ruby;TypeScript
# 83434                           Clojure
# 83436                       Java;Python
# 83437                           Go;Rust
#
#                                  DatabaseHaveWorkedWith  \
# 18                                                  NaN
# 26                                                  NaN
# 31                    DynamoDB;MongoDB;MySQL;PostgreSQL
# 36                                                  NaN
# 37                                                  NaN
# ...                                                 ...
# 83430                    MongoDB;MySQL;PostgreSQL;Redis
# 83432                                  MySQL;PostgreSQL
# 83434                                     Oracle;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
#
#                          DatabaseWantToWorkWith  \
# 18                                          NaN
# 26                                          NaN
# 31     Cassandra;MongoDB;MySQL;PostgreSQL;Redis
# 36                                          NaN
# 37                                          NaN
# ...                                         ...
# 83430                                PostgreSQL
# 83432                                       NaN
# 83434                                    SQLite
# 83436                            DynamoDB;Redis
# 83437                                       NaN
#
#                               PlatformHaveWorkedWith  \
# 18                                               NaN
# 26                                               NaN
# 31         AWS;Google Cloud Platform;Microsoft Azure
# 36                                               NaN
# 37         AWS;Google Cloud Platform;Microsoft Azure
# ...                                              ...
# 83430  AWS;DigitalOcean;Google Cloud Platform;Heroku
# 83432                   Google Cloud Platform;Heroku
# 83434                                            AWS
# 83436                      AWS;Google Cloud Platform
# 83437                                         Heroku
#
#                        PlatformWantToWorkWith  \
# 18                                        NaN
# 26                                        NaN
# 31                  AWS;Google Cloud Platform
# 36                                        NaN
# 37                                        NaN
# ...                                       ...
# 83430  AWS;DigitalOcean;Google Cloud Platform
# 83432                                     NaN
# 83434                                     AWS
# 83436                                     AWS
# 83437                        AWS;DigitalOcean
#
#                     WebframeHaveWorkedWith WebframeWantToWorkWith  \
# 18                                     NaN                    NaN
# 26                                     NaN                    NaN
# 31                                     NaN                    NaN
# 36                                     NaN                    NaN
# 37                                     NaN                    NaN
# ...                                    ...                    ...
# 83430        Django;React.js;Ruby on Rails                    NaN
# 83432  Flask;React.js;Ruby on Rails;Vue.js                    NaN
# 83434                                  NaN                    NaN
# 83436                        FastAPI;Flask          FastAPI;Flask
# 83437        Django;Express;Flask;React.js                    NaN
#
#                       MiscTechHaveWorkedWith  \
# 18                NumPy;Pandas;Torch/PyTorch
# 26                              NumPy;Pandas
# 31                 Apache Spark;NumPy;Pandas
# 36                                       NaN
# 37                                       NaN
# ...                                      ...
# 83430                                    NaN
# 83432  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83434                                    NaN
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
#
#                                   MiscTechWantToWorkWith  \
# 18                            NumPy;Pandas;Torch/PyTorch
# 26                                                   NaN
# 31                                          Apache Spark
# 36                                                   NaN
# 37                                                   NaN
# ...                                                  ...
# 83430                                                NaN
# 83432                                                NaN
# 83434                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
#
#                ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 18                                 NaN                              NaN
# 26                          Docker;Git                       Docker;Git
# 31     Docker;Git;Kubernetes;Terraform            Docker;Git;Kubernetes
# 36                          Docker;Git                              Git
# 37                Docker;Git;Terraform                    Git;Terraform
# ...                                ...                              ...
# 83430                       Docker;Git   Docker;Git;Kubernetes;Unity 3D
# 83432       Docker;Git;Kubernetes;Yarn                              NaN
# 83434                       Docker;Git                   Git;Kubernetes
# 83436     Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437     Ansible;Docker;Git;Terraform             Kubernetes;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 18                                   IPython/Jupyter;Vim
# 26                              IntelliJ;IPython/Jupyter
# 31     Atom;IntelliJ;IPython/Jupyter;PyCharm;Sublime ...
# 36                             IntelliJ;PyCharm;Webstorm
# 37                                Vim;Visual Studio Code
# ...                                                  ...
# 83430                                          Emacs;Vim
# 83432        Atom;IPython/Jupyter;Vim;Visual Studio Code
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 18                                   IPython/Jupyter;Vim  Linux-based
# 26                              IntelliJ;IPython/Jupyter  Linux-based
# 31                           IntelliJ;Visual Studio Code        MacOS
# 36     Android Studio;IntelliJ;PyCharm;Sublime Text;W...  Linux-based
# 37                                Vim;Visual Studio Code        MacOS
# ...                                                  ...          ...
# 83430                                              Emacs  Linux-based
# 83432                                                NaN        MacOS
# 83434                                   Sublime Text;Vim        MacOS
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
#
#                                                 NEWStuck  \
# 18                                             Google it
# 26     Visit Stack Overflow;Go for a walk or other ph...
# 31     Call a coworker or friend;Google it;Do other w...
# 36     Visit Stack Overflow;Google it;Do other work a...
# 37     Google it;Do other work and come back later;Me...
# ...                                                  ...
# 83430  Call a coworker or friend;Visit Stack Overflow...
# 83432  Visit Stack Overflow;Go for a walk or other ph...
# 83434                Call a coworker or friend;Google it
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
#
#                           NEWSOSites                      SOVisitFreq  \
# 18     Stack Overflow;Stack Exchange           Multiple times per day
# 26     Stack Overflow;Stack Exchange           Multiple times per day
# 31     Stack Overflow;Stack Exchange             A few times per week
# 36     Stack Overflow;Stack Exchange            Daily or almost daily
# 37     Stack Overflow;Stack Exchange            Daily or almost daily
# ...                              ...                              ...
# 83430  Stack Overflow;Stack Exchange             A few times per week
# 83432  Stack Overflow;Stack Exchange            Daily or almost daily
# 83434  Stack Overflow;Stack Exchange             A few times per week
# 83436  Stack Overflow;Stack Exchange             A few times per week
# 83437                 Stack Overflow  A few times per month or weekly
#
#       SOAccount                                         SOPartFreq  \
# 18          Yes                             Multiple times per day
# 26          Yes  I have never participated in Q&A on Stack Over...
# 31          Yes                    A few times per month or weekly
# 36          Yes                               A few times per week
# 37          Yes                              Daily or almost daily
# ...         ...                                                ...
# 83430        No                                                NaN
# 83432        No                                                NaN
# 83434        No                                                NaN
# 83436       Yes  I have never participated in Q&A on Stack Over...
# 83437       Yes                Less than once per month or monthly
#
#                 SOComm NEWOtherComms              Age Gender Trans  \
# 18       Yes, somewhat            No  45-54 years old    Man    No
# 26             Neutral            No  25-34 years old    Man    No
# 31      No, not really            No  25-34 years old    Man    No
# 36       Yes, somewhat           Yes  18-24 years old    Man    No
# 37     Yes, definitely            No  35-44 years old    Man    No
# ...                ...           ...              ...    ...   ...
# 83430   No, not really            No  45-54 years old    Man    No
# 83432   No, not really            No  18-24 years old  Woman    No
# 83434   No, not at all            No  25-34 years old    Man    No
# 83436   No, not really            No  25-34 years old    Man    No
# 83437   No, not really            No  25-34 years old    Man    No
#
#                      Sexuality                                    Ethnicity  \
# 18     Straight / Heterosexual                 White or of European descent
# 26                         NaN                 White or of European descent
# 31     Straight / Heterosexual  White or of European descent;Middle Eastern
# 36     Straight / Heterosexual                 White or of European descent
# 37     Straight / Heterosexual                 White or of European descent
# ...                        ...                                          ...
# 83430  Straight / Heterosexual                 White or of European descent
# 83432  Straight / Heterosexual                                   East Asian
# 83434  Straight / Heterosexual                 White or of European descent
# 83436                      NaN                 White or of European descent
# 83437  Straight / Heterosexual                 White or of European descent
#
#            Accessibility                                       MentalHealth  \
# 18     None of the above                                  None of the above
# 26     None of the above                                  None of the above
# 31     None of the above  I have a concentration and/or memory disorder ...
# 36     None of the above                                  Prefer not to say
# 37     None of the above  I have a concentration and/or memory disorder ...
# ...                  ...                                                ...
# 83430  None of the above                                  None of the above
# 83432  None of the above                                  None of the above
# 83434  None of the above  I have a concentration and/or memory disorder ...
# 83436  None of the above                                  None of the above
# 83437  None of the above  I have a mood or emotional disorder (e.g. depr...
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 18     Appropriate in length                        Easy             160932.0
# 26     Appropriate in length                        Easy              81319.0
# 31     Appropriate in length                        Easy             122580.0
# 36                 Too short                        Easy             103000.0
# 37     Appropriate in length                        Easy             300000.0
# ...                      ...                         ...                  ...
# 83430  Appropriate in length                        Easy             125000.0
# 83432  Appropriate in length                        Easy              80169.0
# 83434  Appropriate in length                        Easy             160500.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
#
# [15696 rows x 48 columns]

# %%
datos.loc[salario_alto, ['Country', 'LanguageHaveWorkedWith']]
# Out:
#                         Country                       LanguageHaveWorkedWith
# 18                    Singapore                                   C++;Python
# 26                  Switzerland                                   C++;Python
# 31                       Israel  Bash/Shell;Go;Java;Node.js;Python;Scala;SQL
# 36     United States of America                  Assembly;C;Java;Kotlin;Rust
# 37     United States of America                                           Go
# ...                         ...                                          ...
# 83430  United States of America  APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83432                    Canada                                         Ruby
# 83434  United States of America                           Clojure;Kotlin;SQL
# 83436  United States of America                           Groovy;Java;Python
# 83437                    Canada         Bash/Shell;JavaScript;Node.js;Python
#
# [15696 rows x 2 columns]

# %%
salario_eur = (datos['ConvertedCompYearly'] > 80000) & (datos['Currency'] == 'EUR European Euro')

# %%
datos.loc[salario_eur]
# Out:
#        ResponseId                                         MainBranch  \
# 91             92  I am not primarily a developer, but I write co...
# 96             97                     I am a developer by profession
# 100           101                     I am a developer by profession
# 131           132                     I am a developer by profession
# 145           146                     I am a developer by profession
# ...           ...                                                ...
# 83266       83267                     I am a developer by profession
# 83296       83297                     I am a developer by profession
# 83409       83410                     I am a developer by profession
# 83419       83420                     I am a developer by profession
# 83424       83425                     I am a developer by profession
#
#                                               Employment      Country  \
# 91                                    Employed full-time  Netherlands
# 96                                    Employed full-time      Germany
# 100    Independent contractor, freelancer, or self-em...       France
# 131                                   Employed full-time      Germany
# 145                                   Employed full-time      Germany
# ...                                                  ...          ...
# 83266                                 Employed full-time  Netherlands
# 83296                                 Employed full-time       France
# 83409                                 Employed full-time  Netherlands
# 83419                                 Employed full-time      Austria
# 83424                                 Employed full-time      Germany
#
#       US_State UK_Country                                          EdLevel  \
# 91         NaN        NaN                        Primary/elementary school
# 96         NaN        NaN     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 100        NaN        NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 131        NaN        NaN                                   Something else
# 145        NaN        NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...        ...        ...                                              ...
# 83266      NaN        NaN       Other doctoral degree (Ph.D., Ed.D., etc.)
# 83296      NaN        NaN                                              NaN
# 83409      NaN        NaN       Other doctoral degree (Ph.D., Ed.D., etc.)
# 83419      NaN        NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 83424      NaN        NaN     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#           Age1stCode                                          LearnCode  \
# 91     11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 96     11 - 17 years                            Other (please specify):
# 100    11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 131    25 - 34 years                            Other (please specify):
# 145     5 - 10 years  Other online resources (ex: videos, blogs, etc...
# ...              ...                                                ...
# 83266  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83296  11 - 17 years                             Books / Physical media
# 83409  18 - 24 years                                             School
# 83419   5 - 10 years  Other online resources (ex: videos, blogs, etc...
# 83424  11 - 17 years  Other online resources (ex: videos, blogs, etc...
#
#       YearsCode      YearsCodePro  \
# 91           20                10
# 96           10  Less than 1 year
# 100           8                 3
# 131           6                 3
# 145          27                11
# ...         ...               ...
# 83266        26                 9
# 83296        25                20
# 83409        12                 6
# 83419        30                13
# 83424        17                12
#
#                                                  DevType  \
# 91     Other (please specify):;DevOps specialist;Syst...
# 96                                 Developer, full-stack
# 100    Developer, mobile;Developer, front-end;Develop...
# 131    Developer, front-end;Developer, desktop or ent...
# 145    Developer, back-end;DevOps specialist;Engineer...
# ...                                                  ...
# 83266  Developer, full-stack;Engineer, data;Scientist...
# 83296                            Other (please specify):
# 83409  Developer, desktop or enterprise applications;...
# 83419  Developer, front-end;Developer, desktop or ent...
# 83424  Developer, full-stack;Other (please specify):;...
#
#                                                  OrgSize           Currency  \
# 91                              10,000 or more employees  EUR European Euro
# 96                                  100 to 499 employees  EUR European Euro
# 100    Just me - I am a freelancer, sole proprietor, ...  EUR European Euro
# 131                                   20 to 99 employees  EUR European Euro
# 145                                 100 to 499 employees  EUR European Euro
# ...                                                  ...                ...
# 83266                           10,000 or more employees  EUR European Euro
# 83296                           5,000 to 9,999 employees  EUR European Euro
# 83409                           10,000 or more employees  EUR European Euro
# 83419                               100 to 499 employees  EUR European Euro
# 83424                           10,000 or more employees  EUR European Euro
#
#        CompTotal CompFreq                             LanguageHaveWorkedWith  \
# 91      100000.0   Yearly  Bash/Shell;C#;JavaScript;Node.js;PowerShell;Py...
# 96       40000.0  Monthly  Bash/Shell;Clojure;Haskell;Java;JavaScript;Kot...
# 100     140000.0   Yearly                            Dart;JavaScript;Node.js
# 131      46000.0  Monthly                                  C#;PowerShell;SQL
# 145      90000.0   Yearly  Bash/Shell;C;Dart;Go;HTML/CSS;JavaScript;Node....
# ...          ...      ...                                                ...
# 83266    90000.0   Yearly                                  Java;Julia;Python
# 83296    75000.0   Yearly                                                 F#
# 83409    80000.0   Yearly                                Julia;Matlab;Python
# 83419    77000.0   Yearly  Groovy;HTML/CSS;Java;JavaScript;Node.js;PHP;Po...
# 83424   120000.0   Yearly           Bash/Shell;C;Go;Java;JavaScript;Perl;SQL
#
#                                   LanguageWantToWorkWith  \
# 91           C#;C++;F#;PowerShell;Python;Rust;TypeScript
# 96                                               Haskell
# 100                                       C++;Dart;Swift
# 131                  C#;Objective-C;PowerShell;SQL;Swift
# 145                    Go;Kotlin;Node.js;Rust;TypeScript
# ...                                                  ...
# 83266                                         Julia;Rust
# 83296                                            F#;Rust
# 83409                                              Julia
# 83419  HTML/CSS;Java;JavaScript;Kotlin;Node.js;TypeSc...
# 83424                           Bash/Shell;Java;Rust;SQL
#
#                                   DatabaseHaveWorkedWith  \
# 91                                                   NaN
# 96                                             Cassandra
# 100                           Firebase;PostgreSQL;SQLite
# 131                                                  NaN
# 145    DynamoDB;Elasticsearch;MongoDB;MySQL;Redis;SQLite
# ...                                                  ...
# 83266                                                NaN
# 83296                                         PostgreSQL
# 83409                                              MySQL
# 83419  Elasticsearch;MariaDB;MySQL;Oracle;PostgreSQL;...
# 83424                                              MySQL
#
#                                   DatabaseWantToWorkWith  \
# 91                                                   NaN
# 96                                                   NaN
# 100                                      Firebase;SQLite
# 131                                                  NaN
# 145                                        MongoDB;Redis
# ...                                                  ...
# 83266                                                NaN
# 83296                                         PostgreSQL
# 83409                                                NaN
# 83419  Cassandra;Elasticsearch;MariaDB;MySQL;Oracle;P...
# 83424                                         PostgreSQL
#
#                        PlatformHaveWorkedWith  \
# 91                                        NaN
# 96                  AWS;Google Cloud Platform
# 100                     Google Cloud Platform
# 131                                       NaN
# 145                                       AWS
# ...                                       ...
# 83266                         Microsoft Azure
# 83296                                     NaN
# 83409                                     NaN
# 83419                                     AWS
# 83424  AWS;DigitalOcean;Google Cloud Platform
#
#                       PlatformWantToWorkWith  \
# 91                                       NaN
# 96                                       NaN
# 100                AWS;Google Cloud Platform
# 131                                      NaN
# 145                                      NaN
# ...                                      ...
# 83266  Google Cloud Platform;Microsoft Azure
# 83296                                    NaN
# 83409                                    NaN
# 83419                    AWS;Microsoft Azure
# 83424                                    NaN
#
#                       WebframeHaveWorkedWith  \
# 91     ASP.NET;ASP.NET Core ;jQuery;React.js
# 96                                  React.js
# 100                            Django;Vue.js
# 131                                      NaN
# 145                                 React.js
# ...                                      ...
# 83266                                    NaN
# 83296                   ASP.NET Core ;Vue.js
# 83409                                    NaN
# 83419                         Angular;Spring
# 83424               Angular.js;Spring;Vue.js
#
#                               WebframeWantToWorkWith  \
# 91                   Angular.js;ASP.NET Core ;Vue.js
# 96                                               NaN
# 100                                           Vue.js
# 131                                              NaN
# 145                                         React.js
# ...                                              ...
# 83266                                            NaN
# 83296                                  ASP.NET Core
# 83409                                            NaN
# 83419  Angular;Express;React.js;Spring;Svelte;Vue.js
# 83424                                         Spring
#
#                   MiscTechHaveWorkedWith  \
# 91     .NET Framework;.NET Core / .NET 5
# 96                               Flutter
# 100                              Flutter
# 131    .NET Framework;.NET Core / .NET 5
# 145      Flutter;React Native;TensorFlow
# ...                                  ...
# 83266                                NaN
# 83296                 .NET Core / .NET 5
# 83409                                NaN
# 83419                     .NET Framework
# 83424                                NaN
#
#                               MiscTechWantToWorkWith  \
# 91                 .NET Framework;.NET Core / .NET 5
# 96                                               NaN
# 100                 Flutter;TensorFlow;Torch/PyTorch
# 131                .NET Framework;.NET Core / .NET 5
# 145    Apache Spark;Flutter;TensorFlow;Torch/PyTorch
# ...                                              ...
# 83266                                            NaN
# 83296                             .NET Core / .NET 5
# 83409                                            NaN
# 83419                                            NaN
# 83424                                            NaN
#
#                                ToolsTechHaveWorkedWith  \
# 91     Docker;Git;Kubernetes;Puppet;Terraform;Unity 3D
# 96                               Docker;Git;Kubernetes
# 100                                         Docker;Git
# 131                                                NaN
# 145                         Docker;Git;Kubernetes;Yarn
# ...                                                ...
# 83266                                       Docker;Git
# 83296                                       Docker;Git
# 83409                                       Docker;Git
# 83419                  Docker;Git;Kubernetes;Terraform
# 83424                  Docker;Git;Kubernetes;Terraform
#
#                        ToolsTechWantToWorkWith  \
# 91                                  Docker;Git
# 96                                         Git
# 100                       Docker;Git;Terraform
# 131                                        NaN
# 145                             Git;Kubernetes
# ...                                        ...
# 83266                    Docker;Git;Kubernetes
# 83296                        Docker;Git;Pulumi
# 83409                               Docker;Git
# 83419  Ansible;Docker;Git;Kubernetes;Terraform
# 83424                    Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 91                      Visual Studio;Visual Studio Code
# 96                                      Emacs;Neovim;Vim
# 100              Android Studio;Visual Studio Code;Xcode
# 131                              Notepad++;Visual Studio
# 145                  PHPStorm;PyCharm;Visual Studio Code
# ...                                                  ...
# 83266                             Vim;Visual Studio Code
# 83296             Rider;Visual Studio;Visual Studio Code
# 83409       IPython/Jupyter;Notepad++;Visual Studio Code
# 83419  Android Studio;IntelliJ;Notepad++;Visual Studi...
# 83424                                IntelliJ;Neovim;Vim
#
#                             NEWCollabToolsWantToWorkWith  \
# 91                      Visual Studio;Visual Studio Code
# 96                                      Emacs;Neovim;Vim
# 100                                   Visual Studio Code
# 131    Notepad++;Rider;Visual Studio;Visual Studio Co...
# 145                          PHPStorm;Visual Studio Code
# ...                                                  ...
# 83266                             Vim;Visual Studio Code
# 83296             Rider;Visual Studio;Visual Studio Code
# 83409       IPython/Jupyter;Notepad++;Visual Studio Code
# 83419                                 IntelliJ;Notepad++
# 83424                                    IntelliJ;Neovim
#
#                                    OpSys  \
# 91                               Windows
# 96                           Linux-based
# 100                                MacOS
# 131                              Windows
# 145                                MacOS
# ...                                  ...
# 83266                            Windows
# 83296                            Windows
# 83409                            Windows
# 83419  Windows Subsystem for Linux (WSL)
# 83424                              MacOS
#
#                                                 NEWStuck  \
# 91     Visit Stack Overflow;Go for a walk or other ph...
# 96                       Call a coworker or friend;Panic
# 100    Visit Stack Overflow;Go for a walk or other ph...
# 131    Call a coworker or friend;Visit Stack Overflow...
# 145    Call a coworker or friend;Go for a walk or oth...
# ...                                                  ...
# 83266  Go for a walk or other physical activity;Googl...
# 83296  Call a coworker or friend;Visit Stack Overflow...
# 83409  Call a coworker or friend;Go for a walk or oth...
# 83419  Call a coworker or friend;Visit Stack Overflow...
# 83424  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 91                         Stack Overflow;Stack Exchange
# 96                         Stack Overflow;Stack Exchange
# 100                                       Stack Overflow
# 131                        Stack Overflow;Stack Exchange
# 145                        Stack Overflow;Stack Exchange
# ...                                                  ...
# 83266  Stack Overflow;Stack Overflow for Teams (priva...
# 83296                                     Stack Overflow
# 83409                                     Stack Overflow
# 83419                      Stack Overflow;Stack Exchange
# 83424                      Stack Overflow;Stack Exchange
#
#                                SOVisitFreq SOAccount  \
# 91                  Multiple times per day       Yes
# 96                    A few times per week       Yes
# 100                 Multiple times per day       Yes
# 131                 Multiple times per day       Yes
# 145                   A few times per week       Yes
# ...                                    ...       ...
# 83266  Less than once per month or monthly        No
# 83296                Daily or almost daily       Yes
# 83409                 A few times per week        No
# 83419                Daily or almost daily       Yes
# 83424                 A few times per week       Yes
#
#                                 SOPartFreq           SOComm NEWOtherComms  \
# 91                  Multiple times per day    Yes, somewhat           Yes
# 96     Less than once per month or monthly   No, not really           Yes
# 100                  Daily or almost daily  Yes, definitely           Yes
# 131        A few times per month or weekly    Yes, somewhat            No
# 145        A few times per month or weekly    Yes, somewhat           Yes
# ...                                    ...              ...           ...
# 83266                                  NaN   No, not at all           Yes
# 83296                                  NaN          Neutral           Yes
# 83409                                  NaN   No, not really           Yes
# 83419      A few times per month or weekly    Yes, somewhat           Yes
# 83424  Less than once per month or monthly   No, not really            No
#
#                    Age                                             Gender  \
# 91     25-34 years old                                                Man
# 96     18-24 years old  Non-binary, genderqueer, or gender non-conforming
# 100    18-24 years old                                                Man
# 131    25-34 years old                                                Man
# 145    25-34 years old                                                Man
# ...                ...                                                ...
# 83266  35-44 years old                                                Man
# 83296  35-44 years old                                                Man
# 83409  25-34 years old                                                Man
# 83419  35-44 years old                                                Man
# 83424  25-34 years old                                                Man
#
#       Trans                Sexuality  \
# 91       No                 Bisexual
# 96      Yes           Bisexual;Queer
# 100      No  Straight / Heterosexual
# 131      No  Straight / Heterosexual
# 145      No        Prefer not to say
# ...     ...                      ...
# 83266    No  Straight / Heterosexual
# 83296    No  Straight / Heterosexual
# 83409    No  Straight / Heterosexual
# 83419    No  Straight / Heterosexual
# 83424    No  Straight / Heterosexual
#
#                                                Ethnicity      Accessibility  \
# 91                          White or of European descent  None of the above
# 96                          White or of European descent  None of the above
# 100                         White or of European descent  None of the above
# 131                         White or of European descent  None of the above
# 145                         White or of European descent  None of the above
# ...                                                  ...                ...
# 83266  White or of European descent;Hispanic or Latin...  None of the above
# 83296                                        Multiracial  None of the above
# 83409                       White or of European descent  None of the above
# 83419                       White or of European descent  None of the above
# 83424                       White or of European descent  None of the above
#
#                                             MentalHealth  \
# 91     I have a concentration and/or memory disorder ...
# 96     I have a mood or emotional disorder (e.g. depr...
# 100                                    None of the above
# 131                                    None of the above
# 145                                    None of the above
# ...                                                  ...
# 83266                             Or, in your own words:
# 83296                                  None of the above
# 83409                                  None of the above
# 83419                                  None of the above
# 83424                             Or, in your own words:
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 91     Appropriate in length  Neither easy nor difficult             108098.0
# 96     Appropriate in length                        Easy             518868.0
# 100                 Too long                        Easy             151337.0
# 131    Appropriate in length  Neither easy nor difficult             596700.0
# 145    Appropriate in length                        Easy              97288.0
# ...                      ...                         ...                  ...
# 83266  Appropriate in length                        Easy              97288.0
# 83296              Too short                        Easy              81074.0
# 83409  Appropriate in length                        Easy              86478.0
# 83419  Appropriate in length                        Easy              83236.0
# 83424  Appropriate in length                        Easy             129718.0
#
# [2393 rows x 48 columns]

# %%
datos['LanguageHaveWorkedWith']
# Out:
# 0        C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                    JavaScript;Python
# 2                             Assembly;C;Python;R;Rust
# 3                                JavaScript;TypeScript
# 4                       Bash/Shell;HTML/CSS;Python;SQL
#                              ...
# 83434                               Clojure;Kotlin;SQL
# 83435                                              NaN
# 83436                               Groovy;Java;Python
# 83437             Bash/Shell;JavaScript;Node.js;Python
# 83438           Delphi;Elixir;HTML/CSS;Java;JavaScript
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: object

# %%
filtrar_lenguajes = datos['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
datos.loc[filtrar_lenguajes, 'LanguageHaveWorkedWith']
# Out:
# 1                                        JavaScript;Python
# 2                                 Assembly;C;Python;R;Rust
# 4                           Bash/Shell;HTML/CSS;Python;SQL
# 5        C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 9                                               C++;Python
#                                ...
# 83429               HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83430          APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83431    C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83436                                   Groovy;Java;Python
# 83437                 Bash/Shell;JavaScript;Node.js;Python
# Name: LanguageHaveWorkedWith, Length: 39792, dtype: object

# %%
datos.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
# Cambia a mayúsculas las etiquetas de los campos
datos.columns = (x.upper() for x in datos.columns)

# %%
datos
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  COUNTRY    US_STATE  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UK_COUNTRY                                            EDLEVEL  \
# 0            NaN  Secondary school (e.g. American high school, G...
# 1            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3            NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438        NaN                 Professional degree (JD, MD, etc.)
#
#           AGE1STCODE                                          LEARNCODE  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YEARSCODE YEARSCODEPRO  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DEVTYPE  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  ORGSIZE  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           CURRENCY  COMPTOTAL COMPFREQ  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LANGUAGEHAVEWORKEDWITH  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 0                                                  Swift
# 1                                                    NaN
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DATABASEHAVEWORKEDWITH  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DATABASEWANTTOWORKWITH  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PLATFORMHAVEWORKEDWITH PLATFORMWANTTOWORKWITH  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WEBFRAMEHAVEWORKEDWITH  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WEBFRAMEWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MISCTECHHAVEWORKEDWITH  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MISCTECHWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             TOOLSTECHHAVEWORKEDWITH          TOOLSTECHWANTTOWORKWITH  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWSTUCK  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSITES  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVISITFREQ SOACCOUNT  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPARTFREQ           SOCOMM  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOTHERCOMMS              AGE GENDER TRANS                SEXUALITY  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           ETHNICITY                ACCESSIBILITY  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MENTALHEALTH  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SURVEYLENGTH                  SURVEYEASE  CONVERTEDCOMPYEARLY
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]

# %%
datos.columns = datos.columns.str.replace('_', '')
datos
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  COUNTRY     USSTATE  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 0           NaN  Secondary school (e.g. American high school, G...
# 1           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4       England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...         ...                                                ...
# 83434       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436       NaN  Secondary school (e.g. American high school, G...
# 83437       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438       NaN                 Professional degree (JD, MD, etc.)
#
#           AGE1STCODE                                          LEARNCODE  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YEARSCODE YEARSCODEPRO  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DEVTYPE  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  ORGSIZE  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           CURRENCY  COMPTOTAL COMPFREQ  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LANGUAGEHAVEWORKEDWITH  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 0                                                  Swift
# 1                                                    NaN
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DATABASEHAVEWORKEDWITH  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DATABASEWANTTOWORKWITH  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PLATFORMHAVEWORKEDWITH PLATFORMWANTTOWORKWITH  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WEBFRAMEHAVEWORKEDWITH  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WEBFRAMEWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MISCTECHHAVEWORKEDWITH  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MISCTECHWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             TOOLSTECHHAVEWORKEDWITH          TOOLSTECHWANTTOWORKWITH  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWSTUCK  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSITES  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVISITFREQ SOACCOUNT  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPARTFREQ           SOCOMM  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOTHERCOMMS              AGE GENDER TRANS                SEXUALITY  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           ETHNICITY                ACCESSIBILITY  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MENTALHEALTH  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SURVEYLENGTH                  SURVEYEASE  CONVERTEDCOMPYEARLY
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]

# %%
# Cambiar el nombre a un campo
datos.rename(columns={'RESPONSEID':'ID'})
# Para establecerlo
# datos.rename(columns={'RESPONSEID':'ID'}, inplace=True)
# Out:
#           ID                                         MAINBRANCH  \
# 0          1                     I am a developer by profession
# 1          2             I am a student who is learning to code
# 2          3  I am not primarily a developer, but I write co...
# 3          4                     I am a developer by profession
# 4          5                     I am a developer by profession
# ...      ...                                                ...
# 83434  83435                     I am a developer by profession
# 83435  83436                     I am a developer by profession
# 83436  83437                     I am a developer by profession
# 83437  83438                     I am a developer by profession
# 83438  83439                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  COUNTRY     USSTATE  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 0           NaN  Secondary school (e.g. American high school, G...
# 1           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4       England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...         ...                                                ...
# 83434       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436       NaN  Secondary school (e.g. American high school, G...
# 83437       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438       NaN                 Professional degree (JD, MD, etc.)
#
#           AGE1STCODE                                          LEARNCODE  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YEARSCODE YEARSCODEPRO  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DEVTYPE  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  ORGSIZE  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           CURRENCY  COMPTOTAL COMPFREQ  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LANGUAGEHAVEWORKEDWITH  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 0                                                  Swift
# 1                                                    NaN
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DATABASEHAVEWORKEDWITH  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DATABASEWANTTOWORKWITH  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PLATFORMHAVEWORKEDWITH PLATFORMWANTTOWORKWITH  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WEBFRAMEHAVEWORKEDWITH  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WEBFRAMEWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MISCTECHHAVEWORKEDWITH  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MISCTECHWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             TOOLSTECHHAVEWORKEDWITH          TOOLSTECHWANTTOWORKWITH  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWSTUCK  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSITES  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVISITFREQ SOACCOUNT  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPARTFREQ           SOCOMM  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOTHERCOMMS              AGE GENDER TRANS                SEXUALITY  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           ETHNICITY                ACCESSIBILITY  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MENTALHEALTH  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SURVEYLENGTH                  SURVEYEASE  CONVERTEDCOMPYEARLY
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]

# %%
datos.loc[1]
# Out:
# RESPONSEID                                                                      2
# MAINBRANCH                                 I am a student who is learning to code
# EMPLOYMENT                                                     Student, full-time
# COUNTRY                                                               Netherlands
# USSTATE                                                                       NaN
# UKCOUNTRY                                                                     NaN
# EDLEVEL                              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# AGE1STCODE                                                          11 - 17 years
# LEARNCODE                       Other online resources (ex: videos, blogs, etc...
# YEARSCODE                                                                       7
# YEARSCODEPRO                                                                  NaN
# DEVTYPE                                                                       NaN
# ORGSIZE                                                                       NaN
# CURRENCY                                                                      NaN
# COMPTOTAL                                                                     NaN
# COMPFREQ                                                                      NaN
# LANGUAGEHAVEWORKEDWITH                                          JavaScript;Python
# LANGUAGEWANTTOWORKWITH                                                        NaN
# DATABASEHAVEWORKEDWITH                                                 PostgreSQL
# DATABASEWANTTOWORKWITH                                                        NaN
# PLATFORMHAVEWORKEDWITH                                                        NaN
# PLATFORMWANTTOWORKWITH                                                        NaN
# WEBFRAMEHAVEWORKEDWITH                                       Angular;Flask;Vue.js
# WEBFRAMEWANTTOWORKWITH                                                        NaN
# MISCTECHHAVEWORKEDWITH                                                    Cordova
# MISCTECHWANTTOWORKWITH                                                        NaN
# TOOLSTECHHAVEWORKEDWITH                                           Docker;Git;Yarn
# TOOLSTECHWANTTOWORKWITH                                                       Git
# NEWCOLLABTOOLSHAVEWORKEDWITH            Android Studio;IntelliJ;Notepad++;PyCharm
# NEWCOLLABTOOLSWANTTOWORKWITH                                                  NaN
# OPSYS                                                                     Windows
# NEWSTUCK                                           Visit Stack Overflow;Google it
# NEWSOSITES                                                         Stack Overflow
# SOVISITFREQ                                                 Daily or almost daily
# SOACCOUNT                                                                     Yes
# SOPARTFREQ                                                  Daily or almost daily
# SOCOMM                                                            Yes, definitely
# NEWOTHERCOMMS                                                                  No
# AGE                                                               18-24 years old
# GENDER                                                                        Man
# TRANS                                                                          No
# SEXUALITY                                                 Straight / Heterosexual
# ETHNICITY                                            White or of European descent
# ACCESSIBILITY                                                   None of the above
# MENTALHEALTH                                                    None of the above
# SURVEYLENGTH                                                Appropriate in length
# SURVEYEASE                                                                   Easy
# CONVERTEDCOMPYEARLY                                                           NaN
# Name: 1, dtype: object

# %%
# Cambiar un dato a un registro
datos.loc[1, ['COUNTRY', 'LANGUAGEWANTTOWORKWITH']] = ['Spain', 'Python']

# %%
datos.loc[1]
# Out:
# RESPONSEID                                                                      2
# MAINBRANCH                                 I am a student who is learning to code
# EMPLOYMENT                                                     Student, full-time
# COUNTRY                                                                     Spain
# USSTATE                                                                       NaN
# UKCOUNTRY                                                                     NaN
# EDLEVEL                              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# AGE1STCODE                                                          11 - 17 years
# LEARNCODE                       Other online resources (ex: videos, blogs, etc...
# YEARSCODE                                                                       7
# YEARSCODEPRO                                                                  NaN
# DEVTYPE                                                                       NaN
# ORGSIZE                                                                       NaN
# CURRENCY                                                                      NaN
# COMPTOTAL                                                                     NaN
# COMPFREQ                                                                      NaN
# LANGUAGEHAVEWORKEDWITH                                          JavaScript;Python
# LANGUAGEWANTTOWORKWITH                                                     Python
# DATABASEHAVEWORKEDWITH                                                 PostgreSQL
# DATABASEWANTTOWORKWITH                                                        NaN
# PLATFORMHAVEWORKEDWITH                                                        NaN
# PLATFORMWANTTOWORKWITH                                                        NaN
# WEBFRAMEHAVEWORKEDWITH                                       Angular;Flask;Vue.js
# WEBFRAMEWANTTOWORKWITH                                                        NaN
# MISCTECHHAVEWORKEDWITH                                                    Cordova
# MISCTECHWANTTOWORKWITH                                                        NaN
# TOOLSTECHHAVEWORKEDWITH                                           Docker;Git;Yarn
# TOOLSTECHWANTTOWORKWITH                                                       Git
# NEWCOLLABTOOLSHAVEWORKEDWITH            Android Studio;IntelliJ;Notepad++;PyCharm
# NEWCOLLABTOOLSWANTTOWORKWITH                                                  NaN
# OPSYS                                                                     Windows
# NEWSTUCK                                           Visit Stack Overflow;Google it
# NEWSOSITES                                                         Stack Overflow
# SOVISITFREQ                                                 Daily or almost daily
# SOACCOUNT                                                                     Yes
# SOPARTFREQ                                                  Daily or almost daily
# SOCOMM                                                            Yes, definitely
# NEWOTHERCOMMS                                                                  No
# AGE                                                               18-24 years old
# GENDER                                                                        Man
# TRANS                                                                          No
# SEXUALITY                                                 Straight / Heterosexual
# ETHNICITY                                            White or of European descent
# ACCESSIBILITY                                                   None of the above
# MENTALHEALTH                                                    None of the above
# SURVEYLENGTH                                                Appropriate in length
# SURVEYEASE                                                                   Easy
# CONVERTEDCOMPYEARLY                                                           NaN
# Name: 1, dtype: object

# %%
datos.loc[1, 'COUNTRY'] = 'Netherlands'
datos.at[1, 'COUNTRY'] = 'Netherlands' # Idéntico resultado a datos.loc

# %%
filtro_modificar_pais = (datos['COUNTRY'] == 'Spain')
datos.loc[filtro_modificar_pais, 'COUNTRY'] = 'España'

# %%
datos[filtrar_paises]
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 11             12                     I am a developer by profession
# 23             24                     I am a developer by profession
# 41             42  I am not primarily a developer, but I write co...
# 44             45                     I am a developer by profession
# 68             69                     I am a developer by profession
# ...           ...                                                ...
# 83313       83314                     I am a developer by profession
# 83326       83327             I am a student who is learning to code
# 83333       83334                     I am a developer by profession
# 83344       83345                     I am a developer by profession
# 83420       83421                     I am a developer by profession
#
#                                               EMPLOYMENT COUNTRY USSTATE  \
# 11                                    Employed full-time  ESPAÑA     NaN
# 23                                    Employed full-time  FRANCE     NaN
# 41                                    Employed full-time  FRANCE     NaN
# 44                                    Employed full-time  FRANCE     NaN
# 68                                    Employed full-time  ESPAÑA     NaN
# ...                                                  ...     ...     ...
# 83313  Independent contractor, freelancer, or self-em...  ESPAÑA     NaN
# 83326                                 Student, full-time  FRANCE     NaN
# 83333                                 Employed full-time  FRANCE     NaN
# 83344                                 Employed full-time  FRANCE     NaN
# 83420                                 Employed full-time  FRANCE     NaN
#
#       UKCOUNTRY                                          EDLEVEL  \
# 11          NaN     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 23          NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 41          NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 44          NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 68          NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...         ...                                              ...
# 83313       NaN               Professional degree (JD, MD, etc.)
# 83326       NaN                                   Something else
# 83333       NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 83344       NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 83420       NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#           AGE1STCODE                                          LEARNCODE  \
# 11     11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 23     11 - 17 years             School;Online Courses or Certification
# 41     11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 44     18 - 24 years                                             School
# 68     11 - 17 years                                             School
# ...              ...                                                ...
# 83313  11 - 17 years  Coding Bootcamp;Other online resources (ex: vi...
# 83326  11 - 17 years                    Online Courses or Certification
# 83333  18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 83344  18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 83420   5 - 10 years  Other online resources (ex: videos, blogs, etc...
#
#       YEARSCODE      YEARSCODEPRO  \
# 11           12                 5
# 23            9                 2
# 41            6                 3
# 44            6  Less than 1 year
# 68           20                10
# ...         ...               ...
# 83313        10                 5
# 83326         5               NaN
# 83333         4                 3
# 83344        10                 5
# 83420        16                 4
#
#                                                  DEVTYPE  \
# 11                                   Developer, back-end
# 23     Engineer, data;Data scientist or machine learn...
# 41                 Academic researcher;Scientist;Student
# 44                                 Developer, full-stack
# 68                                   Developer, back-end
# ...                                                  ...
# 83313  Developer, front-end;Developer, full-stack;Dev...
# 83326                                                NaN
# 83333                              Developer, full-stack
# 83344                                Developer, back-end
# 83420  Developer, front-end;Developer, desktop or ent...
#
#                         ORGSIZE           CURRENCY  COMPTOTAL COMPFREQ  \
# 11           10 to 19 employees  EUR European Euro    43000.0   Yearly
# 23           10 to 19 employees  EUR European Euro    36000.0   Yearly
# 41           20 to 99 employees  EUR European Euro    24000.0   Yearly
# 44           10 to 19 employees  EUR European Euro        NaN      NaN
# 68     10,000 or more employees  EUR European Euro    54000.0   Yearly
# ...                         ...                ...        ...      ...
# 83313          2 to 9 employees  EUR European Euro     2300.0  Monthly
# 83326                       NaN                NaN        NaN      NaN
# 83333      100 to 499 employees  EUR European Euro    50000.0   Yearly
# 83344        20 to 99 employees  EUR European Euro    50000.0   Yearly
# 83420          2 to 9 employees  EUR European Euro    33000.0   Yearly
#
#                                   LANGUAGEHAVEWORKEDWITH  \
# 11     Bash/Shell;HTML/CSS;JavaScript;Node.js;SQL;Typ...
# 23                                     JavaScript;Python
# 41                              Bash/Shell;C#;C++;Python
# 44     HTML/CSS;JavaScript;Node.js;Python;R;SQL;TypeS...
# 68              Bash/Shell;JavaScript;Node.js;TypeScript
# ...                                                  ...
# 83313                             Elixir;JavaScript;Ruby
# 83326                                             Python
# 83333             JavaScript;Node.js;Ruby;SQL;TypeScript
# 83344                                HTML/CSS;Python;SQL
# 83420  Bash/Shell;C#;C++;Go;Groovy;HTML/CSS;Java;Java...
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 11     C++;Clojure;JavaScript;Node.js;Rust;SQL;TypeSc...
# 23                                            Python;SQL
# 41                                            C++;Python
# 44                                                   NaN
# 68                  JavaScript;Node.js;Python;TypeScript
# ...                                                  ...
# 83313                                        Elixir;Ruby
# 83326                         HTML/CSS;JavaScript;Python
# 83333  C#;C++;Crystal;Go;JavaScript;Node.js;Python;Ru...
# 83344                HTML/CSS;Python;Rust;SQL;TypeScript
# 83420  HTML/CSS;Java;JavaScript;Node.js;Python;TypeSc...
#
#                                   DATABASEHAVEWORKEDWITH  \
# 11                                            PostgreSQL
# 23                                                 MySQL
# 41                                                   NaN
# 44                                            PostgreSQL
# 68                                              DynamoDB
# ...                                                  ...
# 83313                          Firebase;PostgreSQL;Redis
# 83326                                 MongoDB;PostgreSQL
# 83333                                        MySQL;Redis
# 83344                                            MariaDB
# 83420  Elasticsearch;Firebase;IBM DB2;MariaDB;Microso...
#
#                               DATABASEWANTTOWORKWITH  \
# 11                          MongoDB;PostgreSQL;Redis
# 23            Elasticsearch;MongoDB;MySQL;PostgreSQL
# 41                                               NaN
# 44                                               NaN
# 68                                 DynamoDB;Firebase
# ...                                              ...
# 83313                      Firebase;PostgreSQL;Redis
# 83326                                        MongoDB
# 83333  Elasticsearch;Firebase;MySQL;PostgreSQL;Redis
# 83344                                        MariaDB
# 83420                    Elasticsearch;MongoDB;Redis
#
#                        PLATFORMHAVEWORKEDWITH  \
# 11                                        AWS
# 23                                        NaN
# 41                                        NaN
# 44                      Google Cloud Platform
# 68                                        AWS
# ...                                       ...
# 83313  AWS;DigitalOcean;Google Cloud Platform
# 83326                  Heroku;Microsoft Azure
# 83333                                  Heroku
# 83344                                     NaN
# 83420                                     NaN
#
#                               PLATFORMWANTTOWORKWITH  \
# 11                                               NaN
# 23                                               NaN
# 41                                               NaN
# 44                                               NaN
# 68                               AWS;Microsoft Azure
# ...                                              ...
# 83313         AWS;DigitalOcean;Google Cloud Platform
# 83326                                            NaN
# 83333  AWS;DigitalOcean;Google Cloud Platform;Heroku
# 83344                                            NaN
# 83420                                            NaN
#
#                                   WEBFRAMEHAVEWORKEDWITH  \
# 11                               Express;React.js;Vue.js
# 23                                                   NaN
# 41                                                   NaN
# 44                                   Django;Flask;Vue.js
# 68                                                   NaN
# ...                                                  ...
# 83313                               jQuery;Ruby on Rails
# 83326                              Django;Flask;React.js
# 83333                             React.js;Ruby on Rails
# 83344                                 Angular.js;FastAPI
# 83420  Angular;ASP.NET;ASP.NET Core ;Express;React.js...
#
#                                   WEBFRAMEWANTTOWORKWITH  \
# 11                                        Express;Vue.js
# 23                                                   NaN
# 41                                                   NaN
# 44                                                   NaN
# 68                                                   NaN
# ...                                                  ...
# 83313                        Django;Ruby on Rails;Vue.js
# 83326                                     Flask;React.js
# 83333  ASP.NET;ASP.NET Core ;Django;Express;FastAPI;F...
# 83344                    Angular;FastAPI;React.js;Vue.js
# 83420                     Express;React.js;Spring;Vue.js
#
#                                   MISCTECHHAVEWORKEDWITH  \
# 11                                                   NaN
# 23     Apache Spark;Keras;NumPy;Pandas;TensorFlow;Tor...
# 41     .NET Framework;.NET Core / .NET 5;NumPy;Pandas;Qt
# 44                                      NumPy;TensorFlow
# 68                                                   NaN
# ...                                                  ...
# 83313                                                NaN
# 83326        Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83333                                                NaN
# 83344                                                NaN
# 83420     .NET Framework;.NET Core / .NET 5;Apache Spark
#
#                                   MISCTECHWANTTOWORKWITH  \
# 11                                                   NaN
# 23     Apache Spark;Keras;NumPy;Pandas;TensorFlow;Tor...
# 41     .NET Framework;.NET Core / .NET 5;NumPy;Pandas;Qt
# 44                                                   NaN
# 68                                                   NaN
# ...                                                  ...
# 83313                                                NaN
# 83326        Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83333                                                NaN
# 83344                                                NaN
# 83420              Apache Spark;TensorFlow;Torch/PyTorch
#
#                                  TOOLSTECHHAVEWORKEDWITH  \
# 11                                                   Git
# 23                                            Docker;Git
# 41                                                   Git
# 44                                 Docker;Git;Kubernetes
# 68                                             Terraform
# ...                                                  ...
# 83313                            Ansible;Docker;Git;Yarn
# 83326                                                Git
# 83333                                                Git
# 83344                                         Docker;Git
# 83420  Ansible;Deno;Docker;Git;Kubernetes;Puppet;Terr...
#
#                                  TOOLSTECHWANTTOWORKWITH  \
# 11                                                   Git
# 23                                 Docker;Git;Kubernetes
# 41                                                   Git
# 44                                                   NaN
# 68                                             Terraform
# ...                                                  ...
# 83313                 Ansible;Docker;Git;Kubernetes;Yarn
# 83326                                                Git
# 83333                                      Chef;Deno;Git
# 83344                                         Docker;Git
# 83420  Deno;Docker;Git;Kubernetes;Unity 3D;Unreal Eng...
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 11                                                  Atom
# 23                                    Visual Studio Code
# 41     IPython/Jupyter;Notepad++;Visual Studio;Visual...
# 44                                         Visual Studio
# 68                      Notepad++;Vim;Visual Studio Code
# ...                                                  ...
# 83313                        RubyMine;Visual Studio Code
# 83326                 IPython/Jupyter;Visual Studio Code
# 83333                                 Visual Studio Code
# 83344                                            PyCharm
# 83420  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH  \
# 11                                                  Atom
# 23                                    Visual Studio Code
# 41                    IPython/Jupyter;Visual Studio Code
# 44                                                   NaN
# 68                                Vim;Visual Studio Code
# ...                                                  ...
# 83313                                 Visual Studio Code
# 83326                 IPython/Jupyter;Visual Studio Code
# 83333     PyCharm;Visual Studio;Visual Studio Code;Xcode
# 83344                         PyCharm;Visual Studio Code
# 83420  IntelliJ;IPython/Jupyter;Visual Studio Code;We...
#
#                                    OPSYS  \
# 11                           Linux-based
# 23                           Linux-based
# 41                               Windows
# 44                           Linux-based
# 68                               Windows
# ...                                  ...
# 83313                              MacOS
# 83326  Windows Subsystem for Linux (WSL)
# 83333                              MacOS
# 83344                        Linux-based
# 83420                            Windows
#
#                                                 NEWSTUCK  \
# 11     Call a coworker or friend;Visit Stack Overflow...
# 23                        Visit Stack Overflow;Google it
# 41     Visit Stack Overflow;Google it;Watch help / tu...
# 44                   Call a coworker or friend;Google it
# 68     Call a coworker or friend;Visit Stack Overflow...
# ...                                                  ...
# 83313                     Visit Stack Overflow;Google it
# 83326  Visit Stack Overflow;Google it;Do other work a...
# 83333                                          Google it
# 83344  Visit Stack Overflow;Google it;Do other work a...
# 83420                     Visit Stack Overflow;Google it
#
#                           NEWSOSITES             SOVISITFREQ  \
# 11     Stack Overflow;Stack Exchange   Daily or almost daily
# 23     Stack Overflow;Stack Exchange    A few times per week
# 41     Stack Overflow;Stack Exchange   Daily or almost daily
# 44                    Stack Overflow    A few times per week
# 68     Stack Overflow;Stack Exchange   Daily or almost daily
# ...                              ...                     ...
# 83313  Stack Overflow;Stack Exchange  Multiple times per day
# 83326  Stack Overflow;Stack Exchange   Daily or almost daily
# 83333  Stack Overflow;Stack Exchange   Daily or almost daily
# 83344  Stack Overflow;Stack Exchange   Daily or almost daily
# 83420                 Stack Overflow   Daily or almost daily
#
#                      SOACCOUNT  \
# 11                         Yes
# 23                         Yes
# 41                         Yes
# 44                          No
# 68                         Yes
# ...                        ...
# 83313                      Yes
# 83326                      Yes
# 83333  Not sure/can't remember
# 83344                      Yes
# 83420                      Yes
#
#                                               SOPARTFREQ          SOCOMM  \
# 11                   Less than once per month or monthly   Yes, somewhat
# 23                   Less than once per month or monthly   Yes, somewhat
# 41                                  A few times per week   Yes, somewhat
# 44                                                   NaN         Neutral
# 68                                  A few times per week   Yes, somewhat
# ...                                                  ...             ...
# 83313                Less than once per month or monthly   Yes, somewhat
# 83326                               A few times per week   Yes, somewhat
# 83333                                                NaN   Yes, somewhat
# 83344                Less than once per month or monthly  No, not at all
# 83420  I have never participated in Q&A on Stack Over...         Neutral
#
#       NEWOTHERCOMMS              AGE GENDER TRANS                SEXUALITY  \
# 11              Yes  25-34 years old    Man    No  Straight / Heterosexual
# 23               No  25-34 years old    Man    No                      NaN
# 41               No  25-34 years old    Man    No  Straight / Heterosexual
# 44               No  18-24 years old  Woman    No  Straight / Heterosexual
# 68               No  35-44 years old    Man    No  Straight / Heterosexual
# ...             ...              ...    ...   ...                      ...
# 83313            No  25-34 years old    Man    No  Straight / Heterosexual
# 83326            No  18-24 years old    Man    No        Prefer not to say
# 83333           Yes  25-34 years old    Man    No  Straight / Heterosexual
# 83344            No  25-34 years old    Man    No  Straight / Heterosexual
# 83420           Yes  25-34 years old    Man    No  Straight / Heterosexual
#
#                                                ETHNICITY      ACCESSIBILITY  \
# 11     White or of European descent;Hispanic or Latin...  None of the above
# 23                          White or of European descent  None of the above
# 41                                Hispanic or Latino/a/x  None of the above
# 44                          White or of European descent  None of the above
# 68                                                   NaN  None of the above
# ...                                                  ...                ...
# 83313                             Hispanic or Latino/a/x  None of the above
# 83326                                  Prefer not to say  Prefer not to say
# 83333                       White or of European descent  None of the above
# 83344              White or of European descent;Biracial  None of the above
# 83420                       White or of European descent  None of the above
#
#                                             MENTALHEALTH  \
# 11                                     None of the above
# 23                                     None of the above
# 41                                     None of the above
# 44                                     None of the above
# 68                                     None of the above
# ...                                                  ...
# 83313                                  None of the above
# 83326                                  Prefer not to say
# 83333                                  None of the above
# 83344                                  None of the above
# 83420  I have a mood or emotional disorder (e.g. depr...
#
#                 SURVEYLENGTH                  SURVEYEASE  CONVERTEDCOMPYEARLY
# 11                  Too long                        Easy              46482.0
# 23     Appropriate in length  Neither easy nor difficult              38915.0
# 41                  Too long                        Easy              25944.0
# 44     Appropriate in length  Neither easy nor difficult                  NaN
# 68     Appropriate in length                        Easy              58373.0
# ...                      ...                         ...                  ...
# 83313  Appropriate in length                        Easy              29832.0
# 83326  Appropriate in length                         NaN                  NaN
# 83333  Appropriate in length  Neither easy nor difficult              54049.0
# 83344  Appropriate in length                        Easy              54049.0
# 83420  Appropriate in length                        Easy              35672.0
#
# [4193 rows x 48 columns]

# %%
# Cambiar a mayúsculas el campo country
datos['COUNTRY'] = datos['COUNTRY'].str.upper()

# %%
datos
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  COUNTRY     USSTATE  \
# 0                                               SLOVAKIA         NaN
# 1                                            NETHERLANDS         NaN
# 2                                     RUSSIAN FEDERATION         NaN
# 3                                                AUSTRIA         NaN
# 4      UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...         NaN
# ...                                                  ...         ...
# 83434                           UNITED STATES OF AMERICA       Texas
# 83435                                              BENIN         NaN
# 83436                           UNITED STATES OF AMERICA  New Jersey
# 83437                                             CANADA         NaN
# 83438                                             BRAZIL         NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 0           NaN  Secondary school (e.g. American high school, G...
# 1           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4       England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...         ...                                                ...
# 83434       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436       NaN  Secondary school (e.g. American high school, G...
# 83437       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438       NaN                 Professional degree (JD, MD, etc.)
#
#           AGE1STCODE                                          LEARNCODE  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YEARSCODE YEARSCODEPRO  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DEVTYPE  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  ORGSIZE  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           CURRENCY  COMPTOTAL COMPFREQ  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LANGUAGEHAVEWORKEDWITH  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 0                                                  Swift
# 1                                                 Python
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DATABASEHAVEWORKEDWITH  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DATABASEWANTTOWORKWITH  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PLATFORMHAVEWORKEDWITH PLATFORMWANTTOWORKWITH  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WEBFRAMEHAVEWORKEDWITH  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WEBFRAMEWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MISCTECHHAVEWORKEDWITH  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MISCTECHWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             TOOLSTECHHAVEWORKEDWITH          TOOLSTECHWANTTOWORKWITH  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWSTUCK  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSITES  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVISITFREQ SOACCOUNT  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPARTFREQ           SOCOMM  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOTHERCOMMS              AGE GENDER TRANS                SEXUALITY  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           ETHNICITY                ACCESSIBILITY  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MENTALHEALTH  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SURVEYLENGTH                  SURVEYEASE  CONVERTEDCOMPYEARLY
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]

# %%
# Ejemplos de apply en series de objetos
# Accede a un campo y devuelve las columnas y filas
datos['COUNTRY'].apply(len)
# Out:
# 0         8
# 1        11
# 2        18
# 3         7
# 4        52
#          ..
# 83434    24
# 83435     5
# 83436    24
# 83437     6
# 83438     6
# Name: COUNTRY, Length: 83439, dtype: int64

# %%
def actualizar_pais(COUNTRY):
    return COUNTRY.lower()

# %%
datos['COUNTRY'].apply(actualizar_pais)
# Out:
# 0                                                 slovakia
# 1                                              netherlands
# 2                                       russian federation
# 3                                                  austria
# 4        united kingdom of great britain and northern i...
#                                ...
# 83434                             united states of america
# 83435                                                benin
# 83436                             united states of america
# 83437                                               canada
# 83438                                               brazil
# Name: COUNTRY, Length: 83439, dtype: object

# %%
datos['COUNTRY'] = datos['COUNTRY'].apply(lambda z: z.upper())

# %%
datos
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  COUNTRY     USSTATE  \
# 0                                               SLOVAKIA         NaN
# 1                                            NETHERLANDS         NaN
# 2                                     RUSSIAN FEDERATION         NaN
# 3                                                AUSTRIA         NaN
# 4      UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...         NaN
# ...                                                  ...         ...
# 83434                           UNITED STATES OF AMERICA       Texas
# 83435                                              BENIN         NaN
# 83436                           UNITED STATES OF AMERICA  New Jersey
# 83437                                             CANADA         NaN
# 83438                                             BRAZIL         NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 0           NaN  Secondary school (e.g. American high school, G...
# 1           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4       England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...         ...                                                ...
# 83434       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436       NaN  Secondary school (e.g. American high school, G...
# 83437       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438       NaN                 Professional degree (JD, MD, etc.)
#
#           AGE1STCODE                                          LEARNCODE  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YEARSCODE YEARSCODEPRO  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DEVTYPE  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  ORGSIZE  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           CURRENCY  COMPTOTAL COMPFREQ  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LANGUAGEHAVEWORKEDWITH  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 0                                                  Swift
# 1                                                 Python
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DATABASEHAVEWORKEDWITH  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DATABASEWANTTOWORKWITH  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PLATFORMHAVEWORKEDWITH PLATFORMWANTTOWORKWITH  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WEBFRAMEHAVEWORKEDWITH  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WEBFRAMEWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MISCTECHHAVEWORKEDWITH  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MISCTECHWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             TOOLSTECHHAVEWORKEDWITH          TOOLSTECHWANTTOWORKWITH  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWSTUCK  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSITES  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVISITFREQ SOACCOUNT  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPARTFREQ           SOCOMM  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOTHERCOMMS              AGE GENDER TRANS                SEXUALITY  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           ETHNICITY                ACCESSIBILITY  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MENTALHEALTH  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SURVEYLENGTH                  SURVEYEASE  CONVERTEDCOMPYEARLY
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]

# %%
# Ejemplos de apply en dataframes
# Ejecuta el código en cada serie del dataframe
datos.apply(len)
# Out:
# RESPONSEID                      83439
# MAINBRANCH                      83439
# EMPLOYMENT                      83439
# COUNTRY                         83439
# USSTATE                         83439
# UKCOUNTRY                       83439
# EDLEVEL                         83439
# AGE1STCODE                      83439
# LEARNCODE                       83439
# YEARSCODE                       83439
# YEARSCODEPRO                    83439
# DEVTYPE                         83439
# ORGSIZE                         83439
# CURRENCY                        83439
# COMPTOTAL                       83439
# COMPFREQ                        83439
# LANGUAGEHAVEWORKEDWITH          83439
# LANGUAGEWANTTOWORKWITH          83439
# DATABASEHAVEWORKEDWITH          83439
# DATABASEWANTTOWORKWITH          83439
# PLATFORMHAVEWORKEDWITH          83439
# PLATFORMWANTTOWORKWITH          83439
# WEBFRAMEHAVEWORKEDWITH          83439
# WEBFRAMEWANTTOWORKWITH          83439
# MISCTECHHAVEWORKEDWITH          83439
# MISCTECHWANTTOWORKWITH          83439
# TOOLSTECHHAVEWORKEDWITH         83439
# TOOLSTECHWANTTOWORKWITH         83439
# NEWCOLLABTOOLSHAVEWORKEDWITH    83439
# NEWCOLLABTOOLSWANTTOWORKWITH    83439
# OPSYS                           83439
# NEWSTUCK                        83439
# NEWSOSITES                      83439
# SOVISITFREQ                     83439
# SOACCOUNT                       83439
# SOPARTFREQ                      83439
# SOCOMM                          83439
# NEWOTHERCOMMS                   83439
# AGE                             83439
# GENDER                          83439
# TRANS                           83439
# SEXUALITY                       83439
# ETHNICITY                       83439
# ACCESSIBILITY                   83439
# MENTALHEALTH                    83439
# SURVEYLENGTH                    83439
# SURVEYEASE                      83439
# CONVERTEDCOMPYEARLY             83439
# dtype: int64

# %%
# Ejecuta el código en cada serie del dataframe
# modificando el eje a columna
datos.apply(len, axis='columns')
# Out:
# 0        48
# 1        48
# 2        48
# 3        48
# 4        48
#          ..
# 83434    48
# 83435    48
# 83436    48
# 83437    48
# 83438    48
# Length: 83439, dtype: int64

# %%
# Ejemplos de apply en series
# Ejecuta el código en cada cada valor de la serie
datos.apply(pd.Series)
# Igual que datos
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  COUNTRY     USSTATE  \
# 0                                               SLOVAKIA         NaN
# 1                                            NETHERLANDS         NaN
# 2                                     RUSSIAN FEDERATION         NaN
# 3                                                AUSTRIA         NaN
# 4      UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...         NaN
# ...                                                  ...         ...
# 83434                           UNITED STATES OF AMERICA       Texas
# 83435                                              BENIN         NaN
# 83436                           UNITED STATES OF AMERICA  New Jersey
# 83437                                             CANADA         NaN
# 83438                                             BRAZIL         NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 0           NaN  Secondary school (e.g. American high school, G...
# 1           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4       England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...         ...                                                ...
# 83434       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436       NaN  Secondary school (e.g. American high school, G...
# 83437       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438       NaN                 Professional degree (JD, MD, etc.)
#
#           AGE1STCODE                                          LEARNCODE  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YEARSCODE YEARSCODEPRO  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DEVTYPE  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  ORGSIZE  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           CURRENCY  COMPTOTAL COMPFREQ  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LANGUAGEHAVEWORKEDWITH  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 0                                                  Swift
# 1                                                 Python
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DATABASEHAVEWORKEDWITH  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DATABASEWANTTOWORKWITH  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PLATFORMHAVEWORKEDWITH PLATFORMWANTTOWORKWITH  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WEBFRAMEHAVEWORKEDWITH  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WEBFRAMEWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MISCTECHHAVEWORKEDWITH  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MISCTECHWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             TOOLSTECHHAVEWORKEDWITH          TOOLSTECHWANTTOWORKWITH  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWSTUCK  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSITES  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVISITFREQ SOACCOUNT  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPARTFREQ           SOCOMM  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOTHERCOMMS              AGE GENDER TRANS                SEXUALITY  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           ETHNICITY                ACCESSIBILITY  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MENTALHEALTH  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SURVEYLENGTH                  SURVEYEASE  CONVERTEDCOMPYEARLY
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]

# %%
# Ejemplos de applymap en dataframes
# Ejecuta el código (función) en cada serie del dataframe
datos.applymap
# Out:
# <bound method DataFrame.applymap of        RESPONSEID                                         MAINBRANCH  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  COUNTRY     USSTATE  \
# 0                                               SLOVAKIA         NaN
# 1                                            NETHERLANDS         NaN
# 2                                     RUSSIAN FEDERATION         NaN
# 3                                                AUSTRIA         NaN
# 4      UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...         NaN
# ...                                                  ...         ...
# 83434                           UNITED STATES OF AMERICA       Texas
# 83435                                              BENIN         NaN
# 83436                           UNITED STATES OF AMERICA  New Jersey
# 83437                                             CANADA         NaN
# 83438                                             BRAZIL         NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 0           NaN  Secondary school (e.g. American high school, G...
# 1           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4       England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...         ...                                                ...
# 83434       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436       NaN  Secondary school (e.g. American high school, G...
# 83437       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438       NaN                 Professional degree (JD, MD, etc.)
#
#           AGE1STCODE                                          LEARNCODE  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YEARSCODE YEARSCODEPRO  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DEVTYPE  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  ORGSIZE  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           CURRENCY  COMPTOTAL COMPFREQ  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LANGUAGEHAVEWORKEDWITH  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 0                                                  Swift
# 1                                                 Python
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DATABASEHAVEWORKEDWITH  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DATABASEWANTTOWORKWITH  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PLATFORMHAVEWORKEDWITH PLATFORMWANTTOWORKWITH  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WEBFRAMEHAVEWORKEDWITH  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WEBFRAMEWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MISCTECHHAVEWORKEDWITH  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MISCTECHWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             TOOLSTECHHAVEWORKEDWITH          TOOLSTECHWANTTOWORKWITH  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWSTUCK  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSITES  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVISITFREQ SOACCOUNT  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPARTFREQ           SOCOMM  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOTHERCOMMS              AGE GENDER TRANS                SEXUALITY  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           ETHNICITY                ACCESSIBILITY  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MENTALHEALTH  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SURVEYLENGTH                  SURVEYEASE  CONVERTEDCOMPYEARLY
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]>

# %%
# El método map solamente funciona con series
# Permite cambiar los valores de las series
datos['SOACCOUNT']
# Out:
# 0        Yes
# 1        Yes
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 83434     No
# 83435    Yes
# 83436    Yes
# 83437    Yes
# 83438    Yes
# Name: SOACCOUNT, Length: 83439, dtype: object

# %%
datos['SOACCOUNT'].map({'Yes': True, 'No': False})
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 83434    False
# 83435     True
# 83436     True
# 83437     True
# 83438     True
# Name: SOACCOUNT, Length: 83439, dtype: object

# %%
# Aplicar los cambios
datos['SOACCOUNT'] = datos['SOACCOUNT'].map({'Yes': True, 'No': False})

# %%
# El método replace permite cambiar los valores de las series
# Se aplican los cambios creando una variable que utilize
# este código como en el ejemplo anterior
datos['COUNTRY'].replace({'NETHERLANDS':'PAISES BAJOS'})
# Out:
# 0                                                 SLOVAKIA
# 1                                             PAISES BAJOS
# 2                                       RUSSIAN FEDERATION
# 3                                                  AUSTRIA
# 4        UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
#                                ...
# 83434                             UNITED STATES OF AMERICA
# 83435                                                BENIN
# 83436                             UNITED STATES OF AMERICA
# 83437                                               CANADA
# 83438                                               BRAZIL
# Name: COUNTRY, Length: 83439, dtype: object

# %%
# Haciendo un join de dos columnas con un espacio para delimitarlas
datos['NEWSTUCK'] + ' ' + datos['NEWSOSITES']
# Out:
# 0        Call a coworker or friend;Visit Stack Overflow...
# 1            Visit Stack Overflow;Google it Stack Overflow
# 2        Visit Stack Overflow;Google it;Watch help / tu...
# 3        Call a coworker or friend;Visit Stack Overflow...
# 4        Visit Stack Overflow;Go for a walk or other ph...
#                                ...
# 83434    Call a coworker or friend;Google it Stack Over...
# 83435    Call a coworker or friend;Visit Stack Overflow...
# 83436    Call a coworker or friend;Visit Stack Overflow...
# 83437    Call a coworker or friend;Visit Stack Overflow...
# 83438    Call a coworker or friend;Visit Stack Overflow...
# Length: 83439, dtype: object

# %%
# Crea la nueva columna AYUDA
datos['AYUDA'] = datos['NEWSTUCK'] + ' ' + datos['NEWSOSITES']

# %%
datos
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  COUNTRY     USSTATE  \
# 0                                               SLOVAKIA         NaN
# 1                                            NETHERLANDS         NaN
# 2                                     RUSSIAN FEDERATION         NaN
# 3                                                AUSTRIA         NaN
# 4      UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...         NaN
# ...                                                  ...         ...
# 83434                           UNITED STATES OF AMERICA       Texas
# 83435                                              BENIN         NaN
# 83436                           UNITED STATES OF AMERICA  New Jersey
# 83437                                             CANADA         NaN
# 83438                                             BRAZIL         NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 0           NaN  Secondary school (e.g. American high school, G...
# 1           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4       England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...         ...                                                ...
# 83434       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436       NaN  Secondary school (e.g. American high school, G...
# 83437       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438       NaN                 Professional degree (JD, MD, etc.)
#
#           AGE1STCODE                                          LEARNCODE  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YEARSCODE YEARSCODEPRO  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DEVTYPE  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  ORGSIZE  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           CURRENCY  COMPTOTAL COMPFREQ  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LANGUAGEHAVEWORKEDWITH  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 0                                                  Swift
# 1                                                 Python
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DATABASEHAVEWORKEDWITH  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DATABASEWANTTOWORKWITH  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PLATFORMHAVEWORKEDWITH PLATFORMWANTTOWORKWITH  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WEBFRAMEHAVEWORKEDWITH  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WEBFRAMEWANTTOWORKWITH  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                                                  Flask  ...
# 3                                         Angular;jQuery  ...
# 4                                                  Flask  ...
# ...                                                  ...  ...
# 83434                                                NaN  ...
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...  ...
# 83436                                      FastAPI;Flask  ...
# 83437                                                NaN  ...
# 83438                     Express;Laravel;Spring;Symfony  ...
#
#                                   MISCTECHWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             TOOLSTECHHAVEWORKEDWITH          TOOLSTECHWANTTOWORKWITH  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWSTUCK  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSITES  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVISITFREQ SOACCOUNT  \
# 0               Multiple times per day      True
# 1                Daily or almost daily      True
# 2               Multiple times per day      True
# 3                Daily or almost daily      True
# 4                Daily or almost daily      True
# ...                                ...       ...
# 83434             A few times per week     False
# 83435           Multiple times per day      True
# 83436             A few times per week      True
# 83437  A few times per month or weekly      True
# 83438             A few times per week      True
#
#                                               SOPARTFREQ           SOCOMM  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOTHERCOMMS              AGE GENDER TRANS                SEXUALITY  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           ETHNICITY                ACCESSIBILITY  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MENTALHEALTH  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SURVEYLENGTH                  SURVEYEASE CONVERTEDCOMPYEARLY  \
# 0      Appropriate in length                        Easy             62268.0
# 1      Appropriate in length                        Easy                 NaN
# 2      Appropriate in length                        Easy                 NaN
# 3      Appropriate in length  Neither easy nor difficult                 NaN
# 4      Appropriate in length                        Easy                 NaN
# ...                      ...                         ...                 ...
# 83434  Appropriate in length                        Easy            160500.0
# 83435  Appropriate in length                        Easy              3960.0
# 83436  Appropriate in length  Neither easy nor difficult             90000.0
# 83437  Appropriate in length  Neither easy nor difficult            816816.0
# 83438  Appropriate in length                        Easy             21168.0
#
#                                                    AYUDA
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1          Visit Stack Overflow;Google it Stack Overflow
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434  Call a coworker or friend;Google it Stack Over...
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
# [83439 rows x 49 columns]

# %%
# Eliminar columnas
# Otra opción: del datos['nombre_columna']
# Aplicar los cambios con: inplace=True
datos.drop(columns=['NEWSTUCK', 'NEWSOSITES'])
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  COUNTRY     USSTATE  \
# 0                                               SLOVAKIA         NaN
# 1                                            NETHERLANDS         NaN
# 2                                     RUSSIAN FEDERATION         NaN
# 3                                                AUSTRIA         NaN
# 4      UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...         NaN
# ...                                                  ...         ...
# 83434                           UNITED STATES OF AMERICA       Texas
# 83435                                              BENIN         NaN
# 83436                           UNITED STATES OF AMERICA  New Jersey
# 83437                                             CANADA         NaN
# 83438                                             BRAZIL         NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 0           NaN  Secondary school (e.g. American high school, G...
# 1           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4       England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...         ...                                                ...
# 83434       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436       NaN  Secondary school (e.g. American high school, G...
# 83437       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438       NaN                 Professional degree (JD, MD, etc.)
#
#           AGE1STCODE                                          LEARNCODE  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YEARSCODE YEARSCODEPRO  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DEVTYPE  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  ORGSIZE  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           CURRENCY  COMPTOTAL COMPFREQ  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LANGUAGEHAVEWORKEDWITH  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 0                                                  Swift
# 1                                                 Python
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DATABASEHAVEWORKEDWITH  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DATABASEWANTTOWORKWITH  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PLATFORMHAVEWORKEDWITH PLATFORMWANTTOWORKWITH  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WEBFRAMEHAVEWORKEDWITH  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WEBFRAMEWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MISCTECHHAVEWORKEDWITH  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MISCTECHWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             TOOLSTECHHAVEWORKEDWITH          TOOLSTECHWANTTOWORKWITH  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                            SOVISITFREQ SOACCOUNT  \
# 0               Multiple times per day      True
# 1                Daily or almost daily      True
# 2               Multiple times per day      True
# 3                Daily or almost daily      True
# 4                Daily or almost daily      True
# ...                                ...       ...
# 83434             A few times per week     False
# 83435           Multiple times per day      True
# 83436             A few times per week      True
# 83437  A few times per month or weekly      True
# 83438             A few times per week      True
#
#                                               SOPARTFREQ           SOCOMM  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOTHERCOMMS              AGE GENDER TRANS                SEXUALITY  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           ETHNICITY                ACCESSIBILITY  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MENTALHEALTH  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SURVEYLENGTH                  SURVEYEASE  CONVERTEDCOMPYEARLY  \
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
#                                                    AYUDA
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1          Visit Stack Overflow;Google it Stack Overflow
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434  Call a coworker or friend;Google it Stack Over...
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
# [83439 rows x 47 columns]

# %%
# Dividir una columna
# datos[['datos1', 'datos2']] = datos['nombre_columna'].str.split(' ', expand=True)

# %%
# Agregar una fila o registro
datos.append({'LANGUAGEWANTTOWORKWITH':'Python'}, ignore_index=True)
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 0             1.0                     I am a developer by profession
# 1             2.0             I am a student who is learning to code
# 2             3.0  I am not primarily a developer, but I write co...
# 3             4.0                     I am a developer by profession
# 4             5.0                     I am a developer by profession
# ...           ...                                                ...
# 83435     83436.0                     I am a developer by profession
# 83436     83437.0                     I am a developer by profession
# 83437     83438.0                     I am a developer by profession
# 83438     83439.0                     I am a developer by profession
# 83439         NaN                                                NaN
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
# 83439                                                NaN
#
#                                                  COUNTRY     USSTATE  \
# 0                                               SLOVAKIA         NaN
# 1                                            NETHERLANDS         NaN
# 2                                     RUSSIAN FEDERATION         NaN
# 3                                                AUSTRIA         NaN
# 4      UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...         NaN
# ...                                                  ...         ...
# 83435                                              BENIN         NaN
# 83436                           UNITED STATES OF AMERICA  New Jersey
# 83437                                             CANADA         NaN
# 83438                                             BRAZIL         NaN
# 83439                                                NaN         NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 0           NaN  Secondary school (e.g. American high school, G...
# 1           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4       England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...         ...                                                ...
# 83435       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436       NaN  Secondary school (e.g. American high school, G...
# 83437       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438       NaN                 Professional degree (JD, MD, etc.)
# 83439       NaN                                                NaN
#
#           AGE1STCODE                                          LEARNCODE  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
# 83439            NaN                                                NaN
#
#       YEARSCODE YEARSCODEPRO  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
# 83439       NaN          NaN
#
#                                                  DEVTYPE  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
# 83439                                                NaN
#
#                                                  ORGSIZE  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
# 83439                                                NaN
#
#                           CURRENCY  COMPTOTAL COMPFREQ  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
# 83439                          NaN        NaN      NaN
#
#                               LANGUAGEHAVEWORKEDWITH  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
# 83439                                            NaN
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 0                                                  Swift
# 1                                                 Python
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
# 83439                                             Python
#
#                                  DATABASEHAVEWORKEDWITH  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
# 83439                                               NaN
#
#                                   DATABASEWANTTOWORKWITH  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
# 83439                                                NaN
#
#           PLATFORMHAVEWORKEDWITH PLATFORMWANTTOWORKWITH  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
# 83439                        NaN                    NaN
#
#                              WEBFRAMEHAVEWORKEDWITH  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
# 83439                                           NaN
#
#                                   WEBFRAMEWANTTOWORKWITH  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                                                  Flask  ...
# 3                                         Angular;jQuery  ...
# 4                                                  Flask  ...
# ...                                                  ...  ...
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...  ...
# 83436                                      FastAPI;Flask  ...
# 83437                                                NaN  ...
# 83438                     Express;Laravel;Spring;Symfony  ...
# 83439                                                NaN  ...
#
#                                   MISCTECHWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
# 83439                                                NaN
#
#             TOOLSTECHHAVEWORKEDWITH          TOOLSTECHWANTTOWORKWITH  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
# 83439                           NaN                              NaN
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
# 83439                                                NaN
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
# 83439                                                NaN          NaN
#
#                                                 NEWSTUCK  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
# 83439                                                NaN
#
#                                               NEWSOSITES  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
# 83439                                                NaN
#
#                            SOVISITFREQ SOACCOUNT  \
# 0               Multiple times per day      True
# 1                Daily or almost daily      True
# 2               Multiple times per day      True
# 3                Daily or almost daily      True
# 4                Daily or almost daily      True
# ...                                ...       ...
# 83435           Multiple times per day      True
# 83436             A few times per week      True
# 83437  A few times per month or weekly      True
# 83438             A few times per week      True
# 83439                              NaN       NaN
#
#                                               SOPARTFREQ           SOCOMM  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
# 83439                                                NaN              NaN
#
#       NEWOTHERCOMMS              AGE GENDER TRANS                SEXUALITY  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
# 83439           NaN              NaN    NaN   NaN                      NaN
#
#                           ETHNICITY                ACCESSIBILITY  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
# 83439                           NaN                          NaN
#
#                                             MENTALHEALTH  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
# 83439                                                NaN
#
#                 SURVEYLENGTH                  SURVEYEASE CONVERTEDCOMPYEARLY  \
# 0      Appropriate in length                        Easy             62268.0
# 1      Appropriate in length                        Easy                 NaN
# 2      Appropriate in length                        Easy                 NaN
# 3      Appropriate in length  Neither easy nor difficult                 NaN
# 4      Appropriate in length                        Easy                 NaN
# ...                      ...                         ...                 ...
# 83435  Appropriate in length                        Easy              3960.0
# 83436  Appropriate in length  Neither easy nor difficult             90000.0
# 83437  Appropriate in length  Neither easy nor difficult            816816.0
# 83438  Appropriate in length                        Easy             21168.0
# 83439                    NaN                         NaN                 NaN
#
#                                                    AYUDA
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1          Visit Stack Overflow;Google it Stack Overflow
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
# 83439                                                NaN
#
# [83440 rows x 49 columns]

# %%
# Agregar otro dataframe
datos_doble = datos.append(datos)

# %%
datos_doble
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  COUNTRY     USSTATE  \
# 0                                               SLOVAKIA         NaN
# 1                                            NETHERLANDS         NaN
# 2                                     RUSSIAN FEDERATION         NaN
# 3                                                AUSTRIA         NaN
# 4      UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...         NaN
# ...                                                  ...         ...
# 83434                           UNITED STATES OF AMERICA       Texas
# 83435                                              BENIN         NaN
# 83436                           UNITED STATES OF AMERICA  New Jersey
# 83437                                             CANADA         NaN
# 83438                                             BRAZIL         NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 0           NaN  Secondary school (e.g. American high school, G...
# 1           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4       England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...         ...                                                ...
# 83434       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436       NaN  Secondary school (e.g. American high school, G...
# 83437       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438       NaN                 Professional degree (JD, MD, etc.)
#
#           AGE1STCODE                                          LEARNCODE  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YEARSCODE YEARSCODEPRO  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DEVTYPE  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  ORGSIZE  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           CURRENCY  COMPTOTAL COMPFREQ  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LANGUAGEHAVEWORKEDWITH  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 0                                                  Swift
# 1                                                 Python
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DATABASEHAVEWORKEDWITH  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DATABASEWANTTOWORKWITH  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PLATFORMHAVEWORKEDWITH PLATFORMWANTTOWORKWITH  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WEBFRAMEHAVEWORKEDWITH  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WEBFRAMEWANTTOWORKWITH  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                                                  Flask  ...
# 3                                         Angular;jQuery  ...
# 4                                                  Flask  ...
# ...                                                  ...  ...
# 83434                                                NaN  ...
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...  ...
# 83436                                      FastAPI;Flask  ...
# 83437                                                NaN  ...
# 83438                     Express;Laravel;Spring;Symfony  ...
#
#                                   MISCTECHWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             TOOLSTECHHAVEWORKEDWITH          TOOLSTECHWANTTOWORKWITH  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWSTUCK  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSITES  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVISITFREQ SOACCOUNT  \
# 0               Multiple times per day      True
# 1                Daily or almost daily      True
# 2               Multiple times per day      True
# 3                Daily or almost daily      True
# 4                Daily or almost daily      True
# ...                                ...       ...
# 83434             A few times per week     False
# 83435           Multiple times per day      True
# 83436             A few times per week      True
# 83437  A few times per month or weekly      True
# 83438             A few times per week      True
#
#                                               SOPARTFREQ           SOCOMM  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOTHERCOMMS              AGE GENDER TRANS                SEXUALITY  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           ETHNICITY                ACCESSIBILITY  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MENTALHEALTH  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SURVEYLENGTH                  SURVEYEASE CONVERTEDCOMPYEARLY  \
# 0      Appropriate in length                        Easy             62268.0
# 1      Appropriate in length                        Easy                 NaN
# 2      Appropriate in length                        Easy                 NaN
# 3      Appropriate in length  Neither easy nor difficult                 NaN
# 4      Appropriate in length                        Easy                 NaN
# ...                      ...                         ...                 ...
# 83434  Appropriate in length                        Easy            160500.0
# 83435  Appropriate in length                        Easy              3960.0
# 83436  Appropriate in length  Neither easy nor difficult             90000.0
# 83437  Appropriate in length  Neither easy nor difficult            816816.0
# 83438  Appropriate in length                        Easy             21168.0
#
#                                                    AYUDA
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1          Visit Stack Overflow;Google it Stack Overflow
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434  Call a coworker or friend;Google it Stack Over...
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
# [166878 rows x 49 columns]

# %%
datos_doble = datos_doble.drop_duplicates()

# %%
datos_doble.shape
# Out:
# (83439, 49)

# %%
# Eliminar una fila o registro
datos.drop(index=83438)
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83433       83434                     I am a developer by profession
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83433  Independent contractor, freelancer, or self-em...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
#
#                                                  COUNTRY     USSTATE  \
# 0                                               SLOVAKIA         NaN
# 1                                            NETHERLANDS         NaN
# 2                                     RUSSIAN FEDERATION         NaN
# 3                                                AUSTRIA         NaN
# 4      UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...         NaN
# ...                                                  ...         ...
# 83433                                             BRAZIL         NaN
# 83434                           UNITED STATES OF AMERICA       Texas
# 83435                                              BENIN         NaN
# 83436                           UNITED STATES OF AMERICA  New Jersey
# 83437                                             CANADA         NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 0           NaN  Secondary school (e.g. American high school, G...
# 1           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4       England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...         ...                                                ...
# 83433       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83434       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436       NaN  Secondary school (e.g. American high school, G...
# 83437       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#           AGE1STCODE                                          LEARNCODE  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83433  18 - 24 years  Online Forum;Online Courses or Certification;O...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
#
#       YEARSCODE YEARSCODEPRO  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83433        15           11
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
#
#                                                  DEVTYPE  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83433  Developer, mobile;Developer, front-end;Develop...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
#
#                                                  ORGSIZE  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83433                           1,000 to 4,999 employees
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
#
#                           CURRENCY  COMPTOTAL COMPFREQ  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83433          BRL\tBrazilian real    80000.0   Yearly
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
#
#                               LANGUAGEHAVEWORKEDWITH  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83433  Java;JavaScript;Kotlin;Objective-C;TypeScript
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
#
#                LANGUAGEWANTTOWORKWITH  \
# 0                               Swift
# 1                              Python
# 2                   Julia;Python;Rust
# 3               JavaScript;TypeScript
# 4      Bash/Shell;HTML/CSS;Python;SQL
# ...                               ...
# 83433                          Kotlin
# 83434                         Clojure
# 83435                             NaN
# 83436                     Java;Python
# 83437                         Go;Rust
#
#                                  DATABASEHAVEWORKEDWITH  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83433                     Firebase;MongoDB;MySQL;SQLite
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
#
#                                   DATABASEWANTTOWORKWITH  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83433                                                NaN
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
#
#           PLATFORMHAVEWORKEDWITH PLATFORMWANTTOWORKWITH  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83433                        NaN                    NaN
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
#
#                              WEBFRAMEHAVEWORKEDWITH  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83433                                      React.js
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
#
#                                   WEBFRAMEWANTTOWORKWITH  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                                                  Flask  ...
# 3                                         Angular;jQuery  ...
# 4                                                  Flask  ...
# ...                                                  ...  ...
# 83433                                                NaN  ...
# 83434                                                NaN  ...
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...  ...
# 83436                                      FastAPI;Flask  ...
# 83437                                                NaN  ...
#
#                                   MISCTECHWANTTOWORKWITH  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83433                                            Flutter
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
#
#             TOOLSTECHHAVEWORKEDWITH          TOOLSTECHWANTTOWORKWITH  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83433               Docker;Git;Yarn                       Docker;Git
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83433            Android Studio;Visual Studio Code;Xcode
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83433                               Android Studio;Xcode        MacOS
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
#
#                                                 NEWSTUCK  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83433  Call a coworker or friend;Visit Stack Overflow...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
#
#                           NEWSOSITES                      SOVISITFREQ  \
# 0                     Stack Overflow           Multiple times per day
# 1                     Stack Overflow            Daily or almost daily
# 2      Stack Overflow;Stack Exchange           Multiple times per day
# 3                     Stack Overflow            Daily or almost daily
# 4      Stack Overflow;Stack Exchange            Daily or almost daily
# ...                              ...                              ...
# 83433                 Stack Overflow            Daily or almost daily
# 83434  Stack Overflow;Stack Exchange             A few times per week
# 83435  Stack Overflow;Stack Exchange           Multiple times per day
# 83436  Stack Overflow;Stack Exchange             A few times per week
# 83437                 Stack Overflow  A few times per month or weekly
#
#       SOACCOUNT                                         SOPARTFREQ  \
# 0          True                    A few times per month or weekly
# 1          True                              Daily or almost daily
# 2          True                             Multiple times per day
# 3          True                              Daily or almost daily
# 4          True                               A few times per week
# ...         ...                                                ...
# 83433      True                    A few times per month or weekly
# 83434     False                                                NaN
# 83435      True  I have never participated in Q&A on Stack Over...
# 83436      True  I have never participated in Q&A on Stack Over...
# 83437      True                Less than once per month or monthly
#
#                 SOCOMM NEWOTHERCOMMS              AGE GENDER TRANS  \
# 0      Yes, definitely            No  25-34 years old    Man    No
# 1      Yes, definitely            No  18-24 years old    Man    No
# 2      Yes, definitely           Yes  18-24 years old    Man    No
# 3              Neutral            No  35-44 years old    Man    No
# 4        Yes, somewhat            No  25-34 years old    Man    No
# ...                ...           ...              ...    ...   ...
# 83433    Yes, somewhat            No  25-34 years old    Man    No
# 83434   No, not at all            No  25-34 years old    Man    No
# 83435    Yes, somewhat            No  18-24 years old    Man    No
# 83436   No, not really            No  25-34 years old    Man    No
# 83437   No, not really            No  25-34 years old    Man    No
#
#                      SEXUALITY                     ETHNICITY  \
# 0      Straight / Heterosexual  White or of European descent
# 1      Straight / Heterosexual  White or of European descent
# 2            Prefer not to say             Prefer not to say
# 3      Straight / Heterosexual  White or of European descent
# 4                          NaN  White or of European descent
# ...                        ...                           ...
# 83433  Straight / Heterosexual        Hispanic or Latino/a/x
# 83434  Straight / Heterosexual  White or of European descent
# 83435  Straight / Heterosexual   Black or of African descent
# 83436                      NaN  White or of European descent
# 83437  Straight / Heterosexual  White or of European descent
#
#                      ACCESSIBILITY  \
# 0                None of the above
# 1                None of the above
# 2                None of the above
# 3      I am deaf / hard of hearing
# 4                None of the above
# ...                            ...
# 83433            None of the above
# 83434            None of the above
# 83435            None of the above
# 83436            None of the above
# 83437            None of the above
#
#                                             MENTALHEALTH  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83433                         I have an anxiety disorder
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
#
#                 SURVEYLENGTH                  SURVEYEASE CONVERTEDCOMPYEARLY  \
# 0      Appropriate in length                        Easy             62268.0
# 1      Appropriate in length                        Easy                 NaN
# 2      Appropriate in length                        Easy                 NaN
# 3      Appropriate in length  Neither easy nor difficult                 NaN
# 4      Appropriate in length                        Easy                 NaN
# ...                      ...                         ...                 ...
# 83433  Appropriate in length                        Easy             18326.0
# 83434  Appropriate in length                        Easy            160500.0
# 83435  Appropriate in length                        Easy              3960.0
# 83436  Appropriate in length  Neither easy nor difficult             90000.0
# 83437  Appropriate in length  Neither easy nor difficult            816816.0
#
#                                                    AYUDA
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1          Visit Stack Overflow;Google it Stack Overflow
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83433  Call a coworker or friend;Visit Stack Overflow...
# 83434  Call a coworker or friend;Google it Stack Over...
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
#
# [83438 rows x 49 columns]

# %%
import numpy as np
import pandas as pd

# %%
pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting matplotlib
#
#   Downloading matplotlib-3.5.0-cp310-cp310-win_amd64.whl (7.2 MB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.2-cp310-cp310-win_amd64.whl (52 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\curso_python\codigo\cursopython2021\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\curso_python\codigo\cursopython2021\lib\site-packages (from matplotlib) (3.0.6)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.28.3-py3-none-any.whl (884 kB)
# Requirement already satisfied: numpy>=1.17 in d:\curso_python\codigo\cursopython2021\lib\site-packages (from matplotlib) (1.21.4)
# Requirement already satisfied: packaging>=20.0 in d:\curso_python\codigo\cursopython2021\lib\site-packages (from matplotlib) (21.3)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.4.0-cp310-cp310-win_amd64.whl (3.2 MB)
# Collecting setuptools-scm>=4
#   Downloading setuptools_scm-6.3.2-py3-none-any.whl (33 kB)
# Requirement already satisfied: six>=1.5 in d:\curso_python\codigo\cursopython2021\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: setuptools in d:\curso_python\codigo\cursopython2021\lib\site-packages (from setuptools-scm>=4->matplotlib) (58.3.0)
# Collecting tomli>=1.0.0
#   Downloading tomli-1.2.2-py3-none-any.whl (12 kB)
# Installing collected packages: tomli, setuptools-scm, pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.28.3 kiwisolver-1.3.2 matplotlib-3.5.0 pillow-8.4.0 setuptools-scm-6.3.2 tomli-1.2.2

# %%
import matplotlib.pyplot as plt

# %%
# Creamos la variable grafico
grafico = (datos.COUNTRY.value_counts())

# %%
grafico.plot()
# Out:
# <AxesSubplot:>

# %%
datos.sort_values(by="COUNTRY")
# Out:
#        RESPONSEID                              MAINBRANCH  \
# 14882       14883          I am a developer by profession
# 41840       41841                           None of these
# 4544         4545          I am a developer by profession
# 28378       28379                           None of these
# 55624       55625             I code primarily as a hobby
# ...           ...                                     ...
# 75693       75694  I am a student who is learning to code
# 73741       73742          I am a developer by profession
# 44094       44095          I am a developer by profession
# 13194       13195          I am a developer by profession
# 54148       54149          I am a developer by profession
#
#                                               EMPLOYMENT      COUNTRY USSTATE  \
# 14882                                 Employed full-time  AFGHANISTAN     NaN
# 41840                                I prefer not to say  AFGHANISTAN     NaN
# 4544   Independent contractor, freelancer, or self-em...  AFGHANISTAN     NaN
# 28378             Not employed, and not looking for work  AFGHANISTAN     NaN
# 55624                                I prefer not to say  AFGHANISTAN     NaN
# ...                                                  ...          ...     ...
# 75693                                 Student, full-time     ZIMBABWE     NaN
# 73741                                 Student, part-time     ZIMBABWE     NaN
# 44094                                 Employed full-time     ZIMBABWE     NaN
# 13194                                 Employed full-time     ZIMBABWE     NaN
# 54148                                 Employed full-time     ZIMBABWE     NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 14882       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 41840       NaN                                     Something else
# 4544        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 28378       NaN  Secondary school (e.g. American high school, G...
# 55624       NaN                 Professional degree (JD, MD, etc.)
# ...         ...                                                ...
# 75693       NaN  Secondary school (e.g. American high school, G...
# 73741       NaN  Some college/university study without earning ...
# 44094       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 13194       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 54148       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#           AGE1STCODE                                          LEARNCODE  \
# 14882  18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 41840            NaN                                                NaN
# 4544   18 - 24 years                                    Coding Bootcamp
# 28378  11 - 17 years    Other online resources (ex: videos, blogs, etc)
# 55624   5 - 10 years                            Other (please specify):
# ...              ...                                                ...
# 75693  18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 73741  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 44094  25 - 34 years  Other online resources (ex: videos, blogs, etc...
# 13194  18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 54148  18 - 24 years  Other online resources (ex: videos, blogs, etc...
#
#       YEARSCODE YEARSCODEPRO  \
# 14882         8            4
# 41840       NaN          NaN
# 4544          4            2
# 28378         3          NaN
# 55624         4          NaN
# ...         ...          ...
# 75693         2          NaN
# 73741         5          NaN
# 44094         7            6
# 13194        18           14
# 54148        13            9
#
#                                                  DEVTYPE             ORGSIZE  \
# 14882  Developer, front-end;Developer, full-stack;Dev...  20 to 99 employees
# 41840                                                NaN                 NaN
# 4544   Developer, mobile;Developer, front-end;Develop...  20 to 99 employees
# 28378                                                NaN                 NaN
# 55624                                                NaN                 NaN
# ...                                                  ...                 ...
# 75693                                                NaN                 NaN
# 73741                                                NaN                 NaN
# 44094              Developer, mobile;Developer, back-end  20 to 99 employees
# 13194  Developer, back-end;Database administrator;Sys...    2 to 9 employees
# 54148  Developer, front-end;Developer, desktop or ent...  10 to 19 employees
#
#                         CURRENCY  COMPTOTAL COMPFREQ  \
# 14882        AFN\tAfghan afghani     6500.0   Weekly
# 41840                        NaN        NaN      NaN
# 4544        CAD\tCanadian dollar        NaN  Monthly
# 28378                        NaN        NaN      NaN
# 55624                        NaN        NaN      NaN
# ...                          ...        ...      ...
# 75693                        NaN        NaN      NaN
# 73741                        NaN        NaN      NaN
# 44094  USD\tUnited States dollar        NaN  Monthly
# 13194  USD\tUnited States dollar        NaN      NaN
# 54148  USD\tUnited States dollar     1461.0  Monthly
#
#                                   LANGUAGEHAVEWORKEDWITH  \
# 14882                        HTML/CSS;JavaScript;PHP;SQL
# 41840                                                NaN
# 4544          Dart;HTML/CSS;JavaScript;Python;TypeScript
# 28378                                HTML/CSS;JavaScript
# 55624  APL;Assembly;Bash/Shell;C;C#;C++;Clojure;COBOL...
# ...                                                  ...
# 75693                                             Python
# 73741  Bash/Shell;C#;Go;HTML/CSS;JavaScript;PowerShel...
# 44094                          Dart;Go;Java;Python;Scala
# 13194                                               Rust
# 54148                             C#;HTML/CSS;JavaScript
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 14882                HTML/CSS;JavaScript;Node.js;PHP;SQL
# 41840                                                NaN
# 4544   Dart;HTML/CSS;JavaScript;Node.js;Python;Rust;S...
# 28378                                HTML/CSS;JavaScript
# 55624                                                NaN
# ...                                                  ...
# 75693                                HTML/CSS;JavaScript
# 73741                                                NaN
# 44094                         Dart;Go;Java;Kotlin;Python
# 13194                                               Rust
# 54148           C#;HTML/CSS;JavaScript;Python;TypeScript
#
#                                   DATABASEHAVEWORKEDWITH  \
# 14882  Elasticsearch;Firebase;MongoDB;MySQL;Redis;SQLite
# 41840                                                NaN
# 4544                            Oracle;PostgreSQL;SQLite
# 28378                                                NaN
# 55624                                                NaN
# ...                                                  ...
# 75693                                              MySQL
# 73741                                  PostgreSQL;SQLite
# 44094                                        MySQL;Redis
# 13194                                                NaN
# 54148                               Microsoft SQL Server
#
#                         DATABASEWANTTOWORKWITH  \
# 14882     Elasticsearch;Firebase;MariaDB;MySQL
# 41840                                      NaN
# 4544        Firebase;MongoDB;PostgreSQL;SQLite
# 28378                                      NaN
# 55624                                      NaN
# ...                                        ...
# 75693                                      NaN
# 73741                                      NaN
# 44094     Elasticsearch;MySQL;PostgreSQL;Redis
# 13194                                      NaN
# 54148  Microsoft SQL Server;MongoDB;PostgreSQL
#
#                             PLATFORMHAVEWORKEDWITH  \
# 14882  AWS;DigitalOcean;Heroku;IBM Cloud or Watson
# 41840                                          NaN
# 4544                  Google Cloud Platform;Heroku
# 28378                                          NaN
# 55624                                          NaN
# ...                                            ...
# 75693                                          NaN
# 73741                                          NaN
# 44094                                          NaN
# 13194                                          NaN
# 54148                              Microsoft Azure
#
#                                  PLATFORMWANTTOWORKWITH  \
# 14882                           AWS;DigitalOcean;Heroku
# 41840                                               NaN
# 4544   AWS;Google Cloud Platform;Heroku;Microsoft Azure
# 28378                                               NaN
# 55624                                               NaN
# ...                                                 ...
# 75693                                               NaN
# 73741                                               NaN
# 44094                                               NaN
# 13194                                               NaN
# 54148                               AWS;Microsoft Azure
#
#                                   WEBFRAMEHAVEWORKEDWITH  \
# 14882  Angular;Angular.js;Drupal;jQuery;Laravel;React.js
# 41840                                                NaN
# 4544                               Django;Flask;React.js
# 28378                                                NaN
# 55624                             React.js;Ruby on Rails
# ...                                                  ...
# 75693                                             Django
# 73741                     Angular;Django;jQuery;React.js
# 44094                           Angular.js;Django;Spring
# 13194                                                NaN
# 54148                     ASP.NET;ASP.NET Core ;React.js
#
#                                   WEBFRAMEWANTTOWORKWITH  ...  \
# 14882  Angular;Angular.js;Drupal;jQuery;Laravel;React.js  ...
# 41840                                                NaN  ...
# 4544                       Django;FastAPI;Flask;React.js  ...
# 28378                                                NaN  ...
# 55624                                                NaN  ...
# ...                                                  ...  ...
# 75693                                            ASP.NET  ...
# 73741                                                NaN  ...
# 44094                                    React.js;Vue.js  ...
# 13194                                                NaN  ...
# 54148                             ASP.NET Core ;React.js  ...
#
#                                   MISCTECHWANTTOWORKWITH  \
# 14882                                                NaN
# 41840                                                NaN
# 4544   Flutter;Keras;NumPy;Pandas;TensorFlow;Torch/Py...
# 28378                                                NaN
# 55624                                                NaN
# ...                                                  ...
# 75693                                                NaN
# 73741                                                NaN
# 44094                                            Flutter
# 13194                                                NaN
# 54148  .NET Core / .NET 5;Qt;React Native;TensorFlow;...
#
#       TOOLSTECHHAVEWORKEDWITH        TOOLSTECHWANTTOWORKWITH  \
# 14882              Docker;Git                     Docker;Git
# 41840                     NaN                            NaN
# 4544          Docker;Git;Yarn  Deno;Docker;Git;Unity 3D;Yarn
# 28378                Unity 3D                            NaN
# 55624                     NaN                            NaN
# ...                       ...                            ...
# 75693                     NaN                            NaN
# 73741                     Git                            NaN
# 44094              Docker;Git     Deno;Docker;Git;Kubernetes
# 13194                     Git                            Git
# 54148                     Git         Git;Kubernetes;Xamarin
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 14882  Atom;Eclipse;NetBeans;Notepad++;PHPStorm;Subli...
# 41840                                                NaN
# 4544      Android Studio;Sublime Text;Visual Studio Code
# 28378                       Notepad++;Visual Studio Code
# 55624             Visual Studio;Visual Studio Code;Xcode
# ...                                                  ...
# 75693                       Android Studio;Visual Studio
# 73741  Android Studio;IPython/Jupyter;Sublime Text;Vi...
# 44094  Android Studio;IntelliJ;Neovim;Vim;Visual Stud...
# 13194                                                Vim
# 54148                   Visual Studio;Visual Studio Code
#
#                     NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 14882  Notepad++;Sublime Text;Visual Studio Code  Linux-based
# 41840                                        NaN  Linux-based
# 4544     Android Studio;Visual Studio Code;Xcode      Windows
# 28378                                        NaN      Windows
# 55624                                        NaN      Windows
# ...                                          ...          ...
# 75693                   Visual Studio Code;Xcode      Windows
# 73741                                        NaN      Windows
# 44094                        IntelliJ;Neovim;Vim  Linux-based
# 13194                                        Vim  Linux-based
# 54148           Visual Studio;Visual Studio Code      Windows
#
#                                                 NEWSTUCK  \
# 14882  Call a coworker or friend;Visit Stack Overflow...
# 41840   Visit another developer community (please name):
# 4544   Visit Stack Overflow;Go for a walk or other ph...
# 28378  Google it;Watch help / tutorial videos;Do othe...
# 55624                               Visit Stack Overflow
# ...                                                  ...
# 75693  Visit Stack Overflow;Go for a walk or other ph...
# 73741  Call a coworker or friend;Visit Stack Overflow...
# 44094  Call a coworker or friend;Visit Stack Overflow...
# 13194  Visit Stack Overflow;Google it;Watch help / tu...
# 54148  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSITES  \
# 14882                      Stack Overflow;Stack Exchange
# 41840                                                NaN
# 4544                                      Stack Overflow
# 28378                      Stack Overflow;Stack Exchange
# 55624  Stack Overflow;Stack Exchange;Stack Overflow f...
# ...                                                  ...
# 75693                      Stack Overflow;Stack Exchange
# 73741                                     Stack Overflow
# 44094                      Stack Overflow;Stack Exchange
# 13194                      Stack Overflow;Stack Exchange
# 54148                      Stack Overflow;Stack Exchange
#
#                                SOVISITFREQ SOACCOUNT  \
# 14882                Daily or almost daily      True
# 41840                                  NaN       NaN
# 4544                  A few times per week      True
# 28378  Less than once per month or monthly     False
# 55624                 A few times per week      True
# ...                                    ...       ...
# 75693      A few times per month or weekly      True
# 73741                 A few times per week      True
# 44094      A few times per month or weekly      True
# 13194                 A few times per week      True
# 54148                 A few times per week      True
#
#                                               SOPARTFREQ           SOCOMM  \
# 14882                    A few times per month or weekly    Yes, somewhat
# 41840                                                NaN   No, not really
# 4544                 Less than once per month or monthly    Yes, somewhat
# 28378                                                NaN   No, not at all
# 55624                               A few times per week         Not sure
# ...                                                  ...              ...
# 75693                Less than once per month or monthly    Yes, somewhat
# 73741  I have never participated in Q&A on Stack Over...  Yes, definitely
# 44094  I have never participated in Q&A on Stack Over...   No, not really
# 13194  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 54148                    A few times per month or weekly    Yes, somewhat
#
#       NEWOTHERCOMMS                 AGE GENDER TRANS                SEXUALITY  \
# 14882           Yes     25-34 years old    Man    No                      NaN
# 41840           Yes                 NaN    NaN   NaN                      NaN
# 4544             No     18-24 years old    Man    No  Straight / Heterosexual
# 28378            No  Under 18 years old    Man    No  Straight / Heterosexual
# 55624            No                 NaN    NaN   NaN                      NaN
# ...             ...                 ...    ...   ...                      ...
# 75693           Yes     18-24 years old    Man    No  Straight / Heterosexual
# 73741           Yes     18-24 years old    Man    No  Straight / Heterosexual
# 44094            No                 NaN    Man    No  Straight / Heterosexual
# 13194           Yes     35-44 years old    Man    No  Straight / Heterosexual
# 54148           Yes     35-44 years old    Man    No  Straight / Heterosexual
#
#                          ETHNICITY           ACCESSIBILITY  \
# 14882                  South Asian       None of the above
# 41840                          NaN                     NaN
# 4544                Middle Eastern       None of the above
# 28378              Southeast Asian  Or, in your own words:
# 55624                          NaN                     NaN
# ...                            ...                     ...
# 75693  Black or of African descent       None of the above
# 73741  Black or of African descent       None of the above
# 44094  Black or of African descent       Prefer not to say
# 13194  Black or of African descent       None of the above
# 54148  Black or of African descent       None of the above
#
#                      MENTALHEALTH           SURVEYLENGTH  \
# 14882           None of the above  Appropriate in length
# 41840                         NaN               Too long
# 4544            None of the above  Appropriate in length
# 28378           None of the above  Appropriate in length
# 55624                         NaN               Too long
# ...                           ...                    ...
# 75693  I have an anxiety disorder  Appropriate in length
# 73741           None of the above  Appropriate in length
# 44094           None of the above              Too short
# 13194           None of the above               Too long
# 54148           None of the above  Appropriate in length
#
#                        SURVEYEASE CONVERTEDCOMPYEARLY  \
# 14882                        Easy              4200.0
# 41840                   Difficult                 NaN
# 4544                         Easy                 NaN
# 28378                        Easy                 NaN
# 55624  Neither easy nor difficult                 NaN
# ...                           ...                 ...
# 75693  Neither easy nor difficult                 NaN
# 73741  Neither easy nor difficult                 NaN
# 44094  Neither easy nor difficult                 NaN
# 13194                        Easy                 NaN
# 54148                        Easy             17532.0
#
#                                                    AYUDA
# 14882  Call a coworker or friend;Visit Stack Overflow...
# 41840                                                NaN
# 4544   Visit Stack Overflow;Go for a walk or other ph...
# 28378  Google it;Watch help / tutorial videos;Do othe...
# 55624  Visit Stack Overflow Stack Overflow;Stack Exch...
# ...                                                  ...
# 75693  Visit Stack Overflow;Go for a walk or other ph...
# 73741  Call a coworker or friend;Visit Stack Overflow...
# 44094  Call a coworker or friend;Visit Stack Overflow...
# 13194  Visit Stack Overflow;Google it;Watch help / tu...
# 54148  Call a coworker or friend;Visit Stack Overflow...
#
# [83439 rows x 49 columns]

# %%
datos.sort_values(by="COUNTRY", ascending=False)
# Out:
#        RESPONSEID                              MAINBRANCH  \
# 71232       71233  I am a student who is learning to code
# 61695       61696          I am a developer by profession
# 59222       59223          I am a developer by profession
# 13194       13195          I am a developer by profession
# 13395       13396          I am a developer by profession
# ...           ...                                     ...
# 72314       72315                           None of these
# 72548       72549          I am a developer by profession
# 20301       20302          I am a developer by profession
# 67508       67509  I am a student who is learning to code
# 24552       24553  I am a student who is learning to code
#
#                                               EMPLOYMENT      COUNTRY USSTATE  \
# 71232                 Not employed, but looking for work     ZIMBABWE     NaN
# 61695                                 Employed part-time     ZIMBABWE     NaN
# 59222  Independent contractor, freelancer, or self-em...     ZIMBABWE     NaN
# 13194                                 Employed full-time     ZIMBABWE     NaN
# 13395                 Not employed, but looking for work     ZIMBABWE     NaN
# ...                                                  ...          ...     ...
# 72314                                            Retired  AFGHANISTAN     NaN
# 72548                                 Employed part-time  AFGHANISTAN     NaN
# 20301                                 Student, part-time  AFGHANISTAN     NaN
# 67508                                I prefer not to say  AFGHANISTAN     NaN
# 24552                                 Student, part-time  AFGHANISTAN     NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 71232       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 61695       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 59222       NaN                                     Something else
# 13194       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 13395       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...         ...                                                ...
# 72314       NaN                          Primary/elementary school
# 72548       NaN                          Primary/elementary school
# 20301       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 67508       NaN                          Primary/elementary school
# 24552       NaN  Some college/university study without earning ...
#
#                  AGE1STCODE  \
# 71232         18 - 24 years
# 61695         11 - 17 years
# 59222          5 - 10 years
# 13194         18 - 24 years
# 13395         11 - 17 years
# ...                     ...
# 72314   Older than 64 years
# 72548         25 - 34 years
# 20301         18 - 24 years
# 67508  Younger than 5 years
# 24552         18 - 24 years
#
#                                                LEARNCODE         YEARSCODE  \
# 71232  School;Online Courses or Certification;Books /...                 4
# 61695  Other online resources (ex: videos, blogs, etc...                 8
# 59222  Other online resources (ex: videos, blogs, etc...                10
# 13194  Other online resources (ex: videos, blogs, etc...                18
# 13395                                             School               NaN
# ...                                                  ...               ...
# 72314                            Other (please specify):  Less than 1 year
# 72548             Coding Bootcamp;Books / Physical media                 7
# 20301  Other online resources (ex: videos, blogs, etc...                 2
# 67508                             Books / Physical media  Less than 1 year
# 24552                                             School                 3
#
#            YEARSCODEPRO                                            DEVTYPE  \
# 71232               NaN                                            Student
# 61695                 4  Developer, mobile;Developer, front-end;Develop...
# 59222                 3  Developer, mobile;Developer, desktop or enterp...
# 13194                14  Developer, back-end;Database administrator;Sys...
# 13395               NaN  Developer, mobile;Developer, front-end;Develop...
# ...                 ...                                                ...
# 72314  Less than 1 year                                                NaN
# 72548                 5                                Academic researcher
# 20301               NaN                                                NaN
# 67508               NaN                                                NaN
# 24552               NaN                                                NaN
#
#                   ORGSIZE                   CURRENCY  COMPTOTAL COMPFREQ  \
# 71232                 NaN                        NaN        NaN      NaN
# 61695    2 to 9 employees  USD\tUnited States dollar     4000.0   Yearly
# 59222    2 to 9 employees  USD\tUnited States dollar        NaN      NaN
# 13194    2 to 9 employees  USD\tUnited States dollar        NaN      NaN
# 13395                 NaN                        NaN        NaN      NaN
# ...                   ...                        ...        ...      ...
# 72314                 NaN                        NaN        NaN      NaN
# 72548  10 to 19 employees     AUD\tAustralian dollar        NaN  Monthly
# 20301                 NaN                        NaN        NaN      NaN
# 67508                 NaN                        NaN        NaN      NaN
# 24552                 NaN                        NaN        NaN      NaN
#
#                                   LANGUAGEHAVEWORKEDWITH  \
# 71232  C;C++;Dart;HTML/CSS;Java;JavaScript;PHP;Python...
# 61695                         C#;Java;JavaScript;Node.js
# 59222                               Dart;HTML/CSS;Python
# 13194                                               Rust
# 13395                Bash/Shell;Java;Rust;SQL;TypeScript
# ...                                                  ...
# 72314                 Assembly;Bash/Shell;C;COBOL;Erlang
# 72548                                 C#;Clojure;Crystal
# 20301                            HTML/CSS;JavaScript;PHP
# 67508                                                APL
# 24552                     C;HTML/CSS;Java;JavaScript;SQL
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 71232                                                NaN
# 61695                                                NaN
# 59222                               Dart;HTML/CSS;Python
# 13194                                               Rust
# 13395                                Rust;SQL;TypeScript
# ...                                                  ...
# 72314                                                NaN
# 72548                                                NaN
# 20301                     Java;JavaScript;PHP;TypeScript
# 67508                                                NaN
# 24552  HTML/CSS;JavaScript;Node.js;Python;SQL;TypeScript
#
#                                   DATABASEHAVEWORKEDWITH  \
# 71232                                       MySQL;SQLite
# 61695              Firebase;Microsoft SQL Server;MongoDB
# 59222                    Firebase;MySQL;PostgreSQL;Redis
# 13194                                                NaN
# 13395                           Firebase;MariaDB;MongoDB
# ...                                                  ...
# 72314                                                NaN
# 72548  Couchbase;Elasticsearch;MariaDB;Microsoft SQL ...
# 20301                                              MySQL
# 67508                                                NaN
# 24552                                              MySQL
#
#          DATABASEWANTTOWORKWITH  \
# 71232                       NaN
# 61695                       NaN
# 59222    MySQL;PostgreSQL;Redis
# 13194                       NaN
# 13395                   MariaDB
# ...                         ...
# 72314                       NaN
# 72548                       NaN
# 20301  MongoDB;MySQL;PostgreSQL
# 67508                       NaN
# 24552              MySQL;Oracle
#
#                                PLATFORMHAVEWORKEDWITH  \
# 71232                                             NaN
# 61695                           Google Cloud Platform
# 59222                                          Heroku
# 13194                                             NaN
# 13395         AWS;IBM Cloud or Watson;Microsoft Azure
# ...                                               ...
# 72314                                             NaN
# 72548  AWS;Heroku;IBM Cloud or Watson;Microsoft Azure
# 20301                                             NaN
# 67508                                             NaN
# 24552                                             NaN
#
#                                   PLATFORMWANTTOWORKWITH  \
# 71232                                                NaN
# 61695  AWS;DigitalOcean;Heroku;IBM Cloud or Watson;Mi...
# 59222                                             Heroku
# 13194                                                NaN
# 13395                                                NaN
# ...                                                  ...
# 72314                                                NaN
# 72548                                                NaN
# 20301                                                NaN
# 67508                                                NaN
# 24552                                                NaN
#
#                      WEBFRAMEHAVEWORKEDWITH          WEBFRAMEWANTTOWORKWITH  \
# 71232                              React.js                             NaN
# 61695                              React.js  ASP.NET;Drupal;Express;Laravel
# 59222                                Django                          Django
# 13194                                   NaN                             NaN
# 13395               Laravel;React.js;Vue.js                        React.js
# ...                                     ...                             ...
# 72314                                   NaN                             NaN
# 72548  ASP.NET;ASP.NET Core ;Django;FastAPI                             NaN
# 20301                               Laravel                  Laravel;Vue.js
# 67508                                   NaN                             NaN
# 24552                                   NaN                             NaN
#
#        ... MISCTECHWANTTOWORKWITH      TOOLSTECHHAVEWORKEDWITH  \
# 71232  ...                    NaN                          NaN
# 61695  ...                    NaN                     Git;Yarn
# 59222  ...                Flutter                          Git
# 13194  ...                    NaN                          Git
# 13395  ...             TensorFlow                         Yarn
# ...    ...                    ...                          ...
# 72314  ...                    NaN                          NaN
# 72548  ...                    NaN  Chef;Deno;Docker;Git;Pulumi
# 20301  ...                    NaN                          Git
# 67508  ...                    NaN                          NaN
# 24552  ...                    NaN                          NaN
#
#       TOOLSTECHWANTTOWORKWITH  \
# 71232                     NaN
# 61695            Xamarin;Yarn
# 59222              Docker;Git
# 13194                     Git
# 13395                    Yarn
# ...                       ...
# 72314                     NaN
# 72548                     NaN
# 20301                     Git
# 67508                     NaN
# 24552                     NaN
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 71232             Android Studio;Atom;Visual Studio Code
# 61695  Android Studio;Atom;Eclipse;Notepad++;Visual S...
# 59222  Android Studio;Atom;IntelliJ;IPython/Jupyter;P...
# 13194                                                Vim
# 13395  Android Studio;IntelliJ;Neovim;Vim;Visual Stud...
# ...                                                  ...
# 72314                                                Vim
# 72548                   Emacs;IntelliJ;NetBeans;PHPStorm
# 20301                        PHPStorm;Visual Studio Code
# 67508                                                NaN
# 24552       Atom;PyCharm;Sublime Text;Visual Studio Code
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH  \
# 71232                                                NaN
# 61695                                                NaN
# 59222  Android Studio;Atom;IntelliJ;IPython/Jupyter;P...
# 13194                                                Vim
# 13395                          Neovim;Visual Studio Code
# ...                                                  ...
# 72314                                                NaN
# 72548                                                NaN
# 20301                                 Visual Studio Code
# 67508                                                NaN
# 24552  Android Studio;Sublime Text;Visual Studio Code...
#
#                          OPSYS  \
# 71232                    MacOS
# 61695                    MacOS
# 59222              Linux-based
# 13194              Linux-based
# 13395              Linux-based
# ...                        ...
# 72314  Other (please specify):
# 72548                  Windows
# 20301              Linux-based
# 67508  Other (please specify):
# 24552              Linux-based
#
#                                                 NEWSTUCK  \
# 71232  Call a coworker or friend;Visit Stack Overflow...
# 61695  Visit Stack Overflow;Google it;Visit another d...
# 59222  Visit Stack Overflow;Go for a walk or other ph...
# 13194  Visit Stack Overflow;Google it;Watch help / tu...
# 13395  Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 72314  Meditate;Panic;Visit another developer communi...
# 72548  Call a coworker or friend;Visit Stack Overflow...
# 20301  Call a coworker or friend;Visit Stack Overflow...
# 67508                                              Panic
# 24552  Google it;Watch help / tutorial videos;Do othe...
#
#                                               NEWSOSITES  \
# 71232                      Stack Overflow;Stack Exchange
# 61695  Stack Overflow;Stack Exchange;Stack Overflow f...
# 59222                      Stack Overflow;Stack Exchange
# 13194                      Stack Overflow;Stack Exchange
# 13395                      Stack Overflow;Stack Exchange
# ...                                                  ...
# 72314                      Stack Overflow;Stack Exchange
# 72548                      Stack Overflow;Stack Exchange
# 20301                      Stack Overflow;Stack Exchange
# 67508  I have never visited Stack Overflow or the Sta...
# 24552                                     Stack Overflow
#
#                            SOVISITFREQ SOACCOUNT  \
# 71232             A few times per week      True
# 61695            Daily or almost daily      True
# 59222           Multiple times per day      True
# 13194             A few times per week      True
# 13395  A few times per month or weekly      True
# ...                                ...       ...
# 72314           Multiple times per day      True
# 72548  A few times per month or weekly      True
# 20301  A few times per month or weekly      True
# 67508                              NaN       NaN
# 24552  A few times per month or weekly       NaN
#
#                                               SOPARTFREQ           SOCOMM  \
# 71232                    A few times per month or weekly  Yes, definitely
# 61695  I have never participated in Q&A on Stack Over...  Yes, definitely
# 59222                               A few times per week    Yes, somewhat
# 13194  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 13395                    A few times per month or weekly    Yes, somewhat
# ...                                                  ...              ...
# 72314                             Multiple times per day  Yes, definitely
# 72548                    A few times per month or weekly          Neutral
# 20301                Less than once per month or monthly    Yes, somewhat
# 67508                                                NaN              NaN
# 24552                                                NaN    Yes, somewhat
#
#       NEWOTHERCOMMS                AGE                  GENDER  \
# 71232            No    18-24 years old                     Man
# 61695           Yes    25-34 years old                     Man
# 59222           Yes    18-24 years old                     Man
# 13194           Yes    35-44 years old                     Man
# 13395           Yes    18-24 years old                     Man
# ...             ...                ...                     ...
# 72314           Yes  65 years or older  Or, in your own words:
# 72548           Yes    25-34 years old                     Man
# 20301           Yes    18-24 years old                     Man
# 67508           Yes  Prefer not to say       Prefer not to say
# 24552            No    18-24 years old                     Man
#
#                         TRANS  \
# 71232                      No
# 61695                      No
# 59222                      No
# 13194                      No
# 13395                      No
# ...                       ...
# 72314                     Yes
# 72548                     Yes
# 20301                     NaN
# 67508                     Yes
# 24552  Or, in your own words:
#
#                                                SEXUALITY  \
# 71232                            Straight / Heterosexual
# 61695                            Straight / Heterosexual
# 59222                            Straight / Heterosexual
# 13194                            Straight / Heterosexual
# 13395                            Straight / Heterosexual
# ...                                                  ...
# 72314  Straight / Heterosexual;Bisexual;Prefer to sel...
# 72548                            Bisexual;Gay or Lesbian
# 20301                                                NaN
# 67508                                           Bisexual
# 24552                            Straight / Heterosexual
#
#                                                ETHNICITY  \
# 71232                        Black or of African descent
# 61695                        Black or of African descent
# 59222                        Black or of African descent
# 13194                        Black or of African descent
# 13395                        Black or of African descent
# ...                                                  ...
# 72314  Multiracial;East Asian;Biracial;Or, in your ow...
# 72548        White or of European descent;Middle Eastern
# 20301                          Middle Eastern;East Asian
# 67508  Indigenous (such as Native American, Pacific I...
# 24552                                       I don't know
#
#                                            ACCESSIBILITY  \
# 71232                                  None of the above
# 61695                                                NaN
# 59222                                  None of the above
# 13194                                  None of the above
# 13395                                  None of the above
# ...                                                  ...
# 72314  I am deaf / hard of hearing;I am blind / have ...
# 72548  I am deaf / hard of hearing;I am unable to / f...
# 20301                                  None of the above
# 67508  I am unable to / find it difficult to walk or ...
# 24552                                  None of the above
#
#                                             MENTALHEALTH  \
# 71232                                  None of the above
# 61695                                                NaN
# 59222                                  None of the above
# 13194                                  None of the above
# 13395  I have a mood or emotional disorder (e.g. depr...
# ...                                                  ...
# 72314  I have a concentration and/or memory disorder ...
# 72548  I have a mood or emotional disorder (e.g. depr...
# 20301                                  None of the above
# 67508  I have autism / an autism spectrum disorder (e...
# 24552                                  None of the above
#
#                 SURVEYLENGTH                  SURVEYEASE CONVERTEDCOMPYEARLY  \
# 71232               Too long  Neither easy nor difficult                 NaN
# 61695               Too long  Neither easy nor difficult              4000.0
# 59222  Appropriate in length  Neither easy nor difficult                 NaN
# 13194               Too long                        Easy                 NaN
# 13395  Appropriate in length                        Easy                 NaN
# ...                      ...                         ...                 ...
# 72314              Too short                        Easy                 NaN
# 72548               Too long                        Easy                 NaN
# 20301               Too long                        Easy                 NaN
# 67508               Too long                         NaN                 NaN
# 24552  Appropriate in length  Neither easy nor difficult                 NaN
#
#                                                    AYUDA
# 71232  Call a coworker or friend;Visit Stack Overflow...
# 61695  Visit Stack Overflow;Google it;Visit another d...
# 59222  Visit Stack Overflow;Go for a walk or other ph...
# 13194  Visit Stack Overflow;Google it;Watch help / tu...
# 13395  Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 72314  Meditate;Panic;Visit another developer communi...
# 72548  Call a coworker or friend;Visit Stack Overflow...
# 20301  Call a coworker or friend;Visit Stack Overflow...
# 67508  Panic I have never visited Stack Overflow or t...
# 24552  Google it;Watch help / tutorial videos;Do othe...
#
# [83439 rows x 49 columns]

# %%
datos.sort_values(by=["COUNTRY", "CONVERTEDCOMPYEARLY"])
# Out:
#        RESPONSEID                              MAINBRANCH  \
# 55150       55151          I am a developer by profession
# 17120       17121          I am a developer by profession
# 14882       14883          I am a developer by profession
# 51428       51429          I am a developer by profession
# 17486       17487          I am a developer by profession
# ...           ...                                     ...
# 75693       75694  I am a student who is learning to code
# 76082       76083          I am a developer by profession
# 79301       79302  I am a student who is learning to code
# 80996       80997             I code primarily as a hobby
# 82406       82407  I am a student who is learning to code
#
#                                    EMPLOYMENT      COUNTRY USSTATE UKCOUNTRY  \
# 55150                                 Retired  AFGHANISTAN     NaN       NaN
# 17120                      Employed full-time  AFGHANISTAN     NaN       NaN
# 14882                      Employed full-time  AFGHANISTAN     NaN       NaN
# 51428                      Employed full-time  AFGHANISTAN     NaN       NaN
# 17486                      Employed full-time  AFGHANISTAN     NaN       NaN
# ...                                       ...          ...     ...       ...
# 75693                      Student, full-time     ZIMBABWE     NaN       NaN
# 76082      Not employed, but looking for work     ZIMBABWE     NaN       NaN
# 79301                      Student, part-time     ZIMBABWE     NaN       NaN
# 80996  Not employed, and not looking for work     ZIMBABWE     NaN       NaN
# 82406                      Employed part-time     ZIMBABWE     NaN       NaN
#
#                                                  EDLEVEL  \
# 55150  Secondary school (e.g. American high school, G...
# 17120       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 14882       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 51428       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17486       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                  ...
# 75693  Secondary school (e.g. American high school, G...
# 76082       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 79301  Secondary school (e.g. American high school, G...
# 80996                          Primary/elementary school
# 82406  Some college/university study without earning ...
#
#                  AGE1STCODE  \
# 55150  Younger than 5 years
# 17120         18 - 24 years
# 14882         18 - 24 years
# 51428         18 - 24 years
# 17486         18 - 24 years
# ...                     ...
# 75693         18 - 24 years
# 76082         18 - 24 years
# 79301         35 - 44 years
# 80996         11 - 17 years
# 82406         18 - 24 years
#
#                                                LEARNCODE         YEARSCODE  \
# 55150  Coding Bootcamp;Other online resources (ex: vi...  Less than 1 year
# 17120          Online Courses or Certification;Colleague                 3
# 14882  Coding Bootcamp;Other online resources (ex: vi...                 8
# 51428  Other online resources (ex: videos, blogs, etc...                 7
# 17486                    Online Courses or Certification                 7
# ...                                                  ...               ...
# 75693  Other online resources (ex: videos, blogs, etc...                 2
# 76082  Other online resources (ex: videos, blogs, etc...                 3
# 79301    Other online resources (ex: videos, blogs, etc)                 1
# 80996  Other online resources (ex: videos, blogs, etc...  Less than 1 year
# 82406                      School;Books / Physical media                 3
#
#              YEARSCODEPRO                                            DEVTYPE  \
# 55150  More than 50 years                                                NaN
# 17120                   1  Developer, front-end;Developer, full-stack;Dev...
# 14882                   4  Developer, front-end;Developer, full-stack;Dev...
# 51428                   3  Developer, mobile;Developer, front-end;Develop...
# 17486                   3  Developer, mobile;Developer, front-end;Develop...
# ...                   ...                                                ...
# 75693                 NaN                                                NaN
# 76082                 NaN                              Developer, full-stack
# 79301                 NaN                                                NaN
# 80996                 NaN                                                NaN
# 82406                 NaN  Developer, front-end;Developer, back-end;Datab...
#
#                         ORGSIZE             CURRENCY  COMPTOTAL COMPFREQ  \
# 55150  10,000 or more employees   AWG\tAruban florin        3.0   Weekly
# 17120      100 to 499 employees  AFN\tAfghan afghani    20000.0  Monthly
# 14882        20 to 99 employees  AFN\tAfghan afghani     6500.0   Weekly
# 51428        10 to 19 employees  AFN\tAfghan afghani    30000.0  Monthly
# 17486        10 to 19 employees  AFN\tAfghan afghani    35000.0  Monthly
# ...                         ...                  ...        ...      ...
# 75693                       NaN                  NaN        NaN      NaN
# 76082                       NaN                  NaN        NaN      NaN
# 79301                       NaN                  NaN        NaN      NaN
# 80996                       NaN                  NaN        NaN      NaN
# 82406                       NaN                  NaN        NaN      NaN
#
#                                   LANGUAGEHAVEWORKEDWITH  \
# 55150       APL;Assembly;C;Delphi;Objective-C;PowerShell
# 17120  HTML/CSS;JavaScript;Node.js;PHP;Python;SQL;Typ...
# 14882                        HTML/CSS;JavaScript;PHP;SQL
# 51428      Java;JavaScript;Kotlin;Node.js;PHP;TypeScript
# 17486                     Java;JavaScript;Kotlin;PHP;SQL
# ...                                                  ...
# 75693                                             Python
# 76082                    C++;Dart;Java;JavaScript;Python
# 79301                                                NaN
# 80996                 HTML/CSS;JavaScript;Node.js;Python
# 82406                           C#;JavaScript;PHP;Python
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 55150  Assembly;Bash/Shell;Clojure;Java;JavaScript;Ob...
# 17120  HTML/CSS;JavaScript;Node.js;PHP;Python;SQL;Typ...
# 14882                HTML/CSS;JavaScript;Node.js;PHP;SQL
# 51428              Dart;JavaScript;Kotlin;Node.js;Python
# 17486  Dart;Java;JavaScript;Kotlin;Node.js;PHP;Python...
# ...                                                  ...
# 75693                                HTML/CSS;JavaScript
# 76082                                        Dart;Python
# 79301                                                NaN
# 80996      Assembly;C#;C++;Go;Java;Kotlin;Node.js;Python
# 82406  C#;Java;JavaScript;Kotlin;Matlab;Node.js;PHP;P...
#
#                                   DATABASEHAVEWORKEDWITH  \
# 55150                                           DynamoDB
# 17120                                      MariaDB;MySQL
# 14882  Elasticsearch;Firebase;MongoDB;MySQL;Redis;SQLite
# 51428                                              MySQL
# 17486                                              MySQL
# ...                                                  ...
# 75693                                              MySQL
# 76082                                  PostgreSQL;SQLite
# 79301                            MySQL;PostgreSQL;SQLite
# 80996                                                NaN
# 82406                                              MySQL
#
#                      DATABASEWANTTOWORKWITH  \
# 55150                                   NaN
# 17120              MariaDB;MySQL;PostgreSQL
# 14882  Elasticsearch;Firebase;MariaDB;MySQL
# 51428                         MongoDB;MySQL
# 17486                         MongoDB;MySQL
# ...                                     ...
# 75693                                   NaN
# 76082                     PostgreSQL;SQLite
# 79301               MySQL;PostgreSQL;SQLite
# 80996                                   NaN
# 82406  DynamoDB;MariaDB;MySQL;Oracle;SQLite
#
#                             PLATFORMHAVEWORKEDWITH   PLATFORMWANTTOWORKWITH  \
# 55150                                          NaN                      NaN
# 17120                                          NaN                      NaN
# 14882  AWS;DigitalOcean;Heroku;IBM Cloud or Watson  AWS;DigitalOcean;Heroku
# 51428                                          NaN                      NaN
# 17486                                          NaN                      NaN
# ...                                            ...                      ...
# 75693                                          NaN                      NaN
# 76082                                       Heroku                   Heroku
# 79301                                          NaN                      NaN
# 80996                                          NaN                      NaN
# 82406                                          NaN                      NaN
#
#                                   WEBFRAMEHAVEWORKEDWITH  \
# 55150                               Ruby on Rails;Spring
# 17120          Angular.js;jQuery;Laravel;React.js;Vue.js
# 14882  Angular;Angular.js;Drupal;jQuery;Laravel;React.js
# 51428                             Angular;jQuery;Laravel
# 17486                                            Angular
# ...                                                  ...
# 75693                                             Django
# 76082                                             Django
# 79301                                             Django
# 80996                                           React.js
# 82406                                            ASP.NET
#
#                                   WEBFRAMEWANTTOWORKWITH  ...  \
# 55150                                     Symfony;Vue.js  ...
# 17120                     Django;jQuery;Laravel;React.js  ...
# 14882  Angular;Angular.js;Drupal;jQuery;Laravel;React.js  ...
# 51428                             Angular;Express;jQuery  ...
# 17486                                    Angular;Laravel  ...
# ...                                                  ...  ...
# 75693                                            ASP.NET  ...
# 76082                                             Django  ...
# 79301                                    Django;React.js  ...
# 80996                   Angular.js;Django;Express;jQuery  ...
# 82406                           Angular.js;Django;jQuery  ...
#
#                                   MISCTECHWANTTOWORKWITH  \
# 55150                                                NaN
# 17120                                                NaN
# 14882                                                NaN
# 51428                                 Flutter;TensorFlow
# 17486                                            Flutter
# ...                                                  ...
# 75693                                                NaN
# 76082                                            Flutter
# 79301                                                NaN
# 80996                                                NaN
# 82406  .NET Framework;Flutter;NumPy;Pandas;Torch/PyTorch
#
#       TOOLSTECHHAVEWORKEDWITH TOOLSTECHWANTTOWORKWITH  \
# 55150                    Deno                     NaN
# 17120                     NaN                     NaN
# 14882              Docker;Git              Docker;Git
# 51428                Git;Yarn                Git;Yarn
# 17486                     NaN                     NaN
# ...                       ...                     ...
# 75693                     NaN                     NaN
# 76082                     Git                     Git
# 79301                     Git      Ansible;Docker;Git
# 80996                     NaN                     NaN
# 82406                     NaN                     NaN
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 55150                                                NaN
# 17120  Android Studio;Atom;IntelliJ;IPython/Jupyter;V...
# 14882  Atom;Eclipse;NetBeans;Notepad++;PHPStorm;Subli...
# 51428  Android Studio;Eclipse;IntelliJ;Notepad++;Subl...
# 17486                  Android Studio;Visual Studio Code
# ...                                                  ...
# 75693                       Android Studio;Visual Studio
# 76082          IntelliJ;PyCharm;Visual Studio Code;Xcode
# 79301  Android Studio;PyCharm;Sublime Text;Visual Stu...
# 80996               Notepad++;PyCharm;Visual Studio Code
# 82406  IPython/Jupyter;NetBeans;Notepad++;PyCharm;Sub...
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 55150                                                NaN          NaN
# 17120    Android Studio;Visual Studio;Visual Studio Code      Windows
# 14882          Notepad++;Sublime Text;Visual Studio Code  Linux-based
# 51428  Android Studio;IntelliJ;Notepad++;Sublime Text...      Windows
# 17486                  Android Studio;Visual Studio Code      Windows
# ...                                                  ...          ...
# 75693                           Visual Studio Code;Xcode      Windows
# 76082          IntelliJ;PyCharm;Visual Studio Code;Xcode        MacOS
# 79301  Android Studio;PyCharm;Sublime Text;Visual Stu...  Linux-based
# 80996          Android Studio;PyCharm;Visual Studio Code      Windows
# 82406  Android Studio;Atom;IPython/Jupyter;NetBeans;P...      Windows
#
#                                                 NEWSTUCK  \
# 55150                                                NaN
# 17120  Call a coworker or friend;Visit Stack Overflow...
# 14882  Call a coworker or friend;Visit Stack Overflow...
# 51428  Visit Stack Overflow;Google it;Watch help / tu...
# 17486  Visit Stack Overflow;Google it;Watch help / tu...
# ...                                                  ...
# 75693  Visit Stack Overflow;Go for a walk or other ph...
# 76082  Call a coworker or friend;Visit Stack Overflow...
# 79301                     Visit Stack Overflow;Google it
# 80996  Watch help / tutorial videos;Do other work and...
# 82406  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSITES  \
# 55150  Stack Overflow for Teams (private knowledge sh...
# 17120                      Stack Overflow;Stack Exchange
# 14882                      Stack Overflow;Stack Exchange
# 51428                      Stack Overflow;Stack Exchange
# 17486                                     Stack Overflow
# ...                                                  ...
# 75693                      Stack Overflow;Stack Exchange
# 76082                                     Stack Overflow
# 79301                                     Stack Overflow
# 80996                                     Stack Overflow
# 82406                      Stack Overflow;Stack Exchange
#
#                            SOVISITFREQ SOACCOUNT  \
# 55150             A few times per week       NaN
# 17120            Daily or almost daily      True
# 14882            Daily or almost daily      True
# 51428           Multiple times per day      True
# 17486             A few times per week      True
# ...                                ...       ...
# 75693  A few times per month or weekly      True
# 76082            Daily or almost daily      True
# 79301            Daily or almost daily      True
# 80996  A few times per month or weekly      True
# 82406            Daily or almost daily      True
#
#                                               SOPARTFREQ           SOCOMM  \
# 55150                                                NaN   No, not at all
# 17120                               A few times per week  Yes, definitely
# 14882                    A few times per month or weekly    Yes, somewhat
# 51428                Less than once per month or monthly  Yes, definitely
# 17486                Less than once per month or monthly  Yes, definitely
# ...                                                  ...              ...
# 75693                Less than once per month or monthly    Yes, somewhat
# 76082                    A few times per month or weekly  Yes, definitely
# 79301                Less than once per month or monthly    Yes, somewhat
# 80996  I have never participated in Q&A on Stack Over...   No, not really
# 82406                              Daily or almost daily  Yes, definitely
#
#       NEWOTHERCOMMS                 AGE  \
# 55150            No     35-44 years old
# 17120            No     18-24 years old
# 14882           Yes     25-34 years old
# 51428           Yes     25-34 years old
# 17486            No     25-34 years old
# ...             ...                 ...
# 75693           Yes     18-24 years old
# 76082           Yes     18-24 years old
# 79301            No     35-44 years old
# 80996            No  Under 18 years old
# 82406            No     18-24 years old
#
#                                                   GENDER  \
# 55150  Man;Woman;Non-binary, genderqueer, or gender n...
# 17120                                                Man
# 14882                                                Man
# 51428                                                Man
# 17486                                                Man
# ...                                                  ...
# 75693                                                Man
# 76082                                                Man
# 79301                                                Man
# 80996                                                Man
# 82406                                                Man
#
#                         TRANS  \
# 55150  Or, in your own words:
# 17120                      No
# 14882                      No
# 51428                      No
# 17486                      No
# ...                       ...
# 75693                      No
# 76082                      No
# 79301                      No
# 80996                      No
# 82406       Prefer not to say
#
#                                               SEXUALITY  \
# 55150  Straight / Heterosexual;Prefer to self-describe:
# 17120                                          Bisexual
# 14882                                               NaN
# 51428                           Straight / Heterosexual
# 17486                           Straight / Heterosexual
# ...                                                 ...
# 75693                           Straight / Heterosexual
# 76082                           Straight / Heterosexual
# 79301                                               NaN
# 80996                           Straight / Heterosexual
# 82406                           Straight / Heterosexual
#
#                          ETHNICITY                        ACCESSIBILITY  \
# 55150  Black or of African descent               Or, in your own words:
# 17120               Middle Eastern                    None of the above
# 14882                  South Asian                    None of the above
# 51428                   East Asian                    None of the above
# 17486                   East Asian                    None of the above
# ...                            ...                                  ...
# 75693  Black or of African descent                    None of the above
# 76082  Black or of African descent                    None of the above
# 79301  Black or of African descent                    None of the above
# 80996  Black or of African descent  I am blind / have difficulty seeing
# 82406  Black or of African descent                    None of the above
#
#                      MENTALHEALTH           SURVEYLENGTH  \
# 55150      Or, in your own words:                    NaN
# 17120           None of the above               Too long
# 14882           None of the above  Appropriate in length
# 51428           None of the above              Too short
# 17486           None of the above  Appropriate in length
# ...                           ...                    ...
# 75693  I have an anxiety disorder  Appropriate in length
# 76082           None of the above  Appropriate in length
# 79301           None of the above               Too long
# 80996           None of the above  Appropriate in length
# 82406           None of the above                    NaN
#
#                        SURVEYEASE CONVERTEDCOMPYEARLY  \
# 55150                         NaN               100.0
# 17120  Neither easy nor difficult              3108.0
# 14882                        Easy              4200.0
# 51428                        Easy              4668.0
# 17486                        Easy              5448.0
# ...                           ...                 ...
# 75693  Neither easy nor difficult                 NaN
# 76082                        Easy                 NaN
# 79301                         NaN                 NaN
# 80996                        Easy                 NaN
# 82406  Neither easy nor difficult                 NaN
#
#                                                    AYUDA
# 55150                                                NaN
# 17120  Call a coworker or friend;Visit Stack Overflow...
# 14882  Call a coworker or friend;Visit Stack Overflow...
# 51428  Visit Stack Overflow;Google it;Watch help / tu...
# 17486  Visit Stack Overflow;Google it;Watch help / tu...
# ...                                                  ...
# 75693  Visit Stack Overflow;Go for a walk or other ph...
# 76082  Call a coworker or friend;Visit Stack Overflow...
# 79301      Visit Stack Overflow;Google it Stack Overflow
# 80996  Watch help / tutorial videos;Do other work and...
# 82406  Call a coworker or friend;Visit Stack Overflow...
#
# [83439 rows x 49 columns]

# %%
# COUNTRY ascendente, CONVERTEDCOMPYEARLY descendente
datos.sort_values(by=["COUNTRY", "CONVERTEDCOMPYEARLY"], ascending=[True, False])
# Out:
#        RESPONSEID                              MAINBRANCH  \
# 65399       65400          I am a developer by profession
# 22666       22667          I am a developer by profession
# 27198       27199          I am a developer by profession
# 31086       31087          I am a developer by profession
# 44640       44641          I am a developer by profession
# ...           ...                                     ...
# 75693       75694  I am a student who is learning to code
# 76082       76083          I am a developer by profession
# 79301       79302  I am a student who is learning to code
# 80996       80997             I code primarily as a hobby
# 82406       82407  I am a student who is learning to code
#
#                                               EMPLOYMENT      COUNTRY USSTATE  \
# 65399                                 Employed full-time  AFGHANISTAN     NaN
# 22666  Independent contractor, freelancer, or self-em...  AFGHANISTAN     NaN
# 27198  Independent contractor, freelancer, or self-em...  AFGHANISTAN     NaN
# 31086                                 Employed full-time  AFGHANISTAN     NaN
# 44640                                 Employed full-time  AFGHANISTAN     NaN
# ...                                                  ...          ...     ...
# 75693                                 Student, full-time     ZIMBABWE     NaN
# 76082                 Not employed, but looking for work     ZIMBABWE     NaN
# 79301                                 Student, part-time     ZIMBABWE     NaN
# 80996             Not employed, and not looking for work     ZIMBABWE     NaN
# 82406                                 Employed part-time     ZIMBABWE     NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 65399       NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 22666       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 27198       NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 31086       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 44640       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...         ...                                                ...
# 75693       NaN  Secondary school (e.g. American high school, G...
# 76082       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 79301       NaN  Secondary school (e.g. American high school, G...
# 80996       NaN                          Primary/elementary school
# 82406       NaN  Some college/university study without earning ...
#
#           AGE1STCODE                                          LEARNCODE  \
# 65399  25 - 34 years                    Online Courses or Certification
# 22666  45 - 54 years                                             School
# 27198   5 - 10 years                    Online Courses or Certification
# 31086  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 44640  11 - 17 years                    Online Courses or Certification
# ...              ...                                                ...
# 75693  18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 76082  18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 79301  35 - 44 years    Other online resources (ex: videos, blogs, etc)
# 80996  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 82406  18 - 24 years                      School;Books / Physical media
#
#               YEARSCODE      YEARSCODEPRO  \
# 65399                 7                 3
# 22666                 5  Less than 1 year
# 27198                 3                 3
# 31086                16                13
# 44640                 7                 6
# ...                 ...               ...
# 75693                 2               NaN
# 76082                 3               NaN
# 79301                 1               NaN
# 80996  Less than 1 year               NaN
# 82406                 3               NaN
#
#                                                  DEVTYPE  \
# 65399  Developer, desktop or enterprise applications;...
# 22666                               System administrator
# 27198                        Academic researcher;Student
# 31086  Developer, mobile;Developer, front-end;Develop...
# 44640                              Developer, full-stack
# ...                                                  ...
# 75693                                                NaN
# 76082                              Developer, full-stack
# 79301                                                NaN
# 80996                                                NaN
# 82406  Developer, front-end;Developer, back-end;Datab...
#
#                                                  ORGSIZE  \
# 65399                               500 to 999 employees
# 22666  Just me - I am a freelancer, sole proprietor, ...
# 27198                                 20 to 99 employees
# 31086                               500 to 999 employees
# 44640                                 10 to 19 employees
# ...                                                  ...
# 75693                                                NaN
# 76082                                                NaN
# 79301                                                NaN
# 80996                                                NaN
# 82406                                                NaN
#
#                                 CURRENCY  COMPTOTAL COMPFREQ  \
# 65399  ANG Netherlands Antillean guilder  4544242.0  Monthly
# 22666                AFN\tAfghan afghani  1000000.0  Monthly
# 27198                  JPY\tJapanese yen   480000.0  Monthly
# 31086                AFN\tAfghan afghani   154100.0  Monthly
# 44640                AFN\tAfghan afghani    97333.0  Monthly
# ...                                  ...        ...      ...
# 75693                                NaN        NaN      NaN
# 76082                                NaN        NaN      NaN
# 79301                                NaN        NaN      NaN
# 80996                                NaN        NaN      NaN
# 82406                                NaN        NaN      NaN
#
#                                   LANGUAGEHAVEWORKEDWITH  \
# 65399  Bash/Shell;C++;Elixir;LISP;Node.js;Ruby;Rust;S...
# 22666                     Assembly;C#;C++;JavaScript;VBA
# 27198                               Go;JavaScript;Python
# 31086            HTML/CSS;JavaScript;Node.js;PHP;SQL;VBA
# 44640                     C#;HTML/CSS;JavaScript;PHP;SQL
# ...                                                  ...
# 75693                                             Python
# 76082                    C++;Dart;Java;JavaScript;Python
# 79301                                                NaN
# 80996                 HTML/CSS;JavaScript;Node.js;Python
# 82406                           C#;JavaScript;PHP;Python
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 65399       Clojure;Crystal;Dart;Matlab;Node.js;Python;R
# 22666                     HTML/CSS;Java;PHP;Python;R;SQL
# 27198                               Go;JavaScript;Python
# 31086  HTML/CSS;JavaScript;Kotlin;Node.js;Objective-C...
# 44640         C#;Dart;HTML/CSS;JavaScript;PHP;Python;SQL
# ...                                                  ...
# 75693                                HTML/CSS;JavaScript
# 76082                                        Dart;Python
# 79301                                                NaN
# 80996      Assembly;C#;C++;Go;Java;Kotlin;Node.js;Python
# 82406  C#;Java;JavaScript;Kotlin;Matlab;Node.js;PHP;P...
#
#                     DATABASEHAVEWORKEDWITH  \
# 65399      Couchbase;Elasticsearch;MariaDB
# 22666                 Microsoft SQL Server
# 27198                                MySQL
# 31086  Firebase;MariaDB;MySQL;Redis;SQLite
# 44640   MariaDB;Microsoft SQL Server;MySQL
# ...                                    ...
# 75693                                MySQL
# 76082                    PostgreSQL;SQLite
# 79301              MySQL;PostgreSQL;SQLite
# 80996                                  NaN
# 82406                                MySQL
#
#                                   DATABASEWANTTOWORKWITH  \
# 65399                                       MySQL;Oracle
# 22666                                                NaN
# 27198                                              MySQL
# 31086  Couchbase;DynamoDB;Elasticsearch;Firebase;Mari...
# 44640  Firebase;MariaDB;Microsoft SQL Server;MongoDB;...
# ...                                                  ...
# 75693                                                NaN
# 76082                                  PostgreSQL;SQLite
# 79301                            MySQL;PostgreSQL;SQLite
# 80996                                                NaN
# 82406               DynamoDB;MariaDB;MySQL;Oracle;SQLite
#
#         PLATFORMHAVEWORKEDWITH                     PLATFORMWANTTOWORKWITH  \
# 65399  AWS;IBM Cloud or Watson                Oracle Cloud Infrastructure
# 22666                      NaN                                        NaN
# 27198    Google Cloud Platform                      Google Cloud Platform
# 31086         AWS;DigitalOcean                            Microsoft Azure
# 44640                      AWS  AWS;Google Cloud Platform;Microsoft Azure
# ...                        ...                                        ...
# 75693                      NaN                                        NaN
# 76082                   Heroku                                     Heroku
# 79301                      NaN                                        NaN
# 80996                      NaN                                        NaN
# 82406                      NaN                                        NaN
#
#                             WEBFRAMEHAVEWORKEDWITH  \
# 65399                ASP.NET;Drupal;Laravel;Svelte
# 22666                                          NaN
# 27198                             Express;React.js
# 31086                Express;jQuery;Laravel;Vue.js
# 44640  ASP.NET;ASP.NET Core ;jQuery;Laravel;Vue.js
# ...                                            ...
# 75693                                       Django
# 76082                                       Django
# 79301                                       Django
# 80996                                     React.js
# 82406                                      ASP.NET
#
#                                   WEBFRAMEWANTTOWORKWITH  ...  \
# 65399  Angular;ASP.NET;Django;Express;Flask;jQuery;Ru...  ...
# 22666                                                NaN  ...
# 27198                                   Express;React.js  ...
# 31086              jQuery;Laravel;React.js;Svelte;Vue.js  ...
# 44640  Angular;ASP.NET Core ;Django;jQuery;Laravel;Re...  ...
# ...                                                  ...  ...
# 75693                                            ASP.NET  ...
# 76082                                             Django  ...
# 79301                                    Django;React.js  ...
# 80996                   Angular.js;Django;Express;jQuery  ...
# 82406                           Angular.js;Django;jQuery  ...
#
#                                   MISCTECHWANTTOWORKWITH  \
# 65399                                  Flutter;Pandas;Qt
# 22666                                                NaN
# 27198                                       React Native
# 31086                               Flutter;React Native
# 44640  .NET Core / .NET 5;Flutter;NumPy;Pandas;Qt;Ten...
# ...                                                  ...
# 75693                                                NaN
# 76082                                            Flutter
# 79301                                                NaN
# 80996                                                NaN
# 82406  .NET Framework;Flutter;NumPy;Pandas;Torch/PyTorch
#
#       TOOLSTECHHAVEWORKEDWITH               TOOLSTECHWANTTOWORKWITH  \
# 65399   Docker;Flow;Terraform                       Chef;Docker;Git
# 22666                     NaN                                   NaN
# 27198       Docker;Git;Pulumi                                Docker
# 31086  Docker;Git;Puppet;Yarn  Docker;Git;Kubernetes;Terraform;Yarn
# 44640                Git;Yarn               Docker;Git;Xamarin;Yarn
# ...                       ...                                   ...
# 75693                     NaN                                   NaN
# 76082                     Git                                   Git
# 79301                     Git                    Ansible;Docker;Git
# 80996                     NaN                                   NaN
# 82406                     NaN                                   NaN
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 65399                         NetBeans;PHPStorm;RubyMine
# 22666                                                NaN
# 27198                                      Visual Studio
# 31086  Android Studio;NetBeans;Notepad++;Sublime Text...
# 44640  PHPStorm;Visual Studio;Visual Studio Code;Webs...
# ...                                                  ...
# 75693                       Android Studio;Visual Studio
# 76082          IntelliJ;PyCharm;Visual Studio Code;Xcode
# 79301  Android Studio;PyCharm;Sublime Text;Visual Stu...
# 80996               Notepad++;PyCharm;Visual Studio Code
# 82406  IPython/Jupyter;NetBeans;Notepad++;PyCharm;Sub...
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 65399                                   Eclipse;NetBeans  Linux-based
# 22666                                                NaN      Windows
# 27198                                      Visual Studio  Linux-based
# 31086  Android Studio;Sublime Text;Vim;Visual Studio ...        MacOS
# 44640  Android Studio;PHPStorm;PyCharm;Rider;Visual S...        MacOS
# ...                                                  ...          ...
# 75693                           Visual Studio Code;Xcode      Windows
# 76082          IntelliJ;PyCharm;Visual Studio Code;Xcode        MacOS
# 79301  Android Studio;PyCharm;Sublime Text;Visual Stu...  Linux-based
# 80996          Android Studio;PyCharm;Visual Studio Code      Windows
# 82406  Android Studio;Atom;IPython/Jupyter;NetBeans;P...      Windows
#
#                                                 NEWSTUCK  \
# 65399            Watch help / tutorial videos;Play games
# 22666   Visit another developer community (please name):
# 27198                               Visit Stack Overflow
# 31086  Call a coworker or friend;Visit Stack Overflow...
# 44640            Visit Stack Overflow;Google it;Meditate
# ...                                                  ...
# 75693  Visit Stack Overflow;Go for a walk or other ph...
# 76082  Call a coworker or friend;Visit Stack Overflow...
# 79301                     Visit Stack Overflow;Google it
# 80996  Watch help / tutorial videos;Do other work and...
# 82406  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSITES  \
# 65399  Stack Overflow;Stack Overflow for Teams (priva...
# 22666  Stack Overflow;Stack Exchange;Stack Overflow f...
# 27198                                     Stack Exchange
# 31086                      Stack Overflow;Stack Exchange
# 44640                                     Stack Overflow
# ...                                                  ...
# 75693                      Stack Overflow;Stack Exchange
# 76082                                     Stack Overflow
# 79301                                     Stack Overflow
# 80996                                     Stack Overflow
# 82406                      Stack Overflow;Stack Exchange
#
#                            SOVISITFREQ SOACCOUNT  \
# 65399  A few times per month or weekly       NaN
# 22666           Multiple times per day      True
# 27198  A few times per month or weekly     False
# 31086  A few times per month or weekly      True
# 44640             A few times per week      True
# ...                                ...       ...
# 75693  A few times per month or weekly      True
# 76082            Daily or almost daily      True
# 79301            Daily or almost daily      True
# 80996  A few times per month or weekly      True
# 82406            Daily or almost daily      True
#
#                                               SOPARTFREQ           SOCOMM  \
# 65399                                                NaN   No, not at all
# 22666                             Multiple times per day  Yes, definitely
# 27198                                                NaN   No, not really
# 31086                Less than once per month or monthly    Yes, somewhat
# 44640                Less than once per month or monthly  Yes, definitely
# ...                                                  ...              ...
# 75693                Less than once per month or monthly    Yes, somewhat
# 76082                    A few times per month or weekly  Yes, definitely
# 79301                Less than once per month or monthly    Yes, somewhat
# 80996  I have never participated in Q&A on Stack Over...   No, not really
# 82406                              Daily or almost daily  Yes, definitely
#
#       NEWOTHERCOMMS                 AGE  \
# 65399           Yes     35-44 years old
# 22666           Yes     45-54 years old
# 27198            No     25-34 years old
# 31086            No     25-34 years old
# 44640            No     25-34 years old
# ...             ...                 ...
# 75693           Yes     18-24 years old
# 76082           Yes     18-24 years old
# 79301            No     35-44 years old
# 80996            No  Under 18 years old
# 82406            No     18-24 years old
#
#                                                   GENDER              TRANS  \
# 65399  Man;Non-binary, genderqueer, or gender non-con...                Yes
# 22666                                                Man                 No
# 27198                                                Man                 No
# 31086                                                Man                 No
# 44640                                                Man                 No
# ...                                                  ...                ...
# 75693                                                Man                 No
# 76082                                                Man                 No
# 79301                                                Man                 No
# 80996                                                Man                 No
# 82406                                                Man  Prefer not to say
#
#                                                SEXUALITY  \
# 65399  Bisexual;Prefer to self-describe:;Gay or Lesbi...
# 22666                            Straight / Heterosexual
# 27198                            Straight / Heterosexual
# 31086                            Straight / Heterosexual
# 44640                            Straight / Heterosexual
# ...                                                  ...
# 75693                            Straight / Heterosexual
# 76082                            Straight / Heterosexual
# 79301                                                NaN
# 80996                            Straight / Heterosexual
# 82406                            Straight / Heterosexual
#
#                                                ETHNICITY  \
# 65399  South Asian;Hispanic or Latino/a/x;Black or of...
# 22666                       White or of European descent
# 27198                                         East Asian
# 31086                             Hispanic or Latino/a/x
# 44640                                         East Asian
# ...                                                  ...
# 75693                        Black or of African descent
# 76082                        Black or of African descent
# 79301                        Black or of African descent
# 80996                        Black or of African descent
# 82406                        Black or of African descent
#
#                                            ACCESSIBILITY  \
# 65399  I am unable to / find it difficult to walk or ...
# 22666                                  None of the above
# 27198                                  Prefer not to say
# 31086                                  None of the above
# 44640                                  None of the above
# ...                                                  ...
# 75693                                  None of the above
# 76082                                  None of the above
# 79301                                  None of the above
# 80996                I am blind / have difficulty seeing
# 82406                                  None of the above
#
#                                             MENTALHEALTH  \
# 65399  I have a mood or emotional disorder (e.g. depr...
# 22666                                  None of the above
# 27198                                  Prefer not to say
# 31086                                  None of the above
# 44640                                  None of the above
# ...                                                  ...
# 75693                         I have an anxiety disorder
# 76082                                  None of the above
# 79301                                  None of the above
# 80996                                  None of the above
# 82406                                  None of the above
#
#                 SURVEYLENGTH                  SURVEYEASE CONVERTEDCOMPYEARLY  \
# 65399              Too short                   Difficult          30468516.0
# 22666  Appropriate in length                        Easy            155496.0
# 27198               Too long                   Difficult             51804.0
# 31086               Too long  Neither easy nor difficult             23964.0
# 44640               Too long  Neither easy nor difficult             15132.0
# ...                      ...                         ...                 ...
# 75693  Appropriate in length  Neither easy nor difficult                 NaN
# 76082  Appropriate in length                        Easy                 NaN
# 79301               Too long                         NaN                 NaN
# 80996  Appropriate in length                        Easy                 NaN
# 82406                    NaN  Neither easy nor difficult                 NaN
#
#                                                    AYUDA
# 65399  Watch help / tutorial videos;Play games Stack ...
# 22666  Visit another developer community (please name...
# 27198                Visit Stack Overflow Stack Exchange
# 31086  Call a coworker or friend;Visit Stack Overflow...
# 44640  Visit Stack Overflow;Google it;Meditate Stack ...
# ...                                                  ...
# 75693  Visit Stack Overflow;Go for a walk or other ph...
# 76082  Call a coworker or friend;Visit Stack Overflow...
# 79301      Visit Stack Overflow;Google it Stack Overflow
# 80996  Watch help / tutorial videos;Do other work and...
# 82406  Call a coworker or friend;Visit Stack Overflow...
#
# [83439 rows x 49 columns]

# %%
# Modifica datos
# datos.sort_values(by=["COUNTRY", "CONVERTEDCOMPYEARLY"], ascending=[True, False], inplace=True)
# Reestablece el orden original
# datos.sort_index()

# %%
# Ordena una columna
datos["COUNTRY"].sort_values()
# Out:
# 14882    AFGHANISTAN
# 41840    AFGHANISTAN
# 4544     AFGHANISTAN
# 28378    AFGHANISTAN
# 55624    AFGHANISTAN
#             ...
# 75693       ZIMBABWE
# 73741       ZIMBABWE
# 44094       ZIMBABWE
# 13194       ZIMBABWE
# 54148       ZIMBABWE
# Name: COUNTRY, Length: 83439, dtype: object

# %%
datos["COUNTRY"].head(20)
# Out:
# 0                                              SLOVAKIA
# 1                                           NETHERLANDS
# 2                                    RUSSIAN FEDERATION
# 3                                               AUSTRIA
# 4     UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
# 5                              UNITED STATES OF AMERICA
# 6                              UNITED STATES OF AMERICA
# 7                                              MALAYSIA
# 8                                                 INDIA
# 9                                                SWEDEN
# 10    UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
# 11                                               ESPAÑA
# 12                                              GERMANY
# 13                                                 PERU
# 14    UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
# 15                             UNITED STATES OF AMERICA
# 16                                               TURKEY
# 17                                               CANADA
# 18                                            SINGAPORE
# 19                                               BRAZIL
# Name: COUNTRY, dtype: object

# %%
datos.sort_values(by=["CONVERTEDCOMPYEARLY", "COUNTRY"], ascending=[False, True]).head(50)
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 66910       66911                     I am a developer by profession
# 65399       65400                     I am a developer by profession
# 40586       40587                     I am a developer by profession
# 28791       28792                     I am a developer by profession
# 12700       12701                     I am a developer by profession
# 9608         9609  I am not primarily a developer, but I write co...
# 5305         5306                     I am a developer by profession
# 12903       12904                     I am a developer by profession
# 66488       66489                     I am a developer by profession
# 7205         7206                     I am a developer by profession
# 47563       47564                     I am a developer by profession
# 3733         3734                     I am a developer by profession
# 33255       33256                     I am a developer by profession
# 35779       35780                     I am a developer by profession
# 7904         7905                     I am a developer by profession
# 10372       10373                     I am a developer by profession
# 9189         9190                     I am a developer by profession
# 20908       20909                     I am a developer by profession
# 52070       52071  I am not primarily a developer, but I write co...
# 53028       53029                     I am a developer by profession
# 64111       64112                     I am a developer by profession
# 66323       66324  I am not primarily a developer, but I write co...
# 82156       82157                     I am a developer by profession
# 7134         7135                     I am a developer by profession
# 60701       60702                     I am a developer by profession
# 66417       66418                     I am a developer by profession
# 64281       64282                     I am a developer by profession
# 51240       51241                     I am a developer by profession
# 33313       33314                     I am a developer by profession
# 47536       47537                     I am a developer by profession
# 51010       51011                     I am a developer by profession
# 47210       47211                     I am a developer by profession
# 45288       45289                     I am a developer by profession
# 33919       33920                     I am a developer by profession
# 55534       55535                     I am a developer by profession
# 66013       66014                     I am a developer by profession
# 77060       77061                     I am a developer by profession
# 78554       78555                     I am a developer by profession
# 4395         4396                     I am a developer by profession
# 54701       54702                     I am a developer by profession
# 25102       25103                     I am a developer by profession
# 1931         1932                     I am a developer by profession
# 5000         5001                     I am a developer by profession
# 46391       46392                     I am a developer by profession
# 59563       59564                     I am a developer by profession
# 77655       77656                     I am a developer by profession
# 36552       36553                     I am a developer by profession
# 27561       27562                     I am a developer by profession
# 30569       30570                     I am a developer by profession
# 50225       50226                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 66910                                I prefer not to say
# 65399                                 Employed full-time
# 40586                                 Employed full-time
# 28791                                 Employed full-time
# 12700                                 Employed full-time
# 9608                                  Employed full-time
# 5305   Independent contractor, freelancer, or self-em...
# 12903                                 Employed full-time
# 66488                                 Employed full-time
# 7205   Independent contractor, freelancer, or self-em...
# 47563                                 Employed full-time
# 3733   Independent contractor, freelancer, or self-em...
# 33255                                 Employed full-time
# 35779                                 Employed full-time
# 7904                                  Employed full-time
# 10372                                 Employed full-time
# 9189                                  Employed full-time
# 20908                                 Employed full-time
# 52070                                 Employed full-time
# 53028                                 Employed full-time
# 64111                                 Employed full-time
# 66323                                 Employed full-time
# 82156                                 Employed full-time
# 7134                                  Employed full-time
# 60701                                 Employed full-time
# 66417                                 Employed full-time
# 64281                                 Employed full-time
# 51240                                 Employed full-time
# 33313                                 Employed full-time
# 47536                                 Employed full-time
# 51010                                 Employed full-time
# 47210                                 Employed full-time
# 45288  Independent contractor, freelancer, or self-em...
# 33919                                 Employed full-time
# 55534                                 Employed full-time
# 66013                                 Employed full-time
# 77060                                 Employed full-time
# 78554                                 Employed full-time
# 4395                                  Employed full-time
# 54701                                 Employed full-time
# 25102  Independent contractor, freelancer, or self-em...
# 1931                                  Employed full-time
# 5000                                  Employed full-time
# 46391                                 Employed full-time
# 59563                                 Employed full-time
# 77655                                 Employed full-time
# 36552                                 Employed full-time
# 27561                                 Employed full-time
# 30569                                 Employed full-time
# 50225                                 Employed full-time
#
#                                                  COUNTRY         USSTATE  \
# 66910                                            BELGIUM             NaN
# 65399                                        AFGHANISTAN             NaN
# 40586                           UNITED STATES OF AMERICA      California
# 28791                                              INDIA             NaN
# 12700                                              INDIA             NaN
# 9608                            UNITED STATES OF AMERICA        New York
# 5305                            UNITED STATES OF AMERICA      New Jersey
# 12903                                             SERBIA             NaN
# 66488                           UNITED STATES OF AMERICA      Washington
# 7205                            UNITED STATES OF AMERICA  South Carolina
# 47563                           UNITED STATES OF AMERICA        Colorado
# 3733                            UNITED STATES OF AMERICA        Virginia
# 33255                           UNITED STATES OF AMERICA         Florida
# 35779                           UNITED STATES OF AMERICA    Pennsylvania
# 7904                            UNITED STATES OF AMERICA      Washington
# 10372                           UNITED STATES OF AMERICA     Connecticut
# 9189                            UNITED STATES OF AMERICA      Washington
# 20908                           UNITED STATES OF AMERICA           Texas
# 52070                           UNITED STATES OF AMERICA      California
# 53028                           UNITED STATES OF AMERICA        Missouri
# 64111                           UNITED STATES OF AMERICA      California
# 66323                           UNITED STATES OF AMERICA         Indiana
# 82156                       IRAN, ISLAMIC REPUBLIC OF...             NaN
# 7134                            UNITED STATES OF AMERICA      California
# 60701                           UNITED STATES OF AMERICA        Colorado
# 66417                           UNITED STATES OF AMERICA           Texas
# 64281                           UNITED STATES OF AMERICA        Illinois
# 51240                           UNITED STATES OF AMERICA            Ohio
# 33313                                        NEW ZEALAND             NaN
# 47536                           UNITED STATES OF AMERICA    Pennsylvania
# 51010                           UNITED STATES OF AMERICA        New York
# 47210                           UNITED STATES OF AMERICA   Massachusetts
# 45288  UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...             NaN
# 33919                           UNITED STATES OF AMERICA    Pennsylvania
# 55534                           UNITED STATES OF AMERICA      California
# 66013                           UNITED STATES OF AMERICA        Virginia
# 77060                           UNITED STATES OF AMERICA        New York
# 78554                                          INDONESIA             NaN
# 4395                            UNITED STATES OF AMERICA       Tennessee
# 54701                           UNITED STATES OF AMERICA        New York
# 25102                                             CANADA             NaN
# 1931                            UNITED STATES OF AMERICA           Idaho
# 5000                            UNITED STATES OF AMERICA      Washington
# 46391                           UNITED STATES OF AMERICA            Ohio
# 59563                           UNITED STATES OF AMERICA        Illinois
# 77655                           UNITED STATES OF AMERICA        Illinois
# 36552                           UNITED STATES OF AMERICA      New Jersey
# 27561                           UNITED STATES OF AMERICA         Florida
# 30569                           UNITED STATES OF AMERICA      Washington
# 50225                           UNITED STATES OF AMERICA        Illinois
#
#       UKCOUNTRY                                            EDLEVEL  \
# 66910       NaN                          Primary/elementary school
# 65399       NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 40586       NaN  Some college/university study without earning ...
# 28791       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12700       NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 9608        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5305        NaN                 Professional degree (JD, MD, etc.)
# 12903       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 66488       NaN  Some college/university study without earning ...
# 7205        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 47563       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3733        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33255       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 35779       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 7904        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 10372       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9189        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 20908       NaN  Some college/university study without earning ...
# 52070       NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 53028       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64111       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 66323       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 82156       NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 7134        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 60701       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 66417       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64281       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 51240       NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 33313       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 47536       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 51010       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 47210       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 45288   England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 33919       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 55534       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 66013       NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 77060       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 78554       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4395        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 54701       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 25102       NaN  Some college/university study without earning ...
# 1931        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5000        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 46391       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 59563       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 77655       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 36552       NaN  Some college/university study without earning ...
# 27561       NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 30569       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 50225       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                  AGE1STCODE  \
# 66910         55 - 64 years
# 65399         25 - 34 years
# 40586  Younger than 5 years
# 28791         35 - 44 years
# 12700         25 - 34 years
# 9608          18 - 24 years
# 5305          11 - 17 years
# 12903         11 - 17 years
# 66488         18 - 24 years
# 7205           5 - 10 years
# 47563         11 - 17 years
# 3733          11 - 17 years
# 33255         11 - 17 years
# 35779         18 - 24 years
# 7904          18 - 24 years
# 10372          5 - 10 years
# 9189           5 - 10 years
# 20908         11 - 17 years
# 52070          5 - 10 years
# 53028          5 - 10 years
# 64111         11 - 17 years
# 66323          5 - 10 years
# 82156         25 - 34 years
# 7134          11 - 17 years
# 60701         11 - 17 years
# 66417         18 - 24 years
# 64281         11 - 17 years
# 51240         11 - 17 years
# 33313         11 - 17 years
# 47536         25 - 34 years
# 51010          5 - 10 years
# 47210         11 - 17 years
# 45288         11 - 17 years
# 33919         11 - 17 years
# 55534         25 - 34 years
# 66013          5 - 10 years
# 77060         11 - 17 years
# 78554         18 - 24 years
# 4395          18 - 24 years
# 54701         18 - 24 years
# 25102         11 - 17 years
# 1931          18 - 24 years
# 5000          18 - 24 years
# 46391         11 - 17 years
# 59563         18 - 24 years
# 77655         25 - 34 years
# 36552         11 - 17 years
# 27561         25 - 34 years
# 30569         25 - 34 years
# 50225         18 - 24 years
#
#                                                LEARNCODE YEARSCODE  \
# 66910                             Books / Physical media         1
# 65399                    Online Courses or Certification         7
# 40586  Other online resources (ex: videos, blogs, etc...        37
# 28791  Coding Bootcamp;Other online resources (ex: vi...        11
# 12700                                       Online Forum         5
# 9608                                              School        25
# 5305      Friend or family member;Books / Physical media        25
# 12903  Other online resources (ex: videos, blogs, etc...         6
# 66488  School;Online Courses or Certification;Books /...         5
# 7205   Other online resources (ex: videos, blogs, etc...        30
# 47563                             Books / Physical media        24
# 3733                             Friend or family member        28
# 33255  School;Other (please specify):;Books / Physica...        37
# 35779  Other online resources (ex: videos, blogs, etc...        13
# 7904                       School;Books / Physical media        11
# 10372                      School;Books / Physical media        35
# 9189   Other online resources (ex: videos, blogs, etc...        35
# 20908  Other online resources (ex: videos, blogs, etc...        20
# 52070  Other online resources (ex: videos, blogs, etc...        20
# 53028  Other online resources (ex: videos, blogs, etc...        20
# 64111  Other online resources (ex: videos, blogs, etc...        12
# 66323                             Coding Bootcamp;School        33
# 82156  Other online resources (ex: videos, blogs, etc...       NaN
# 7134   School;Friend or family member;Online Courses ...        13
# 60701  Coding Bootcamp;School;Friend or family member...        14
# 66417                      School;Books / Physical media        38
# 64281  Other online resources (ex: videos, blogs, etc...        17
# 51240                             Books / Physical media        30
# 33313  Other online resources (ex: videos, blogs, etc...        38
# 47536  Other online resources (ex: videos, blogs, etc...         5
# 51010  Other online resources (ex: videos, blogs, etc...         8
# 47210  Other online resources (ex: videos, blogs, etc...        24
# 45288  Other online resources (ex: videos, blogs, etc...        17
# 33919                      School;Books / Physical media        25
# 55534                                    Coding Bootcamp         6
# 66013                      School;Books / Physical media        30
# 77060                            Friend or family member        16
# 78554                                             School        10
# 4395   Other online resources (ex: videos, blogs, etc...        15
# 54701  Coding Bootcamp;School;Online Courses or Certi...        10
# 25102                                             School         6
# 1931   Other online resources (ex: videos, blogs, etc...        22
# 5000                       School;Books / Physical media        12
# 46391                                             School        13
# 59563  Other online resources (ex: videos, blogs, etc...         9
# 77655  Other online resources (ex: videos, blogs, etc...         5
# 36552                                             School        12
# 27561  Coding Bootcamp;Other online resources (ex: vi...         5
# 30569  Other online resources (ex: videos, blogs, etc...        10
# 50225                                             School        10
#
#       YEARSCODEPRO                                            DEVTYPE  \
# 66910           21                                                NaN
# 65399            3  Developer, desktop or enterprise applications;...
# 40586           13                            Other (please specify):
# 28791            9  Developer, desktop or enterprise applications;...
# 12700            5                              Developer, full-stack
# 9608            21               Senior Executive (C-Suite, VP, etc.)
# 5305             5            Developer, full-stack;DevOps specialist
# 12903            1  Developer, front-end;Developer, full-stack;Dev...
# 66488            3  Developer, desktop or enterprise applications;...
# 7205            20  Developer, front-end;Developer, desktop or ent...
# 47563           13                               Developer, front-end
# 3733            19                                Developer, back-end
# 33255           33  Developer, mobile;Developer, front-end;Develop...
# 35779           13                              Developer, full-stack
# 7904             7                                  Developer, mobile
# 10372           21         Developer, front-end;Developer, full-stack
# 9189            24            Developer, back-end;Engineering manager
# 20908           20  Developer, front-end;Developer, desktop or ent...
# 52070           10  Developer, front-end;Data scientist or machine...
# 53028           15                              Developer, full-stack
# 64111            7                                Developer, back-end
# 66323           23        Developer, embedded applications or devices
# 82156            5                                Developer, back-end
# 7134             9                              Developer, full-stack
# 60701           11  Engineer, data;Data scientist or machine learn...
# 66417           35        Developer, embedded applications or devices
# 64281           11            Developer, full-stack;DevOps specialist
# 51240           26  Developer, mobile;Developer, front-end;Develop...
# 33313           30          Developer, full-stack;Engineering manager
# 47536            5            Developer, full-stack;DevOps specialist
# 51010            4  Developer, desktop or enterprise applications;...
# 47210           14                                  Developer, mobile
# 45288            8      Data scientist or machine learning specialist
# 33919           20                              Developer, full-stack
# 55534            5                              Developer, full-stack
# 66013           20  Developer, front-end;Developer, desktop or ent...
# 77060            6  Developer, full-stack;Data scientist or machin...
# 78554            5  Developer, front-end;Developer, full-stack;Dev...
# 4395            11                Developer, back-end;Product manager
# 54701            6  Developer, front-end;Developer, full-stack;Dev...
# 25102            1  Developer, front-end;Developer, full-stack;Dev...
# 1931            20  Developer, front-end;Developer, full-stack;Dev...
# 5000             9  Developer, full-stack;Developer, back-end;DevO...
# 46391            9                                  Developer, mobile
# 59563            6  Developer, back-end;DevOps specialist;Engineer...
# 77655            3          Developer, full-stack;Developer, back-end
# 36552           10                                Developer, back-end
# 27561            5                              Developer, full-stack
# 30569            3  Developer, front-end;Developer, desktop or ent...
# 50225            7  Developer, desktop or enterprise applications;...
#
#                                                  ORGSIZE  \
# 66910  Just me - I am a freelancer, sole proprietor, ...
# 65399                               500 to 999 employees
# 40586                           10,000 or more employees
# 28791                               100 to 499 employees
# 12700                               100 to 499 employees
# 9608                                  20 to 99 employees
# 5305   Just me - I am a freelancer, sole proprietor, ...
# 12903                               100 to 499 employees
# 66488                                 20 to 99 employees
# 7205   Just me - I am a freelancer, sole proprietor, ...
# 47563                           10,000 or more employees
# 3733   Just me - I am a freelancer, sole proprietor, ...
# 33255                               100 to 499 employees
# 35779                                 20 to 99 employees
# 7904                            5,000 to 9,999 employees
# 10372                           10,000 or more employees
# 9189                            10,000 or more employees
# 20908                           5,000 to 9,999 employees
# 52070                           1,000 to 4,999 employees
# 53028                           10,000 or more employees
# 64111                                 20 to 99 employees
# 66323                           10,000 or more employees
# 82156                                 10 to 19 employees
# 7134                                    2 to 9 employees
# 60701                               100 to 499 employees
# 66417                           10,000 or more employees
# 64281                           1,000 to 4,999 employees
# 51240                               500 to 999 employees
# 33313                                 10 to 19 employees
# 47536                                 20 to 99 employees
# 51010                           10,000 or more employees
# 47210                               100 to 499 employees
# 45288                           10,000 or more employees
# 33919                           1,000 to 4,999 employees
# 55534                           1,000 to 4,999 employees
# 66013                           1,000 to 4,999 employees
# 77060                           10,000 or more employees
# 78554                                 10 to 19 employees
# 4395                                500 to 999 employees
# 54701                           1,000 to 4,999 employees
# 25102  Just me - I am a freelancer, sole proprietor, ...
# 1931                                  20 to 99 employees
# 5000                                  10 to 19 employees
# 46391                           1,000 to 4,999 employees
# 59563                           10,000 or more employees
# 77655                           10,000 or more employees
# 36552                           1,000 to 4,999 employees
# 27561                                 20 to 99 employees
# 30569                           10,000 or more employees
# 50225                                 20 to 99 employees
#
#                                 CURRENCY     COMPTOTAL COMPFREQ  \
# 66910                  ALL\tAlbanian lek  5.123468e+09   Yearly
# 65399  ANG Netherlands Antillean guilder  4.544242e+06  Monthly
# 40586          USD\tUnited States dollar  4.364450e+05   Weekly
# 28791          USD\tUnited States dollar  2.000000e+07   Yearly
# 12700          USD\tUnited States dollar  1.600000e+06  Monthly
# 9608           USD\tUnited States dollar  3.500000e+05   Weekly
# 5305           USD\tUnited States dollar  3.000000e+05   Weekly
# 12903                  EUR European Euro  1.111000e+06  Monthly
# 66488          USD\tUnited States dollar  2.550000e+05   Weekly
# 7205           USD\tUnited States dollar  2.500000e+05   Weekly
# 47563          USD\tUnited States dollar  2.500000e+05   Weekly
# 3733           USD\tUnited States dollar  2.250000e+05   Weekly
# 33255          USD\tUnited States dollar  2.250000e+05   Weekly
# 35779          USD\tUnited States dollar  2.200000e+05   Weekly
# 7904           USD\tUnited States dollar  2.100000e+05   Weekly
# 10372          USD\tUnited States dollar  2.070000e+05   Weekly
# 9189           USD\tUnited States dollar  8.500000e+05  Monthly
# 20908          USD\tUnited States dollar  2.000000e+05   Weekly
# 52070          USD\tUnited States dollar  2.000000e+05   Weekly
# 53028          USD\tUnited States dollar  2.000000e+05   Weekly
# 64111          USD\tUnited States dollar  2.000000e+05   Weekly
# 66323          USD\tUnited States dollar  2.000000e+05   Weekly
# 82156                  IRR\tIranian rial  3.500000e+10  Monthly
# 7134           USD\tUnited States dollar  1.900000e+05   Weekly
# 60701          USD\tUnited States dollar  1.900000e+05   Weekly
# 66417          USD\tUnited States dollar  1.820000e+05   Weekly
# 64281          USD\tUnited States dollar  1.800000e+05   Weekly
# 51240          USD\tUnited States dollar  1.770000e+05   Weekly
# 33313            NZD\tNew Zealand dollar  1.350000e+07   Yearly
# 47536          USD\tUnited States dollar  1.700000e+05   Weekly
# 51010          USD\tUnited States dollar  1.650000e+05   Weekly
# 47210          USD\tUnited States dollar  1.620000e+05   Weekly
# 45288                GBP\tPound sterling  1.250000e+05   Weekly
# 33919          USD\tUnited States dollar  1.600000e+05   Weekly
# 55534          USD\tUnited States dollar  1.600000e+05   Weekly
# 66013          USD\tUnited States dollar  1.600000e+05   Weekly
# 77060          USD\tUnited States dollar  1.600000e+05   Weekly
# 78554             IDR\tIndonesian rupiah  9.000000e+09  Monthly
# 4395           USD\tUnited States dollar  1.580000e+05   Weekly
# 54701          USD\tUnited States dollar  1.580000e+05   Weekly
# 25102               CAD\tCanadian dollar  1.000000e+07   Yearly
# 1931           USD\tUnited States dollar  1.500000e+05   Weekly
# 5000           USD\tUnited States dollar  1.500000e+05   Weekly
# 46391          USD\tUnited States dollar  1.500000e+05   Weekly
# 59563          USD\tUnited States dollar  1.500000e+05   Weekly
# 77655          USD\tUnited States dollar  1.500000e+05   Weekly
# 36552          USD\tUnited States dollar  1.476500e+05   Weekly
# 27561          USD\tUnited States dollar  1.450000e+05   Weekly
# 30569          USD\tUnited States dollar  1.400000e+05   Weekly
# 50225          USD\tUnited States dollar  1.400000e+05   Weekly
#
#                                   LANGUAGEHAVEWORKEDWITH  \
# 66910                                                APL
# 65399  Bash/Shell;C++;Elixir;LISP;Node.js;Ruby;Rust;S...
# 40586  Bash/Shell;HTML/CSS;Java;JavaScript;Node.js;Py...
# 28791  C#;C++;Groovy;HTML/CSS;Java;JavaScript;Node.js...
# 12700                                         JavaScript
# 9608   Bash/Shell;Go;HTML/CSS;Java;JavaScript;Kotlin;...
# 5305                                              Python
# 12903                       C#;JavaScript;Node.js;Python
# 66488  Bash/Shell;Go;HTML/CSS;Java;JavaScript;Kotlin;...
# 7205   Bash/Shell;C#;HTML/CSS;JavaScript;PHP;PowerShe...
# 47563           Go;HTML/CSS;JavaScript;Python;TypeScript
# 3733   Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;Nod...
# 33255  Bash/Shell;C;C#;C++;Go;HTML/CSS;Java;JavaScrip...
# 35779    Bash/Shell;HTML/CSS;JavaScript;Node.js;Ruby;SQL
# 7904                    Bash/Shell;C++;Objective-C;Swift
# 10372    HTML/CSS;Java;JavaScript;Node.js;SQL;TypeScript
# 9189        Bash/Shell;Go;Java;Kotlin;Node.js;TypeScript
# 20908  C#;HTML/CSS;JavaScript;PowerShell;Python;SQL;T...
# 52070              Bash/Shell;C++;JavaScript;Python;Rust
# 53028  C;C++;Go;HTML/CSS;Java;JavaScript;Node.js;Pyth...
# 64111                                            Go;Java
# 66323                                                  C
# 82156                            HTML/CSS;JavaScript;PHP
# 7134   Bash/Shell;JavaScript;Node.js;Rust;SQL;Swift;T...
# 60701                    Bash/Shell;Java;Python;Ruby;SQL
# 66417                                  Assembly;C;Python
# 64281                               C#;Groovy;PowerShell
# 51240                         C#;Delphi;HTML/CSS;PHP;SQL
# 33313                                             Delphi
# 47536          HTML/CSS;JavaScript;Python;SQL;TypeScript
# 51010  Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;Typ...
# 47210                                              Swift
# 45288                                  Bash/Shell;Python
# 33919                                                 C#
# 55534            Bash/Shell;HTML/CSS;Ruby;SQL;TypeScript
# 66013              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 77060  HTML/CSS;Java;JavaScript;Node.js;Python;Swift;...
# 78554   Delphi;Go;Java;JavaScript;Node.js;PHP;TypeScript
# 4395   Bash/Shell;C++;Go;JavaScript;Node.js;Python;SQ...
# 54701                       HTML/CSS;JavaScript;Ruby;SQL
# 25102          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 1931   Bash/Shell;HTML/CSS;Java;JavaScript;Node.js;PH...
# 5000   Assembly;Bash/Shell;HTML/CSS;Java;JavaScript;K...
# 46391                              JavaScript;Ruby;Swift
# 59563                                         Clojure;Go
# 77655                    Java;JavaScript;Python;Ruby;SQL
# 36552    C#;Dart;Java;JavaScript;Kotlin;Node.js;Ruby;SQL
# 27561  C#;Go;HTML/CSS;JavaScript;Node.js;Python;SQL;T...
# 30569          C;C#;C++;HTML/CSS;JavaScript;Node.js;Rust
# 50225             Bash/Shell;C;Node.js;Python;TypeScript
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 66910                                                NaN
# 65399       Clojure;Crystal;Dart;Matlab;Node.js;Python;R
# 40586  Bash/Shell;Haskell;HTML/CSS;Java;JavaScript;No...
# 28791                                         Ruby;Swift
# 12700                                         JavaScript
# 9608                                                 NaN
# 5305                                     Python;Rust;SQL
# 12903                                          C#;Python
# 66488                             Node.js;SQL;TypeScript
# 7205               Bash/Shell;C#;HTML/CSS;JavaScript;SQL
# 47563         HTML/CSS;JavaScript;Python;Rust;TypeScript
# 3733   Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;Nod...
# 33255  Bash/Shell;C;Go;HTML/CSS;Kotlin;Node.js;TypeSc...
# 35779    Bash/Shell;HTML/CSS;JavaScript;Node.js;Ruby;SQL
# 7904                                   Objective-C;Swift
# 10372                            Java;Node.js;TypeScript
# 9189             Bash/Shell;Go;Kotlin;Node.js;TypeScript
# 20908  C#;HTML/CSS;JavaScript;PowerShell;Python;SQL;T...
# 52070                  Bash/Shell;JavaScript;Python;Rust
# 53028  C;C++;Go;HTML/CSS;Java;JavaScript;Node.js;Pyth...
# 64111                                                 Go
# 66323                                           C;Python
# 82156                        HTML/CSS;JavaScript;PHP;SQL
# 7134                         Node.js;Rust;SQL;TypeScript
# 60701                                   Python;Scala;SQL
# 66417                                                NaN
# 64281                C#;Go;JavaScript;Node.js;PowerShell
# 51240                             C#;Delphi;HTML/CSS;SQL
# 33313                             C++;Delphi;Python;Rust
# 47536                             Python;Rust;TypeScript
# 51010  Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;Nod...
# 47210                              Rust;Swift;TypeScript
# 45288                                           C++;Rust
# 33919                                                 C#
# 55534                         Bash/Shell;Ruby;TypeScript
# 66013  C#;HTML/CSS;JavaScript;Node.js;Python;SQL;Type...
# 77060   Bash/Shell;HTML/CSS;Java;Python;Swift;TypeScript
# 78554        Go;Java;JavaScript;Node.js;Swift;TypeScript
# 4395                                                Rust
# 54701     HTML/CSS;JavaScript;Python;Ruby;SQL;TypeScript
# 25102                                                NaN
# 1931   Bash/Shell;Go;HTML/CSS;JavaScript;Node.js;PHP;...
# 5000   JavaScript;Kotlin;Node.js;Python;Rust;Swift;Ty...
# 46391                   JavaScript;Ruby;Swift;TypeScript
# 59563                                         Clojure;Go
# 77655                                        Go;Ruby;SQL
# 36552                              Kotlin;SQL;TypeScript
# 27561  Go;JavaScript;Node.js;Python;Rust;Scala;SQL;Ty...
# 30569                                    Rust;TypeScript
# 50225                                C;Python;TypeScript
#
#                                   DATABASEHAVEWORKEDWITH  \
# 66910                                          Couchbase
# 65399                    Couchbase;Elasticsearch;MariaDB
# 40586                               MariaDB;MySQL;SQLite
# 28791  Microsoft SQL Server;MySQL;Oracle;PostgreSQL;S...
# 12700                           MongoDB;MySQL;PostgreSQL
# 9608   Elasticsearch;IBM DB2;MariaDB;MongoDB;MySQL;Or...
# 5305                                                 NaN
# 12903                                   MySQL;PostgreSQL
# 66488  DynamoDB;Elasticsearch;Firebase;MySQL;PostgreS...
# 7205                   Microsoft SQL Server;MySQL;Oracle
# 47563                                         PostgreSQL
# 3733                              MariaDB;MongoDB;Oracle
# 33255  DynamoDB;Elasticsearch;Firebase;Microsoft SQL ...
# 35779            DynamoDB;Elasticsearch;PostgreSQL;Redis
# 7904                                              SQLite
# 10372                    Microsoft SQL Server;PostgreSQL
# 9189                                      MariaDB;SQLite
# 20908                   Microsoft SQL Server;MySQL;Redis
# 52070                                             SQLite
# 53028  DynamoDB;Elasticsearch;MySQL;Oracle;PostgreSQL...
# 64111                                         PostgreSQL
# 66323                                                NaN
# 82156                                              MySQL
# 7134   Microsoft SQL Server;MongoDB;MySQL;PostgreSQL;...
# 60701                                DynamoDB;PostgreSQL
# 66417                                                NaN
# 64281                                                NaN
# 51240  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 33313                               Microsoft SQL Server
# 47536            DynamoDB;MariaDB;MySQL;PostgreSQL;Redis
# 51010                                      MongoDB;MySQL
# 47210                                                NaN
# 45288                                         PostgreSQL
# 33919                        Microsoft SQL Server;SQLite
# 55534                           Elasticsearch;PostgreSQL
# 66013                         Microsoft SQL Server;MySQL
# 77060                  DynamoDB;Elasticsearch;PostgreSQL
# 78554  Couchbase;Firebase;MongoDB;MySQL;PostgreSQL;Redis
# 4395                 DynamoDB;MongoDB;MySQL;Redis;SQLite
# 54701                                   MySQL;PostgreSQL
# 25102                    MongoDB;PostgreSQL;Redis;SQLite
# 1931                                  MySQL;Redis;SQLite
# 5000                                    MySQL;PostgreSQL
# 46391                                                NaN
# 59563                                      Elasticsearch
# 77655                                         PostgreSQL
# 36552           DynamoDB;Firebase;MySQL;PostgreSQL;Redis
# 27561  Microsoft SQL Server;MongoDB;MySQL;PostgreSQL;...
# 30569                                      MongoDB;MySQL
# 50225                                              MySQL
#
#                                   DATABASEWANTTOWORKWITH  \
# 66910                                                NaN
# 65399                                       MySQL;Oracle
# 40586                               MariaDB;MySQL;SQLite
# 28791                                            MongoDB
# 12700                           MongoDB;MySQL;PostgreSQL
# 9608                                                 NaN
# 5305                                                 NaN
# 12903                                   MySQL;PostgreSQL
# 66488                                     DynamoDB;Redis
# 7205                     Microsoft SQL Server;PostgreSQL
# 47563                                         PostgreSQL
# 3733                          MariaDB;MongoDB;PostgreSQL
# 33255           Elasticsearch;Microsoft SQL Server;Redis
# 35779            DynamoDB;Elasticsearch;PostgreSQL;Redis
# 7904                                              SQLite
# 10372                                                NaN
# 9189                                      MariaDB;SQLite
# 20908                   Microsoft SQL Server;MySQL;Redis
# 52070                                                NaN
# 53028  Cassandra;DynamoDB;Elasticsearch;PostgreSQL;Redis
# 64111                                         PostgreSQL
# 66323                                                NaN
# 82156                                              MySQL
# 7134                                    PostgreSQL;Redis
# 60701                                         PostgreSQL
# 66417                                                NaN
# 64281                                                NaN
# 51240                               MariaDB;MySQL;SQLite
# 33313                                              MySQL
# 47536                             MySQL;PostgreSQL;Redis
# 51010               Elasticsearch;Firebase;MongoDB;MySQL
# 47210                                                NaN
# 45288                                                NaN
# 33919                        Microsoft SQL Server;SQLite
# 55534                                                NaN
# 66013                         Microsoft SQL Server;MySQL
# 77060                                DynamoDB;PostgreSQL
# 78554            Couchbase;Firebase;MongoDB;Redis;SQLite
# 4395                                                 NaN
# 54701                             MySQL;PostgreSQL;Redis
# 25102                                                NaN
# 1931                           MySQL;Oracle;Redis;SQLite
# 5000                                          PostgreSQL
# 46391                                                NaN
# 59563                                      Elasticsearch
# 77655                                         PostgreSQL
# 36552                                   PostgreSQL;Redis
# 27561                     Elasticsearch;MySQL;PostgreSQL
# 30569                                                NaN
# 50225                                                NaN
#
#                                   PLATFORMHAVEWORKEDWITH  \
# 66910                                                AWS
# 65399                            AWS;IBM Cloud or Watson
# 40586                                    Microsoft Azure
# 28791                            AWS;DigitalOcean;Heroku
# 12700                                         AWS;Heroku
# 9608                                    AWS;DigitalOcean
# 5305                           AWS;Google Cloud Platform
# 12903                                                NaN
# 66488                          AWS;Google Cloud Platform
# 7205                                     Microsoft Azure
# 47563                                                AWS
# 3733                                                 AWS
# 33255  AWS;DigitalOcean;Google Cloud Platform;Microso...
# 35779                   AWS;Google Cloud Platform;Heroku
# 7904                                                 NaN
# 10372                                                AWS
# 9189           AWS;Google Cloud Platform;Microsoft Azure
# 20908                                    Microsoft Azure
# 52070                                                AWS
# 53028  AWS;DigitalOcean;Google Cloud Platform;Heroku;...
# 64111                              Google Cloud Platform
# 66323                                                NaN
# 82156                                                NaN
# 7134           AWS;Google Cloud Platform;Microsoft Azure
# 60701                                                AWS
# 66417                                                NaN
# 64281                                    Microsoft Azure
# 51240                   AWS;DigitalOcean;Microsoft Azure
# 33313                                                NaN
# 47536      AWS;DigitalOcean;Google Cloud Platform;Heroku
# 51010                                                AWS
# 47210                                                NaN
# 45288                                AWS;Microsoft Azure
# 33919                                    Microsoft Azure
# 55534                                         AWS;Heroku
# 66013                                AWS;Microsoft Azure
# 77060                                                AWS
# 78554      AWS;DigitalOcean;Google Cloud Platform;Heroku
# 4395                                                 AWS
# 54701                                         AWS;Heroku
# 25102                                         AWS;Heroku
# 1931           AWS;Google Cloud Platform;Microsoft Azure
# 5000                           AWS;Google Cloud Platform
# 46391                                    Microsoft Azure
# 59563                                                AWS
# 77655                                                AWS
# 36552                                                AWS
# 27561   AWS;Google Cloud Platform;Heroku;Microsoft Azure
# 30569                                                NaN
# 50225                                                AWS
#
#                           PLATFORMWANTTOWORKWITH  \
# 66910                                        NaN
# 65399                Oracle Cloud Infrastructure
# 40586                            Microsoft Azure
# 28791        IBM Cloud or Watson;Microsoft Azure
# 12700                                 AWS;Heroku
# 9608                                         NaN
# 5305                                         NaN
# 12903                                        NaN
# 66488                                        AWS
# 7205                             Microsoft Azure
# 47563                                        NaN
# 3733                                         AWS
# 33255           AWS;DigitalOcean;Microsoft Azure
# 35779                                 AWS;Heroku
# 7904                                         NaN
# 10372                                        NaN
# 9189   AWS;Google Cloud Platform;Microsoft Azure
# 20908                            Microsoft Azure
# 52070                                        NaN
# 53028                  AWS;Google Cloud Platform
# 64111                      Google Cloud Platform
# 66323                                        NaN
# 82156                                        NaN
# 7134                   AWS;Google Cloud Platform
# 60701                                        AWS
# 66417                                        NaN
# 64281                            Microsoft Azure
# 51240                               DigitalOcean
# 33313                                        NaN
# 47536                    AWS;DigitalOcean;Heroku
# 51010           AWS;Google Cloud Platform;Heroku
# 47210                                        NaN
# 45288                                        NaN
# 33919                            Microsoft Azure
# 55534                                        AWS
# 66013                        AWS;Microsoft Azure
# 77060                                        AWS
# 78554           AWS;Google Cloud Platform;Heroku
# 4395                                         NaN
# 54701                        AWS;Microsoft Azure
# 25102                                        NaN
# 1931                       Google Cloud Platform
# 5000                                         AWS
# 46391                                        NaN
# 59563                                        AWS
# 77655                  AWS;Google Cloud Platform
# 36552                                        NaN
# 27561           AWS;Google Cloud Platform;Heroku
# 30569                                        NaN
# 50225                            Microsoft Azure
#
#                                   WEBFRAMEHAVEWORKEDWITH  \
# 66910                                                NaN
# 65399                      ASP.NET;Drupal;Laravel;Svelte
# 40586                                              Flask
# 28791    Angular.js;Drupal;Laravel;Ruby on Rails;Symfony
# 12700                                           React.js
# 9608                               Angular;jQuery;Spring
# 5305                                               Flask
# ...
# 12700                                        South Asian
# 9608                        White or of European descent
# 5305                        White or of European descent
# 12903                       White or of European descent
# 66488                                  Prefer not to say
# 7205                        White or of European descent
# 47563                                  Prefer not to say
# 3733                                                 NaN
# 33255                       White or of European descent
# 35779                       White or of European descent
# 7904                        White or of European descent
# 10372                       White or of European descent
# 9189        White or of European descent;Southeast Asian
# 20908                       White or of European descent
# 52070                       White or of European descent
# 53028                                                NaN
# 64111                       White or of European descent
# 66323                       White or of European descent
# 82156                                     Middle Eastern
# 7134   White or of European descent;Southeast Asian;B...
# 60701                       White or of European descent
# 66417                       White or of European descent
# 64281                       White or of European descent
# 51240                       White or of European descent
# 33313                             Hispanic or Latino/a/x
# 47536                       White or of European descent
# 51010                       White or of European descent
# 47210                       White or of European descent
# 45288                       White or of European descent
# 33919                                                NaN
# 55534                       White or of European descent
# 66013  White or of European descent;Indigenous (such ...
# 77060                       White or of European descent
# 78554                                    Southeast Asian
# 4395                        White or of European descent
# 54701                       White or of European descent
# 25102                                                NaN
# 1931                        White or of European descent
# 5000                        White or of European descent
# 46391                       White or of European descent
# 59563                       White or of European descent
# 77655                       White or of European descent
# 36552                             Or, in your own words:
# 27561                       White or of European descent
# 30569                                  Prefer not to say
# 50225                       White or of European descent
#
#                                            ACCESSIBILITY  \
# 66910                I am blind / have difficulty seeing
# 65399  I am unable to / find it difficult to walk or ...
# 40586                I am blind / have difficulty seeing
# 28791                                  Prefer not to say
# 12700                                  None of the above
# 9608                                   None of the above
# 5305                                   None of the above
# 12903                                  None of the above
# 66488                                  Prefer not to say
# 7205                                   None of the above
# 47563                                  None of the above
# 3733                                                 NaN
# 33255                                  None of the above
# 35779                                  None of the above
# 7904                                   None of the above
# 10372                                  None of the above
# 9189                                   None of the above
# 20908                                  None of the above
# 52070                                  None of the above
# 53028                                                NaN
# 64111                                  None of the above
# 66323                                  None of the above
# 82156                                                NaN
# 7134                                   None of the above
# 60701                                  None of the above
# 66417                                  None of the above
# 64281                                  None of the above
# 51240                                  None of the above
# 33313                                  None of the above
# 47536                                  None of the above
# 51010                                  None of the above
# 47210                                  None of the above
# 45288                                  None of the above
# 33919                                                NaN
# 55534                                  None of the above
# 66013                                  None of the above
# 77060                                  None of the above
# 78554                                  None of the above
# 4395                                   None of the above
# 54701                                  None of the above
# 25102                                  None of the above
# 1931                                   None of the above
# 5000                                   None of the above
# 46391                                  None of the above
# 59563                                  None of the above
# 77655                                  None of the above
# 36552                                  None of the above
# 27561                                  None of the above
# 30569                                  Prefer not to say
# 50225                                  None of the above
#
#                                             MENTALHEALTH  \
# 66910  I have a concentration and/or memory disorder ...
# 65399  I have a mood or emotional disorder (e.g. depr...
# 40586  I have a concentration and/or memory disorder ...
# 28791                                  None of the above
# 12700                                  None of the above
# 9608                                   None of the above
# 5305                                   None of the above
# 12903                                  None of the above
# 66488                                  Prefer not to say
# 7205                                   None of the above
# 47563                         I have an anxiety disorder
# 3733                                                 NaN
# 33255                                  None of the above
# 35779                                  None of the above
# 7904                                   None of the above
# 10372                             Or, in your own words:
# 9189                                   None of the above
# 20908                                  None of the above
# 52070                                  None of the above
# 53028                                                NaN
# 64111                                  None of the above
# 66323                                  None of the above
# 82156                                  None of the above
# 7134   I have a concentration and/or memory disorder ...
# 60701                                                NaN
# 66417                                  None of the above
# 64281                         I have an anxiety disorder
# 51240                                  None of the above
# 33313                                  None of the above
# 47536                                  None of the above
# 51010                             Or, in your own words:
# 47210                                  Prefer not to say
# 45288                                  None of the above
# 33919                                                NaN
# 55534  I have a concentration and/or memory disorder ...
# 66013                                  None of the above
# 77060  I have a concentration and/or memory disorder ...
# 78554                                  None of the above
# 4395                                   Prefer not to say
# 54701  I have a mood or emotional disorder (e.g. depr...
# 25102  I have autism / an autism spectrum disorder (e...
# 1931   I have a concentration and/or memory disorder ...
# 5000                                   Prefer not to say
# 46391  I have a concentration and/or memory disorder ...
# 59563                                  None of the above
# 77655  I have a concentration and/or memory disorder ...
# 36552                                  None of the above
# 27561                                  None of the above
# 30569                                  Prefer not to say
# 50225                                  None of the above
#
#                 SURVEYLENGTH                  SURVEYEASE CONVERTEDCOMPYEARLY  \
# 66910              Too short                         NaN          45241312.0
# 65399              Too short                   Difficult          30468516.0
# 40586  Appropriate in length                        Easy          21822250.0
# 28791  Appropriate in length                        Easy          20000000.0
# 12700  Appropriate in length                        Easy          19200000.0
# 9608   Appropriate in length                        Easy          17500000.0
# 5305                Too long                        Easy          15000000.0
# 12903               Too long  Neither easy nor difficult          14411628.0
# 66488  Appropriate in length                        Easy          12750000.0
# 7205   Appropriate in length                        Easy          12500000.0
# 47563  Appropriate in length  Neither easy nor difficult          12500000.0
# 3733   Appropriate in length                        Easy          11250000.0
# 33255               Too long                        Easy          11250000.0
# 35779  Appropriate in length                        Easy          11000000.0
# 7904   Appropriate in length  Neither easy nor difficult          10500000.0
# 10372  Appropriate in length  Neither easy nor difficult          10350000.0
# 9189   Appropriate in length                        Easy          10200000.0
# 20908  Appropriate in length                        Easy          10000000.0
# 52070              Too short                        Easy          10000000.0
# 53028  Appropriate in length                        Easy          10000000.0
# 64111              Too short                        Easy          10000000.0
# 66323  Appropriate in length                        Easy          10000000.0
# 82156               Too long  Neither easy nor difficult           9975060.0
# 7134   Appropriate in length                        Easy           9500000.0
# 60701  Appropriate in length  Neither easy nor difficult           9500000.0
# 66417  Appropriate in length  Neither easy nor difficult           9100000.0
# 64281  Appropriate in length                        Easy           9000000.0
# 51240  Appropriate in length                        Easy           8850000.0
# 33313  Appropriate in length                        Easy           8625145.0
# 47536  Appropriate in length                        Easy           8500000.0
# 51010  Appropriate in length                        Easy           8250000.0
# 47210  Appropriate in length                        Easy           8100000.0
# 45288  Appropriate in length                        Easy           8078700.0
# 33919  Appropriate in length                        Easy           8000000.0
# 55534  Appropriate in length                        Easy           8000000.0
# 66013               Too long                        Easy           8000000.0
# 77060  Appropriate in length                        Easy           8000000.0
# 78554               Too long                        Easy           7903704.0
# 4395   Appropriate in length                        Easy           7900000.0
# 54701  Appropriate in length                        Easy           7900000.0
# 25102               Too long                        Easy           7563129.0
# 1931   Appropriate in length                        Easy           7500000.0
# 5000   Appropriate in length                        Easy           7500000.0
# 46391  Appropriate in length                        Easy           7500000.0
# 59563  Appropriate in length                        Easy           7500000.0
# 77655  Appropriate in length                        Easy           7500000.0
# 36552              Too short                        Easy           7382500.0
# 27561  Appropriate in length                        Easy           7250000.0
# 30569  Appropriate in length                        Easy           7000000.0
# 50225  Appropriate in length                        Easy           7000000.0
#
#                                                    AYUDA
# 66910  Visit Stack Overflow;Go for a walk or other ph...
# 65399  Watch help / tutorial videos;Play games Stack ...
# 40586  Visit Stack Overflow;Google it;Do other work a...
# 28791  Visit Stack Overflow;Google it;Visit another d...
# 12700  Visit Stack Overflow;Google it;Visit another d...
# 9608   Call a coworker or friend;Google it Stack Over...
# 5305   Other (please specify): Stack Overflow;Stack E...
# 12903  Visit Stack Overflow;Google it;Watch help / tu...
# 66488  Call a coworker or friend;Google it;Meditate S...
# 7205   Go for a walk or other physical activity;Googl...
# 47563  Go for a walk or other physical activity;Googl...
# 3733   Visit Stack Overflow;Go for a walk or other ph...
# 33255  Visit Stack Overflow;Go for a walk or other ph...
# 35779  Call a coworker or friend;Visit Stack Overflow...
# 7904   Call a coworker or friend;Go for a walk or oth...
# 10372  Call a coworker or friend;Go for a walk or oth...
# 9189   Call a coworker or friend;Go for a walk or oth...
# 20908  Visit Stack Overflow;Do other work and come ba...
# 52070  Call a coworker or friend;Visit Stack Overflow...
# 53028  Go for a walk or other physical activity;Do ot...
# 64111  Call a coworker or friend;Visit Stack Overflow...
# 66323  Visit Stack Overflow;Google it Stack Overflow;...
# 82156  Call a coworker or friend;Visit Stack Overflow...
# 7134   Call a coworker or friend;Visit Stack Overflow...
# 60701  Call a coworker or friend;Visit Stack Overflow...
# 66417  Call a coworker or friend;Visit Stack Overflow...
# 64281  Visit Stack Overflow;Go for a walk or other ph...
# 51240            Google it Stack Overflow;Stack Exchange
# 33313  Visit Stack Overflow;Google it;Watch help / tu...
# 47536  Visit Stack Overflow;Go for a walk or other ph...
# 51010  Call a coworker or friend;Visit Stack Overflow...
# 47210  Visit Stack Overflow;Google it;Do other work a...
# 45288            Google it Stack Overflow;Stack Exchange
# 33919  Visit Stack Overflow;Google it;Watch help / tu...
# 55534  Visit Stack Overflow;Google it;Do other work a...
# 66013  Call a coworker or friend;Visit Stack Overflow...
# 77060  Call a coworker or friend;Visit Stack Overflow...
# 78554  Visit Stack Overflow;Go for a walk or other ph...
# 4395   Visit Stack Overflow;Go for a walk or other ph...
# 54701  Call a coworker or friend;Visit Stack Overflow...
# 25102  Visit Stack Overflow;Go for a walk or other ph...
# 1931   Visit Stack Overflow;Go for a walk or other ph...
# 5000   Visit Stack Overflow;Go for a walk or other ph...
# 46391  Call a coworker or friend;Visit Stack Overflow...
# 59563  Call a coworker or friend;Go for a walk or oth...
# 77655  Call a coworker or friend;Visit Stack Overflow...
# 36552  Call a coworker or friend;Google it Stack Over...
# 27561  Visit Stack Overflow;Do other work and come ba...
# 30569  Visit Stack Overflow;Google it;Watch help / tu...
# 50225  Call a coworker or friend;Google it;Do other w...
#
# [50 rows x 49 columns]

# %%
datos["CONVERTEDCOMPYEARLY"].nlargest(25)
# Out:
# 66910    45241312.0
# 65399    30468516.0
# 40586    21822250.0
# 28791    20000000.0
# 12700    19200000.0
# 9608     17500000.0
# 5305     15000000.0
# 12903    14411628.0
# 66488    12750000.0
# 7205     12500000.0
# 47563    12500000.0
# 3733     11250000.0
# 33255    11250000.0
# 35779    11000000.0
# 7904     10500000.0
# 10372    10350000.0
# 9189     10200000.0
# 20908    10000000.0
# 52070    10000000.0
# 53028    10000000.0
# 64111    10000000.0
# 66323    10000000.0
# 82156     9975060.0
# 7134      9500000.0
# 60701     9500000.0
# Name: CONVERTEDCOMPYEARLY, dtype: float64

# %%
datos.nlargest(25, "CONVERTEDCOMPYEARLY")
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 66910       66911                     I am a developer by profession
# 65399       65400                     I am a developer by profession
# 40586       40587                     I am a developer by profession
# 28791       28792                     I am a developer by profession
# 12700       12701                     I am a developer by profession
# 9608         9609  I am not primarily a developer, but I write co...
# 5305         5306                     I am a developer by profession
# 12903       12904                     I am a developer by profession
# 66488       66489                     I am a developer by profession
# 7205         7206                     I am a developer by profession
# 47563       47564                     I am a developer by profession
# 3733         3734                     I am a developer by profession
# 33255       33256                     I am a developer by profession
# 35779       35780                     I am a developer by profession
# 7904         7905                     I am a developer by profession
# 10372       10373                     I am a developer by profession
# 9189         9190                     I am a developer by profession
# 20908       20909                     I am a developer by profession
# 52070       52071  I am not primarily a developer, but I write co...
# 53028       53029                     I am a developer by profession
# 64111       64112                     I am a developer by profession
# 66323       66324  I am not primarily a developer, but I write co...
# 82156       82157                     I am a developer by profession
# 7134         7135                     I am a developer by profession
# 60701       60702                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 66910                                I prefer not to say
# 65399                                 Employed full-time
# 40586                                 Employed full-time
# 28791                                 Employed full-time
# 12700                                 Employed full-time
# 9608                                  Employed full-time
# 5305   Independent contractor, freelancer, or self-em...
# 12903                                 Employed full-time
# 66488                                 Employed full-time
# 7205   Independent contractor, freelancer, or self-em...
# 47563                                 Employed full-time
# 3733   Independent contractor, freelancer, or self-em...
# 33255                                 Employed full-time
# 35779                                 Employed full-time
# 7904                                  Employed full-time
# 10372                                 Employed full-time
# 9189                                  Employed full-time
# 20908                                 Employed full-time
# 52070                                 Employed full-time
# 53028                                 Employed full-time
# 64111                                 Employed full-time
# 66323                                 Employed full-time
# 82156                                 Employed full-time
# 7134                                  Employed full-time
# 60701                                 Employed full-time
#
#                             COUNTRY         USSTATE UKCOUNTRY  \
# 66910                       BELGIUM             NaN       NaN
# 65399                   AFGHANISTAN             NaN       NaN
# 40586      UNITED STATES OF AMERICA      California       NaN
# 28791                         INDIA             NaN       NaN
# 12700                         INDIA             NaN       NaN
# 9608       UNITED STATES OF AMERICA        New York       NaN
# 5305       UNITED STATES OF AMERICA      New Jersey       NaN
# 12903                        SERBIA             NaN       NaN
# 66488      UNITED STATES OF AMERICA      Washington       NaN
# 7205       UNITED STATES OF AMERICA  South Carolina       NaN
# 47563      UNITED STATES OF AMERICA        Colorado       NaN
# 3733       UNITED STATES OF AMERICA        Virginia       NaN
# 33255      UNITED STATES OF AMERICA         Florida       NaN
# 35779      UNITED STATES OF AMERICA    Pennsylvania       NaN
# 7904       UNITED STATES OF AMERICA      Washington       NaN
# 10372      UNITED STATES OF AMERICA     Connecticut       NaN
# 9189       UNITED STATES OF AMERICA      Washington       NaN
# 20908      UNITED STATES OF AMERICA           Texas       NaN
# 52070      UNITED STATES OF AMERICA      California       NaN
# 53028      UNITED STATES OF AMERICA        Missouri       NaN
# 64111      UNITED STATES OF AMERICA      California       NaN
# 66323      UNITED STATES OF AMERICA         Indiana       NaN
# 82156  IRAN, ISLAMIC REPUBLIC OF...             NaN       NaN
# 7134       UNITED STATES OF AMERICA      California       NaN
# 60701      UNITED STATES OF AMERICA        Colorado       NaN
#
#                                                  EDLEVEL  \
# 66910                          Primary/elementary school
# 65399    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 40586  Some college/university study without earning ...
# 28791       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12700    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 9608        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5305                  Professional degree (JD, MD, etc.)
# 12903       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 66488  Some college/university study without earning ...
# 7205        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 47563       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3733        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33255       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 35779       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 7904        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 10372       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9189        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 20908  Some college/university study without earning ...
# 52070    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 53028       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64111       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 66323       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 82156    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 7134        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 60701       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                  AGE1STCODE  \
# 66910         55 - 64 years
# 65399         25 - 34 years
# 40586  Younger than 5 years
# 28791         35 - 44 years
# 12700         25 - 34 years
# 9608          18 - 24 years
# 5305          11 - 17 years
# 12903         11 - 17 years
# 66488         18 - 24 years
# 7205           5 - 10 years
# 47563         11 - 17 years
# 3733          11 - 17 years
# 33255         11 - 17 years
# 35779         18 - 24 years
# 7904          18 - 24 years
# 10372          5 - 10 years
# 9189           5 - 10 years
# 20908         11 - 17 years
# 52070          5 - 10 years
# 53028          5 - 10 years
# 64111         11 - 17 years
# 66323          5 - 10 years
# 82156         25 - 34 years
# 7134          11 - 17 years
# 60701         11 - 17 years
#
#                                                LEARNCODE YEARSCODE  \
# 66910                             Books / Physical media         1
# 65399                    Online Courses or Certification         7
# 40586  Other online resources (ex: videos, blogs, etc...        37
# 28791  Coding Bootcamp;Other online resources (ex: vi...        11
# 12700                                       Online Forum         5
# 9608                                              School        25
# 5305      Friend or family member;Books / Physical media        25
# 12903  Other online resources (ex: videos, blogs, etc...         6
# 66488  School;Online Courses or Certification;Books /...         5
# 7205   Other online resources (ex: videos, blogs, etc...        30
# 47563                             Books / Physical media        24
# 3733                             Friend or family member        28
# 33255  School;Other (please specify):;Books / Physica...        37
# 35779  Other online resources (ex: videos, blogs, etc...        13
# 7904                       School;Books / Physical media        11
# 10372                      School;Books / Physical media        35
# 9189   Other online resources (ex: videos, blogs, etc...        35
# 20908  Other online resources (ex: videos, blogs, etc...        20
# 52070  Other online resources (ex: videos, blogs, etc...        20
# 53028  Other online resources (ex: videos, blogs, etc...        20
# 64111  Other online resources (ex: videos, blogs, etc...        12
# 66323                             Coding Bootcamp;School        33
# 82156  Other online resources (ex: videos, blogs, etc...       NaN
# 7134   School;Friend or family member;Online Courses ...        13
# 60701  Coding Bootcamp;School;Friend or family member...        14
#
#       YEARSCODEPRO                                            DEVTYPE  \
# 66910           21                                                NaN
# 65399            3  Developer, desktop or enterprise applications;...
# 40586           13                            Other (please specify):
# 28791            9  Developer, desktop or enterprise applications;...
# 12700            5                              Developer, full-stack
# 9608            21               Senior Executive (C-Suite, VP, etc.)
# 5305             5            Developer, full-stack;DevOps specialist
# 12903            1  Developer, front-end;Developer, full-stack;Dev...
# 66488            3  Developer, desktop or enterprise applications;...
# 7205            20  Developer, front-end;Developer, desktop or ent...
# 47563           13                               Developer, front-end
# 3733            19                                Developer, back-end
# 33255           33  Developer, mobile;Developer, front-end;Develop...
# 35779           13                              Developer, full-stack
# 7904             7                                  Developer, mobile
# 10372           21         Developer, front-end;Developer, full-stack
# 9189            24            Developer, back-end;Engineering manager
# 20908           20  Developer, front-end;Developer, desktop or ent...
# 52070           10  Developer, front-end;Data scientist or machine...
# 53028           15                              Developer, full-stack
# 64111            7                                Developer, back-end
# 66323           23        Developer, embedded applications or devices
# 82156            5                                Developer, back-end
# 7134             9                              Developer, full-stack
# 60701           11  Engineer, data;Data scientist or machine learn...
#
#                                                  ORGSIZE  \
# 66910  Just me - I am a freelancer, sole proprietor, ...
# 65399                               500 to 999 employees
# 40586                           10,000 or more employees
# 28791                               100 to 499 employees
# 12700                               100 to 499 employees
# 9608                                  20 to 99 employees
# 5305   Just me - I am a freelancer, sole proprietor, ...
# 12903                               100 to 499 employees
# 66488                                 20 to 99 employees
# 7205   Just me - I am a freelancer, sole proprietor, ...
# 47563                           10,000 or more employees
# 3733   Just me - I am a freelancer, sole proprietor, ...
# 33255                               100 to 499 employees
# 35779                                 20 to 99 employees
# 7904                            5,000 to 9,999 employees
# 10372                           10,000 or more employees
# 9189                            10,000 or more employees
# 20908                           5,000 to 9,999 employees
# 52070                           1,000 to 4,999 employees
# 53028                           10,000 or more employees
# 64111                                 20 to 99 employees
# 66323                           10,000 or more employees
# 82156                                 10 to 19 employees
# 7134                                    2 to 9 employees
# 60701                               100 to 499 employees
#
#                                 CURRENCY     COMPTOTAL COMPFREQ  \
# 66910                  ALL\tAlbanian lek  5.123468e+09   Yearly
# 65399  ANG Netherlands Antillean guilder  4.544242e+06  Monthly
# 40586          USD\tUnited States dollar  4.364450e+05   Weekly
# 28791          USD\tUnited States dollar  2.000000e+07   Yearly
# 12700          USD\tUnited States dollar  1.600000e+06  Monthly
# 9608           USD\tUnited States dollar  3.500000e+05   Weekly
# 5305           USD\tUnited States dollar  3.000000e+05   Weekly
# 12903                  EUR European Euro  1.111000e+06  Monthly
# 66488          USD\tUnited States dollar  2.550000e+05   Weekly
# 7205           USD\tUnited States dollar  2.500000e+05   Weekly
# 47563          USD\tUnited States dollar  2.500000e+05   Weekly
# 3733           USD\tUnited States dollar  2.250000e+05   Weekly
# 33255          USD\tUnited States dollar  2.250000e+05   Weekly
# 35779          USD\tUnited States dollar  2.200000e+05   Weekly
# 7904           USD\tUnited States dollar  2.100000e+05   Weekly
# 10372          USD\tUnited States dollar  2.070000e+05   Weekly
# 9189           USD\tUnited States dollar  8.500000e+05  Monthly
# 20908          USD\tUnited States dollar  2.000000e+05   Weekly
# 52070          USD\tUnited States dollar  2.000000e+05   Weekly
# 53028          USD\tUnited States dollar  2.000000e+05   Weekly
# 64111          USD\tUnited States dollar  2.000000e+05   Weekly
# 66323          USD\tUnited States dollar  2.000000e+05   Weekly
# 82156                  IRR\tIranian rial  3.500000e+10  Monthly
# 7134           USD\tUnited States dollar  1.900000e+05   Weekly
# 60701          USD\tUnited States dollar  1.900000e+05   Weekly
#
#                                   LANGUAGEHAVEWORKEDWITH  \
# 66910                                                APL
# 65399  Bash/Shell;C++;Elixir;LISP;Node.js;Ruby;Rust;S...
# 40586  Bash/Shell;HTML/CSS;Java;JavaScript;Node.js;Py...
# 28791  C#;C++;Groovy;HTML/CSS;Java;JavaScript;Node.js...
# 12700                                         JavaScript
# 9608   Bash/Shell;Go;HTML/CSS;Java;JavaScript;Kotlin;...
# 5305                                              Python
# 12903                       C#;JavaScript;Node.js;Python
# 66488  Bash/Shell;Go;HTML/CSS;Java;JavaScript;Kotlin;...
# 7205   Bash/Shell;C#;HTML/CSS;JavaScript;PHP;PowerShe...
# 47563           Go;HTML/CSS;JavaScript;Python;TypeScript
# 3733   Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;Nod...
# 33255  Bash/Shell;C;C#;C++;Go;HTML/CSS;Java;JavaScrip...
# 35779    Bash/Shell;HTML/CSS;JavaScript;Node.js;Ruby;SQL
# 7904                    Bash/Shell;C++;Objective-C;Swift
# 10372    HTML/CSS;Java;JavaScript;Node.js;SQL;TypeScript
# 9189        Bash/Shell;Go;Java;Kotlin;Node.js;TypeScript
# 20908  C#;HTML/CSS;JavaScript;PowerShell;Python;SQL;T...
# 52070              Bash/Shell;C++;JavaScript;Python;Rust
# 53028  C;C++;Go;HTML/CSS;Java;JavaScript;Node.js;Pyth...
# 64111                                            Go;Java
# 66323                                                  C
# 82156                            HTML/CSS;JavaScript;PHP
# 7134   Bash/Shell;JavaScript;Node.js;Rust;SQL;Swift;T...
# 60701                    Bash/Shell;Java;Python;Ruby;SQL
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 66910                                                NaN
# 65399       Clojure;Crystal;Dart;Matlab;Node.js;Python;R
# 40586  Bash/Shell;Haskell;HTML/CSS;Java;JavaScript;No...
# 28791                                         Ruby;Swift
# 12700                                         JavaScript
# 9608                                                 NaN
# 5305                                     Python;Rust;SQL
# 12903                                          C#;Python
# 66488                             Node.js;SQL;TypeScript
# 7205               Bash/Shell;C#;HTML/CSS;JavaScript;SQL
# 47563         HTML/CSS;JavaScript;Python;Rust;TypeScript
# 3733   Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;Nod...
# 33255  Bash/Shell;C;Go;HTML/CSS;Kotlin;Node.js;TypeSc...
# 35779    Bash/Shell;HTML/CSS;JavaScript;Node.js;Ruby;SQL
# 7904                                   Objective-C;Swift
# 10372                            Java;Node.js;TypeScript
# 9189             Bash/Shell;Go;Kotlin;Node.js;TypeScript
# 20908  C#;HTML/CSS;JavaScript;PowerShell;Python;SQL;T...
# 52070                  Bash/Shell;JavaScript;Python;Rust
# 53028  C;C++;Go;HTML/CSS;Java;JavaScript;Node.js;Pyth...
# 64111                                                 Go
# 66323                                           C;Python
# 82156                        HTML/CSS;JavaScript;PHP;SQL
# 7134                         Node.js;Rust;SQL;TypeScript
# 60701                                   Python;Scala;SQL
#
#                                   DATABASEHAVEWORKEDWITH  \
# 66910                                          Couchbase
# 65399                    Couchbase;Elasticsearch;MariaDB
# 40586                               MariaDB;MySQL;SQLite
# 28791  Microsoft SQL Server;MySQL;Oracle;PostgreSQL;S...
# 12700                           MongoDB;MySQL;PostgreSQL
# 9608   Elasticsearch;IBM DB2;MariaDB;MongoDB;MySQL;Or...
# 5305                                                 NaN
# 12903                                   MySQL;PostgreSQL
# 66488  DynamoDB;Elasticsearch;Firebase;MySQL;PostgreS...
# 7205                   Microsoft SQL Server;MySQL;Oracle
# 47563                                         PostgreSQL
# 3733                              MariaDB;MongoDB;Oracle
# 33255  DynamoDB;Elasticsearch;Firebase;Microsoft SQL ...
# 35779            DynamoDB;Elasticsearch;PostgreSQL;Redis
# 7904                                              SQLite
# 10372                    Microsoft SQL Server;PostgreSQL
# 9189                                      MariaDB;SQLite
# 20908                   Microsoft SQL Server;MySQL;Redis
# 52070                                             SQLite
# 53028  DynamoDB;Elasticsearch;MySQL;Oracle;PostgreSQL...
# 64111                                         PostgreSQL
# 66323                                                NaN
# 82156                                              MySQL
# 7134   Microsoft SQL Server;MongoDB;MySQL;PostgreSQL;...
# 60701                                DynamoDB;PostgreSQL
#
#                                   DATABASEWANTTOWORKWITH  \
# 66910                                                NaN
# 65399                                       MySQL;Oracle
# 40586                               MariaDB;MySQL;SQLite
# 28791                                            MongoDB
# 12700                           MongoDB;MySQL;PostgreSQL
# 9608                                                 NaN
# 5305                                                 NaN
# 12903                                   MySQL;PostgreSQL
# 66488                                     DynamoDB;Redis
# 7205                     Microsoft SQL Server;PostgreSQL
# 47563                                         PostgreSQL
# 3733                          MariaDB;MongoDB;PostgreSQL
# 33255           Elasticsearch;Microsoft SQL Server;Redis
# 35779            DynamoDB;Elasticsearch;PostgreSQL;Redis
# 7904                                              SQLite
# 10372                                                NaN
# 9189                                      MariaDB;SQLite
# 20908                   Microsoft SQL Server;MySQL;Redis
# 52070                                                NaN
# 53028  Cassandra;DynamoDB;Elasticsearch;PostgreSQL;Redis
# 64111                                         PostgreSQL
# 66323                                                NaN
# 82156                                              MySQL
# 7134                                    PostgreSQL;Redis
# 60701                                         PostgreSQL
#
#                                   PLATFORMHAVEWORKEDWITH  \
# 66910                                                AWS
# 65399                            AWS;IBM Cloud or Watson
# 40586                                    Microsoft Azure
# 28791                            AWS;DigitalOcean;Heroku
# 12700                                         AWS;Heroku
# 9608                                    AWS;DigitalOcean
# 5305                           AWS;Google Cloud Platform
# 12903                                                NaN
# 66488                          AWS;Google Cloud Platform
# 7205                                     Microsoft Azure
# 47563                                                AWS
# 3733                                                 AWS
# 33255  AWS;DigitalOcean;Google Cloud Platform;Microso...
# 35779                   AWS;Google Cloud Platform;Heroku
# 7904                                                 NaN
# 10372                                                AWS
# 9189           AWS;Google Cloud Platform;Microsoft Azure
# 20908                                    Microsoft Azure
# 52070                                                AWS
# 53028  AWS;DigitalOcean;Google Cloud Platform;Heroku;...
# 64111                              Google Cloud Platform
# 66323                                                NaN
# 82156                                                NaN
# 7134           AWS;Google Cloud Platform;Microsoft Azure
# 60701                                                AWS
#
#                           PLATFORMWANTTOWORKWITH  \
# 66910                                        NaN
# 65399                Oracle Cloud Infrastructure
# 40586                            Microsoft Azure
# 28791        IBM Cloud or Watson;Microsoft Azure
# 12700                                 AWS;Heroku
# 9608                                         NaN
# 5305                                         NaN
# 12903                                        NaN
# 66488                                        AWS
# 7205                             Microsoft Azure
# 47563                                        NaN
# 3733                                         AWS
# 33255           AWS;DigitalOcean;Microsoft Azure
# 35779                                 AWS;Heroku
# 7904                                         NaN
# 10372                                        NaN
# 9189   AWS;Google Cloud Platform;Microsoft Azure
# 20908                            Microsoft Azure
# 52070                                        NaN
# 53028                  AWS;Google Cloud Platform
# 64111                      Google Cloud Platform
# 66323                                        NaN
# 82156                                        NaN
# 7134                   AWS;Google Cloud Platform
# 60701                                        AWS
#
#                                   WEBFRAMEHAVEWORKEDWITH  \
# 66910                                                NaN
# 65399                      ASP.NET;Drupal;Laravel;Svelte
# 40586                                              Flask
# 28791    Angular.js;Drupal;Laravel;Ruby on Rails;Symfony
# 12700                                           React.js
# 9608                               Angular;jQuery;Spring
# 5305                                               Flask
# 12903  Angular;ASP.NET;ASP.NET Core ;Django;jQuery;Re...
# 66488                            Express;React.js;Spring
# 7205                        ASP.NET;ASP.NET Core ;jQuery
# 47563                                    React.js;Vue.js
# 3733                                              Spring
# 33255  ASP.NET;ASP.NET Core ;Express;jQuery;Spring;Vu...
# 35779                     Express;React.js;Ruby on Rails
# 7904                                                 NaN
# 10372                                            Angular
# 9189                                      Express;jQuery
# 20908              Angular;ASP.NET Core ;React.js;Vue.js
# 52070                                  Angular.js;jQuery
# 53028                                   Express;React.js
# 64111                                                NaN
# 66323                                                NaN
# 82156                                             jQuery
# 7134                                  Angular;Angular.js
# 60701                                Flask;Ruby on Rails
#
#                                   WEBFRAMEWANTTOWORKWITH  ...  \
# 66910                                                NaN  ...
# 65399  Angular;ASP.NET;Django;Express;Flask;jQuery;Ru...  ...
# 40586                      Express;Flask;React.js;Svelte  ...
# 28791                                    Angular;ASP.NET  ...
# 12700                                           React.js  ...
# 9608                                                 NaN  ...
# 5305                                              Django  ...
# 12903              Angular;ASP.NET Core ;Django;React.js  ...
# 66488                                   Express;React.js  ...
# 7205                Angular;ASP.NET;ASP.NET Core ;jQuery  ...
# 47563                                    React.js;Vue.js  ...
# 3733                              React.js;Spring;Vue.js  ...
# 33255                       Express;jQuery;Svelte;Vue.js  ...
# 35779                             React.js;Ruby on Rails  ...
# 7904                                                 NaN  ...
# 10372                                            Angular  ...
# 9189                                      Express;jQuery  ...
# 20908              Angular;ASP.NET Core ;React.js;Vue.js  ...
# 52070                                             jQuery  ...
# 53028                                            Express  ...
# 64111                                                NaN  ...
# 66323                                                NaN  ...
# 82156               Angular;Django;jQuery;Laravel;Vue.js  ...
# 7134                                                 NaN  ...
# 60701                                Flask;Ruby on Rails  ...
#
#                                   MISCTECHWANTTOWORKWITH  \
# 66910                                                NaN
# 65399                                  Flutter;Pandas;Qt
# 40586                                                NaN
# 28791                                     .NET Framework
# 12700                                                NaN
# 9608                                                 NaN
# 5305                                                 NaN
# 12903                                 .NET Core / .NET 5
# 66488                                       NumPy;Pandas
# 7205                   .NET Framework;.NET Core / .NET 5
# 47563                                                NaN
# 3733                                                 NaN
# 33255                                                NaN
# 35779                            React Native;TensorFlow
# 7904                                                 NaN
# 10372                                                NaN
# 9189                                                 NaN
# 20908                                 .NET Core / .NET 5
# 52070              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 53028                                         TensorFlow
# 64111                                                NaN
# 66323                                                NaN
# 82156                                                NaN
# 7134                                                 NaN
# 60701  Apache Spark;NumPy;Pandas;TensorFlow;Torch/PyT...
#
#             TOOLSTECHHAVEWORKEDWITH          TOOLSTECHWANTTOWORKWITH  \
# 66910                           NaN                              NaN
# 65399         Docker;Flow;Terraform                  Chef;Docker;Git
# 40586                           Git                       Docker;Git
# 28791                           Git    Chef;Docker;Kubernetes;Puppet
# 12700                           Git                              Git
# 9608                 Git;Kubernetes                              NaN
# 5305   Ansible;Docker;Git;Terraform                       Docker;Git
# 12903                    Docker;Git                       Docker;Git
# 66488               Docker;Git;Yarn                              Git
# 7205                            Git                              NaN
# 47563    Docker;Git;Kubernetes;Yarn                         Git;Yarn
# 3733                     Docker;Git                       Docker;Git
# 33255    Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# 35779                          Yarn                             Yarn
# 7904                            Git                              Git
# 10372                        Docker                           Docker
# 9189                     Docker;Git                              Git
# 20908         Docker;Git;Kubernetes   Docker;Git;Kubernetes;Unity 3D
# 52070                    Docker;Git                       Docker;Git
# 53028               Docker;Flow;Git          Terraform;Unreal Engine
# 64111         Docker;Git;Kubernetes            Docker;Git;Kubernetes
# 66323                           Git                              Git
# 82156                           NaN                              NaN
# 7134          Docker;Git;Kubernetes            Docker;Git;Kubernetes
# 60701    Docker;Git;Kubernetes;Yarn  Docker;Git;Kubernetes;Terraform
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 66910                                   IntelliJ;PyCharm
# 65399                         NetBeans;PHPStorm;RubyMine
# 40586                        IntelliJ;Visual Studio Code
# 28791  Android Studio;Atom;Eclipse;IPython/Jupyter;Ne...
# 12700                         Eclipse;Visual Studio Code
# 9608   Android Studio;IntelliJ;Notepad++;PHPStorm;Vim...
# 5305                                                 Vim
# 12903           PyCharm;Visual Studio;Visual Studio Code
# 66488  Atom;IntelliJ;PyCharm;Sublime Text;Visual Stud...
# 7205                             Notepad++;Visual Studio
# 47563                                 Visual Studio Code
# 3733                 Eclipse;IntelliJ;Visual Studio Code
# 33255  Eclipse;IntelliJ;Notepad++;Vim;Visual Studio;V...
# 35779   Android Studio;TextMate;Visual Studio Code;Xcode
# 7904           Sublime Text;Vim;Visual Studio Code;Xcode
# 10372                                           IntelliJ
# 9189   Android Studio;IntelliJ;RStudio;Visual Studio;...
# 20908         Notepad++;Visual Studio;Visual Studio Code
# 52070                        Atom;Vim;Visual Studio Code
# 53028                    IntelliJ;Vim;Visual Studio Code
# 64111                        IntelliJ;Visual Studio Code
# 66323                                  Eclipse;Notepad++
# 82156                            Android Studio;PHPStorm
# 7134                             IntelliJ;Webstorm;Xcode
# 60701                                IPython/Jupyter;Vim
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH  \
# 66910                                                NaN
# 65399                                   Eclipse;NetBeans
# 40586          IntelliJ;Visual Studio;Visual Studio Code
# 28791                                 Visual Studio Code
# 12700                         Eclipse;Visual Studio Code
# 9608                                                 NaN
# 5305                                                 Vim
# 12903           PyCharm;Visual Studio;Visual Studio Code
# 66488                                 Visual Studio Code
# 7205          Notepad++;Visual Studio;Visual Studio Code
# 47563                                 Visual Studio Code
# 3733                                            IntelliJ
# 33255                             Vim;Visual Studio Code
# 35779                  Android Studio;Visual Studio Code
# 7904           Sublime Text;Vim;Visual Studio Code;Xcode
# 10372                        IntelliJ;Visual Studio Code
# 9189   Android Studio;IntelliJ;Visual Studio;Visual S...
# 20908         Notepad++;Visual Studio;Visual Studio Code
# 52070                        Atom;Vim;Visual Studio Code
# 53028                                                Vim
# 64111                        IntelliJ;Visual Studio Code
# 66323                                  Eclipse;Notepad++
# 82156                                           PHPStorm
# 7134                            IntelliJ;Neovim;Webstorm
# 60701                                IPython/Jupyter;Vim
#
#                          OPSYS  \
# 66910  Other (please specify):
# 65399              Linux-based
# 40586                    MacOS
# 28791                    MacOS
# 12700                  Windows
# 9608                   Windows
# 5305               Linux-based
# 12903                  Windows
# 66488                    MacOS
# 7205                   Windows
# 47563                    MacOS
# 3733                   Windows
# 33255                    MacOS
# 35779                    MacOS
# 7904                     MacOS
# 10372                  Windows
# 9189                     MacOS
# 20908                  Windows
# 52070              Linux-based
# 53028                    MacOS
# 64111                    MacOS
# 66323                  Windows
# 82156                  Windows
# 7134                     MacOS
# 60701                    MacOS
#
#                                                 NEWSTUCK  \
# 66910  Visit Stack Overflow;Go for a walk or other ph...
# 65399            Watch help / tutorial videos;Play games
# 40586  Visit Stack Overflow;Google it;Do other work a...
# 28791  Visit Stack Overflow;Google it;Visit another d...
# 12700  Visit Stack Overflow;Google it;Visit another d...
# 9608                 Call a coworker or friend;Google it
# 5305                             Other (please specify):
# 12903  Visit Stack Overflow;Google it;Watch help / tu...
# 66488       Call a coworker or friend;Google it;Meditate
# 7205   Go for a walk or other physical activity;Googl...
# 47563  Go for a walk or other physical activity;Googl...
# 3733   Visit Stack Overflow;Go for a walk or other ph...
# 33255  Visit Stack Overflow;Go for a walk or other ph...
# 35779  Call a coworker or friend;Visit Stack Overflow...
# 7904   Call a coworker or friend;Go for a walk or oth...
# 10372  Call a coworker or friend;Go for a walk or oth...
# 9189   Call a coworker or friend;Go for a walk or oth...
# 20908  Visit Stack Overflow;Do other work and come ba...
# 52070  Call a coworker or friend;Visit Stack Overflow...
# 53028  Go for a walk or other physical activity;Do ot...
# 64111  Call a coworker or friend;Visit Stack Overflow...
# 66323                     Visit Stack Overflow;Google it
# 82156  Call a coworker or friend;Visit Stack Overflow...
# 7134   Call a coworker or friend;Visit Stack Overflow...
# 60701  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSITES  \
# 66910  Stack Overflow for Teams (private knowledge sh...
# 65399  Stack Overflow;Stack Overflow for Teams (priva...
# 40586  Stack Overflow;Stack Exchange;Stack Overflow f...
# 28791  Stack Overflow;Stack Exchange;Stack Overflow f...
# 12700                                     Stack Exchange
# 9608                                      Stack Overflow
# 5305                       Stack Overflow;Stack Exchange
# 12903                      Stack Overflow;Stack Exchange
# 66488                      Stack Overflow;Stack Exchange
# 7205                       Stack Overflow;Stack Exchange
# 47563                                     Stack Overflow
# 3733                       Stack Overflow;Stack Exchange
# 33255                      Stack Overflow;Stack Exchange
# 35779                      Stack Overflow;Stack Exchange
# 7904   Stack Overflow;Stack Overflow for Teams (priva...
# 10372                                     Stack Overflow
# 9189                                      Stack Overflow
# 20908                      Stack Overflow;Stack Exchange
# 52070                      Stack Overflow;Stack Exchange
# 53028                      Stack Overflow;Stack Exchange
# 64111                      Stack Overflow;Stack Exchange
# 66323                      Stack Overflow;Stack Exchange
# 82156                      Stack Overflow;Stack Exchange
# 7134                                      Stack Overflow
# 60701                      Stack Overflow;Stack Exchange
#
#                                SOVISITFREQ SOACCOUNT  \
# 66910  Less than once per month or monthly      True
# 65399      A few times per month or weekly       NaN
# 40586               Multiple times per day      True
# 28791      A few times per month or weekly      True
# 12700                 A few times per week      True
# 9608   Less than once per month or monthly     False
# 5305                  A few times per week      True
# 12903                Daily or almost daily     False
# 66488                Daily or almost daily      True
# 7205       A few times per month or weekly      True
# 47563      A few times per month or weekly      True
# 3733                  A few times per week      True
# 33255                Daily or almost daily     False
# 35779               Multiple times per day     False
# 7904                Multiple times per day      True
# 10372                Daily or almost daily      True
# 9189       A few times per month or weekly      True
# 20908                 A few times per week      True
# 52070                Daily or almost daily      True
# 53028                 A few times per week      True
# 64111                Daily or almost daily      True
# 66323      A few times per month or weekly     False
# 82156                Daily or almost daily      True
# 7134                Multiple times per day     False
# 60701                 A few times per week      True
#
#                                               SOPARTFREQ           SOCOMM  \
# 66910  I have never participated in Q&A on Stack Over...   No, not at all
# 65399                                                NaN   No, not at all
# 40586                              Daily or almost daily    Yes, somewhat
# 28791                    A few times per month or weekly          Neutral
# 12700                               A few times per week          Neutral
# 9608                                                 NaN          Neutral
# 5305                 Less than once per month or monthly    Yes, somewhat
# 12903                                                NaN          Neutral
# 66488  I have never participated in Q&A on Stack Over...   No, not really
# 7205                 Less than once per month or monthly    Yes, somewhat
# 47563  I have never participated in Q&A on Stack Over...          Neutral
# 3733                 Less than once per month or monthly   No, not really
# 33255                                                NaN          Neutral
# 35779                                                NaN   No, not really
# 7904                     A few times per month or weekly          Neutral
# 10372                    A few times per month or weekly    Yes, somewhat
# 9189                 Less than once per month or monthly   No, not really
# 20908  I have never participated in Q&A on Stack Over...  Yes, definitely
# 52070                               A few times per week    Yes, somewhat
# 53028                Less than once per month or monthly          Neutral
# 64111                Less than once per month or monthly   No, not really
# 66323                                                NaN   No, not at all
# 82156                               A few times per week  Yes, definitely
# 7134                                                 NaN   No, not really
# 60701                Less than once per month or monthly    Yes, somewhat
#
#       NEWOTHERCOMMS              AGE  \
# 66910           Yes  55-64 years old
# 65399           Yes  35-44 years old
# 40586           Yes  35-44 years old
# 28791           Yes  35-44 years old
# 12700           Yes  35-44 years old
# 9608            Yes  35-44 years old
# 5305            Yes  35-44 years old
# 12903            No  18-24 years old
# 66488            No  25-34 years old
# 7205            Yes  35-44 years old
# 47563            No  35-44 years old
# 3733             No  35-44 years old
# 33255           Yes  55-64 years old
# 35779            No  35-44 years old
# 7904            Yes  25-34 years old
# 10372           Yes  45-54 years old
# 9189            Yes  35-44 years old
# 20908            No  35-44 years old
# 52070           Yes  35-44 years old
# 53028           Yes              NaN
# 64111            No  25-34 years old
# 66323           Yes  45-54 years old
# 82156            No  25-34 years old
# 7134             No  25-34 years old
# 60701           Yes  35-44 years old
#
#                                                   GENDER  \
# 66910                                                NaN
# 65399  Man;Non-binary, genderqueer, or gender non-con...
# 40586                                                Man
# 28791                                                Man
# 12700                                                Man
# 9608                                                 Man
# 5305                                                 Man
# 12903                                                Man
# 66488                                                Man
# 7205                                                 Man
# 47563                                  Prefer not to say
# 3733                                                 NaN
# 33255                                                Man
# 35779                                                Man
# 7904                                                 Man
# 10372                                                Man
# 9189                                                 Man
# 20908                                                Man
# 52070                                                Man
# 53028                                                NaN
# 64111                                                Man
# 66323                                                Man
# 82156                                              Woman
# 7134   Man;Non-binary, genderqueer, or gender non-con...
# 60701                                                Man
#
#                         TRANS  \
# 66910                     Yes
# 65399                     Yes
# 40586                      No
# 28791                      No
# 12700                      No
# 9608                       No
# 5305                       No
# 12903                      No
# 66488                      No
# 7205                       No
# 47563       Prefer not to say
# 3733                      NaN
# 33255                      No
# 35779                      No
# 7904                       No
# 10372                      No
# 9189                       No
# 20908  Or, in your own words:
# 52070                      No
# 53028                     NaN
# 64111                      No
# 66323                      No
# 82156                      No
# 7134        Prefer not to say
# 60701                      No
#
#                                                SEXUALITY  \
# 66910                                                NaN
# 65399  Bisexual;Prefer to self-describe:;Gay or Lesbi...
# 40586                                           Bisexual
# 28791                                  Prefer not to say
# 12700                            Straight / Heterosexual
# 9608                             Straight / Heterosexual
# 5305                                                 NaN
# 12903                            Straight / Heterosexual
# 66488                            Straight / Heterosexual
# 7205                             Straight / Heterosexual
# 47563                                  Prefer not to say
# 3733                                                 NaN
# 33255                            Straight / Heterosexual
# 35779                            Straight / Heterosexual
# 7904                             Straight / Heterosexual
# 10372   Straight / Heterosexual;Prefer to self-describe:
# 9189                             Straight / Heterosexual
# 20908                            Straight / Heterosexual
# 52070                            Straight / Heterosexual
# 53028                                                NaN
# 64111                            Straight / Heterosexual
# 66323                            Straight / Heterosexual
# 82156                            Straight / Heterosexual
# 7134                                      Bisexual;Queer
# 60701                            Straight / Heterosexual
#
#                                                ETHNICITY  \
# 66910                        Black or of African descent
# 65399  South Asian;Hispanic or Latino/a/x;Black or of...
# 40586                       White or of European descent
# 28791                                  Prefer not to say
# 12700                                        South Asian
# 9608                        White or of European descent
# 5305                        White or of European descent
# 12903                       White or of European descent
# 66488                                  Prefer not to say
# 7205                        White or of European descent
# 47563                                  Prefer not to say
# 3733                                                 NaN
# 33255                       White or of European descent
# 35779                       White or of European descent
# 7904                        White or of European descent
# 10372                       White or of European descent
# 9189        White or of European descent;Southeast Asian
# 20908                       White or of European descent
# 52070                       White or of European descent
# 53028                                                NaN
# 64111                       White or of European descent
# 66323                       White or of European descent
# 82156                                     Middle Eastern
# 7134   White or of European descent;Southeast Asian;B...
# 60701                       White or of European descent
#
#                                            ACCESSIBILITY  \
# 66910                I am blind / have difficulty seeing
# 65399  I am unable to / find it difficult to walk or ...
# 40586                I am blind / have difficulty seeing
# 28791                                  Prefer not to say
# 12700                                  None of the above
# 9608                                   None of the above
# 5305                                   None of the above
# 12903                                  None of the above
# 66488                                  Prefer not to say
# 7205                                   None of the above
# 47563                                  None of the above
# 3733                                                 NaN
# 33255                                  None of the above
# 35779                                  None of the above
# 7904                                   None of the above
# 10372                                  None of the above
# 9189                                   None of the above
# 20908                                  None of the above
# 52070                                  None of the above
# 53028                                                NaN
# 64111                                  None of the above
# 66323                                  None of the above
# 82156                                                NaN
# 7134                                   None of the above
# 60701                                  None of the above
#
#                                             MENTALHEALTH  \
# 66910  I have a concentration and/or memory disorder ...
# 65399  I have a mood or emotional disorder (e.g. depr...
# 40586  I have a concentration and/or memory disorder ...
# 28791                                  None of the above
# 12700                                  None of the above
# 9608                                   None of the above
# 5305                                   None of the above
# 12903                                  None of the above
# 66488                                  Prefer not to say
# 7205                                   None of the above
# 47563                         I have an anxiety disorder
# 3733                                                 NaN
# 33255                                  None of the above
# 35779                                  None of the above
# 7904                                   None of the above
# 10372                             Or, in your own words:
# 9189                                   None of the above
# 20908                                  None of the above
# 52070                                  None of the above
# 53028                                                NaN
# 64111                                  None of the above
# 66323                                  None of the above
# 82156                                  None of the above
# 7134   I have a concentration and/or memory disorder ...
# 60701                                                NaN
#
#                 SURVEYLENGTH                  SURVEYEASE CONVERTEDCOMPYEARLY  \
# 66910              Too short                         NaN          45241312.0
# 65399              Too short                   Difficult          30468516.0
# 40586  Appropriate in length                        Easy          21822250.0
# 28791  Appropriate in length                        Easy          20000000.0
# 12700  Appropriate in length                        Easy          19200000.0
# 9608   Appropriate in length                        Easy          17500000.0
# 5305                Too long                        Easy          15000000.0
# 12903               Too long  Neither easy nor difficult          14411628.0
# 66488  Appropriate in length                        Easy          12750000.0
# 7205   Appropriate in length                        Easy          12500000.0
# 47563  Appropriate in length  Neither easy nor difficult          12500000.0
# 3733   Appropriate in length                        Easy          11250000.0
# 33255               Too long                        Easy          11250000.0
# 35779  Appropriate in length                        Easy          11000000.0
# 7904   Appropriate in length  Neither easy nor difficult          10500000.0
# 10372  Appropriate in length  Neither easy nor difficult          10350000.0
# 9189   Appropriate in length                        Easy          10200000.0
# 20908  Appropriate in length                        Easy          10000000.0
# 52070              Too short                        Easy          10000000.0
# 53028  Appropriate in length                        Easy          10000000.0
# 64111              Too short                        Easy          10000000.0
# 66323  Appropriate in length                        Easy          10000000.0
# 82156               Too long  Neither easy nor difficult           9975060.0
# 7134   Appropriate in length                        Easy           9500000.0
# 60701  Appropriate in length  Neither easy nor difficult           9500000.0
#
#                                                    AYUDA
# 66910  Visit Stack Overflow;Go for a walk or other ph...
# 65399  Watch help / tutorial videos;Play games Stack ...
# 40586  Visit Stack Overflow;Google it;Do other work a...
# 28791  Visit Stack Overflow;Google it;Visit another d...
# 12700  Visit Stack Overflow;Google it;Visit another d...
# 9608   Call a coworker or friend;Google it Stack Over...
# 5305   Other (please specify): Stack Overflow;Stack E...
# 12903  Visit Stack Overflow;Google it;Watch help / tu...
# 66488  Call a coworker or friend;Google it;Meditate S...
# 7205   Go for a walk or other physical activity;Googl...
# 47563  Go for a walk or other physical activity;Googl...
# 3733   Visit Stack Overflow;Go for a walk or other ph...
# 33255  Visit Stack Overflow;Go for a walk or other ph...
# 35779  Call a coworker or friend;Visit Stack Overflow...
# 7904   Call a coworker or friend;Go for a walk or oth...
# 10372  Call a coworker or friend;Go for a walk or oth...
# 9189   Call a coworker or friend;Go for a walk or oth...
# 20908  Visit Stack Overflow;Do other work and come ba...
# 52070  Call a coworker or friend;Visit Stack Overflow...
# 53028  Go for a walk or other physical activity;Do ot...
# 64111  Call a coworker or friend;Visit Stack Overflow...
# 66323  Visit Stack Overflow;Google it Stack Overflow;...
# 82156  Call a coworker or friend;Visit Stack Overflow...
# 7134   Call a coworker or friend;Visit Stack Overflow...
# 60701  Call a coworker or friend;Visit Stack Overflow...
#
# [25 rows x 49 columns]

# %%
datos.nsmallest(25, "CONVERTEDCOMPYEARLY")
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 1924         1925                     I am a developer by profession
# 24285       24286                     I am a developer by profession
# 46464       46465  I am not primarily a developer, but I write co...
# 15163       15164                     I am a developer by profession
# 56790       56791                     I am a developer by profession
# 22032       22033                     I am a developer by profession
# 59043       59044                     I am a developer by profession
# 22453       22454                     I am a developer by profession
# 41440       41441                     I am a developer by profession
# 45141       45142  I am not primarily a developer, but I write co...
# 53306       53307                     I am a developer by profession
# 37761       37762                     I am a developer by profession
# 22162       22163                     I am a developer by profession
# 12290       12291                     I am a developer by profession
# 16621       16622                     I am a developer by profession
# 18322       18323                     I am a developer by profession
# 33043       33044                     I am a developer by profession
# 33504       33505  I am not primarily a developer, but I write co...
# 33930       33931                     I am a developer by profession
# 62386       62387                     I am a developer by profession
# 69262       69263                     I am a developer by profession
# 82173       82174                     I am a developer by profession
# 82198       82199                     I am a developer by profession
# 43572       43573                     I am a developer by profession
# 17680       17681                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 1924                                  Employed full-time
# 24285  Independent contractor, freelancer, or self-em...
# 46464                                 Employed full-time
# 15163                                 Employed full-time
# 56790                                 Employed full-time
# 22032                                 Employed full-time
# 59043                                 Employed full-time
# 22453                                 Employed full-time
# 41440  Independent contractor, freelancer, or self-em...
# 45141                                 Employed full-time
# 53306                                 Employed full-time
# 37761                                 Employed full-time
# 22162                                 Employed full-time
# 12290                                 Employed full-time
# 16621                                 Employed full-time
# 18322  Independent contractor, freelancer, or self-em...
# 33043                                 Employed part-time
# 33504                                 Employed full-time
# 33930                                 Employed part-time
# 62386                                 Employed full-time
# 69262                                 Employed full-time
# 82173                                 Employed full-time
# 82198                                 Employed full-time
# 43572                                 Employed full-time
# 17680                                 Employed full-time
#
#                                                  COUNTRY       USSTATE  \
# 1924                            UNITED STATES OF AMERICA  Pennsylvania
# 24285                           UNITED STATES OF AMERICA    California
# 46464                           UNITED STATES OF AMERICA    Washington
# 15163                                              CHINA           NaN
# 56790                                             TAIWAN           NaN
# 22032                                  REPUBLIC OF KOREA           NaN
# 59043                                             TAIWAN           NaN
# 22453                                              JAPAN           NaN
# 41440                           UNITED STATES OF AMERICA    California
# 45141                                              CHINA           NaN
# 53306                                              JAPAN           NaN
# 37761                                        SOUTH KOREA           NaN
# 22162                                             TURKEY           NaN
# 12290                       IRAN, ISLAMIC REPUBLIC OF...           NaN
# 16621                                              CHINA           NaN
# 18322                                              INDIA           NaN
# 33043                                            LIBERIA           NaN
# 33504                                              KENYA           NaN
# 33930                                            HUNGARY           NaN
# 62386                                           COLOMBIA           NaN
# 69262                                              EGYPT           NaN
# 82173                                              INDIA           NaN
# 82198                                              INDIA           NaN
# 43572                       IRAN, ISLAMIC REPUBLIC OF...           NaN
# 17680  UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...           NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 1924        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 24285       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 46464       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 15163       NaN                          Primary/elementary school
# 56790       NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 22032       NaN                Associate degree (A.A., A.S., etc.)
# 59043       NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 22453       NaN  Secondary school (e.g. American high school, G...
# 41440       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 45141       NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 53306       NaN  Some college/university study without earning ...
# 37761       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 22162       NaN                                     Something else
# 12290       NaN                Associate degree (A.A., A.S., etc.)
# 16621       NaN                Associate degree (A.A., A.S., etc.)
# 18322       NaN                                     Something else
# 33043       NaN  Secondary school (e.g. American high school, G...
# 33504       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33930       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 62386       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 69262       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 82173       NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 82198       NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 43572       NaN  Secondary school (e.g. American high school, G...
# 17680   England  Some college/university study without earning ...
#
#                  AGE1STCODE  \
# 1924          11 - 17 years
# 24285         11 - 17 years
# 46464         11 - 17 years
# 15163  Younger than 5 years
# 56790         11 - 17 years
# 22032         18 - 24 years
# 59043         18 - 24 years
# 22453          5 - 10 years
# 41440         18 - 24 years
# 45141         11 - 17 years
# 53306         11 - 17 years
# 37761         11 - 17 years
# 22162         35 - 44 years
# 12290         11 - 17 years
# 16621         18 - 24 years
# 18322         18 - 24 years
# 33043         11 - 17 years
# 33504         18 - 24 years
# 33930         18 - 24 years
# 62386         18 - 24 years
# 69262         25 - 34 years
# 82173         18 - 24 years
# 82198         18 - 24 years
# 43572         18 - 24 years
# 17680         11 - 17 years
#
#                                                LEARNCODE         YEARSCODE  \
# 1924                      School;Other (please specify):                30
# 24285                             Books / Physical media                16
# 46464  Coding Bootcamp;Other online resources (ex: vi...                27
# 15163                             Books / Physical media                 5
# 56790                                             School                12
# 22032  Coding Bootcamp;Other online resources (ex: vi...                 5
# 59043  Other online resources (ex: videos, blogs, etc...                20
# 22453    Other online resources (ex: videos, blogs, etc)  Less than 1 year
# 41440  Other online resources (ex: videos, blogs, etc...                10
# 45141  Other online resources (ex: videos, blogs, etc...                12
# 53306  Other online resources (ex: videos, blogs, etc...                25
# 37761  Other online resources (ex: videos, blogs, etc...                19
# 22162                                       Online Forum                 1
# 12290  Other online resources (ex: videos, blogs, etc...                10
# 16621  Coding Bootcamp;Other online resources (ex: vi...                 6
# 18322    Other online resources (ex: videos, blogs, etc)                 5
# 33043  Coding Bootcamp;Other online resources (ex: vi...                 5
# 33504                                             School                 5
# 33930                                             School                 5
# 62386  Coding Bootcamp;School;Online Courses or Certi...                13
# 69262                                             School                12
# 82173                                          Colleague                 6
# 82198  Other online resources (ex: videos, blogs, etc...                16
# 43572  Coding Bootcamp;Other online resources (ex: vi...                 3
# 17680    Other online resources (ex: videos, blogs, etc)                 6
#
#            YEARSCODEPRO                                            DEVTYPE  \
# 1924                 25  Developer, mobile;Developer, front-end;Develop...
# 24285                 9  Other (please specify):;Data scientist or mach...
# 46464                12  Engineer, data;Data scientist or machine learn...
# 15163                 1                                Academic researcher
# 56790                 2  Developer, full-stack;Database administrator;S...
# 22032  Less than 1 year                               Developer, front-end
# 59043               NaN                               Developer, front-end
# 22453                 6                              Developer, full-stack
# 41440                 3            Developer, mobile;Developer, full-stack
# 45141                 1                                          Scientist
# 53306                17  Developer, mobile;Data scientist or machine le...
# 37761                14                               Developer, front-end
# 22162                21                            Other (please specify):
# 12290                 6  Developer, full-stack;Developer, back-end;Engi...
# 16621                 3                                Developer, back-end
# 18322                 3          Developer, mobile;Other (please specify):
# 33043                 5  Developer, desktop or enterprise applications;...
# 33504                 2                                  DevOps specialist
# 33930                 3                              Developer, QA or test
# 62386                 8  Developer, mobile;Developer, desktop or enterp...
# 69262                 4            Developer, full-stack;DevOps specialist
# 82173  Less than 1 year                                Developer, back-end
# 82198                10                              Developer, full-stack
# 43572                 1  Developer, front-end;Developer, back-end;Datab...
# 17680                 1                      Developer, full-stack;Student
#
#                                                  ORGSIZE  \
# 1924                            1,000 to 4,999 employees
# 24285                                   2 to 9 employees
# 46464                                 10 to 19 employees
# 15163                                   2 to 9 employees
# 56790                               100 to 499 employees
# 22032                                 20 to 99 employees
# 59043                               100 to 499 employees
# 22453                                 20 to 99 employees
# 41440  Just me - I am a freelancer, sole proprietor, ...
# 45141                           1,000 to 4,999 employees
# 53306                           10,000 or more employees
# 37761                               500 to 999 employees
# 22162                               100 to 499 employees
# 12290                                   2 to 9 employees
# 16621                               500 to 999 employees
# 18322                                 20 to 99 employees
# 33043                               500 to 999 employees
# 33504                               100 to 499 employees
# 33930                               100 to 499 employees
# 62386                           1,000 to 4,999 employees
# 69262                                                NaN
# 82173                                 20 to 99 employees
# 82198                                 20 to 99 employees
# 43572  Just me - I am a freelancer, sole proprietor, ...
# 17680                                   2 to 9 employees
#
#                          CURRENCY  COMPTOTAL COMPFREQ  \
# 1924    USD\tUnited States dollar        1.0   Yearly
# 24285   USD\tUnited States dollar        1.0   Yearly
# 46464   USD\tUnited States dollar        1.0   Yearly
# 15163  CNY\tChinese Yuan Renminbi       11.0   Yearly
# 56790      TWD\tNew Taiwan dollar       50.0   Yearly
# 22032       KRW\tSouth Korean won     3800.0   Yearly
# 59043      TWD\tNew Taiwan dollar       90.0   Yearly
# 22453           JPY\tJapanese yen      450.0   Yearly
# 41440   USD\tUnited States dollar        5.0   Yearly
# 45141  CNY\tChinese Yuan Renminbi       35.0   Yearly
# 53306           JPY\tJapanese yen      600.0   Yearly
# 37761       KRW\tSouth Korean won     7600.0   Yearly
# 22162   USD\tUnited States dollar       10.0   Yearly
# 12290           IRR\tIranian rial    50000.0  Monthly
# 16621  CNY\tChinese Yuan Renminbi        8.0  Monthly
# 18322           INR\tIndian rupee       60.0  Monthly
# 33043        LRD\tLiberian dollar      136.0  Monthly
# 33504        KES\tKenyan shilling       90.0  Monthly
# 33930       HUF\tHungarian forint      400.0  Monthly
# 62386         COP\tColombian peso     5000.0  Monthly
# 69262         EGP\tEgyptian pound       20.0  Monthly
# 82173           INR\tIndian rupee       75.0  Monthly
# 82198       UGX\tUgandan shilling     3500.0  Monthly
# 43572       DJF\tDjiboutian franc     3750.0   Yearly
# 17680         GBP\tPound sterling       18.0   Yearly
#
#                                   LANGUAGEHAVEWORKEDWITH  \
# 1924               C#;HTML/CSS;JavaScript;PowerShell;SQL
# 24285                                         Python;SQL
# 46464                                        Perl;Python
# 15163                                        Objective-C
# 56790             HTML/CSS;JavaScript;Node.js;Python;SQL
# 22032                              JavaScript;TypeScript
# 59043  HTML/CSS;JavaScript;Node.js;PowerShell;TypeScript
# 22453                         C#;HTML/CSS;SQL;TypeScript
# 41440                       Java;JavaScript;Kotlin;Swift
# 45141                        C++;Java;Python;R;Scala;SQL
# 53306  Bash/Shell;HTML/CSS;Java;JavaScript;Kotlin;Nod...
# 37761             HTML/CSS;JavaScript;Node.js;TypeScript
# 22162    APL;Dart;JavaScript;PowerShell;Swift;TypeScript
# 12290     HTML/CSS;JavaScript;Node.js;PHP;SQL;TypeScript
# 16621                                          Java;Rust
# 18322                                     C;C++;Java;PHP
# 33043          JavaScript;Python;Ruby;SQL;TypeScript;VBA
# 33504                                                 Go
# 33930                                             Python
# 62386                                              Swift
# 69262                                  C#;JavaScript;SQL
# 82173                           HTML/CSS;JavaScript;Ruby
# 82198                       HTML/CSS;JavaScript;Ruby;SQL
# 43572                     HTML/CSS;JavaScript;Python;SQL
# 17680       Bash/Shell;C#;Java;JavaScript;Node.js;Python
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 1924               C#;HTML/CSS;JavaScript;PowerShell;SQL
# 24285                                             Python
# 46464                          JavaScript;Node.js;Python
# 15163                                                NaN
# 56790                                                NaN
# 22032                              JavaScript;TypeScript
# 59043             HTML/CSS;JavaScript;Node.js;TypeScript
# 22453                         C#;HTML/CSS;SQL;TypeScript
# 41440                                       Kotlin;Swift
# 45141                                         C++;Python
# 53306  Bash/Shell;C#;HTML/CSS;Java;Kotlin;Python;SQL;...
# 37761             HTML/CSS;JavaScript;Node.js;TypeScript
# 22162                                                NaN
# 12290  HTML/CSS;JavaScript;Node.js;PHP;Python;SQL;Typ...
# 16621                                               Rust
# 18322                              JavaScript;TypeScript
# 33043                                                NaN
# 33504                                            Go;Rust
# 33930                                             Python
# 62386                                              Swift
# 69262                                  C#;JavaScript;SQL
# 82173                           HTML/CSS;JavaScript;Ruby
# 82198                                             Python
# 43572                C;C#;HTML/CSS;JavaScript;Python;SQL
# 17680    Bash/Shell;JavaScript;Node.js;Python;TypeScript
#
#                                DATABASEHAVEWORKEDWITH  \
# 1924                             Microsoft SQL Server
# 24285                                PostgreSQL;Redis
# 46464                                          SQLite
# 15163                                           MySQL
# 56790                         MySQL;PostgreSQL;SQLite
# 22032                          MySQL;PostgreSQL;Redis
# 59043      Elasticsearch;Firebase;MongoDB;MySQL;Redis
# 22453                                          Oracle
# 41440                                          SQLite
# 45141                                             NaN
# 53306                Firebase;MySQL;PostgreSQL;SQLite
# 37761                                   MariaDB;MySQL
# 22162                                Cassandra;SQLite
# 12290                                           MySQL
# 16621                                     MySQL;Redis
# 18322                                    MySQL;SQLite
# 33043    Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# 33504  Elasticsearch;MariaDB;MongoDB;PostgreSQL;Redis
# 33930                         MySQL;Oracle;PostgreSQL
# 62386                                             NaN
# 69262               Microsoft SQL Server;MySQL;Oracle
# 82173                        MongoDB;MySQL;PostgreSQL
# 82198                   MySQL;PostgreSQL;Redis;SQLite
# 43572          Firebase;MySQL;PostgreSQL;Redis;SQLite
# 17680         Couchbase;Elasticsearch;IBM DB2;MongoDB
#
#                                DATABASEWANTTOWORKWITH  \
# 1924                             Microsoft SQL Server
# 24285                                PostgreSQL;Redis
# 46464                                             NaN
# 15163                                             NaN
# 56790                                             NaN
# 22032                          MySQL;PostgreSQL;Redis
# 59043                                        Firebase
# 22453                                          Oracle
# 41440                               DynamoDB;Firebase
# 45141                                             NaN
# 53306                       MariaDB;PostgreSQL;SQLite
# 37761                                   MariaDB;MySQL
# 22162                                             NaN
# 12290                  MongoDB;MySQL;PostgreSQL;Redis
# 16621                                     MySQL;Redis
# 18322                                        Firebase
# 33043                                             NaN
# 33504  Elasticsearch;MariaDB;MongoDB;PostgreSQL;Redis
# 33930                         MySQL;Oracle;PostgreSQL
# 62386                                             NaN
# 69262                            Microsoft SQL Server
# 82173                  MongoDB;MySQL;PostgreSQL;Redis
# 82198                                   Elasticsearch
# 43572   MariaDB;MongoDB;MySQL;PostgreSQL;Redis;SQLite
# 17680                           Elasticsearch;MongoDB
#
#                         PLATFORMHAVEWORKEDWITH  \
# 1924                       AWS;Microsoft Azure
# 24285                                      AWS
# 46464                    Google Cloud Platform
# 15163                          Microsoft Azure
# 56790                                      NaN
# 22032                AWS;Google Cloud Platform
# 59043             DigitalOcean;Microsoft Azure
# 22453                      AWS;Microsoft Azure
# 41440                                      AWS
# 45141                                      NaN
# 53306                                      AWS
# 37761              Oracle Cloud Infrastructure
# 22162                AWS;Google Cloud Platform
# 12290                                      NaN
# 16621                                      NaN
# 18322              Oracle Cloud Infrastructure
# 33043                      DigitalOcean;Heroku
# 33504                AWS;Google Cloud Platform
# 33930                                      NaN
# 62386                                      AWS
# 69262                      AWS;Microsoft Azure
# 82173                  AWS;DigitalOcean;Heroku
# 82198                               AWS;Heroku
# 43572       DigitalOcean;Google Cloud Platform
# 17680  DigitalOcean;Heroku;IBM Cloud or Watson
#
#                                   PLATFORMWANTTOWORKWITH  \
# 1924                                                 NaN
# 24285                                                AWS
# 46464                                                NaN
# 15163                                                NaN
# 56790                                                NaN
# 22032                          AWS;Google Cloud Platform
# 59043                                                NaN
# 22453                                AWS;Microsoft Azure
# 41440                          AWS;Google Cloud Platform
# 45141                                                NaN
# 53306                                                AWS
# 37761  AWS;Google Cloud Platform;Microsoft Azure;Orac...
# 22162                                                NaN
# 12290                                                NaN
# 16621                                                NaN
# 18322          AWS;Google Cloud Platform;Microsoft Azure
# 33043                                                NaN
# 33504                          AWS;Google Cloud Platform
# 33930                                                NaN
# 62386                                                AWS
# 69262                                    Microsoft Azure
# 82173                            AWS;DigitalOcean;Heroku
# 82198                                    Microsoft Azure
# 43572          DigitalOcean;Google Cloud Platform;Heroku
# 17680                DigitalOcean;Heroku;Microsoft Azure
#
#                                   WEBFRAMEHAVEWORKEDWITH  \
# 1924     Angular;Angular.js;ASP.NET;ASP.NET Core ;jQuery
# 24285                                       Django;Flask
# 46464                                              Flask
# 15163                                             Vue.js
# 56790                                      Django;jQuery
# 22032                                           React.js
# 59043                                    Angular;Express
# 22453                              Angular;ASP.NET Core
# 41440                                   Angular;React.js
# 45141                                                NaN
# 53306        Angular;Express;Flask;Laravel;Spring;Vue.js
# 37761                     Express;jQuery;React.js;Vue.js
# 22162                                 Angular;Angular.js
# 12290                     Angular;Express;jQuery;Laravel
# 16621                                             Vue.js
# 18322                                                NaN
# 33043  Angular;Angular.js;Django;Drupal;Flask;jQuery;...
# 33504                                      Django;Vue.js
# 33930                                             Django
# 62386                                                NaN
# 69262                       ASP.NET;ASP.NET Core ;jQuery
# 82173                                      Ruby on Rails
# 82198                               jQuery;Ruby on Rails
# 43572                              Django;FastAPI;jQuery
# 17680               Django;Express;Flask;Gatsby;React.js
#
#                                 WEBFRAMEWANTTOWORKWITH  ...  \
# 1924   Angular;Angular.js;ASP.NET;ASP.NET Core ;jQuery  ...
# 24285                                     Django;Flask  ...
# 46464                                            Flask  ...
# 15163                                              NaN  ...
# 56790                                              NaN  ...
# 22032                           React.js;Svelte;Vue.js  ...
# 59043                                          Angular  ...
# 22453                            Angular;ASP.NET Core   ...
# 41440                                 Angular;React.js  ...
# 45141                                              NaN  ...
# 53306            Angular;ASP.NET Core ;FastAPI;Laravel  ...
# 37761                          Express;React.js;Svelte  ...
# 22162                                              NaN  ...
# 12290                    Express;jQuery;Laravel;Vue.js  ...
# 16621                                           Vue.js  ...
# 18322                                              NaN  ...
# 33043                                              NaN  ...
# 33504                                           Vue.js  ...
# 33930                                           Django  ...
# 62386                                              NaN  ...
# 69262             Angular;ASP.NET;ASP.NET Core ;jQuery  ...
# 82173                    Django;React.js;Ruby on Rails  ...
# 82198                                         React.js  ...
# 43572      ASP.NET;ASP.NET Core ;Django;FastAPI;jQuery  ...
# 17680             Express;Flask;Gatsby;React.js;Spring  ...
#
#                                   MISCTECHWANTTOWORKWITH  \
# 1924                   .NET Framework;.NET Core / .NET 5
# 24285                            NumPy;Pandas;TensorFlow
# 46464                                                NaN
# 15163                                                NaN
# 56790                                                NaN
# 22032                        Flutter;Hadoop;React Native
# 59043                                                NaN
# 22453                                 .NET Core / .NET 5
# 41440                            React Native;TensorFlow
# 45141                         NumPy;Pandas;Torch/PyTorch
# 53306      .NET Core / .NET 5;NumPy;Pandas;Torch/PyTorch
# 37761                                                NaN
# 22162                                 .NET Core / .NET 5
# 12290                                                NaN
# 16621                                            Flutter
# 18322                                                NaN
# 33043                  .NET Framework;.NET Core / .NET 5
# 33504                                                NaN
# 33930                                                NaN
# 62386                                                NaN
# 69262                  .NET Framework;.NET Core / .NET 5
# 82173                                                NaN
# 82198                                                NaN
# 43572  .NET Framework;.NET Core / .NET 5;Apache Spark...
# 17680                                                NaN
#
#                             TOOLSTECHHAVEWORKEDWITH  \
# 1924                          Docker;Git;Kubernetes
# 24285                          Docker;Git;Terraform
# 46464                                           Git
# 15163                                           NaN
# 56790                                    Docker;Git
# 22032                    Docker;Git;Kubernetes;Yarn
# 59043                            Ansible;Docker;Git
# 22453                                           NaN
# 41440                                           NaN
# 45141                                           Git
# 53306                                    Docker;Git
# 37761                           Git;Kubernetes;Yarn
# 22162                                       Ansible
# 12290                                           Git
# 16621                               Docker;Git;Yarn
# 18322                                           NaN
# 33043                                           NaN
# 33504  Ansible;Docker;Git;Kubernetes;Terraform;Yarn
# 33930                                       Xamarin
# 62386                                           Git
# 69262                                    Docker;Git
# 82173                                      Git;Yarn
# 82198                       Ansible;Docker;Git;Yarn
# 43572                                           NaN
# 17680           Docker;Git;Kubernetes;Unity 3D;Yarn
#
#                             TOOLSTECHWANTTOWORKWITH  \
# 1924                          Docker;Git;Kubernetes
# 24285                          Docker;Git;Terraform
# 46464                                           Git
# 15163                                           NaN
# 56790                                           NaN
# 22032               Deno;Docker;Git;Kubernetes;Yarn
# 59043                                    Docker;Git
# 22453                                           NaN
# 41440                                           NaN
# 45141                                           Git
# 53306                    Git;Unity 3D;Unreal Engine
# 37761                           Git;Kubernetes;Yarn
# 22162                                           NaN
# 12290                                           Git
# 16621                               Docker;Git;Yarn
# 18322                                           NaN
# 33043                                           NaN
# 33504  Ansible;Docker;Git;Kubernetes;Terraform;Yarn
# 33930                                           NaN
# 62386                                           Git
# 69262                                    Docker;Git
# 82173                    Docker;Git;Kubernetes;Yarn
# 82198                                    Kubernetes
# 43572                                           NaN
# 17680                         Docker;Git;Kubernetes
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 1924          Notepad++;Visual Studio;Visual Studio Code
# 24285                            IPython/Jupyter;PyCharm
# 46464       Android Studio;IntelliJ;PyCharm;Sublime Text
# 15163                                                NaN
# 56790                                            PyCharm
# 22032                        Visual Studio Code;Webstorm
# 59043  IntelliJ;Notepad++;Vim;Visual Studio Code;Webs...
# 22453                   Visual Studio;Visual Studio Code
# 41440  Android Studio;Sublime Text;Visual Studio Code...
# 45141  IntelliJ;PyCharm;RStudio;Visual Studio;Visual ...
# 53306  Android Studio;IntelliJ;IPython/Jupyter;PHPSto...
# 37761                                 Visual Studio Code
# 22162                Android Studio;PyCharm;TextMate;Vim
# 12290                        IntelliJ;Visual Studio Code
# 16621                    IntelliJ;Vim;Visual Studio Code
# 18322                        Atom;Notepad++;Sublime Text
# 33043  Android Studio;Atom;Eclipse;IPython/Jupyter;Su...
# 33504                    IntelliJ;Vim;Visual Studio Code
# 33930                     Android Studio;Notepad++;Xcode
# 62386                                 Sublime Text;Xcode
# 69262                   Visual Studio;Visual Studio Code
# 82173                                       Sublime Text
# 82198                    Sublime Text;Visual Studio Code
# 43572  Atom;IPython/Jupyter;Notepad++;PyCharm;Visual ...
# 17680                IntelliJ;PyCharm;Visual Studio Code
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH  \
# 1924          Notepad++;Visual Studio;Visual Studio Code
# 24285                            IPython/Jupyter;PyCharm
# 46464                               PyCharm;Sublime Text
# 15163                                                NaN
# 56790                                                NaN
# 22032                        Visual Studio Code;Webstorm
# 59043  IntelliJ;Notepad++;Vim;Visual Studio Code;Webs...
# 22453                   Visual Studio;Visual Studio Code
# 41440   Android Studio;Visual Studio Code;Webstorm;Xcode
# 45141                                 Visual Studio Code
# 53306  Android Studio;IntelliJ;PHPStorm;PyCharm;Vim;V...
# 37761                    Vim;Visual Studio Code;Webstorm
# 22162                                         Atom;Xcode
# 12290                        IntelliJ;Visual Studio Code
# 16621                    IntelliJ;Vim;Visual Studio Code
# 18322            Android Studio;Visual Studio Code;Xcode
# 33043                                                NaN
# 33504                    IntelliJ;Vim;Visual Studio Code
# 33930                                  Notepad++;PyCharm
# 62386                                 Sublime Text;Xcode
# 69262                   Visual Studio;Visual Studio Code
# 82173                    Sublime Text;Visual Studio Code
# 82198                                                NaN
# 43572   IPython/Jupyter;Visual Studio;Visual Studio Code
# 17680                         PyCharm;Visual Studio Code
#
#                                    OPSYS  \
# 1924                             Windows
# 24285                              MacOS
# 46464                              MacOS
# 15163                              MacOS
# 56790                            Windows
# 22032                              MacOS
# 59043                              MacOS
# 22453                            Windows
# 41440                            Windows
# 45141                            Windows
# 53306                        Linux-based
# 37761                              MacOS
# 22162                            Windows
# 12290                            Windows
# 16621                        Linux-based
# 18322                              MacOS
# 33043                        Linux-based
# 33504                        Linux-based
# 33930                            Windows
# 62386                              MacOS
# 69262                            Windows
# 82173                        Linux-based
# 82198                              MacOS
# 43572                            Windows
# 17680  Windows Subsystem for Linux (WSL)
#
#                                                 NEWSTUCK  \
# 1924   Call a coworker or friend;Visit Stack Overflow...
# 24285  Visit Stack Overflow;Go for a walk or other ph...
# 46464  Go for a walk or other physical activity;Do ot...
# 15163                                          Google it
# 56790  Call a coworker or friend;Visit Stack Overflow...
# 22032  Visit Stack Overflow;Go for a walk or other ph...
# 59043  Go for a walk or other physical activity;Googl...
# 22453                 Call a coworker or friend;Meditate
# 41440  Visit Stack Overflow;Do other work and come ba...
# 45141  Visit Stack Overflow;Google it;Do other work a...
# 53306  Visit Stack Overflow;Google it;Watch help / tu...
# 37761  Visit Stack Overflow;Go for a walk or other ph...
# 22162  Google it;Meditate;Panic;Visit another develop...
# 12290  Visit Stack Overflow;Google it;Watch help / tu...
# 16621  Call a coworker or friend;Visit Stack Overflow...
# 18322                                                NaN
# 33043  Visit Stack Overflow;Go for a walk or other ph...
# 33504                     Visit Stack Overflow;Google it
# 33930                                          Google it
# 62386  Visit Stack Overflow;Go for a walk or other ph...
# 69262                                          Google it
# 82173  Call a coworker or friend;Visit Stack Overflow...
# 82198                     Visit Stack Overflow;Google it
# 43572  Visit Stack Overflow;Google it;Watch help / tu...
# 17680                               Visit Stack Overflow
#
#                                               NEWSOSITES  \
# 1924                       Stack Overflow;Stack Exchange
# 24285                      Stack Overflow;Stack Exchange
# 46464                                     Stack Overflow
# 15163  Stack Overflow for Teams (private knowledge sh...
# 56790                                     Stack Overflow
# 22032                                     Stack Overflow
# 59043                                     Stack Overflow
# 22453                                     Stack Overflow
# 41440                      Stack Overflow;Stack Exchange
# 45141                      Stack Overflow;Stack Exchange
# 53306                      Stack Overflow;Stack Exchange
# 37761                                     Stack Overflow
# 22162                                     Stack Exchange
# 12290                                     Stack Overflow
# 16621                                     Stack Overflow
# 18322                                     Stack Overflow
# 33043                      Stack Overflow;Stack Exchange
# 33504                                     Stack Overflow
# 33930                      Stack Overflow;Stack Exchange
# 62386                      Stack Overflow;Stack Exchange
# 69262                      Stack Overflow;Stack Exchange
# 82173                                     Stack Overflow
# 82198                      Stack Overflow;Stack Exchange
# 43572                                     Stack Overflow
# 17680                      Stack Overflow;Stack Exchange
#
#                                SOVISITFREQ SOACCOUNT  \
# 1924                  A few times per week      True
# 24285                 A few times per week      True
# 46464  Less than once per month or monthly     False
# 15163  Less than once per month or monthly      True
# 56790                Daily or almost daily      True
# 22032                Daily or almost daily      True
# 59043               Multiple times per day      True
# 22453      A few times per month or weekly       NaN
# 41440                 A few times per week      True
# 45141                Daily or almost daily      True
# 53306                Daily or almost daily     False
# 37761               Multiple times per day      True
# 22162                Daily or almost daily      True
# 12290               Multiple times per day      True
# 16621                 A few times per week       NaN
# 18322                Daily or almost daily      True
# 33043                Daily or almost daily      True
# 33504                 A few times per week      True
# 33930               Multiple times per day      True
# 62386                 A few times per week      True
# 69262                Daily or almost daily      True
# 82173                Daily or almost daily      True
# 82198                 A few times per week      True
# 43572               Multiple times per day      True
# 17680               Multiple times per day      True
#
#                                               SOPARTFREQ           SOCOMM  \
# 1924                                A few times per week  Yes, definitely
# 24285                               A few times per week    Yes, somewhat
# 46464                                                NaN   No, not at all
# 15163  I have never participated in Q&A on Stack Over...   No, not at all
# 56790                Less than once per month or monthly   No, not really
# 22032                Less than once per month or monthly    Yes, somewhat
# 59043  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 22453                                                NaN   No, not at all
# 41440                               A few times per week    Yes, somewhat
# 45141                    A few times per month or weekly    Yes, somewhat
# 53306                                                NaN          Neutral
# 37761  I have never participated in Q&A on Stack Over...   No, not at all
# 22162                              Daily or almost daily   No, not at all
# 12290                              Daily or almost daily    Yes, somewhat
# 16621                                                NaN   No, not at all
# 18322                                                NaN  Yes, definitely
# 33043                    A few times per month or weekly    Yes, somewhat
# 33504  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 33930                               A few times per week    Yes, somewhat
# 62386                Less than once per month or monthly    Yes, somewhat
# 69262                Less than once per month or monthly    Yes, somewhat
# 82173                Less than once per month or monthly          Neutral
# 82198                Less than once per month or monthly  Yes, definitely
# 43572                               A few times per week   No, not really
# 17680  I have never participated in Q&A on Stack Over...   No, not at all
#
#       NEWOTHERCOMMS              AGE GENDER              TRANS  \
# 1924             No  45-54 years old    Man                 No
# 24285           Yes  35-44 years old    Man                 No
# 46464            No  35-44 years old    Man  Prefer not to say
# 15163           Yes  35-44 years old  Woman                Yes
# 56790            No  25-34 years old  Woman                 No
# 22032            No  25-34 years old    Man                 No
# 59043            No  25-34 years old    Man                 No
# 22453            No  35-44 years old    Man                 No
# 41440           Yes  25-34 years old    Man                 No
# 45141           Yes  18-24 years old    Man                 No
# 53306            No  35-44 years old    Man                 No
# 37761           Yes  35-44 years old    Man                 No
# 22162           Yes  35-44 years old  Woman                Yes
# 12290            No  25-34 years old    Man                 No
# 16621            No  25-34 years old    Man                 No
# 18322            No  18-24 years old    Man                NaN
# 33043            No  25-34 years old    Man                 No
# 33504            No              NaN    NaN                NaN
# 33930           Yes  18-24 years old    Man                 No
# 62386            No  25-34 years old    Man                 No
# 69262           Yes  25-34 years old    Man                 No
# 82173            No  25-34 years old    Man                 No
# 82198            No  25-34 years old    Man                 No
# 43572           Yes  18-24 years old    Man                 No
# 17680            No  18-24 years old    Man                 No
#
#                       SEXUALITY                                    ETHNICITY  \
# 1924                        NaN                 White or of European descent
# 24285  Prefer to self-describe:                 White or of European descent
# 46464         Prefer not to say                            Prefer not to say
# 15163                  Bisexual                  Black or of African descent
# 56790   Straight / Heterosexual                                   East Asian
# 22032                       NaN                                   East Asian
# 59043         Prefer not to say                              Southeast Asian
# 22453                       NaN                                   East Asian
# 41440   Straight / Heterosexual                                   East Asian
# 45141   Straight / Heterosexual                                   East Asian
# 53306   Straight / Heterosexual                                   East Asian
# 37761   Straight / Heterosexual                                   East Asian
# 22162   Straight / Heterosexual     White or of European descent;South Asian
# 12290   Straight / Heterosexual  White or of European descent;Middle Eastern
# 16621   Straight / Heterosexual                                   East Asian
# 18322   Straight / Heterosexual                                          NaN
# 33043   Straight / Heterosexual                  Black or of African descent
# 33504                       NaN                                          NaN
# 33930   Straight / Heterosexual                 White or of European descent
# 62386   Straight / Heterosexual                       Hispanic or Latino/a/x
# 69262   Straight / Heterosexual                                          NaN
# 82173   Straight / Heterosexual                                  South Asian
# 82198   Straight / Heterosexual                            Prefer not to say
# 43572                       NaN                                   East Asian
# 17680   Straight / Heterosexual                 White or of European descent
#
#                                     ACCESSIBILITY  \
# 1924                            None of the above
# 24285                           None of the above
# 46464                           Prefer not to say
# 15163         I am blind / have difficulty seeing
# 56790                           None of the above
# 22032                           None of the above
# 59043                           None of the above
# 22453                           None of the above
# 41440                                         NaN
# 45141                           None of the above
# 53306                           None of the above
# 37761                           None of the above
# 22162  I am unable to / find it difficult to type
# 12290                           None of the above
# 16621                           None of the above
# 18322                           None of the above
# 33043                           None of the above
# 33504                                         NaN
# 33930                           None of the above
# 62386                                         NaN
# 69262                                         NaN
# 82173                           None of the above
# 82198                                         NaN
# 43572                           None of the above
# 17680                           None of the above
#
#                                             MENTALHEALTH  \
# 1924                                   None of the above
# 24285                                  None of the above
# 46464                                  Prefer not to say
# 15163  I have a concentration and/or memory disorder ...
# 56790                                  None of the above
# 22032                         I have an anxiety disorder
# 59043                                  None of the above
# 22453                                                NaN
# 41440  I have a concentration and/or memory disorder ...
# 45141  I have a mood or emotional disorder (e.g. depr...
# 53306                                  None of the above
# 37761                                  None of the above
# 22162  I have a mood or emotional disorder (e.g. depr...
# 12290  I have a concentration and/or memory disorder ...
# 16621  I have a concentration and/or memory disorder ...
# 18322                                  None of the above
# 33043                                  None of the above
# 33504                                                NaN
# 33930                                  None of the above
# 62386                                                NaN
# 69262                                                NaN
# 82173  I have a concentration and/or memory disorder ...
# 82198                                                NaN
# 43572                                  Prefer not to say
# 17680                                  None of the above
#
#                 SURVEYLENGTH                  SURVEYEASE CONVERTEDCOMPYEARLY  \
# 1924                Too long  Neither easy nor difficult                 1.0
# 24285  Appropriate in length                        Easy                 1.0
# 46464               Too long                        Easy                 1.0
# 15163              Too short                        Easy                 2.0
# 56790  Appropriate in length                        Easy                 2.0
# 22032  Appropriate in length                        Easy                 3.0
# 59043  Appropriate in length                        Easy                 3.0
# 22453  Appropriate in length                        Easy                 4.0
# 41440  Appropriate in length                        Easy                 5.0
# 45141               Too long                        Easy                 5.0
# 53306  Appropriate in length                        Easy                 5.0
# 37761                    NaN                   Difficult                 6.0
# 22162               Too long                        Easy                10.0
# 12290  Appropriate in length                        Easy                12.0
# 16621  Appropriate in length                        Easy                12.0
# 18322               Too long                         NaN                12.0
# 33043  Appropriate in length  Neither easy nor difficult                12.0
# 33504                    NaN                         NaN                12.0
# 33930  Appropriate in length                        Easy                12.0
# 62386  Appropriate in length                        Easy                12.0
# 69262               Too long                        Easy                12.0
# 82173  Appropriate in length                        Easy                12.0
# 82198               Too long                        Easy                12.0
# 43572               Too long                        Easy                21.0
# 17680  Appropriate in length  Neither easy nor difficult                23.0
#
#                                                    AYUDA
# 1924   Call a coworker or friend;Visit Stack Overflow...
# 24285  Visit Stack Overflow;Go for a walk or other ph...
# 46464  Go for a walk or other physical activity;Do ot...
# 15163  Google it Stack Overflow for Teams (private kn...
# 56790  Call a coworker or friend;Visit Stack Overflow...
# 22032  Visit Stack Overflow;Go for a walk or other ph...
# 59043  Go for a walk or other physical activity;Googl...
# 22453  Call a coworker or friend;Meditate Stack Overflow
# 41440  Visit Stack Overflow;Do other work and come ba...
# 45141  Visit Stack Overflow;Google it;Do other work a...
# 53306  Visit Stack Overflow;Google it;Watch help / tu...
# 37761  Visit Stack Overflow;Go for a walk or other ph...
# 22162  Google it;Meditate;Panic;Visit another develop...
# 12290  Visit Stack Overflow;Google it;Watch help / tu...
# 16621  Call a coworker or friend;Visit Stack Overflow...
# 18322                                                NaN
# 33043  Visit Stack Overflow;Go for a walk or other ph...
# 33504      Visit Stack Overflow;Google it Stack Overflow
# 33930            Google it Stack Overflow;Stack Exchange
# 62386  Visit Stack Overflow;Go for a walk or other ph...
# 69262            Google it Stack Overflow;Stack Exchange
# 82173  Call a coworker or friend;Visit Stack Overflow...
# 82198  Visit Stack Overflow;Google it Stack Overflow;...
# 43572  Visit Stack Overflow;Google it;Watch help / tu...
# 17680  Visit Stack Overflow Stack Overflow;Stack Exch...
#
# [25 rows x 49 columns]

# %%
datos.describe()
# Out:
#          RESPONSEID     COMPTOTAL  CONVERTEDCOMPYEARLY
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07

# %%
datos["CONVERTEDCOMPYEARLY"].mean()
# Out:
# 118426.15289044488

# %%
datos.median()
# Out:
# C:\Users\rjyanez\AppData\Local\Temp/ipykernel_11460/44699025.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   datos.median()
# RESPONSEID             41720.0
# COMPTOTAL              67000.0
# SOACCOUNT                  1.0
# CONVERTEDCOMPYEARLY    56211.0
# dtype: float64

# %%
datos["MAINBRANCH"].value_counts()
# Out:
# I am a developer by profession                                                   58153
# I am a student who is learning to code                                           12029
# I am not primarily a developer, but I write code sometimes as part of my work     6578
# I code primarily as a hobby                                                       4929
# I used to be a developer by profession, but no longer am                          1237
# None of these                                                                      513
# Name: MAINBRANCH, dtype: int64

# %%
# datos["NEWOTHERCOMMS"].value_counts()
# normalize=True convierte a porcentaje los valores
datos["NEWOTHERCOMMS"].value_counts(normalize=True)
# Out:
# No     0.644275
# Yes    0.355725
# Name: NEWOTHERCOMMS, dtype: float64

# %%
pais = datos.groupby(["COUNTRY"])

# %%
pais.get_group("ESPAÑA")
# Out:
#        RESPONSEID                              MAINBRANCH  \
# 11             12          I am a developer by profession
# 68             69          I am a developer by profession
# 79             80          I am a developer by profession
# 108           109          I am a developer by profession
# 267           268          I am a developer by profession
# ...           ...                                     ...
# 83097       83098  I am a student who is learning to code
# 83133       83134          I am a developer by profession
# 83137       83138          I am a developer by profession
# 83159       83160          I am a developer by profession
# 83313       83314          I am a developer by profession
#
#                                               EMPLOYMENT COUNTRY USSTATE  \
# 11                                    Employed full-time  ESPAÑA     NaN
# 68                                    Employed full-time  ESPAÑA     NaN
# 79                                    Employed full-time  ESPAÑA     NaN
# 108                                   Employed full-time  ESPAÑA     NaN
# 267                                   Employed full-time  ESPAÑA     NaN
# ...                                                  ...     ...     ...
# 83097                                 Student, part-time  ESPAÑA     NaN
# 83133                                 Employed full-time  ESPAÑA     NaN
# 83137                 Not employed, but looking for work  ESPAÑA     NaN
# 83159                                 Student, full-time  ESPAÑA     NaN
# 83313  Independent contractor, freelancer, or self-em...  ESPAÑA     NaN
#
#       UKCOUNTRY                                            EDLEVEL  \
# 11          NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 68          NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 79          NaN                Associate degree (A.A., A.S., etc.)
# 108         NaN                Associate degree (A.A., A.S., etc.)
# 267         NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...         ...                                                ...
# 83097       NaN  Secondary school (e.g. American high school, G...
# 83133       NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 83137       NaN  Some college/university study without earning ...
# 83159       NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 83313       NaN                 Professional degree (JD, MD, etc.)
#
#           AGE1STCODE                                          LEARNCODE  \
# 11     11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 68     11 - 17 years                                             School
# 79     11 - 17 years                    Online Courses or Certification
# 108    25 - 34 years                             Coding Bootcamp;School
# 267    11 - 17 years                            Other (please specify):
# ...              ...                                                ...
# 83097  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83133  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83137   5 - 10 years  Other online resources (ex: videos, blogs, etc...
# 83159  11 - 17 years    Other online resources (ex: videos, blogs, etc)
# 83313  11 - 17 years  Coding Bootcamp;Other online resources (ex: vi...
#
#       YEARSCODE YEARSCODEPRO  \
# 11           12            5
# 68           20           10
# 79          NaN          NaN
# 108          10            8
# 267          27           13
# ...         ...          ...
# 83097         3          NaN
# 83133         8            3
# 83137        30          NaN
# 83159        10          NaN
# 83313        10            5
#
#                                                  DEVTYPE  \
# 11                                   Developer, back-end
# 68                                   Developer, back-end
# 79                                   Developer, back-end
# 108    Developer, full-stack;Developer, back-end;Prod...
# 267                                Developer, full-stack
# ...                                                  ...
# 83097                                                NaN
# 83133  Engineer, data;Data scientist or machine learn...
# 83137  Developer, mobile;Developer, front-end;Develop...
# 83159                                                NaN
# 83313  Developer, front-end;Developer, full-stack;Dev...
#
#                         ORGSIZE           CURRENCY  COMPTOTAL COMPFREQ  \
# 11           10 to 19 employees  EUR European Euro    43000.0   Yearly
# 68     10,000 or more employees  EUR European Euro    54000.0   Yearly
# 79         100 to 499 employees  EUR European Euro    20000.0   Yearly
# 108        100 to 499 employees  EUR European Euro    36000.0   Yearly
# 267    1,000 to 4,999 employees  EUR European Euro        NaN  Monthly
# ...                         ...                ...        ...      ...
# 83097                       NaN                NaN        NaN      NaN
# 83133        20 to 99 employees  EUR European Euro    50000.0   Yearly
# 83137                       NaN                NaN        NaN      NaN
# 83159                       NaN                NaN        NaN      NaN
# 83313          2 to 9 employees  EUR European Euro     2300.0  Monthly
#
#                                   LANGUAGEHAVEWORKEDWITH  \
# 11     Bash/Shell;HTML/CSS;JavaScript;Node.js;SQL;Typ...
# 68              Bash/Shell;JavaScript;Node.js;TypeScript
# 79                                     C#;Go;Java;Python
# 108          HTML/CSS;Java;JavaScript;Node.js;Python;SQL
# 267                 HTML/CSS;Java;JavaScript;Node.js;SQL
# ...                                                  ...
# 83097                                  HTML/CSS;Java;SQL
# 83133        C;C++;Go;HTML/CSS;JavaScript;Node.js;Python
# 83137  Bash/Shell;F#;HTML/CSS;Java;JavaScript;Kotlin;...
# 83159  Assembly;Bash/Shell;C;C#;C++;HTML/CSS;Java;Jav...
# 83313                             Elixir;JavaScript;Ruby
#
#                                   LANGUAGEWANTTOWORKWITH  \
# 11     C++;Clojure;JavaScript;Node.js;Rust;SQL;TypeSc...
# 68                  JavaScript;Node.js;Python;TypeScript
# 79                                   C++;Clojure;Go;Rust
# 108    HTML/CSS;Java;JavaScript;Node.js;Python;SQL;Ty...
# 267          HTML/CSS;Java;JavaScript;Node.js;Python;SQL
# ...                                                  ...
# 83097  C#;HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;SQL
# 83133        C;C++;Go;Haskell;HTML/CSS;Python;Rust;Scala
# 83137                      F#;HTML/CSS;Kotlin;TypeScript
# 83159  Assembly;Bash/Shell;C;C#;C++;Clojure;Crystal;E...
# 83313                                        Elixir;Ruby
#
#                                   DATABASEHAVEWORKEDWITH  \
# 11                                            PostgreSQL
# 68                                              DynamoDB
# 79     Elasticsearch;Firebase;MariaDB;MySQL;PostgreSQ...
# 108              Microsoft SQL Server;MongoDB;PostgreSQL
# 267                                       MongoDB;Oracle
# ...                                                  ...
# 83097                                      MariaDB;MySQL
# 83133                  Cassandra;PostgreSQL;Redis;SQLite
# 83137                        Firebase;MySQL;Redis;SQLite
# 83159             Cassandra;MariaDB;MongoDB;MySQL;SQLite
# 83313                          Firebase;PostgreSQL;Redis
#
#                                   DATABASEWANTTOWORKWITH  \
# 11                              MongoDB;PostgreSQL;Redis
# 68                                     DynamoDB;Firebase
# 79                                            PostgreSQL
# 108                                   MongoDB;PostgreSQL
# 267                                       MongoDB;Oracle
# ...                                                  ...
# 83097                                       MySQL;SQLite
# 83133                  Cassandra;PostgreSQL;Redis;SQLite
# 83137                        Firebase;MySQL;Redis;SQLite
# 83159  Couchbase;Elasticsearch;MongoDB;MySQL;PostgreS...
# 83313                          Firebase;PostgreSQL;Redis
#
#                        PLATFORMHAVEWORKEDWITH  \
# 11                                        AWS
# 68                                        AWS
# 79           AWS;Google Cloud Platform;Heroku
# 108                                       NaN
# 267                                       NaN
# ...                                       ...
# 83097                                     NaN
# 83133               AWS;Google Cloud Platform
# 83137                                     AWS
# 83159                                     AWS
# 83313  AWS;DigitalOcean;Google Cloud Platform
#
#                        PLATFORMWANTTOWORKWITH        WEBFRAMEHAVEWORKEDWITH  \
# 11                                        NaN       Express;React.js;Vue.js
# 68                        AWS;Microsoft Azure                           NaN
# 79                                 AWS;Heroku  Angular;Django;FastAPI;Flask
# 108                                       NaN                 jQuery;Spring
# 267                                       NaN         Express;jQuery;Spring
# ...                                       ...                           ...
# 83097                                     NaN                           NaN
# 83133               AWS;Google Cloud Platform                Flask;React.js
# 83137                                     NaN  jQuery;Svelte;Symfony;Vue.js
# 83159                                     AWS        Express;Flask;React.js
# 83313  AWS;DigitalOcean;Google Cloud Platform          jQuery;Ruby on Rails
#
#                                   WEBFRAMEWANTTOWORKWITH  ...  \
# 11                                        Express;Vue.js  ...
# 68                                                   NaN  ...
# 79                                              React.js  ...
# 108                    Angular;Angular.js;Express;Spring  ...
# 267                                Express;jQuery;Spring  ...
# ...                                                  ...  ...
# 83097                                                NaN  ...
# 83133                             FastAPI;Flask;React.js  ...
# 83137                                      Svelte;Vue.js  ...
# 83159  Angular;Express;Flask;Gatsby;jQuery;Laravel;Re...  ...
# 83313                        Django;Ruby on Rails;Vue.js  ...
#
#                                   MISCTECHWANTTOWORKWITH  \
# 11                                                   NaN
# 68                                                   NaN
# 79                                          NumPy;Pandas
# 108                                                  NaN
# 267                                                  NaN
# ...                                                  ...
# 83097                                                NaN
# 83133                   Apache Spark;NumPy;Torch/PyTorch
# 83137                                                NaN
# 83159  .NET Framework;Apache Spark;Cordova;Flutter;Ke...
# 83313                                                NaN
#
#                             TOOLSTECHHAVEWORKEDWITH  \
# 11                                              Git
# 68                                        Terraform
# 79                    Docker;Git;Terraform;Unity 3D
# 108                                      Docker;Git
# 267                                             NaN
# ...                                             ...
# 83097                                           Git
# 83133               Docker;Git;Kubernetes;Terraform
# 83137                                    Docker;Git
# 83159  Docker;Git;Kubernetes;Unity 3D;Unreal Engine
# 83313                       Ansible;Docker;Git;Yarn
#
#                       TOOLSTECHWANTTOWORKWITH  \
# 11                                        Git
# 68                                  Terraform
# 79                       Deno;Kubernetes;Yarn
# 108                        Ansible;Docker;Git
# 267                                       NaN
# ...                                       ...
# 83097                            Git;Unity 3D
# 83133  Docker;Git;Kubernetes;Puppet;Terraform
# 83137                         Deno;Docker;Git
# 83159     Ansible;Docker;Git;Unity 3D;Xamarin
# 83313      Ansible;Docker;Git;Kubernetes;Yarn
#
#                             NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 11                                                  Atom
# 68                      Notepad++;Vim;Visual Studio Code
# 79     Android Studio;IntelliJ;NetBeans;Visual Studio...
# 108                                    Eclipse;Notepad++
# 267                                    Eclipse;Notepad++
# ...                                                  ...
# 83097                                  Eclipse;Notepad++
# 83133                       Emacs;Vim;Visual Studio Code
# 83137  Android Studio;Atom;NetBeans;Notepad++;Sublime...
# 83159  Android Studio;Atom;Eclipse;IPython/Jupyter;Ne...
# 83313                        RubyMine;Visual Studio Code
#
#                             NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 11                                                  Atom  Linux-based
# 68                                Vim;Visual Studio Code      Windows
# 79                                          Emacs;Neovim        MacOS
# 108                                    Eclipse;Notepad++      Windows
# 267                                    Eclipse;Notepad++      Windows
# ...                                                  ...          ...
# 83097  Android Studio;Eclipse;Notepad++;Visual Studio...      Windows
# 83133                       Emacs;Vim;Visual Studio Code  Linux-based
# 83137                  Android Studio;Visual Studio Code  Linux-based
# 83159  Atom;IPython/Jupyter;Notepad++;Visual Studio Code  Linux-based
# 83313                                 Visual Studio Code        MacOS
#
#                                                 NEWSTUCK  \
# 11     Call a coworker or friend;Visit Stack Overflow...
# 68     Call a coworker or friend;Visit Stack Overflow...
# 79     Call a coworker or friend;Visit Stack Overflow...
# 108    Visit Stack Overflow;Go for a walk or other ph...
# 267    Visit Stack Overflow;Google it;Do other work a...
# ...                                                  ...
# 83097  Call a coworker or friend;Visit Stack Overflow...
# 83133  Call a coworker or friend;Visit Stack Overflow...
# 83137  Visit Stack Overflow;Google it;Do other work a...
# 83159  Go for a walk or other physical activity;Play ...
# 83313                     Visit Stack Overflow;Google it
#
#                           NEWSOSITES             SOVISITFREQ SOACCOUNT  \
# 11     Stack Overflow;Stack Exchange   Daily or almost daily      True
# 68     Stack Overflow;Stack Exchange   Daily or almost daily      True
# 79     Stack Overflow;Stack Exchange   Daily or almost daily      True
# 108                   Stack Overflow  Multiple times per day      True
# 267    Stack Overflow;Stack Exchange   Daily or almost daily      True
# ...                              ...                     ...       ...
# 83097                 Stack Overflow   Daily or almost daily      True
# 83133  Stack Overflow;Stack Exchange    A few times per week      True
# 83137  Stack Overflow;Stack Exchange    A few times per week      True
# 83159  Stack Overflow;Stack Exchange   Daily or almost daily      True
# 83313  Stack Overflow;Stack Exchange  Multiple times per day      True
#
#                                               SOPARTFREQ           SOCOMM  \
# 11                   Less than once per month or monthly    Yes, somewhat
# 68                                  A few times per week    Yes, somewhat
# 79     I have never participated in Q&A on Stack Over...   No, not at all
# 108                                 A few times per week  Yes, definitely
# 267                      A few times per month or weekly    Yes, somewhat
# ...                                                  ...              ...
# 83097  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83133                Less than once per month or monthly    Yes, somewhat
# 83137  I have never participated in Q&A on Stack Over...   No, not really
# 83159                    A few times per month or weekly  Yes, definitely
# 83313                Less than once per month or monthly    Yes, somewhat
#
#       NEWOTHERCOMMS              AGE             GENDER              TRANS  \
# 11              Yes  25-34 years old                Man                 No
# 68               No  35-44 years old                Man                 No
# 79               No  18-24 years old                Man                 No
# 108              No  25-34 years old                Man                 No
# 267              No  35-44 years old                Man                 No
# ...             ...              ...                ...                ...
# 83097           Yes  18-24 years old                Man                 No
# 83133            No  25-34 years old                Man                 No
# 83137            No  35-44 years old  Prefer not to say  Prefer not to say
# 83159           Yes  18-24 years old                Man                 No
# 83313            No  25-34 years old                Man                 No
#
#                      SEXUALITY  \
# 11     Straight / Heterosexual
# 68     Straight / Heterosexual
# 79     Straight / Heterosexual
# 108    Straight / Heterosexual
# 267    Straight / Heterosexual
# ...                        ...
# 83097  Straight / Heterosexual
# 83133  Straight / Heterosexual
# 83137        Prefer not to say
# 83159  Straight / Heterosexual
# 83313  Straight / Heterosexual
#
#                                                ETHNICITY      ACCESSIBILITY  \
# 11     White or of European descent;Hispanic or Latin...  None of the above
# 68                                                   NaN  None of the above
# 79                                Hispanic or Latino/a/x                NaN
# 108                         White or of European descent  None of the above
# 267                         White or of European descent  None of the above
# ...                                                  ...                ...
# 83097                       White or of European descent  None of the above
# 83133                       White or of European descent  None of the above
# 83137                                  Prefer not to say  Prefer not to say
# 83159                       White or of European descent  None of the above
# 83313                             Hispanic or Latino/a/x  None of the above
#
#                                             MENTALHEALTH  \
# 11                                     None of the above
# 68                                     None of the above
# 79                                                   NaN
# 108                                    None of the above
# 267                                    None of the above
# ...                                                  ...
# 83097                                  None of the above
# 83133  I have a concentration and/or memory disorder ...
# 83137                                  Prefer not to say
# 83159                                  None of the above
# 83313                                  None of the above
#
#                 SURVEYLENGTH                  SURVEYEASE CONVERTEDCOMPYEARLY  \
# 11                  Too long                        Easy             46482.0
# 68     Appropriate in length                        Easy             58373.0
# 79     Appropriate in length                        Easy             21620.0
# 108    Appropriate in length  Neither easy nor difficult             38915.0
# 267    Appropriate in length  Neither easy nor difficult                 NaN
# ...                      ...                         ...                 ...
# 83097  Appropriate in length                        Easy                 NaN
# 83133  Appropriate in length                        Easy             54049.0
# 83137  Appropriate in length  Neither easy nor difficult                 NaN
# 83159  Appropriate in length                        Easy                 NaN
# 83313  Appropriate in length                        Easy             29832.0
#
#                                                    AYUDA
# 11     Call a coworker or friend;Visit Stack Overflow...
# 68     Call a coworker or friend;Visit Stack Overflow...
# 79     Call a coworker or friend;Visit Stack Overflow...
# 108    Visit Stack Overflow;Go for a walk or other ph...
# 267    Visit Stack Overflow;Google it;Do other work a...
# ...                                                  ...
# 83097  Call a coworker or friend;Visit Stack Overflow...
# 83133  Call a coworker or friend;Visit Stack Overflow...
# 83137  Visit Stack Overflow;Google it;Do other work a...
# 83159  Go for a walk or other physical activity;Play ...
# 83313  Visit Stack Overflow;Google it Stack Overflow;...
#
# [1485 rows x 49 columns]

# %%
pais["MAINBRANCH"].value_counts().head(20)
# Out:
# COUNTRY      MAINBRANCH
# AFGHANISTAN  I am a developer by profession                                                   27
#              I am a student who is learning to code                                           15
#              None of these                                                                    11
#              I code primarily as a hobby                                                       9
#              I am not primarily a developer, but I write code sometimes as part of my work     3
# ALBANIA      I am a developer by profession                                                   52
#              I am a student who is learning to code                                           17
#              I am not primarily a developer, but I write code sometimes as part of my work     4
# ALGERIA      I am a developer by profession                                                   27
#              I am a student who is learning to code                                            8
#              I code primarily as a hobby                                                       7
#              I am not primarily a developer, but I write code sometimes as part of my work     3
#              None of these                                                                     1
# ANDORRA      I am a developer by profession                                                    6
#              I code primarily as a hobby                                                       3
#              I am a student who is learning to code                                            2
#              None of these                                                                     1
# ANGOLA       I am a developer by profession                                                   16
#              I am a student who is learning to code                                            5
#              None of these                                                                     3
# Name: MAINBRANCH, dtype: int64

# %%
pais["CONVERTEDCOMPYEARLY"].median().head(20)
# Out:
# COUNTRY
# AFGHANISTAN     9792.0
# ALBANIA        15900.0
# ALGERIA         9875.0
# ANDORRA        94045.5
# ANGOLA          9750.0
# ARGENTINA      35712.0
# ARMENIA        25080.0
# AUSTRALIA      80172.0
# AUSTRIA        54049.0
# AZERBAIJAN     18324.0
# BAHAMAS            NaN
# BAHRAIN        44688.0
# BANGLADESH      7776.0
# BARBADOS       18000.0
# BELARUS        32676.0
# BELGIUM        49170.0
# BELIZE         22625.0
# BENIN           4800.0
# BHUTAN         14718.0
# BOLIVIA        17676.0
# Name: CONVERTEDCOMPYEARLY, dtype: float64

# %%
pais["CONVERTEDCOMPYEARLY"].agg(["median", "mean", "count"])
# Out:
#                                        median          mean  count
# COUNTRY
# AFGHANISTAN                            9792.0  2.794748e+06     11
# ALBANIA                               15900.0  4.499814e+04     35
# ALGERIA                                9875.0  1.446114e+04     14
# ANDORRA                               94045.5  8.928200e+04      4
# ANGOLA                                 9750.0  2.155680e+04     10
# ...                                       ...           ...    ...
# VENEZUELA, BOLIVARIAN REPUBLIC OF...  12000.0  2.246505e+04     62
# VIET NAM                              12678.0  1.995289e+04    148
# YEMEN                                  3954.0  5.628667e+03      6
# ZAMBIA                                 9816.0  1.991491e+04     11
# ZIMBABWE                               7200.0  1.141477e+04     13
#
# [181 rows x 3 columns]

# %%
filtro = datos['COUNTRY'] == 'ESPAÑA'
datos_españa = datos.loc[filtro]
datos_españa.head()
# Out:
#      RESPONSEID                      MAINBRANCH          EMPLOYMENT COUNTRY  \
# 11           12  I am a developer by profession  Employed full-time  ESPAÑA
# 68           69  I am a developer by profession  Employed full-time  ESPAÑA
# 79           80  I am a developer by profession  Employed full-time  ESPAÑA
# 108         109  I am a developer by profession  Employed full-time  ESPAÑA
# 267         268  I am a developer by profession  Employed full-time  ESPAÑA
#
#     USSTATE UKCOUNTRY                                          EDLEVEL  \
# 11      NaN       NaN     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 68      NaN       NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 79      NaN       NaN              Associate degree (A.A., A.S., etc.)
# 108     NaN       NaN              Associate degree (A.A., A.S., etc.)
# 267     NaN       NaN     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#         AGE1STCODE                                          LEARNCODE  \
# 11   11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 68   11 - 17 years                                             School
# 79   11 - 17 years                    Online Courses or Certification
# 108  25 - 34 years                             Coding Bootcamp;School
# 267  11 - 17 years                            Other (please specify):
#
#     YEARSCODE YEARSCODEPRO                                            DEVTYPE  \
# 11         12            5                                Developer, back-end
# 68         20           10                                Developer, back-end
# 79        NaN          NaN                                Developer, back-end
# 108        10            8  Developer, full-stack;Developer, back-end;Prod...
# 267        27           13                              Developer, full-stack
#
#                       ORGSIZE           CURRENCY  COMPTOTAL COMPFREQ  \
# 11         10 to 19 employees  EUR European Euro    43000.0   Yearly
# 68   10,000 or more employees  EUR European Euro    54000.0   Yearly
# 79       100 to 499 employees  EUR European Euro    20000.0   Yearly
# 108      100 to 499 employees  EUR European Euro    36000.0   Yearly
# 267  1,000 to 4,999 employees  EUR European Euro        NaN  Monthly
#
#                                 LANGUAGEHAVEWORKEDWITH  \
# 11   Bash/Shell;HTML/CSS;JavaScript;Node.js;SQL;Typ...
# 68            Bash/Shell;JavaScript;Node.js;TypeScript
# 79                                   C#;Go;Java;Python
# 108        HTML/CSS;Java;JavaScript;Node.js;Python;SQL
# 267               HTML/CSS;Java;JavaScript;Node.js;SQL
#
#                                 LANGUAGEWANTTOWORKWITH  \
# 11   C++;Clojure;JavaScript;Node.js;Rust;SQL;TypeSc...
# 68                JavaScript;Node.js;Python;TypeScript
# 79                                 C++;Clojure;Go;Rust
# 108  HTML/CSS;Java;JavaScript;Node.js;Python;SQL;Ty...
# 267        HTML/CSS;Java;JavaScript;Node.js;Python;SQL
#
#                                 DATABASEHAVEWORKEDWITH  \
# 11                                          PostgreSQL
# 68                                            DynamoDB
# 79   Elasticsearch;Firebase;MariaDB;MySQL;PostgreSQ...
# 108            Microsoft SQL Server;MongoDB;PostgreSQL
# 267                                     MongoDB;Oracle
#
#        DATABASEWANTTOWORKWITH            PLATFORMHAVEWORKEDWITH  \
# 11   MongoDB;PostgreSQL;Redis                               AWS
# 68          DynamoDB;Firebase                               AWS
# 79                 PostgreSQL  AWS;Google Cloud Platform;Heroku
# 108        MongoDB;PostgreSQL                               NaN
# 267            MongoDB;Oracle                               NaN
#
#     PLATFORMWANTTOWORKWITH        WEBFRAMEHAVEWORKEDWITH  \
# 11                     NaN       Express;React.js;Vue.js
# 68     AWS;Microsoft Azure                           NaN
# 79              AWS;Heroku  Angular;Django;FastAPI;Flask
# 108                    NaN                 jQuery;Spring
# 267                    NaN         Express;jQuery;Spring
#
#                 WEBFRAMEWANTTOWORKWITH  ... MISCTECHWANTTOWORKWITH  \
# 11                      Express;Vue.js  ...                    NaN
# 68                                 NaN  ...                    NaN
# 79                            React.js  ...           NumPy;Pandas
# 108  Angular;Angular.js;Express;Spring  ...                    NaN
# 267              Express;jQuery;Spring  ...                    NaN
#
#            TOOLSTECHHAVEWORKEDWITH TOOLSTECHWANTTOWORKWITH  \
# 11                             Git                     Git
# 68                       Terraform               Terraform
# 79   Docker;Git;Terraform;Unity 3D    Deno;Kubernetes;Yarn
# 108                     Docker;Git      Ansible;Docker;Git
# 267                            NaN                     NaN
#
#                           NEWCOLLABTOOLSHAVEWORKEDWITH  \
# 11                                                Atom
# 68                    Notepad++;Vim;Visual Studio Code
# 79   Android Studio;IntelliJ;NetBeans;Visual Studio...
# 108                                  Eclipse;Notepad++
# 267                                  Eclipse;Notepad++
#
#     NEWCOLLABTOOLSWANTTOWORKWITH        OPSYS  \
# 11                          Atom  Linux-based
# 68        Vim;Visual Studio Code      Windows
# 79                  Emacs;Neovim        MacOS
# 108            Eclipse;Notepad++      Windows
# 267            Eclipse;Notepad++      Windows
#
#                                               NEWSTUCK  \
# 11   Call a coworker or friend;Visit Stack Overflow...
# 68   Call a coworker or friend;Visit Stack Overflow...
# 79   Call a coworker or friend;Visit Stack Overflow...
# 108  Visit Stack Overflow;Go for a walk or other ph...
# 267  Visit Stack Overflow;Google it;Do other work a...
#
#                         NEWSOSITES             SOVISITFREQ SOACCOUNT  \
# 11   Stack Overflow;Stack Exchange   Daily or almost daily      True
# 68   Stack Overflow;Stack Exchange   Daily or almost daily      True
# 79   Stack Overflow;Stack Exchange   Daily or almost daily      True
# 108                 Stack Overflow  Multiple times per day      True
# 267  Stack Overflow;Stack Exchange   Daily or almost daily      True
#
#                                             SOPARTFREQ           SOCOMM  \
# 11                 Less than once per month or monthly    Yes, somewhat
# 68                                A few times per week    Yes, somewhat
# 79   I have never participated in Q&A on Stack Over...   No, not at all
# 108                               A few times per week  Yes, definitely
# 267                    A few times per month or weekly    Yes, somewhat
#
#     NEWOTHERCOMMS              AGE GENDER TRANS                SEXUALITY  \
# 11            Yes  25-34 years old    Man    No  Straight / Heterosexual
# 68             No  35-44 years old    Man    No  Straight / Heterosexual
# 79             No  18-24 years old    Man    No  Straight / Heterosexual
# 108            No  25-34 years old    Man    No  Straight / Heterosexual
# 267            No  35-44 years old    Man    No  Straight / Heterosexual
#
#                                              ETHNICITY      ACCESSIBILITY  \
# 11   White or of European descent;Hispanic or Latin...  None of the above
# 68                                                 NaN  None of the above
# 79                              Hispanic or Latino/a/x                NaN
# 108                       White or of European descent  None of the above
# 267                       White or of European descent  None of the above
#
#           MENTALHEALTH           SURVEYLENGTH                  SURVEYEASE  \
# 11   None of the above               Too long                        Easy
# 68   None of the above  Appropriate in length                        Easy
# 79                 NaN  Appropriate in length                        Easy
# 108  None of the above  Appropriate in length  Neither easy nor difficult
# 267  None of the above  Appropriate in length  Neither easy nor difficult
#
#     CONVERTEDCOMPYEARLY                                              AYUDA
# 11              46482.0  Call a coworker or friend;Visit Stack Overflow...
# 68              58373.0  Call a coworker or friend;Visit Stack Overflow...
# 79              21620.0  Call a coworker or friend;Visit Stack Overflow...
# 108             38915.0  Visit Stack Overflow;Go for a walk or other ph...
# 267                 NaN  Visit Stack Overflow;Google it;Do other work a...
#
# [5 rows x 49 columns]

# %%
# exportar a .csv
datos_españa.to_csv('datos_españa.csv')

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in d:\curso_python\codigo\cursopython2021\lib\site-packages (3.0.9)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: et-xmlfile in d:\curso_python\codigo\cursopython2021\lib\site-packages (from openpyxl) (1.1.0)

# %%
datos_españa.to_excel('datos_españa.xlsx')
